# %%
library(Seurat)
library(SeuratData)
library(cowplot)
library(patchwork)
library(scHOT)
library(tidyverse)
library(dplyr)
library(BiocParallel)
library(Matrix)
# Out:
# Attaching SeuratObject
#
# Registered S3 method overwritten by 'cli':
#   method     from
#   print.boxx spatstat.geom
#
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# Warning message in if (is.na(desc)) {:
# “the condition has length > 1 and only the first element will be used”
# ── Installed datasets ───────────────────────────────────── SeuratData v0.2.1 ──
#
# ✔ ifnb        3.1.0                     ✔ thp1.eccite 3.1.5
#
#
# ────────────────────────────────────── Key ─────────────────────────────────────
#
# ✔ Dataset loaded successfully
# ❯ Dataset built with a newer version of Seurat than installed
# ❓ Unknown version of Seurat installed
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack

# %%
library(Seurat)
library(SeuratData)
library(SeuratDisk)
# Out:
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat

# %% [markdown]
# # scHOT

# %% [markdown]
# # Loading Data

# %% [markdown]
# # Normalized h5ad

# %%
setwd('/data_volume/memento/simulation/acc_fpr')

# %%
Convert('subsampled_0.1_norm.h5ad', dest = "h5seurat", overwrite = TRUE, verbose = FALSE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X_tsne as cell embeddings for tsne

# %%
Convert('subsampled_0.8_norm.h5ad', dest = "h5seurat", overwrite = TRUE, verbose = FALSE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X_tsne as cell embeddings for tsne

# %%
norm.subsampled_8 <- LoadH5Seurat("subsampled_0.8_norm.h5seurat", verbose = FALSE)
# Out:
# Validating h5Seurat file

# %%
Convert('subsampled_0.2_norm.h5ad', dest = "h5seurat", overwrite = TRUE, verbose = FALSE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X_tsne as cell embeddings for tsne

# %%
Convert('subsampled_0.4_norm.h5ad', dest = "h5seurat", overwrite = TRUE, verbose = FALSE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X_tsne as cell embeddings for tsne

# %%
Convert('subsampled_0.6_norm.h5ad', dest = "h5seurat", overwrite = TRUE, verbose = FALSE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X_tsne as cell embeddings for tsne

# %%
norm.subsampled.1 <- LoadH5Seurat("subsampled_0.1_norm.h5seurat", verbose = FALSE)
# Out:
# Validating h5Seurat file

# %%
norm.subsampled.2 <- LoadH5Seurat("subsampled_0.2_norm.h5seurat", verbose = FALSE)
# Out:
# Validating h5Seurat file

# %%
norm.subsampled.4 <- LoadH5Seurat("subsampled_0.4_norm.h5seurat", verbose = FALSE)
# Out:
# Validating h5Seurat file

# %%
norm.subsampled.6 <- LoadH5Seurat("subsampled_0.6_norm.h5seurat", verbose = FALSE)
# Out:
# Validating h5Seurat file

# %%
norm.subsampled.8 <- LoadH5Seurat("subsampled_0.8_norm.h5seurat", verbose = FALSE)
# Out:
# Validating h5Seurat file

# %% [markdown]
# # Running scHOT

# %%
library(scHOT)

# %%
# Function for to run scHOT with the seurat object as input 
scHOT_workflow <- function(seurat_dat){
    subsample.sce <- as.SingleCellExperiment(seurat_dat)
    #create scHOT object 
    scHOT_traj <- scHOT_buildFromSCE(
        subsample.sce,
        assayName = 'logcounts',
        positionType = "trajectory",
        positionColData = "stim_indicator")
    # setting Weight Matrix
    scHOT_traj <- scHOT_setWeightMatrix(scHOT_traj,
        positionType = "trajectory",
        positionColData = c("stim_indicator"),
        nrow.out = 2,
        averageAcrossTrajectoryTies = TRUE,
        span = 0.1)
    # scHOT wrapper function
    test_genes <- as.matrix(rownames((scHOT_traj)))
#     print(test_genes)
    scHOT_traj_wrap_1 = scHOT(scHOT_traj,
        testingScaffold = test_genes,
        weightMatrix = scHOT_traj@weightMatrix,
        higherOrderFunction = matrixStats::weightedVar,
        higherOrderFunctionType = "weighted",
        numberPermutations = 100,
        parallel = TRUE,
        BPPARAM = BiocParallel::MulticoreParam(workers = 10),
        verbose = FALSE)

}

# %%
scHOT.8 <- scHOT_workflow(norm.subsampled_8)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# higherOrderSummaryFunction will replace any stored param

# %%
scHOT.6 <- scHOT_workflow(norm.subsampled.6)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# higherOrderSummaryFunction will replace any stored param

# %%
scHOT.4 <- scHOT_workflow(norm.subsampled.4)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# higherOrderSummaryFunction will replace any stored param

# %%
scHOT.2 <- scHOT_workflow(norm.subsampled.2)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# higherOrderSummaryFunction will replace any stored param

# %%
scHOT.1 <- scHOT_workflow(norm.subsampled.1)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# higherOrderSummaryFunction will replace any stored param

# %%
test_genes <- as.matrix(rownames(scHOT.8)[1:20])

# %%
plotHigherOrderSequence(scHOT.8, test_genes)

# %%
slot(scHOT.1, "scHOT_output")
# Out:
# DataFrame with 125 rows and 14 columns
#               gene_1 globalHigherOrderFunction numberPermutations
#          <character>                  <matrix>          <numeric>
# ISG15          ISG15                         1                  0
# RPL11          RPL11                         1                  0
# SH3BGRL3    SH3BGRL3                         1                  0
# IFI6            IFI6                         1                  0
# S100A10      S100A10                         1                  0
# ...              ...                       ...                ...
# LGALS1        LGALS1                         1                  0
# APOBEC3A    APOBEC3A                         1                  0
# RPL3            RPL3                         1                  0
# TYMP            TYMP                         1                  0
# CSTB            CSTB                         1                  0
#          storePermutations higherOrderSequence higherOrderStatistic
#                  <logical>       <NumericList>            <numeric>
# ISG15                 TRUE 0.0382296,1.0049040           0.68354203
# RPL11                 TRUE     1.17249,1.00362           0.11940954
# SH3BGRL3              TRUE     1.12892,1.00371           0.08853895
# IFI6                  TRUE   0.170689,1.007500           0.59171408
# S100A10               TRUE     1.01284,1.00448           0.00591108
# ...                    ...                 ...                  ...
# LGALS1                TRUE     1.02525,1.00441            0.0147356
# APOBEC3A              TRUE 0.0715961,1.0066075            0.6611529
# RPL3                  TRUE     1.30549,1.00285            0.2139990
# TYMP                  TRUE   0.645127,1.005734            0.2549876
# CSTB                  TRUE   0.896011,1.005011            0.0770748
#           permutations pvalPermutations FDRPermutations
#          <NumericList>        <numeric>       <numeric>
# ISG15               NA               NA              NA
# RPL11               NA               NA              NA
# SH3BGRL3            NA               NA              NA
# IFI6                NA               NA              NA
# S100A10             NA               NA              NA
# ...                ...              ...             ...
# LGALS1              NA               NA              NA
# APOBEC3A            NA               NA              NA
# RPL3                NA               NA              NA
# TYMP                NA               NA              NA
# CSTB                NA               NA              NA
#          numberPermutationsEstimated globalLowerRangeEstimated
#                            <integer>                 <numeric>
# ISG15                            500                         1
# RPL11                            500                         1
# SH3BGRL3                         500                         1
# IFI6                             500                         1
# S100A10                          500                         1
# ...                              ...                       ...
# LGALS1                           500                         1
# APOBEC3A                         500                         1
# RPL3                             500                         1
# TYMP                             500                         1
# CSTB                             500                         1
#          globalUpperRangeEstimated pvalEstimated FDREstimated
#                          <numeric>     <numeric>    <numeric>
# ISG15                            1    0.00199601   0.00297619
# RPL11                            1    0.00199601   0.00297619
# SH3BGRL3                         1    0.00200000   0.00297619
# IFI6                             1    0.00199601   0.00297619
# S100A10                          1    0.81000000   0.82317073
# ...                            ...           ...          ...
# LGALS1                           1    0.50400000   0.52066116
# APOBEC3A                         1    0.00199601   0.00297619
# RPL3                             1    0.00199601   0.00297619
# TYMP                             1    0.00199601   0.00297619
# CSTB                             1    0.00400000   0.00581395

# %%
write_csv(as.data.frame(res.8), 'scHOT_0.8_res.csv')
# Out:
# Error: Don't know how to handle vector of type list in column 'higherOrderSequence'.
# Traceback:
#
# 1. write_csv(as.data.frame(res.8), "scHOT_0.8_res.csv")
# 2. write_delim(x, file, delim = ",", na = na, append = append, col_names = col_names,
#  .     quote_escape = quote_escape, eol = eol)
# 3. stream_delim(x, file, delim = delim, col_names = col_names, append = append,
#  .     na = na, quote_escape = quote_escape, eol = eol)
# 4. stream_delim_(df, file, ..., bom = bom, quote_escape = quote_escape,
#  .     eol = eol)

# %%
plotHigherOrderSequence(scHOT.6, test_genes)
# Out:
# Warning message in plotHigherOrderSequence(scHOT.6, test_genes):
# “Not all the cell position has higherOrderSequence statistics,
#             set nrow.out = NULL in scHOT_setWeightMatrix to calculate
#             higherOrderSequence for all positions!”
# branches information is not provided
#
# Warning message in type.convert.default(X[[i]], ...):
# “'as.is' should be specified by the caller; using TRUE”
# Warning message:
# “Use of `branch_long$SampleOrder` is discouraged. Use `SampleOrder` instead.”
# Warning message:
# “Use of `branch_long$WeightedCorrelation` is discouraged. Use `WeightedCorrelation` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# plot without title

# %%
plotHigherOrderSequence(scHOT.4, test_genes)
# Out:
# Warning message in plotHigherOrderSequence(scHOT.4, test_genes):
# “Not all the cell position has higherOrderSequence statistics,
#             set nrow.out = NULL in scHOT_setWeightMatrix to calculate
#             higherOrderSequence for all positions!”
# branches information is not provided
#
# Warning message in type.convert.default(X[[i]], ...):
# “'as.is' should be specified by the caller; using TRUE”
# Warning message:
# “Use of `branch_long$SampleOrder` is discouraged. Use `SampleOrder` instead.”
# Warning message:
# “Use of `branch_long$WeightedCorrelation` is discouraged. Use `WeightedCorrelation` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# plot without title

# %%
plotHigherOrderSequence(scHOT.2, test_genes)
# Out:
# Warning message in plotHigherOrderSequence(scHOT.2, test_genes):
# “Not all the cell position has higherOrderSequence statistics,
#             set nrow.out = NULL in scHOT_setWeightMatrix to calculate
#             higherOrderSequence for all positions!”
# branches information is not provided
#
# Warning message in type.convert.default(X[[i]], ...):
# “'as.is' should be specified by the caller; using TRUE”
# Warning message:
# “Use of `branch_long$SampleOrder` is discouraged. Use `SampleOrder` instead.”
# Warning message:
# “Use of `branch_long$WeightedCorrelation` is discouraged. Use `WeightedCorrelation` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# plot without title

# %%
plotHigherOrderSequence(scHOT.1, test_genes)
# Out:
# Warning message in plotHigherOrderSequence(scHOT.1, test_genes):
# “Not all the cell position has higherOrderSequence statistics,
#             set nrow.out = NULL in scHOT_setWeightMatrix to calculate
#             higherOrderSequence for all positions!”
# branches information is not provided
#
# Warning message in type.convert.default(X[[i]], ...):
# “'as.is' should be specified by the caller; using TRUE”
# Warning message:
# “Use of `branch_long$SampleOrder` is discouraged. Use `SampleOrder` instead.”
# Warning message:
# “Use of `branch_long$WeightedCorrelation` is discouraged. Use `WeightedCorrelation` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# plot without title

# %%
toCSV <- function(scHOT){
    columns = c('gene_1','higherOrderStatistic','pvalEstimated','FDREstimated')
    df = as.data.frame(slot(scHOT, "scHOT_output"))[columns]
    return(df)
}

# %%
setwd('/data/MEMENTO/csv_files/')

# %%
res.1 <- toCSV(scHOT.1)
write_csv(res.1, file = 'scHOT_0.1_res.csv')

# %%
res.2 <- toCSV(scHOT.2)
write_csv(res.2, file = 'scHOT_0.2_res.csv')

# %%
res.4 <- toCSV(scHOT.4)
write_csv(res.4, file = 'scHOT_0.4_res.csv')

# %%
res.6 <- toCSV(scHOT.6)
write_csv(res.6, file = 'scHOT_0.6_res.csv')

# %%
res.8 <- toCSV(scHOT.8)
write_csv(res.8, file = 'scHOT_0.8_res.csv')

# %% [markdown]
# ### Running scHOT for correlation

# %%
# Function for to run scHOT with the seurat object as input 
scHOT_workflow_corr <- function(seurat_dat){
    subsample.sce <- as.SingleCellExperiment(seurat_dat)
    #create scHOT object 
    scHOT_traj <- scHOT_buildFromSCE(
        subsample.sce,
        assayName = 'logcounts',
        positionType = "trajectory",
        positionColData = "stim_indicator")
    # setting Weight Matrix
    scHOT_traj <- scHOT_setWeightMatrix(scHOT_traj,
        positionType = "trajectory",
        positionColData = c("stim_indicator"),
        nrow.out = 2,
        averageAcrossTrajectoryTies = TRUE,
        span = 0.1)
    # scHOT wrapper function
    test_genes <- matrix(test_genes, ncol = 2, byrow = TRUE)
#     print(test_genes)
    scHOT_traj_wrap_1 = scHOT(scHOT_traj,
        testingScaffold = test_genes,
        weightMatrix = scHOT_traj@weightMatrix,
        higherOrderFunction = weightedSpearman,
        higherOrderFunctionType = "weighted",
        numberPermutations = 100,
        parallel = TRUE,
        BPPARAM = BiocParallel::MulticoreParam(workers = 10),
        verbose = FALSE)

}

# %%
scHOT.8 <- scHOT_workflow_corr(norm.subsampled_8)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# Warning message in matrix(test_genes, ncol = 2, byrow = TRUE):
# “data length [125] is not a sub-multiple or multiple of the number of rows [63]”
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# numberScaffold set higher than the scaffold, setting permutation number for all tests
#
# higherOrderSummaryFunction will replace any stored param

# %%
scHOT.6 <- scHOT_workflow_corr(norm.subsampled.6)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# Warning message in matrix(test_genes, ncol = 2, byrow = TRUE):
# “data length [125] is not a sub-multiple or multiple of the number of rows [63]”
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# numberScaffold set higher than the scaffold, setting permutation number for all tests
#
# higherOrderSummaryFunction will replace any stored param

# %%
scHOT.4 <- scHOT_workflow_corr(norm.subsampled.4)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# Warning message in matrix(test_genes, ncol = 2, byrow = TRUE):
# “data length [125] is not a sub-multiple or multiple of the number of rows [63]”
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# numberScaffold set higher than the scaffold, setting permutation number for all tests
#
# higherOrderSummaryFunction will replace any stored param

# %%
scHOT.2 <- scHOT_workflow_corr(norm.subsampled.2)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# Warning message in matrix(test_genes, ncol = 2, byrow = TRUE):
# “data length [125] is not a sub-multiple or multiple of the number of rows [63]”
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# numberScaffold set higher than the scaffold, setting permutation number for all tests
#
# higherOrderSummaryFunction will replace any stored param

# %%
scHOT.1 <- scHOT_workflow_corr(norm.subsampled.1)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular
#
# Warning message in matrix(test_genes, ncol = 2, byrow = TRUE):
# “data length [125] is not a sub-multiple or multiple of the number of rows [63]”
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# numberScaffold set higher than the scaffold, setting permutation number for all tests
#
# higherOrderSummaryFunction will replace any stored param

# %%
toCSV <- function(scHOT){
    columns = c('gene_1','higherOrderStatistic','pvalEstimated','FDREstimated')
    df = as.data.frame(slot(scHOT, "scHOT_output"))[columns]
    return(df)
}

# %%
setwd('/data_volume/memento/simulation/acc_fpr/csv_results/')

# %%
res.1 <- toCSV(scHOT.1)
write_csv(res.1, file = 'scHOT_0.1_res_corr.csv')

# %%
res.2 <- toCSV(scHOT.2)
write_csv(res.2, file = 'scHOT_0.2_res_corr.csv')

# %%
res.4 <- toCSV(scHOT.4)
write_csv(res.4, file = 'scHOT_0.4_res_corr.csv')

# %%
res.6 <- toCSV(scHOT.6)
write_csv(res.6, file = 'scHOT_0.6_res_corr.csv')

# %%
res.8 <- toCSV(scHOT.8)
write_csv(res.8, file = 'scHOT_0.8_res_corr.csv')

# %% [markdown]
# # BASiCS

# %%
library(BASiCS)
# Out:
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:Matrix’:
#
#     expand
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays
#
#
#     Welcome to 'BASiCS'. If you used 'BASiCS' before its release in
#     Bioconductor, please visit:
#     https://github.com/catavallejos/BASiCS/wiki.

# %% [markdown]
# # Loading Data
# ## Not Normalized

# %%
setwd('/data_volume/memento/simulation/acc_fpr')

# %%
Convert('subsampled_0.1.h5ad', dest = "h5seurat", overwrite = TRUE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding X as data
#
# Adding X as counts
#
# Adding meta.features from var
#
# Adding X_tsne as cell embeddings for tsne

# %%
subsampled_1 <- LoadH5Seurat("subsampled_0.1.h5seurat")
# Out:
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding scale.data for RNA
#
# Adding feature-level metadata for RNA
#
# Adding reduction tsne
#
# Adding cell embeddings for tsne
#
# Adding miscellaneous information for tsne
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results

# %%
Convert('subsampled_0.2.h5ad', dest = "h5seurat", overwrite = TRUE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding X as data
#
# Adding X as counts
#
# Adding meta.features from var
#
# Adding X_tsne as cell embeddings for tsne

# %%
subsampled_2 <- LoadH5Seurat("subsampled_0.2.h5seurat")
# Out:
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding scale.data for RNA
#
# Adding feature-level metadata for RNA
#
# Adding reduction tsne
#
# Adding cell embeddings for tsne
#
# Adding miscellaneous information for tsne
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results

# %%
Convert('subsampled_0.4.h5ad', dest = "h5seurat", overwrite = TRUE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding X as data
#
# Adding X as counts
#
# Adding meta.features from var
#
# Adding X_tsne as cell embeddings for tsne

# %%
subsampled_4 <- LoadH5Seurat("subsampled_0.4.h5seurat")
# Out:
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding scale.data for RNA
#
# Adding feature-level metadata for RNA
#
# Adding reduction tsne
#
# Adding cell embeddings for tsne
#
# Adding miscellaneous information for tsne
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results

# %%
Convert('subsampled_0.6.h5ad', dest = "h5seurat", overwrite = TRUE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding X as data
#
# Adding X as counts
#
# Adding meta.features from var
#
# Adding X_tsne as cell embeddings for tsne

# %%
subsampled_6 <- LoadH5Seurat("subsampled_0.6.h5seurat")
# Out:
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding scale.data for RNA
#
# Adding feature-level metadata for RNA
#
# Adding reduction tsne
#
# Adding cell embeddings for tsne
#
# Adding miscellaneous information for tsne
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results

# %%
Convert('subsampled_0.8.h5ad', dest = "h5seurat", overwrite = TRUE)
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding X as data
#
# Adding X as counts
#
# Adding meta.features from var
#
# Adding X_tsne as cell embeddings for tsne

# %%
subsampled_8 <- LoadH5Seurat("subsampled_0.8.h5seurat")
# Out:
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding scale.data for RNA
#
# Adding feature-level metadata for RNA
#
# Adding reduction tsne
#
# Adding cell embeddings for tsne
#
# Adding miscellaneous information for tsne
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results

# %% [markdown]
# # running BASiCS

# %%
runCtrlBASiCS <- function(seurat, stim, stat){
    Idents(seurat) <- 'stim'
    dat <- subset(x = seurat, idents = stim)
    dat.sce <- SingleCellExperiment(
    assays=list(counts = GetAssayData(dat)),
    colData = data.frame(BatchInfo = dat$batch))
    Chain <- BASiCS_MCMC(
      dat.sce,
      N = 1000, Thin = 10, Burn = 500, WithSpikes = FALSE, SubsetBy = 'cell',
      PrintProgress = FALSE, Regression = TRUE,Threads = getOption("Ncpus", 10),)
    df = as.data.frame(displayChainBASiCS(Chain, Param = stat))
    return(df)
}

# %%
setwd('/data/MEMENTO/csv_files/')

# %% [markdown]
# # Mean - Control and Stim

# %%
ctrl1 <- runCtrlBASiCS(subsampled_1, 'ctrl','mu')
write_csv(ctrl1, file = 'mu_0.1_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.204
# Average acceptance rate among mu[i]'s: 0.471264
# Maximum acceptance rate among mu[i]'s: 0.8
#
#
# Minimum acceptance rate among delta[i]'s: 0.274
# Average acceptance rate among delta[i]'s: 0.613696
# Maximum acceptance rate among delta[i]'s: 0.806
#
#
# Minimum acceptance rate among nu[jk]'s: 0.578
# Average acceptance rate among nu[jk]'s: 0.892928
# Maximum acceptance rate among nu[jk]'s: 0.96
#
#
# Minimum acceptance rate among theta[k]'s: 0.416
# Average acceptance rate among theta[k]'s: 0.416
# Maximum acceptance rate among theta[k]'s: 0.416
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 132.63
# system: 24.472
# elapsed: 13.099
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim1 <- runCtrlBASiCS(subsampled_1, 'stim','mu')
write_csv(stim1, file = 'mu_0.1_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.214
# Average acceptance rate among mu[i]'s: 0.42504
# Maximum acceptance rate among mu[i]'s: 0.552
#
#
# Minimum acceptance rate among delta[i]'s: 0.304
# Average acceptance rate among delta[i]'s: 0.570048
# Maximum acceptance rate among delta[i]'s: 0.754
#
#
# Minimum acceptance rate among nu[jk]'s: 0.744
# Average acceptance rate among nu[jk]'s: 0.934244
# Maximum acceptance rate among nu[jk]'s: 0.984
#
#
# Minimum acceptance rate among theta[k]'s: 0.43
# Average acceptance rate among theta[k]'s: 0.43
# Maximum acceptance rate among theta[k]'s: 0.43
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 127.561
# system: 23.502
# elapsed: 12.594
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
ctrl2 <- runCtrlBASiCS(subsampled_2, 'ctrl','mu')
write_csv(ctrl2, file = 'mu_0.2_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.178
# Average acceptance rate among mu[i]'s: 0.444752
# Maximum acceptance rate among mu[i]'s: 0.784
#
#
# Minimum acceptance rate among delta[i]'s: 0.24
# Average acceptance rate among delta[i]'s: 0.528496
# Maximum acceptance rate among delta[i]'s: 0.774
#
#
# Minimum acceptance rate among nu[jk]'s: 0.784
# Average acceptance rate among nu[jk]'s: 0.930802
# Maximum acceptance rate among nu[jk]'s: 0.978
#
#
# Minimum acceptance rate among theta[k]'s: 0.496
# Average acceptance rate among theta[k]'s: 0.496
# Maximum acceptance rate among theta[k]'s: 0.496
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 130.499
# system: 23.824
# elapsed: 12.865
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim2 <- runCtrlBASiCS(subsampled_2, 'stim','mu')
write_csv(stim2, file = 'mu_0.2_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.14
# Average acceptance rate among mu[i]'s: 0.40032
# Maximum acceptance rate among mu[i]'s: 0.526
#
#
# Minimum acceptance rate among delta[i]'s: 0.246
# Average acceptance rate among delta[i]'s: 0.4884
# Maximum acceptance rate among delta[i]'s: 0.704
#
#
# Minimum acceptance rate among nu[jk]'s: 0.754
# Average acceptance rate among nu[jk]'s: 0.925568
# Maximum acceptance rate among nu[jk]'s: 0.982
#
#
# Minimum acceptance rate among theta[k]'s: 0.456
# Average acceptance rate among theta[k]'s: 0.456
# Maximum acceptance rate among theta[k]'s: 0.456
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 132.413
# system: 24.171
# elapsed: 13.058
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
ctrl4 <- runCtrlBASiCS(subsampled_4, 'ctrl','mu')
write_csv(ctrl4, file = 'mu_0.4_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.18
# Average acceptance rate among mu[i]'s: 0.395616
# Maximum acceptance rate among mu[i]'s: 0.822
#
#
# Minimum acceptance rate among delta[i]'s: 0.234
# Average acceptance rate among delta[i]'s: 0.46584
# Maximum acceptance rate among delta[i]'s: 0.712
#
#
# Minimum acceptance rate among nu[jk]'s: 0.686
# Average acceptance rate among nu[jk]'s: 0.906464
# Maximum acceptance rate among nu[jk]'s: 0.974
#
#
# Minimum acceptance rate among theta[k]'s: 0.386
# Average acceptance rate among theta[k]'s: 0.386
# Maximum acceptance rate among theta[k]'s: 0.386
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 133.437
# system: 24.095
# elapsed: 13.133
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim4 <- runCtrlBASiCS(subsampled_4, 'stim','mu')
write_csv(stim4, file = 'mu_0.4_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.138
# Average acceptance rate among mu[i]'s: 0.368224
# Maximum acceptance rate among mu[i]'s: 0.508
#
#
# Minimum acceptance rate among delta[i]'s: 0.238
# Average acceptance rate among delta[i]'s: 0.436848
# Maximum acceptance rate among delta[i]'s: 0.712
#
#
# Minimum acceptance rate among nu[jk]'s: 0.676
# Average acceptance rate among nu[jk]'s: 0.897854
# Maximum acceptance rate among nu[jk]'s: 0.956
#
#
# Minimum acceptance rate among theta[k]'s: 0.412
# Average acceptance rate among theta[k]'s: 0.412
# Maximum acceptance rate among theta[k]'s: 0.412
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 136.175
# system: 24.841
# elapsed: 13.425
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
ctrl6 <- runCtrlBASiCS(subsampled_6, 'ctrl','mu')
write_csv(ctrl6, file = 'mu_0.6_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.126
# Average acceptance rate among mu[i]'s: 0.382592
# Maximum acceptance rate among mu[i]'s: 0.81
#
#
# Minimum acceptance rate among delta[i]'s: 0.208
# Average acceptance rate among delta[i]'s: 0.437648
# Maximum acceptance rate among delta[i]'s: 0.636
#
#
# Minimum acceptance rate among nu[jk]'s: 0.612
# Average acceptance rate among nu[jk]'s: 0.862414
# Maximum acceptance rate among nu[jk]'s: 0.944
#
#
# Minimum acceptance rate among theta[k]'s: 0.39
# Average acceptance rate among theta[k]'s: 0.39
# Maximum acceptance rate among theta[k]'s: 0.39
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 141.161
# system: 25.715
# elapsed: 13.91
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim6 <- runCtrlBASiCS(subsampled_6, 'stim','mu')
write_csv(stim6, file = 'mu_0.6_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.098
# Average acceptance rate among mu[i]'s: 0.349344
# Maximum acceptance rate among mu[i]'s: 0.552
#
#
# Minimum acceptance rate among delta[i]'s: 0.246
# Average acceptance rate among delta[i]'s: 0.42336
# Maximum acceptance rate among delta[i]'s: 0.714
#
#
# Minimum acceptance rate among nu[jk]'s: 0.594
# Average acceptance rate among nu[jk]'s: 0.86367
# Maximum acceptance rate among nu[jk]'s: 0.944
#
#
# Minimum acceptance rate among theta[k]'s: 0.406
# Average acceptance rate among theta[k]'s: 0.406
# Maximum acceptance rate among theta[k]'s: 0.406
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 136.142
# system: 24.573
# elapsed: 13.399
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
ctrl8 <- runCtrlBASiCS(subsampled_8, 'ctrl','mu')
write_csv(ctrl8, file = 'mu_0.8_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.138
# Average acceptance rate among mu[i]'s: 0.366048
# Maximum acceptance rate among mu[i]'s: 0.792
#
#
# Minimum acceptance rate among delta[i]'s: 0.236
# Average acceptance rate among delta[i]'s: 0.425744
# Maximum acceptance rate among delta[i]'s: 0.668
#
#
# Minimum acceptance rate among nu[jk]'s: 0.684
# Average acceptance rate among nu[jk]'s: 0.898854
# Maximum acceptance rate among nu[jk]'s: 0.964
#
#
# Minimum acceptance rate among theta[k]'s: 0.422
# Average acceptance rate among theta[k]'s: 0.422
# Maximum acceptance rate among theta[k]'s: 0.422
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 134.831
# system: 24.862
# elapsed: 13.313
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim8 <- runCtrlBASiCS(subsampled_8, 'stim','mu')
write_csv(stim8, file = 'mu_0.8_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.128
# Average acceptance rate among mu[i]'s: 0.332128
# Maximum acceptance rate among mu[i]'s: 0.536
#
#
# Minimum acceptance rate among delta[i]'s: 0.23
# Average acceptance rate among delta[i]'s: 0.395472
# Maximum acceptance rate among delta[i]'s: 0.53
#
#
# Minimum acceptance rate among nu[jk]'s: 0.666
# Average acceptance rate among nu[jk]'s: 0.887652
# Maximum acceptance rate among nu[jk]'s: 0.956
#
#
# Minimum acceptance rate among theta[k]'s: 0.328
# Average acceptance rate among theta[k]'s: 0.328
# Maximum acceptance rate among theta[k]'s: 0.328
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 131.772
# system: 23.509
# elapsed: 12.946
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %% [markdown]
# # Dispersion - Control and Stim

# %%
ctrl1 <- runCtrlBASiCS(subsampled_1, 'ctrl','delta')
write_csv(ctrl1, file = 'delta_0.1_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.204
# Average acceptance rate among mu[i]'s: 0.471264
# Maximum acceptance rate among mu[i]'s: 0.8
#
#
# Minimum acceptance rate among delta[i]'s: 0.274
# Average acceptance rate among delta[i]'s: 0.613696
# Maximum acceptance rate among delta[i]'s: 0.806
#
#
# Minimum acceptance rate among nu[jk]'s: 0.578
# Average acceptance rate among nu[jk]'s: 0.892928
# Maximum acceptance rate among nu[jk]'s: 0.96
#
#
# Minimum acceptance rate among theta[k]'s: 0.416
# Average acceptance rate among theta[k]'s: 0.416
# Maximum acceptance rate among theta[k]'s: 0.416
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 135.858
# system: 24.975
# elapsed: 13.403
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim1 <- runCtrlBASiCS(subsampled_1, 'stim','delta')
write_csv(stim1, file = 'delta_0.1_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.214
# Average acceptance rate among mu[i]'s: 0.42504
# Maximum acceptance rate among mu[i]'s: 0.552
#
#
# Minimum acceptance rate among delta[i]'s: 0.304
# Average acceptance rate among delta[i]'s: 0.570048
# Maximum acceptance rate among delta[i]'s: 0.754
#
#
# Minimum acceptance rate among nu[jk]'s: 0.744
# Average acceptance rate among nu[jk]'s: 0.934244
# Maximum acceptance rate among nu[jk]'s: 0.984
#
#
# Minimum acceptance rate among theta[k]'s: 0.43
# Average acceptance rate among theta[k]'s: 0.43
# Maximum acceptance rate among theta[k]'s: 0.43
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 133.58
# system: 24.512
# elapsed: 13.18
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
ctrl2 <- runCtrlBASiCS(subsampled_2, 'ctrl','delta')
write_csv(ctrl2, file = 'delta_0.2_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.178
# Average acceptance rate among mu[i]'s: 0.444752
# Maximum acceptance rate among mu[i]'s: 0.784
#
#
# Minimum acceptance rate among delta[i]'s: 0.24
# Average acceptance rate among delta[i]'s: 0.528496
# Maximum acceptance rate among delta[i]'s: 0.774
#
#
# Minimum acceptance rate among nu[jk]'s: 0.784
# Average acceptance rate among nu[jk]'s: 0.930802
# Maximum acceptance rate among nu[jk]'s: 0.978
#
#
# Minimum acceptance rate among theta[k]'s: 0.496
# Average acceptance rate among theta[k]'s: 0.496
# Maximum acceptance rate among theta[k]'s: 0.496
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 133.479
# system: 24.345
# elapsed: 13.157
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim2 <- runCtrlBASiCS(subsampled_2, 'stim','delta')
write_csv(stim2, file = 'delta_0.2_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.14
# Average acceptance rate among mu[i]'s: 0.40032
# Maximum acceptance rate among mu[i]'s: 0.526
#
#
# Minimum acceptance rate among delta[i]'s: 0.246
# Average acceptance rate among delta[i]'s: 0.4884
# Maximum acceptance rate among delta[i]'s: 0.704
#
#
# Minimum acceptance rate among nu[jk]'s: 0.754
# Average acceptance rate among nu[jk]'s: 0.925568
# Maximum acceptance rate among nu[jk]'s: 0.982
#
#
# Minimum acceptance rate among theta[k]'s: 0.456
# Average acceptance rate among theta[k]'s: 0.456
# Maximum acceptance rate among theta[k]'s: 0.456
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 135.049
# system: 24.605
# elapsed: 13.308
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
ctrl4 <- runCtrlBASiCS(subsampled_4, 'ctrl','delta')
write_csv(ctrl4, file = 'delta_0.4_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.18
# Average acceptance rate among mu[i]'s: 0.395616
# Maximum acceptance rate among mu[i]'s: 0.822
#
#
# Minimum acceptance rate among delta[i]'s: 0.234
# Average acceptance rate among delta[i]'s: 0.46584
# Maximum acceptance rate among delta[i]'s: 0.712
#
#
# Minimum acceptance rate among nu[jk]'s: 0.686
# Average acceptance rate among nu[jk]'s: 0.906464
# Maximum acceptance rate among nu[jk]'s: 0.974
#
#
# Minimum acceptance rate among theta[k]'s: 0.386
# Average acceptance rate among theta[k]'s: 0.386
# Maximum acceptance rate among theta[k]'s: 0.386
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 138.315
# system: 25.406
# elapsed: 13.648
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim4 <- runCtrlBASiCS(subsampled_4, 'stim','delta')
write_csv(stim4, file = 'delta_0.4_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.138
# Average acceptance rate among mu[i]'s: 0.368224
# Maximum acceptance rate among mu[i]'s: 0.508
#
#
# Minimum acceptance rate among delta[i]'s: 0.238
# Average acceptance rate among delta[i]'s: 0.436848
# Maximum acceptance rate among delta[i]'s: 0.712
#
#
# Minimum acceptance rate among nu[jk]'s: 0.676
# Average acceptance rate among nu[jk]'s: 0.897854
# Maximum acceptance rate among nu[jk]'s: 0.956
#
#
# Minimum acceptance rate among theta[k]'s: 0.412
# Average acceptance rate among theta[k]'s: 0.412
# Maximum acceptance rate among theta[k]'s: 0.412
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 138.291
# system: 24.939
# elapsed: 13.607
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
ctrl6 <- runCtrlBASiCS(subsampled_6, 'ctrl','delta')
write_csv(ctrl6, file = 'delta_0.6_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.126
# Average acceptance rate among mu[i]'s: 0.382592
# Maximum acceptance rate among mu[i]'s: 0.81
#
#
# Minimum acceptance rate among delta[i]'s: 0.208
# Average acceptance rate among delta[i]'s: 0.437648
# Maximum acceptance rate among delta[i]'s: 0.636
#
#
# Minimum acceptance rate among nu[jk]'s: 0.612
# Average acceptance rate among nu[jk]'s: 0.862414
# Maximum acceptance rate among nu[jk]'s: 0.944
#
#
# Minimum acceptance rate among theta[k]'s: 0.39
# Average acceptance rate among theta[k]'s: 0.39
# Maximum acceptance rate among theta[k]'s: 0.39
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 147.065
# system: 26.714
# elapsed: 14.492
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim6 <- runCtrlBASiCS(subsampled_6, 'stim','delta')
write_csv(stim6, file = 'delta_0.6_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.098
# Average acceptance rate among mu[i]'s: 0.349344
# Maximum acceptance rate among mu[i]'s: 0.552
#
#
# Minimum acceptance rate among delta[i]'s: 0.246
# Average acceptance rate among delta[i]'s: 0.42336
# Maximum acceptance rate among delta[i]'s: 0.714
#
#
# Minimum acceptance rate among nu[jk]'s: 0.594
# Average acceptance rate among nu[jk]'s: 0.86367
# Maximum acceptance rate among nu[jk]'s: 0.944
#
#
# Minimum acceptance rate among theta[k]'s: 0.406
# Average acceptance rate among theta[k]'s: 0.406
# Maximum acceptance rate among theta[k]'s: 0.406
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 138.134
# system: 25.194
# elapsed: 13.609
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
ctrl8 <- runCtrlBASiCS(subsampled_8, 'ctrl','delta')
write_csv(ctrl8, file = 'delta_0.8_ctrl.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.138
# Average acceptance rate among mu[i]'s: 0.366048
# Maximum acceptance rate among mu[i]'s: 0.792
#
#
# Minimum acceptance rate among delta[i]'s: 0.236
# Average acceptance rate among delta[i]'s: 0.425744
# Maximum acceptance rate among delta[i]'s: 0.668
#
#
# Minimum acceptance rate among nu[jk]'s: 0.684
# Average acceptance rate among nu[jk]'s: 0.898854
# Maximum acceptance rate among nu[jk]'s: 0.964
#
#
# Minimum acceptance rate among theta[k]'s: 0.422
# Average acceptance rate among theta[k]'s: 0.422
# Maximum acceptance rate among theta[k]'s: 0.422
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 144.675
# system: 26.449
# elapsed: 14.271
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
stim8 <- runCtrlBASiCS(subsampled_8, 'stim','delta')
write_csv(stim8, file = 'delta_0.8_stim.csv')
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.128
# Average acceptance rate among mu[i]'s: 0.332128
# Maximum acceptance rate among mu[i]'s: 0.536
#
#
# Minimum acceptance rate among delta[i]'s: 0.23
# Average acceptance rate among delta[i]'s: 0.395472
# Maximum acceptance rate among delta[i]'s: 0.53
#
#
# Minimum acceptance rate among nu[jk]'s: 0.666
# Average acceptance rate among nu[jk]'s: 0.887652
# Maximum acceptance rate among nu[jk]'s: 0.956
#
#
# Minimum acceptance rate among theta[k]'s: 0.328
# Average acceptance rate among theta[k]'s: 0.328
# Maximum acceptance rate among theta[k]'s: 0.328
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 140.337
# system: 25.645
# elapsed: 13.835
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
# [41,] 0.15598926 0.36648824
# [42,] 0.11591758 0.24247816
# [43,] 0.14082784 0.24629284
# [44,] 0.23844726 0.34126358
# [45,] 0.15517346 0.41886599
# [46,] 0.15544704 0.38620066
# [47,] 0.12400020 0.36974282
# [48,] 0.15429342 0.10759124
# [49,] 0.21337262 0.30659739
# [50,] 0.17996825 0.24766989

# %%
Idents(subsampled_8) <- 'stim'

# %%
ctrl.8 <- subset(x = subsampled_8, idents = 'ctrl')

# %%
ctrl8.sce <- SingleCellExperiment(
    assays=list(counts = GetAssayData(ctrl.8)),
    colData = data.frame(BatchInfo = ctrl.8$stim)
)

# %%
ChainCtrl <- BASiCS_MCMC(
  ctrl8.sce,
  N = 1000, Thin = 10, Burn = 500, WithSpikes = FALSE, SubsetBy = 'cell',
  PrintProgress = FALSE, Regression = TRUE,Threads = getOption("Ncpus", 10)
)
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.204
# Average acceptance rate among mu[i]'s: 0.471264
# Maximum acceptance rate among mu[i]'s: 0.8
#
#
# Minimum acceptance rate among delta[i]'s: 0.274
# Average acceptance rate among delta[i]'s: 0.613696
# Maximum acceptance rate among delta[i]'s: 0.806
#
#
# Minimum acceptance rate among nu[jk]'s: 0.578
# Average acceptance rate among nu[jk]'s: 0.892928
# Maximum acceptance rate among nu[jk]'s: 0.96
#
#
# Minimum acceptance rate among theta[k]'s: 0.416
# Average acceptance rate among theta[k]'s: 0.416
# Maximum acceptance rate among theta[k]'s: 0.416
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 132.707
# system: 24.8
# elapsed: 13.093
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
plot(ChainCtrl, Param = "mu", Gene = 1, log = "y")
# Out:
# plot without title

# %%
stim.8 <- subset(x = subsampled_8, idents = 'stim')
stim8.sce <- SingleCellExperiment(
    assays=list(counts = GetAssayData(stim.8)),
    colData = data.frame(BatchInfo = stim.8$stim)
)

# %%
ChainStim <- BASiCS_MCMC(
  stim8.sce,
  N = 1000, Thin = 10, Burn = 500, WithSpikes = FALSE, SubsetBy = 'cell',
  PrintProgress = FALSE, Regression = TRUE,Threads = getOption("Ncpus", 10)
)
# Out:
# Warning message in .ChecksBASiCS_Data(Data, WithSpikes):
# “If spike-in genes are not available, BASiCS recommends that the data contain at least 2 batches of cells (for the same population)
# ”
# Running no spikes BASiCS sampler (regression case) ...
# -----------------------------------------------------
# MCMC sampler has been started: 1000 iterations to go.
# -----------------------------------------------------
# -----------------------------------------------------
# End of Burn-in period.
# -----------------------------------------------------
#
# -----------------------------------------------------
# -----------------------------------------------------
# All 1000 MCMC iterations have been completed.
# -----------------------------------------------------
# -----------------------------------------------------
#
# -----------------------------------------------------
# Please see below a summary of the overall acceptance rates.
# -----------------------------------------------------
#
# Minimum acceptance rate among mu[i]'s: 0.18
# Average acceptance rate among mu[i]'s: 0.422944
# Maximum acceptance rate among mu[i]'s: 0.512
#
#
# Minimum acceptance rate among delta[i]'s: 0.298
# Average acceptance rate among delta[i]'s: 0.565056
# Maximum acceptance rate among delta[i]'s: 0.734
#
#
# Minimum acceptance rate among nu[jk]'s: 0.716
# Average acceptance rate among nu[jk]'s: 0.910848
# Maximum acceptance rate among nu[jk]'s: 0.972
#
#
# Minimum acceptance rate among theta[k]'s: 0.44
# Average acceptance rate among theta[k]'s: 0.44
# Maximum acceptance rate among theta[k]'s: 0.44
#
#
# -----------------------------------------------------
# -------------------------------------------------------------
# MCMC running time
# -------------------------------------------------------------
# user: 129.097
# system: 23.72
# elapsed: 12.739
#
#
# -------------------------------------------------------------
# Output
# -------------------------------------------------------------

# %%
plot(ChainStim, Param = "mu", Gene = 1, log = "y")
# Out:
# plot without title

# %%
Test <- BASiCS_TestDE(
  Chain1 = ChainCtrl, Chain2 = ChainStim,
  GroupLabel1 = "ctrl", GroupLabel2 = "stim",
  EpsilonM = 0, EpsilonD = 0,
  EFDR_M = 1b, EFDR_D = 1,
  Offset = TRUE, PlotOffset = TRUE, Plot = TRUE
)
# Out:
# -------------------------------------------------------------
# Log-fold change thresholds are now set in a log2 scale.
# Original BASiCS release used a natural logarithm scale.
#
# -------------------------------------------------------------
# Offset estimate: 0.9914
# (ratio ctrl vs stim).
# -------------------------------------------------------------
#
#
# EFDR calibration failed for Differential mean task.
# Probability threshold automatically set equal to 'ProbThresholdM'.
#
# EFDR calibration failed for Differential dispersion task.
# Probability threshold automatically set equal to 'ProbThresholdD'.
#
# EFDR calibration failed for Differential residual dispersion task.
# Probability threshold automatically set equal to 'ProbThresholdR'.

# %%
displayChainBASiCS(ChainCtrl, Param = 'delta')
# Out:
#       ISG15     RPL11      SH3BGRL3   IFI6       S100A10    S100A11
#  [1,] 0.1129662 0.03640793 0.20760219 0.08876934 0.14030057 0.17224051
#  [2,] 0.1433054 0.20089934 0.13822426 0.17336423 0.17545180 0.14881330
#  [3,] 0.1184871 0.09878922 0.11972093 0.13865229 0.20508068 0.19431420
#  [4,] 0.1252996 0.26808038 0.20575316 0.14388207 0.15535946 0.07850773
#  [5,] 0.1399925 0.03594843 0.40108024 0.06266758 0.21165712 0.11460571
#  [6,] 0.1442254 0.06228789 0.26155854 0.06343685 0.27250549 0.10687736
#  [7,] 0.1439557 0.17379298 0.07947342 0.04205474 0.21059345 0.12520130
#  [8,] 0.1244185 0.18439295 0.10213114 0.04215974 0.16903715 0.17031848
#  [9,] 0.1378599 0.11161027 0.18768514 0.05702637 0.29291259 0.13383016
# [10,] 0.1404166 0.12939296 0.34490708 0.01116950 0.17876132 0.13175697
# [11,] 0.1275247 0.17058998 0.23285385 0.14395116 0.16791275 0.09561833
# [12,] 0.1309832 0.12737608 0.39633570 0.36319189 0.36902413 0.12267651
# [13,] 0.1235234 0.12831165 0.21951686 0.15679436 0.25685944 0.13232556
# [14,] 0.1232088 0.10112897 0.24578172 0.04021779 0.15570213 0.12494935
# [15,] 0.1298373 0.13518052 0.67087404 0.01604414 0.28138271 0.09203954
# [16,] 0.1350170 0.10693630 0.39329712 0.05011293 0.20305977 0.06527124
# [17,] 0.1227090 0.22481977 0.25312677 0.06634604 0.19527745 0.06392680
# [18,] 0.1347345 0.10901264 0.37527319 0.05924922 0.20179601 0.06775033
# [13,] 0.16147857 0.25686591
# [14,] 0.19948102 0.29515303
# [15,] 0.10670431 0.14830455
# [16,] 0.14917691 0.18415062
# [17,] 0.07441266 0.24551049
# [18,] 0.15298451 0.36121416
# [19,] 0.19798098 0.37176689
# [20,] 0.10377856 0.12255264
# [21,] 0.23604862 0.19362016
# [22,] 0.07864139 0.32108274
# [23,] 0.17757137 0.36730774
# [24,] 0.15658755 0.29573515
# [25,] 0.14472578 0.44980485
# [26,] 0.05413282 0.44541571
# [27,] 0.12657982 0.32492518
# [28,] 0.05672205 0.24281316
# [29,] 0.09238640 0.28452120
# [30,] 0.10091181 0.41131321
# [31,] 0.06795380 0.29122257
# [32,] 0.10089214 0.37116590
# [33,] 0.15492323 0.27581765
# [34,] 0.15154529 0.07754914
# [35,] 0.16970385 0.30717957
# [36,] 0.13351565 0.32218242
# [37,] 0.12745846 0.34422994
# [38,] 0.06820185 0.41351773
# [39,] 0.19010456 0.26743308
# [40,] 0.10793616 0.35335002
# [41,] 0.15598926 0.36648824
# [42,] 0.11591758 0.24247816
# [43,] 0.14082784 0.24629284
# [44,] 0.23844726 0.34126358
# [45,] 0.15517346 0.41886599
# [46,] 0.15544704 0.38620066
# [47,] 0.12400020 0.36974282
# [48,] 0.15429342 0.10759124
# [49,] 0.21337262 0.30659739
# [50,] 0.17996825 0.24766989

# %%
BASiCS_PlotDE(Test, Plots = c("MA", "Volcano"))
# Out:
# plot without title

# %%
Test
# Out:
# An object of class BASiCS_ResultsDE, containing:
# -------------------------------------------------------------
#   An object of class BASiCS_ResultDE.
# -------------------------------------------------------------
#  0 genes with a change in mean expression
#  - Higher mean expression in ctrl samples: 0
#  - Higher mean expression in stim samples: 0
#  - Fold change tolerance = 100 %
#  - Probability threshold = 0.666666666666667
#  - EFDR = NA %
#  - EFNR = NA %
# -------------------------------------------------------------
#   An object of class BASiCS_ResultDE.
# -------------------------------------------------------------
#  0 genes with a change in over dispersion
#  - Higher over dispersion in ctrl samples: 0
#  - Higher over dispersion in stim samples: 0
#  - Fold change tolerance = 100 %
#  - Probability threshold = 0.666666666666667
#  - EFDR = NA %
#  - EFNR = NA %
# -------------------------------------------------------------
#   An object of class BASiCS_ResultDE.
# -------------------------------------------------------------
#  0 genes with a change in residual over dispersion
#  - Higher residual over dispersion in ctrl samples: 0
#  - Higher residual over dispersion in stim samples: 0
#  - Distance tolerance = 132.45 %
#  - Probability threshold = 0.666666666666667
#  - EFDR = NA %
#  - EFNR = NA %

# %%
as.data.frame(Test, Parameter = "Mean")
# Out:
#      GeneName MeanOverall Mean1 Mean2 MeanFC MeanLog2FC ProbDiffMean
#      ResultDiffMean

# %%
head(as.data.frame(Test, Parameter = "Disp"))
# Out:
#      GeneName DispOverall Disp1 Disp2 DispFC DispLog2FC ProbDiffDisp
#      ResultDiffDisp

# %% [markdown]
# # PRACTICE

# %%
scHOT_traj <- scHOT_buildFromSCE(
    subsample1.sce,
    assayName = 'logcounts',
    positionType = "trajectory",
    positionColData = "stim_indicator"

)

# %%
scHOT_traj <- scHOT_buildFromMatrix(
  mat = as.matrix(GetAssayData(mono_small)),
  cellData = list(pseudotime = mono_small$psuedotime),
  positionType = "trajectory",
  positionColData = "pseudotime")

# %%
?scHOT_buildFromSCE
# Out:
# scHOT_buildFromSCE            package:scHOT            R Documentation
#
# E
#
# n:
#
#      Create scHOT object from a SingleCellExperiment object
#
# e:
#
#      scHOT_buildFromSCE(
#        sce,
#        assayName = "counts",
#        positionType = NULL,
#        positionColData = NULL
#      )
#
# s:
#
#      sce: A SingleCellExperiment object
#
# assayName: is a single assay to pull out from sce as the expression
#           matrix input of scHOT
#
# positionType: A string indicates the position type, either trajectory
#           or spatial
#
# positionColData: Strings indicate the position information stored in
#           colData. If positionType is "trajectory" then positionColData
#           should be a sortable vector if positionType is "spatial" then
#           positionColData should be a matrix type object.
#
# e:
#
#      A scHOT object
#
# s:
#
#      library(SingleCellExperiment)
#      dat <- rbind(rnorm(50), rnorm(50), rnorm(50))
#      colnames(dat) <- paste0("cell_", 1:ncol(dat))
#      rownames(dat) <- c("gene_1","gene_2", "gene_2")
#
#      sce <- SingleCellExperiment::SingleCellExperiment(assays =
#      S4Vectors::SimpleList(counts = dat))
#      scHOT <- scHOT_buildFromSCE(sce)

# %%
# setting Weight Matrix
scHOT_traj <- scHOT_setWeightMatrix(scHOT_traj,
                                    positionType = "trajectory",
                                    positionColData = c("stim_indicator"),
                                    nrow.out = 2,
                                    averageAcrossTrajectoryTies = TRUE,
                                    span = 0.1)
# Out:
# weightMatrix not provided, generating one using parameter settings...
#
# type not specified, defaulting to triangular

# %%
plot(scHOT_traj@weightMatrix[1,])
# Out:
# plot without title

# %%
plot(scHOT_traj@weightMatrix[2,])
# Out:
# plot without title

# %%
dim(scHOT_traj@weightMatrix)
# Out:
# [1]    2 2000

# %%
test_genes <- as.matrix(rownames(scHOT_traj))

# %%
dim(test_genes)
# Out:
# [1] 125   1

# %%
scHOT_traj
# Out:
# class: scHOT
# dim: 125 2000
# metadata(0):
# assays(1): expression
# rownames(125): ISG15 RPL11 ... TYMP CSTB
# rowData names(0):
# colnames(2000): TCCTACCTCTCAGA-1-0 GTGAACACGCCTTC-1-0 ...
#   GAGGGTGATTGCTT-1-1 CGCAGGTGCCTCAC-1-1
# colData names(21): tsne1 tsne2 ... stim_indicator ident
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):
# testingScaffold dim: 0 0
# weightMatrix dim: 2 2000
# scHOT_output colnames (0):
# param names (0):
# position type: trajectory

# %%
ptm <- proc.time()
# scHOT wrapper function
scHOT_traj_wrap_1 = scHOT(scHOT_traj,
                        testingScaffold = test_genes,
                        weightMatrix = scHOT_traj@weightMatrix,
                        higherOrderFunction = matrixStats::weightedVar,
                        higherOrderFunctionType = "weighted",
                        numberPermutations = 100,
                        parallel = TRUE,
                        BPPARAM = BiocParallel::MulticoreParam(workers = 10),
                        verbose = FALSE
                      )
proc.time() - ptm
# Out:
# higherOrderFunctionType given will replace any stored param
#
# higherOrderFunction given will replace any stored param
#
# higherOrderSummaryFunction will replace any stored param
#    user  system elapsed
#  12.969   3.272   4.718

# %%
scHOT_traj_wrap_1
# Out:
# class: scHOT
# dim: 125 2000
# metadata(0):
# assays(1): expression
# rownames(125): ISG15 RPL11 ... TYMP CSTB
# rowData names(0):
# colnames(2000): TCCTACCTCTCAGA-1-0 GTGAACACGCCTTC-1-0 ...
#   GAGGGTGATTGCTT-1-1 CGCAGGTGCCTCAC-1-1
# colData names(21): tsne1 tsne2 ... stim_indicator ident
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):
# testingScaffold dim: 125 1
# weightMatrix dim: 2 2000
# scHOT_output colnames (14): gene_1 globalHigherOrderFunction ...
#   pvalEstimated FDREstimated
# param names (3): higherOrderFunctionType higherOrderFunction
#   higherOrderSummaryFunction
# position type: trajectory

# %%
head(slot(scHOT_traj_wrap_1, "scHOT_output"))
# Out:
# DataFrame with 6 rows and 14 columns
#               gene_1 globalHigherOrderFunction numberPermutations
#          <character>                  <matrix>          <numeric>
# ISG15          ISG15                         0                  0
# RPL11          RPL11                         0                  0
# SH3BGRL3    SH3BGRL3                         0                  0
# IFI6            IFI6                         0                  0
# S100A10      S100A10                         0                  0
# S100A11      S100A11                         0                  0
#          storePermutations higherOrderSequence higherOrderStatistic
#                  <logical>       <NumericList>            <numeric>
# ISG15                 TRUE                 0,0                    0
# RPL11                 TRUE                 0,0                    0
# SH3BGRL3              TRUE                 0,0                    0
# IFI6                  TRUE                 0,0                    0
# S100A10               TRUE                 0,0                    0
# S100A11               TRUE                 0,0                    0
#           permutations pvalPermutations FDRPermutations
#          <NumericList>        <numeric>       <numeric>
# ISG15               NA               NA              NA
# RPL11               NA               NA              NA
# SH3BGRL3            NA               NA              NA
# IFI6                NA               NA              NA
# S100A10             NA               NA              NA
# S100A11             NA               NA              NA
#          numberPermutationsEstimated globalLowerRangeEstimated
#                            <integer>                 <numeric>
# ISG15                            500                         0
# RPL11                            500                         0
# SH3BGRL3                         500                         0
# IFI6                             500                         0
# S100A10                          500                         0
# S100A11                          500                         0
#          globalUpperRangeEstimated pvalEstimated FDREstimated
#                          <numeric>     <numeric>    <numeric>
# ISG15                            0             1            1
# RPL11                            0             1            1
# SH3BGRL3                         0             1            1
# IFI6                             0             1            1
# S100A10                          0             1            1
# S100A11                          0             1            1

# %%
plotHigherOrderSequence(scHOT_traj_wrap_1, test_genes[1:10,])
# Out:
# Warning message in plotHigherOrderSequence(scHOT_traj_wrap_1, test_genes[1:10, ]):
# “Not all the cell position has higherOrderSequence statistics,
#             set nrow.out = NULL in scHOT_setWeightMatrix to calculate
#             higherOrderSequence for all positions!”
# branches information is not provided
#
# Warning message in type.convert.default(X[[i]], ...):
# “'as.is' should be specified by the caller; using TRUE”
# Warning message:
# “Use of `branch_long$SampleOrder` is discouraged. Use `SampleOrder` instead.”
# Warning message:
# “Use of `branch_long$WeightedCorrelation` is discouraged. Use `WeightedCorrelation` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# Warning message:
# “Use of `branch_long$GenePair` is discouraged. Use `GenePair` instead.”
# plot without title
