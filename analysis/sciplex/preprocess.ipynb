# %% [markdown]
# ### Preprocess sci-plex data

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import scipy.io as io
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data_path = '/data_volume/memento/sciplex/'

# %% [markdown]
# ### Assemble sci-plex data

# %%
genes = pd.read_csv(
    data_path + 'raw/GSM4150378_sciPlex3_A549_MCF7_K562_screen_gene.annotations.txt', 
    index_col=0,
    sep=' ')
var_df = pd.DataFrame(index=genes['gene_short_name'])
var_df['gene_id'] = genes.index.values

# %%
cells = pd.read_csv(
    data_path + 'raw/GSM4150378_sciPlex3_pData.txt', 
    index_col=0,
    sep=' ')
# obs_df = pd.DataFrame(index=cells['0'])
# obs_df['cell'] = cells['0'].tolist()

# %%
print('gene', genes.shape)
print('cell', cells.shape)
# Out:
# gene (110983, 1)
# cell (799317, 39)

# %%
# Takes a very long time to read
a = io.mmread(data_path + '/raw/formatted_UMI_count.matrix')

# %%
adata = sc.AnnData(X=a.T.tocsr(), obs=cells, var=var_df)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata.write(data_path + 'h5ad/sciplex.h5ad')
# Out:
# ... storing 'sample' as categorical
# ... storing 'top_oligo_W' as categorical
# ... storing 'top_oligo_P' as categorical
# ... storing 'pcr_well' as categorical
# ... storing 'pcr_plate' as categorical
# ... storing 'culture_plate' as categorical
# ... storing 'Combo' as categorical
# ... storing 'well_oligo' as categorical
# ... storing 'plate_oligo' as categorical
# ... storing 'cell_type' as categorical
# ... storing 'replicate' as categorical
# ... storing 'drug_dose' as categorical
# ... storing 'catalog_number' as categorical
# ... storing 'treatment' as categorical
# ... storing 'pathway_level_1' as categorical
# ... storing 'pathway_level_2' as categorical
# ... storing 'product_name' as categorical
# ... storing 'target' as categorical
# ... storing 'pathway' as categorical

# %% [markdown]
# ### Filter  and subset the sci-plex data
#
# also, do some sanity checks if the file was correctly loaded....

# %%
adata = sc.read(data_path + 'h5ad/sciplex.h5ad')
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata.var_names_make_unique()
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD113-1', 'SNORD113-2', 'SNORD113-3', 'SNORD113-4', 'SNORD113-5']
#   warnings.warn(

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt', size=1)
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
adata = adata[adata.obs.n_genes_by_counts < 8000, :]
adata = adata[adata.obs.pct_counts_mt < 50, :]
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %% [markdown]
# ### Create a cell type and HDAC subsets

# %%
adata.obs.vehicle.value_counts()
# Out:
# False    776181
# True      17503
# Name: vehicle, dtype: int64

# %%
adata_dict = {}
cell_types = ['MCF7', 'A549', 'K562']
for ct in cell_types:
    
    adata_ct = adata[adata.obs.cell_type==ct]
    adata_ct.write(data_path + 'h5ad/{}.h5ad'.format(ct))
    adata_ct_hdac = adata_ct[(adata_ct.obs.target == 'HDAC') | adata_ct.obs.vehicle]
    adata_ct_hdac.write(data_path + 'h5ad/{}_HDAC.h5ad'.format(ct))
    
    print(ct, adata_ct.shape, adata_ct_hdac.shape)
# Out:
# MCF7 (343939, 65090) (52041, 65090)
# A549 (242144, 65090) (43056, 65090)
# K562 (172460, 65090) (22037, 65090)

# %% [markdown]
# ### Create big buckets for analysis

# %%
df = adata_ct.obs.copy()
df['pathway_level_2'] = df['pathway_level_2'].astype(str)
df['target'] = df['target'].astype(str)
df['product_name'] = df['product_name'].astype(str)

# %%
multidrug_targets = df.drop_duplicates(['product_name']).groupby('target').size()
multidrug_targets = multidrug_targets[multidrug_targets > 3]

# %%
multidrug_targets.index.tolist()
# Out:
# ['Aurora Kinase',
#  'DNA/RNA Synthesis',
#  'HDAC',
#  'Histone Methyltransferase',
#  'JAK',
#  'PARP',
#  'Sirtuin']

# %%
df.groupby(['target', 'product_name']).size()
# Out:
# target                                                     product_name
# ALK,c-Met                                                  Crizotinib (PF-02341066)                         753
# AMPK                                                       AICAR (Acadesine)                               1055
# Androgen Receptor                                          Andarine                                        1019
# Aromatase                                                  Aminoglutethimide                               1119
# Aurora Kinase                                              AMG-900                                          845
#                                                            Alisertib (MLN8237)                              631
#                                                            Aurora A Inhibitor I                             954
#                                                            Barasertib (AZD1152-HQPA)                        738
#                                                            GSK1070916                                       702
#                                                            Hesperadin                                       735
#                                                            MK-5108 (VX-689)                                 766
#                                                            MLN8054                                          685
#                                                            PHA-680632                                       763
#                                                            SNS-314                                          765
#                                                            TAK-901                                          662
#                                                            Tozasertib (VX-680, MK-0457)                     649
#                                                            ZM 447439                                        932
# Aurora Kinase,Bcr-Abl,FLT3                                 KW-2449                                          891
# Aurora Kinase,Bcr-Abl,JAK                                  AT9283                                           645
# Aurora Kinase,Bcr-Abl,c-RET,FGFR                           Danusertib (PHA-739358)                          641
# Aurora Kinase,CDK                                          JNJ-7706621                                      847
# Aurora Kinase,FLT3,VEGFR                                   ENMD-2076                                        867
#                                                            ENMD-2076 L-(+)-Tartaric acid                    789
# Aurora Kinase,VEGFR                                        CYC116                                           925
# Autophagy,ROCK                                             Fasudil (HA-1077) HCl                            946
# Autophagy,Sirtuin                                          Resveratrol                                      984
# Bcl-2                                                      ABT-737                                          911
#                                                            Navitoclax (ABT-263)                             811
#                                                            Obatoclax Mesylate (GX15-070)                    922
# Bcr-Abl                                                    Nilotinib (AMN-107)                              743
# Bcr-Abl,c-Kit,Src                                          Dasatinib                                        502
# Beta Amyloid,Gamma-secretase                               Avagacestat (BMS-708163)                         961
#                                                            MK-0752                                         1025
# CCR                                                        Maraviroc                                        967
# CDK                                                        BMS-265246                                      1015
#                                                            Flavopiridol HCl                                 435
#                                                            Roscovitine (Seliciclib,CYC202)                 1077
# COX                                                        Celecoxib                                        983
# CSF-1R,PDGFR,VEGFR                                         Linifanib (ABT-869)                             1064
# DNA Methyltransferase                                      Azacitidine                                      866
#                                                            Decitabine                                       886
#                                                            RG108                                            968
# DNA alkylator                                              Altretamine                                     1057
#                                                            Busulfan                                        1183
#                                                            Streptozotocin (STZ)                            1041
# DNA/RNA Synthesis                                          Capecitabine                                    1151
#                                                            Carmofur                                        1094
#                                                            Clevudine                                        975
#                                                            Cyclocytidine HCl                                950
#                                                            Fluorouracil (5-Fluoracil, 5-FU)                1044
#                                                            Lomustine                                        965
#                                                            Mercaptopurine (6-MP)                            903
#                                                            Raltitrexed                                      803
# Dehydrogenase                                              Disulfiram                                      1025
# Dopamine Receptor                                          Amisulpride                                     1123
# E3 Ligase ,TNF-alpha                                       Thalidomide                                      980
# E3 Ligase ,p53                                             JNJ-26854165 (Serdemetan)                        978
# EGFR                                                       AG-490 (Tyrphostin B42)                         1101
#                                                            Pelitinib (EKB-569)                              873
# EGFR,HDAC,HER2                                             CUDC-101                                         809
# EGFR,HER2                                                  AC480 (BMS-599626)                               955
#                                                            Lapatinib (GW-572016) Ditosylate                 962
# EGFR,JAK                                                   WHI-P154                                         993
# Epigenetic Reader Domain                                   (+)-JQ1                                          730
#                                                            EED226                                           988
#                                                            PFI-1 (PF-6405761)                               945
# Estrogen/progestogen Receptor                              Fulvestrant                                      979
#                                                            Toremifene Citrate                              1033
# FAAH                                                       PF-3845                                          932
# FAK                                                        PF-573228                                        894
# FGFR,PDGFR,VEGFR                                           Nintedanib (BIBF 1120)                           797
# FGFR,VEGFR                                                 PD173074                                        1062
# GABA Receptor,HDAC,Autophagy                               Valproic acid sodium salt (Sodium valproate)    1004
# Glucocorticoid Receptor                                    Meprednisone                                    1100
#                                                            Triamcinolone Acetonide                         1158
# Glucocorticoid Receptor,Immunology & Inflammation related  Prednisone                                      1024
# HDAC                                                       AR-42                                            680
#                                                            Abexinostat (PCI-24781)                          640
#                                                            Belinostat (PXD101)                              800
#                                                            Dacinostat (LAQ824)                              492
#                                                            Divalproex Sodium                               1014
#                                                            Droxinostat                                      930
#                                                            Entinostat (MS-275)                              899
#                                                            Givinostat (ITF2357)                             736
#                                                            ITSA-1 (ITSA1)                                   873
#                                                            M344                                             703
#                                                            MC1568                                          1023
#                                                            Mocetinostat (MGCD0103)                          692
#                                                            PCI-34051                                        960
#                                                            Panobinostat (LBH589)                            443
#                                                            Pracinostat (SB939)                              684
#                                                            Quisinostat (JNJ-26481585) 2HCl                  442
#                                                            Resminostat                                      841
#                                                            Sodium Phenylbutyrate                            902
#                                                            TMP195                                           955
#                                                            Tacedinaline (CI994)                             896
#                                                            Trichostatin A (TSA)                             786
#                                                            Tubastatin A HCl                                 940
#                                                            Tucidinostat (Chidamide)                         794
# HDAC,PI3K                                                  CUDC-907                                         434
# HIF                                                        2-Methoxyestradiol (2-MeOE2)                     732
#                                                            IOX2                                            1018
#                                                            Roxadustat (FG-4592)                             943
# HSP (e.g. HSP90)                                           Alvespimycin (17-DMAG) HCl                       650
#                                                            Luminespib (AUY-922, NVP-AUY922)                 505
#                                                            Tanespimycin (17-AAG)                            695
# Histamine Receptor                                         Cimetidine                                       969
# Histone Acetyltransferase                                  Anacardic Acid                                   948
# Histone Demethylase                                        GSK J1                                           965
#                                                            GSK-LSD1 2HCl                                    936
# Histone Methyltransferase                                  A-366                                           1053
#                                                            BRD4770                                         1025
#                                                            Entacapone                                       968
#                                                            Tazemetostat (EPZ-6438)                         1085
#                                                            UNC0379                                          967
#                                                            UNC0631                                          978
#                                                            UNC1999                                          929
# IDH1                                                       Ivosidenib (AG-120)                              975
# IGF-1R                                                     BMS-536924                                      1034
# JAK                                                        AZ 960                                           818
#                                                            AZD1480                                          829
#                                                            BMS-911543                                       912
#                                                            Baricitinib (LY3009104, INCB028050)             1061
#                                                            CEP-33779                                        986
#                                                            Cerdulatinib (PRT062070, PRT2070)               1000
#                                                            FLLL32                                           872
#                                                            Fedratinib (SAR302503, TG101348)                 731
#                                                            Filgotinib (GLPG0634)                            988
#                                                            Gandotinib (LY2784544)                           890
#                                                            Momelotinib (CYT387)                             902
#                                                            NVP-BSK805 2HCl                                  885
#                                                            Ruxolitinib (INCB018424)                         932
#                                                            S-Ruxolitinib (INCB018424)                       932
#                                                            Tofacitinib (CP-690550) Citrate                 1043
#                                                            WP1066                                           947
# LPA Receptor                                               Ki16425                                          956
# Lipoxygenase                                               Zileuton                                        1051
# MAO                                                        Tranylcypromine (2-PCPA) HCl                     996
# MEK                                                        PD98059                                         1024
#                                                            SL-327                                           954
#                                                            Trametinib (GSK1120212)                          720
# MT Receptor                                                Ramelteon                                       1080
# Microtubule Associated                                     Epothilone A                                     353
#                                                            Patupilone (EPO906, Epothilone B)                313
# NF-κB,HDAC,Histone Acetyltransferase,Nrf2                  Curcumin                                        1033
# Others                                                     Alendronate sodium trihydrate                   1076
#                                                            Mesna                                           1099
#                                                            Thiotepa                                        1111
# PARP                                                       AG-14361                                         926
#                                                            G007-LK                                          877
#                                                            INO-1001 (3-Aminobenzamide)                     1052
#                                                            Iniparib (BSI-201)                               960
#                                                            PJ34                                             982
#                                                            Rucaparib (AG-014699,PF-01367338) phosphate      973
#                                                            Veliparib (ABT-888)                             1062
# PDGFR,Raf,VEGFR                                            Sorafenib Tosylate                               887
# PI3K                                                       TGX-221                                         1005
# PKA,EGFR,PKC                                               Daphnetin                                        918
# PKC                                                        Bisindolylmaleimide IX (Ro 31-8220 Mesylate)     754
#                                                            Enzastaurin (LY317615)                           944
# PLK                                                        Rigosertib (ON-01910)                            550
# Pim                                                        SGI-1776 free base                               796
# STAT                                                       S3I-201                                         1126
# Sirtuin                                                    SRT1720 HCl                                      930
#                                                            SRT2104 (GSK2245840)                            1112
#                                                            SRT3025 HCl                                      888
#                                                            Selisistat (EX 527)                              986
#                                                            Sirtinol                                        1044
# Src                                                        Bosutinib (SKI-606)                              548
# Src,Sirtuin,PKC,PI3K                                       Quercetin                                        899
# Survivin                                                   YM155 (Sepantronium Bromide)                     678
# TGF-beta/Smad                                              SB431542                                        1056
# TNF-alpha                                                  Lenalidomide (CC-5013)                          1003
# Telomerase                                                 Costunolide                                     1093
# Tie-2                                                      Tie2 kinase inhibitor                           1136
# Topoisomerase                                              Ellagic acid                                     925
#                                                            Ofloxacin                                       1124
#                                                            Pirarubicin                                      814
# VEGFR                                                      Cediranib (AZD2171)                              970
#                                                            Vandetanib (ZD6474)                              812
# VEGFR,PDGFR,c-Kit                                          Motesanib Diphosphate (AMG-706)                 1034
# Vehicle                                                    Vehicle                                         3912
# Wnt/beta-catenin                                           XAV-939                                          933
# c-Kit,PDGFR,VEGFR                                          Ki8751                                           888
# c-Met,IGF-1R,Trk receptor                                  BMS-754807                                      1022
# c-Met,Tie-2,VEGFR                                          Glesatinib?(MGCD265)                             953
# c-RET,FLT3,JAK                                             TG101209                                         808
# c-RET,VEGFR                                                Regorafenib (BAY 73-4506)                        801
# mTOR                                                       Temsirolimus (CCI-779, NSC 683864)               796
# dtype: int64

# %%
adata_ct.obs.drop_duplicates(['target', 'product_name']).groupby(['target']).product_name.count()
# Out:
# target
# ALK,c-Met                                                     1
# AMPK                                                          1
# Androgen Receptor                                             1
# Aromatase                                                     1
# Aurora Kinase                                                13
# Aurora Kinase,Bcr-Abl,FLT3                                    1
# Aurora Kinase,Bcr-Abl,JAK                                     1
# Aurora Kinase,Bcr-Abl,c-RET,FGFR                              1
# Aurora Kinase,CDK                                             1
# Aurora Kinase,FLT3,VEGFR                                      2
# Aurora Kinase,VEGFR                                           1
# Autophagy,ROCK                                                1
# Autophagy,Sirtuin                                             1
# Bcl-2                                                         3
# Bcr-Abl                                                       1
# Bcr-Abl,c-Kit,Src                                             1
# Beta Amyloid,Gamma-secretase                                  2
# CCR                                                           1
# CDK                                                           3
# COX                                                           1
# CSF-1R,PDGFR,VEGFR                                            1
# DNA Methyltransferase                                         3
# DNA alkylator                                                 3
# DNA/RNA Synthesis                                             8
# Dehydrogenase                                                 1
# Dopamine Receptor                                             1
# E3 Ligase ,TNF-alpha                                          1
# E3 Ligase ,p53                                                1
# EGFR                                                          2
# EGFR,HDAC,HER2                                                1
# EGFR,HER2                                                     2
# EGFR,JAK                                                      1
# Epigenetic Reader Domain                                      3
# Estrogen/progestogen Receptor                                 2
# FAAH                                                          1
# FAK                                                           1
# FGFR,PDGFR,VEGFR                                              1
# FGFR,VEGFR                                                    1
# GABA Receptor,HDAC,Autophagy                                  1
# Glucocorticoid Receptor                                       2
# Glucocorticoid Receptor,Immunology & Inflammation related     1
# HDAC                                                         23
# HDAC,PI3K                                                     1
# HIF                                                           3
# HSP (e.g. HSP90)                                              3
# Histamine Receptor                                            1
# Histone Acetyltransferase                                     1
# Histone Demethylase                                           2
# Histone Methyltransferase                                     7
# IDH1                                                          1
# IGF-1R                                                        1
# JAK                                                          16
# LPA Receptor                                                  1
# Lipoxygenase                                                  1
# MAO                                                           1
# MEK                                                           3
# MT Receptor                                                   1
# Microtubule Associated                                        2
# NF-κB,HDAC,Histone Acetyltransferase,Nrf2                     1
# Others                                                        3
# PARP                                                          7
# PDGFR,Raf,VEGFR                                               1
# PI3K                                                          1
# PKA,EGFR,PKC                                                  1
# PKC                                                           2
# PLK                                                           1
# Pim                                                           1
# STAT                                                          1
# Sirtuin                                                       5
# Src                                                           1
# Src,Sirtuin,PKC,PI3K                                          1
# Survivin                                                      1
# TGF-beta/Smad                                                 1
# TNF-alpha                                                     1
# Telomerase                                                    1
# Tie-2                                                         1
# Topoisomerase                                                 3
# VEGFR                                                         2
# VEGFR,PDGFR,c-Kit                                             1
# Vehicle                                                       1
# Wnt/beta-catenin                                              1
# c-Kit,PDGFR,VEGFR                                             1
# c-Met,IGF-1R,Trk receptor                                     1
# c-Met,Tie-2,VEGFR                                             1
# c-RET,FLT3,JAK                                                1
# c-RET,VEGFR                                                   1
# mTOR                                                          1
# Name: product_name, dtype: int64

# %%
adata_ct.obs.groupby(['target']).product_name.value_counts()
# Out:
# target                     product_name
# ALK,c-Met                  Crizotinib (PF-02341066)               753
# AMPK                       AICAR (Acadesine)                     1055
# Androgen Receptor          Andarine                              1019
# Aromatase                  Aminoglutethimide                     1119
# Aurora Kinase              Aurora A Inhibitor I                   954
#                                                                  ...
# c-Met,IGF-1R,Trk receptor  BMS-754807                            1022
# c-Met,Tie-2,VEGFR          Glesatinib?(MGCD265)                   953
# c-RET,FLT3,JAK             TG101209                               808
# c-RET,VEGFR                Regorafenib (BAY 73-4506)              801
# mTOR                       Temsirolimus (CCI-779, NSC 683864)     796
# Name: product_name, Length: 189, dtype: int64

# %% [markdown]
# ### Create pseudotime for each of the cell types for HDAC inhibitors
#
# LOLOL Use UMAP1 as pseudodose....

# %%
ct = 'A549'

# %%
adata = sc.read(data_path + 'h5ad/{}_HDAC.h5ad'.format(ct))

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
adata.raw = adata
adata = adata[:, adata.var.highly_variable]

# %%
adata.uns['iroot'] = np.flatnonzero(adata.obs['vehicle']  == True)[0]

# %%
sc.pp.neighbors(adata, n_neighbors=500, n_pcs=20)
sc.tl.umap(adata)
sc.tl.diffmap(adata)

# %%
adata.obs.head(5)

# %%
adata.obs['is_vehicle'] = adata.obs.vehicle.apply(lambda x: 'vehicle' if x else 'HDAC').astype('category')

# %%
adata.obs['sample'].value_counts()

# %%
adata.obs['pseudodose'] = adata.obsm['X_umap'][:, 1]

# %%
plt.figure(figsize=(3,4))
sns.boxplot(y='pseudodose', x='dose', data=adata.obs)

# %%
max_dose_df = adata.obs.query('dose > 9000')

# %%
max_dose_df.pseudodose.min()

# %%
doses = adata.obs.dose.value_counts()

# %%
for drug in max_dose_df.product_name.drop_duplicates():
    
    plt.figure()
    for dose in [0, 10, 100, 1000, 10000]:
        sns.kdeplot(adata.obs.query('product_name == "{}" & dose == {}'.format(drug, dose)).pseudodose)
    plt.xlim(-8, 8)
    plt.title(drug)
