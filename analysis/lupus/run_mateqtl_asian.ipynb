# %% [markdown]
# # Matrix eQTL

# %%
library("MatrixEQTL");

# %%
base.dir = '/data_volume/memento/lupus/full_analysis/mateqtl/inputs/'

# %%
pop <- 'asian'

# %%
useModel = modelLINEAR; # modelANOVA, modelLINEAR, or modelLINEAR_CROSS
SNP_file_name = paste(base.dir, pop, '_genos.tsv', sep="");
snps_location_file_name = paste(base.dir, pop, "_snpspos.txt", sep="");
covariates_file_name = paste(base.dir,  pop, '_mateqtl_cov.txt', sep="");
pvOutputThreshold_cis = 1;
errorCovariance = numeric();
cisDist = 100000;

gene_location_file_name = paste(base.dir, "geneloc_tss_hg19.txt", sep="");


## Load genotype data

snps = SlicedData$new();
snps$fileDelimiter = "\t";      # the TAB character
snps$fileOmitCharacters = "NA"; # denote missing values;
snps$fileSkipRows = 1;          # one row of column labels
snps$fileSkipColumns = 1;       # one column of row labels
snps$fileSliceSize = 100000;      # read file in slices of 2,000 rows
snps$LoadFile(SNP_file_name);


## Load covariates

cvrt = SlicedData$new();
cvrt$fileDelimiter = "\t";      # the TAB character
cvrt$fileOmitCharacters = "NA"; # denote missing values;
cvrt$fileSkipRows = 1;          # one row of column labels
cvrt$fileSkipColumns = 1;       # one column of row labels
if(length(covariates_file_name)>0) {
cvrt$LoadFile(covariates_file_name);
}
# Out:
# Rows read: 100,000
#
# Rows read: 200,000
#
# Rows read: 300,000
#
# Rows read: 400,000
#
# Rows read: 500,000
#
# Rows read: 600,000
#
# Rows read: 700,000
#
# Rows read: 800,000
#
# Rows read: 900,000
#
# Rows read: 1,000,000
#
# Rows read: 1,100,000
#
# Rows read: 1,200,000
#
# Rows read: 1,300,000
#
# Rows read: 1,400,000
#
# Rows read: 1,500,000
#
# Rows read: 1,600,000
#
# Rows read: 1,700,000
#
# Rows read: 1,800,000
#
# Rows read: 1,900,000
#
# Rows read: 2,000,000
#
# Rows read: 2,100,000
#
# Rows read: 2,200,000
#
# Rows read: 2,300,000
#
# Rows read: 2,400,000
#
# Rows read: 2,500,000
#
# Rows read: 2,600,000
#
# Rows read: 2,700,000
#
# Rows read: 2,800,000
#
# Rows read: 2,900,000
#
# Rows read: 3,000,000
#
# Rows read: 3,100,000
#
# Rows read: 3,200,000
#
# Rows read: 3285470 done.
#
# Rows read: 35 done.

# %%
snpspos = read.table(snps_location_file_name, header = TRUE, stringsAsFactors = FALSE);
genepos = read.table(gene_location_file_name, header = TRUE, stringsAsFactors = FALSE, sep='\t');

for (ct in c('T8', 'T4', 'NK', 'ncM', 'cM', 'B')){
# for (ct in c('B')){


    expression_file_name = paste(base.dir, "../pseudobulk/", pop, '_', ct, '.csv',sep="");
    output_file_name = paste(base.dir, "../outputs/", pop, '_', ct, '_all_hg19.csv', sep="");
    ## Load gene expression data

    gene = SlicedData$new();
    gene$fileDelimiter = "\t";      # the TAB character
    gene$fileOmitCharacters = "NA"; # denote missing values;
    gene$fileSkipRows = 1;          # one row of column labels
    gene$fileSkipColumns = 1;       # one column of row labels
    gene$fileSliceSize = 2000;      # read file in slices of 2,000 rows
    gene$LoadFile(expression_file_name);


    me = Matrix_eQTL_main(
        snps = snps,
        gene = gene,
        cvrt = cvrt,
#         output_file_name     = output_file_name,
#         pvOutputThreshold     = pvOutputThreshold,
        useModel = useModel,
        errorCovariance = errorCovariance,
        verbose = FALSE,
        output_file_name.cis = output_file_name,
        pvOutputThreshold.cis = pvOutputThreshold_cis,
        snpspos = snpspos,
        genepos = genepos,
        cisDist = cisDist,
        pvalue.hist = "qqplot",
        min.pv.by.genesnp = FALSE,
        noFDRsaveMemory = FALSE);
    
    }
# Out:
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7531 done.
#
# 7531 of 7531 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 40,622 cis-eQTLs, 2,780 trans-eQTLs
#
#  1.51% done, 6,003 trans-eQTLs
#
#  2.27% done, 9,949 trans-eQTLs
#
#  3.03% done, 12,110 trans-eQTLs
#
#  3.78% done, 102,495 cis-eQTLs, 14,197 trans-eQTLs
#
#  4.54% done, 16,099 trans-eQTLs
#
#  5.30% done, 18,420 trans-eQTLs
#
#  6.06% done, 19,972 trans-eQTLs
#
#  6.81% done, 164,339 cis-eQTLs, 24,562 trans-eQTLs
#
#  7.57% done, 29,099 trans-eQTLs
#
#  8.33% done, 32,208 trans-eQTLs
#
#  9.09% done, 36,089 trans-eQTLs
#
#  9.84% done, 209,051 cis-eQTLs, 38,931 trans-eQTLs
#
# 10.60% done, 41,076 trans-eQTLs
#
# 11.36% done, 43,724 trans-eQTLs
#
# 12.12% done, 45,724 trans-eQTLs
#
# 12.87% done, 281,226 cis-eQTLs, 48,017 trans-eQTLs
#
# 13.63% done, 49,639 trans-eQTLs
#
# 14.39% done, 51,576 trans-eQTLs
#
# 15.15% done, 52,555 trans-eQTLs
#
# 15.90% done, 326,690 cis-eQTLs, 53,936 trans-eQTLs
#
# 16.66% done, 55,312 trans-eQTLs
#
# 17.42% done, 56,864 trans-eQTLs
#
# 18.18% done, 57,759 trans-eQTLs
#
# 18.93% done, 350,224 cis-eQTLs, 59,551 trans-eQTLs
#
# 19.69% done, 61,455 trans-eQTLs
#
# 20.45% done, 63,364 trans-eQTLs
#
# 21.21% done, 64,858 trans-eQTLs
#
# 21.96% done, 382,858 cis-eQTLs, 67,116 trans-eQTLs
#
# 22.72% done, 69,248 trans-eQTLs
#
# 23.48% done, 71,184 trans-eQTLs
#
# 24.24% done, 72,833 trans-eQTLs
#
# 25.00% done, 425,619 cis-eQTLs, 74,758 trans-eQTLs
#
# 25.75% done, 76,621 trans-eQTLs
#
# 26.51% done, 78,500 trans-eQTLs
#
# 27.27% done, 79,997 trans-eQTLs
#
# 28.03% done, 461,611 cis-eQTLs, 81,804 trans-eQTLs
#
# 28.78% done, 83,943 trans-eQTLs
#
# 29.54% done, 85,843 trans-eQTLs
#
# 30.30% done, 86,842 trans-eQTLs
#
# 31.06% done, 499,540 cis-eQTLs, 89,376 trans-eQTLs
#
# 31.81% done, 528,460 cis-eQTLs, 92,150 trans-eQTLs
#
# 32.57% done, 94,329 trans-eQTLs
#
# 33.33% done, 96,282 trans-eQTLs
#
# 34.09% done, 97,820 trans-eQTLs
#
# 34.84% done, 588,346 cis-eQTLs, 99,603 trans-eQTLs
#
# 35.60% done, 101,177 trans-eQTLs
#
# 36.36% done, 102,444 trans-eQTLs
#
# 37.12% done, 103,883 trans-eQTLs
#
# 37.87% done, 653,436 cis-eQTLs, 105,225 trans-eQTLs
#
# 38.63% done, 106,846 trans-eQTLs
#
# 39.39% done, 107,943 trans-eQTLs
#
# 40.15% done, 109,378 trans-eQTLs
#
# 40.90% done, 723,709 cis-eQTLs, 111,169 trans-eQTLs
#
# 41.66% done, 113,118 trans-eQTLs
#
# 42.42% done, 114,276 trans-eQTLs
#
# 43.18% done, 116,603 trans-eQTLs
#
# 43.93% done, 816,633 cis-eQTLs, 118,410 trans-eQTLs
#
# 44.69% done, 120,306 trans-eQTLs
#
# 45.45% done, 121,565 trans-eQTLs
#
# 46.21% done, 123,304 trans-eQTLs
#
# 46.96% done, 875,516 cis-eQTLs, 125,455 trans-eQTLs
#
# 47.72% done, 127,426 trans-eQTLs
#
# 48.48% done, 128,959 trans-eQTLs
#
# 49.24% done, 130,310 trans-eQTLs
#
# 50.00% done, 923,762 cis-eQTLs, 131,656 trans-eQTLs
#
# 50.75% done, 133,316 trans-eQTLs
#
# 51.51% done, 134,323 trans-eQTLs
#
# 52.27% done, 135,771 trans-eQTLs
#
# 53.03% done, 943,364 cis-eQTLs, 137,306 trans-eQTLs
#
# 53.78% done, 956,481 cis-eQTLs, 139,022 trans-eQTLs
#
# 54.54% done, 139,972 trans-eQTLs
#
# 55.30% done, 142,962 trans-eQTLs
#
# 56.06% done, 146,785 trans-eQTLs
#
# 56.81% done, 1,014,766 cis-eQTLs, 149,069 trans-eQTLs
#
# 57.57% done, 151,927 trans-eQTLs
#
# 58.33% done, 153,757 trans-eQTLs
#
# 59.09% done, 155,200 trans-eQTLs
#
# 59.84% done, 1,075,174 cis-eQTLs, 156,646 trans-eQTLs
#
# 60.60% done, 157,616 trans-eQTLs
#
# 61.36% done, 159,108 trans-eQTLs
#
# 62.12% done, 160,586 trans-eQTLs
#
# 62.87% done, 1,138,207 cis-eQTLs, 162,479 trans-eQTLs
#
# 63.63% done, 163,410 trans-eQTLs
#
# 64.39% done, 165,282 trans-eQTLs
#
# 65.15% done, 167,013 trans-eQTLs
#
# 65.90% done, 1,179,711 cis-eQTLs, 168,470 trans-eQTLs
#
# 66.66% done, 169,661 trans-eQTLs
#
# 67.42% done, 171,809 trans-eQTLs
#
# 68.18% done, 175,600 trans-eQTLs
#
# 68.93% done, 1,211,159 cis-eQTLs, 178,574 trans-eQTLs
#
# 69.69% done, 180,843 trans-eQTLs
#
# 70.45% done, 182,077 trans-eQTLs
#
# 71.21% done, 183,693 trans-eQTLs
#
# 71.96% done, 1,251,290 cis-eQTLs, 185,196 trans-eQTLs
#
# 72.72% done, 186,128 trans-eQTLs
#
# 73.48% done, 188,441 trans-eQTLs
#
# 74.24% done, 190,235 trans-eQTLs
#
# 75.00% done, 1,311,304 cis-eQTLs, 192,119 trans-eQTLs
#
# 75.75% done, 193,179 trans-eQTLs
#
# 76.51% done, 197,091 trans-eQTLs
#
# 77.27% done, 200,400 trans-eQTLs
#
# 78.03% done, 1,343,056 cis-eQTLs, 203,243 trans-eQTLs
#
# 78.78% done, 205,586 trans-eQTLs
#
# 79.54% done, 208,199 trans-eQTLs
#
# 80.30% done, 210,501 trans-eQTLs
#
# 81.06% done, 1,366,410 cis-eQTLs, 212,924 trans-eQTLs
#
# 81.81% done, 214,999 trans-eQTLs
#
# 82.57% done, 216,736 trans-eQTLs
#
# 83.33% done, 218,798 trans-eQTLs
#
# 84.09% done, 1,399,944 cis-eQTLs, 220,495 trans-eQTLs
#
# 84.84% done, 222,121 trans-eQTLs
#
# 85.60% done, 223,813 trans-eQTLs
#
# 86.36% done, 225,759 trans-eQTLs
#
# 87.12% done, 1,431,279 cis-eQTLs, 227,975 trans-eQTLs
#
# 87.87% done, 1,532,125 cis-eQTLs, 229,370 trans-eQTLs
#
# 88.63% done, 231,079 trans-eQTLs
#
# 89.39% done, 233,010 trans-eQTLs
#
# 90.15% done, 234,702 trans-eQTLs
#
# 90.90% done, 1,618,632 cis-eQTLs, 236,480 trans-eQTLs
#
# 91.66% done, 238,222 trans-eQTLs
#
# 92.42% done, 240,136 trans-eQTLs
#
# 93.18% done, 241,721 trans-eQTLs
#
# 93.93% done, 1,667,774 cis-eQTLs, 243,394 trans-eQTLs
#
# 94.69% done, 245,353 trans-eQTLs
#
# 95.45% done, 247,101 trans-eQTLs
#
# 96.21% done, 249,600 trans-eQTLs
#
# 96.96% done, 1,726,220 cis-eQTLs, 251,346 trans-eQTLs
#
# 97.72% done, 253,809 trans-eQTLs
#
# 98.48% done, 255,442 trans-eQTLs
#
# 99.24% done, 257,424 trans-eQTLs
#
# 100.00% done, 1,810,826 cis-eQTLs, 259,006 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7382 done.
#
# 7382 of 7382 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 40,356 cis-eQTLs, 3,179 trans-eQTLs
#
#  1.51% done, 6,150 trans-eQTLs
#
#  2.27% done, 9,061 trans-eQTLs
#
#  3.03% done, 11,476 trans-eQTLs
#
#  3.78% done, 99,972 cis-eQTLs, 13,354 trans-eQTLs
#
#  4.54% done, 15,282 trans-eQTLs
#
#  5.30% done, 17,389 trans-eQTLs
#
#  6.06% done, 18,387 trans-eQTLs
#
#  6.81% done, 160,056 cis-eQTLs, 22,103 trans-eQTLs
#
#  7.57% done, 25,970 trans-eQTLs
#
#  8.33% done, 28,771 trans-eQTLs
#
#  9.09% done, 32,141 trans-eQTLs
#
#  9.84% done, 203,130 cis-eQTLs, 34,402 trans-eQTLs
#
# 10.60% done, 36,459 trans-eQTLs
#
# 11.36% done, 38,368 trans-eQTLs
#
# 12.12% done, 40,123 trans-eQTLs
#
# 12.87% done, 274,270 cis-eQTLs, 42,379 trans-eQTLs
#
# 13.63% done, 45,172 trans-eQTLs
#
# 14.39% done, 47,812 trans-eQTLs
#
# 15.15% done, 49,669 trans-eQTLs
#
# 15.90% done, 320,579 cis-eQTLs, 51,515 trans-eQTLs
#
# 16.66% done, 53,162 trans-eQTLs
#
# 17.42% done, 54,628 trans-eQTLs
#
# 18.18% done, 55,799 trans-eQTLs
#
# 18.93% done, 343,517 cis-eQTLs, 57,623 trans-eQTLs
#
# 19.69% done, 59,303 trans-eQTLs
#
# 20.45% done, 60,948 trans-eQTLs
#
# 21.21% done, 62,317 trans-eQTLs
#
# 21.96% done, 375,201 cis-eQTLs, 63,836 trans-eQTLs
#
# 22.72% done, 65,799 trans-eQTLs
#
# 23.48% done, 67,636 trans-eQTLs
#
# 24.24% done, 68,827 trans-eQTLs
#
# 25.00% done, 417,302 cis-eQTLs, 72,792 trans-eQTLs
#
# 25.75% done, 76,341 trans-eQTLs
#
# 26.51% done, 79,761 trans-eQTLs
#
# 27.27% done, 82,107 trans-eQTLs
#
# 28.03% done, 453,945 cis-eQTLs, 83,871 trans-eQTLs
#
# 28.78% done, 85,321 trans-eQTLs
#
# 29.54% done, 87,009 trans-eQTLs
#
# 30.30% done, 87,996 trans-eQTLs
#
# 31.06% done, 499,511 cis-eQTLs, 89,680 trans-eQTLs
#
# 31.81% done, 519,102 cis-eQTLs, 91,263 trans-eQTLs
#
# 32.57% done, 93,079 trans-eQTLs
#
# 33.33% done, 94,249 trans-eQTLs
#
# 34.09% done, 95,828 trans-eQTLs
#
# 34.84% done, 576,933 cis-eQTLs, 97,486 trans-eQTLs
#
# 35.60% done, 98,977 trans-eQTLs
#
# 36.36% done, 100,172 trans-eQTLs
#
# 37.12% done, 101,885 trans-eQTLs
#
# 37.87% done, 638,825 cis-eQTLs, 103,616 trans-eQTLs
#
# 38.63% done, 105,149 trans-eQTLs
#
# 39.39% done, 106,280 trans-eQTLs
#
# 40.15% done, 108,150 trans-eQTLs
#
# 40.90% done, 707,108 cis-eQTLs, 109,760 trans-eQTLs
#
# 41.66% done, 111,823 trans-eQTLs
#
# 42.42% done, 112,998 trans-eQTLs
#
# 43.18% done, 114,272 trans-eQTLs
#
# 43.93% done, 795,873 cis-eQTLs, 116,166 trans-eQTLs
#
# 44.69% done, 117,700 trans-eQTLs
#
# 45.45% done, 119,002 trans-eQTLs
#
# 46.21% done, 120,416 trans-eQTLs
#
# 46.96% done, 853,425 cis-eQTLs, 122,501 trans-eQTLs
#
# 47.72% done, 124,060 trans-eQTLs
#
# 48.48% done, 125,175 trans-eQTLs
#
# 49.24% done, 126,630 trans-eQTLs
#
# 50.00% done, 900,276 cis-eQTLs, 128,310 trans-eQTLs
#
# 50.75% done, 129,811 trans-eQTLs
#
# 51.51% done, 130,787 trans-eQTLs
#
# 52.27% done, 132,215 trans-eQTLs
#
# 53.03% done, 933,293 cis-eQTLs, 133,596 trans-eQTLs
#
# 53.78% done, 135,375 trans-eQTLs
#
# 54.54% done, 136,429 trans-eQTLs
#
# 55.30% done, 137,983 trans-eQTLs
#
# 56.06% done, 934,011 cis-eQTLs, 139,503 trans-eQTLs
#
# 56.81% done, 991,212 cis-eQTLs, 141,122 trans-eQTLs
#
# 57.57% done, 142,089 trans-eQTLs
#
# 58.33% done, 144,225 trans-eQTLs
#
# 59.09% done, 146,964 trans-eQTLs
#
# 59.84% done, 1,049,711 cis-eQTLs, 149,319 trans-eQTLs
#
# 60.60% done, 151,082 trans-eQTLs
#
# 61.36% done, 152,638 trans-eQTLs
#
# 62.12% done, 153,833 trans-eQTLs
#
# 62.87% done, 1,111,130 cis-eQTLs, 155,453 trans-eQTLs
#
# 63.63% done, 156,534 trans-eQTLs
#
# 64.39% done, 158,422 trans-eQTLs
#
# 65.15% done, 160,321 trans-eQTLs
#
# 65.90% done, 1,152,852 cis-eQTLs, 161,865 trans-eQTLs
#
# 66.66% done, 163,062 trans-eQTLs
#
# 67.42% done, 165,359 trans-eQTLs
#
# 68.18% done, 167,224 trans-eQTLs
#
# 68.93% done, 1,184,254 cis-eQTLs, 169,200 trans-eQTLs
#
# 69.69% done, 170,654 trans-eQTLs
#
# 70.45% done, 172,277 trans-eQTLs
#
# 71.21% done, 173,779 trans-eQTLs
#
# 71.96% done, 1,221,996 cis-eQTLs, 175,527 trans-eQTLs
#
# 72.72% done, 176,437 trans-eQTLs
#
# 73.48% done, 178,244 trans-eQTLs
#
# 74.24% done, 180,300 trans-eQTLs
#
# 75.00% done, 1,280,122 cis-eQTLs, 182,011 trans-eQTLs
#
# 75.75% done, 183,426 trans-eQTLs
#
# 76.51% done, 186,496 trans-eQTLs
#
# 77.27% done, 189,654 trans-eQTLs
#
# 78.03% done, 1,310,865 cis-eQTLs, 192,588 trans-eQTLs
#
# 78.78% done, 195,402 trans-eQTLs
#
# 79.54% done, 198,161 trans-eQTLs
#
# 80.30% done, 200,459 trans-eQTLs
#
# 81.06% done, 1,333,396 cis-eQTLs, 202,693 trans-eQTLs
#
# 81.81% done, 203,995 trans-eQTLs
#
# 82.57% done, 205,617 trans-eQTLs
#
# 83.33% done, 207,027 trans-eQTLs
#
# 84.09% done, 1,365,969 cis-eQTLs, 208,932 trans-eQTLs
#
# 84.84% done, 210,260 trans-eQTLs
#
# 85.60% done, 212,491 trans-eQTLs
#
# 86.36% done, 214,505 trans-eQTLs
#
# 87.12% done, 1,430,715 cis-eQTLs, 216,729 trans-eQTLs
#
# 87.87% done, 1,494,988 cis-eQTLs, 218,366 trans-eQTLs
#
# 88.63% done, 219,960 trans-eQTLs
#
# 89.39% done, 221,358 trans-eQTLs
#
# 90.15% done, 223,356 trans-eQTLs
#
# 90.90% done, 1,579,045 cis-eQTLs, 224,552 trans-eQTLs
#
# 91.66% done, 227,007 trans-eQTLs
#
# 92.42% done, 229,076 trans-eQTLs
#
# 93.18% done, 230,783 trans-eQTLs
#
# 93.93% done, 1,627,465 cis-eQTLs, 232,280 trans-eQTLs
#
# 94.69% done, 233,924 trans-eQTLs
#
# 95.45% done, 235,335 trans-eQTLs
#
# 96.21% done, 236,796 trans-eQTLs
#
# 96.96% done, 1,686,148 cis-eQTLs, 238,068 trans-eQTLs
#
# 97.72% done, 240,172 trans-eQTLs
#
# 98.48% done, 242,774 trans-eQTLs
#
# 99.24% done, 245,407 trans-eQTLs
#
# 100.00% done, 1,770,056 cis-eQTLs, 246,857 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7945 done.
#
# 7945 of 7945 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 45,477 cis-eQTLs, 2,166 trans-eQTLs
#
#  1.51% done, 4,104 trans-eQTLs
#
#  2.27% done, 6,028 trans-eQTLs
#
#  3.03% done, 8,192 trans-eQTLs
#
#  3.78% done, 108,394 cis-eQTLs, 11,385 trans-eQTLs
#
#  4.54% done, 15,779 trans-eQTLs
#
#  5.30% done, 19,337 trans-eQTLs
#
#  6.06% done, 23,148 trans-eQTLs
#
#  6.81% done, 173,436 cis-eQTLs, 26,006 trans-eQTLs
#
#  7.57% done, 29,203 trans-eQTLs
#
#  8.33% done, 31,997 trans-eQTLs
#
#  9.09% done, 34,805 trans-eQTLs
#
#  9.84% done, 220,449 cis-eQTLs, 36,968 trans-eQTLs
#
# 10.60% done, 39,342 trans-eQTLs
#
# 11.36% done, 41,939 trans-eQTLs
#
# 12.12% done, 44,019 trans-eQTLs
#
# 12.87% done, 295,485 cis-eQTLs, 45,595 trans-eQTLs
#
# 13.63% done, 47,240 trans-eQTLs
#
# 14.39% done, 49,489 trans-eQTLs
#
# 15.15% done, 51,511 trans-eQTLs
#
# 15.90% done, 342,935 cis-eQTLs, 53,847 trans-eQTLs
#
# 16.66% done, 55,884 trans-eQTLs
#
# 17.42% done, 58,317 trans-eQTLs
#
# 18.18% done, 60,550 trans-eQTLs
#
# 18.93% done, 367,927 cis-eQTLs, 63,919 trans-eQTLs
#
# 19.69% done, 67,257 trans-eQTLs
#
# 20.45% done, 71,468 trans-eQTLs
#
# 21.21% done, 75,062 trans-eQTLs
#
# 21.96% done, 404,030 cis-eQTLs, 77,427 trans-eQTLs
#
# 22.72% done, 79,339 trans-eQTLs
#
# 23.48% done, 81,138 trans-eQTLs
#
# 24.24% done, 83,096 trans-eQTLs
#
# 25.00% done, 447,547 cis-eQTLs, 85,645 trans-eQTLs
#
# 25.75% done, 88,241 trans-eQTLs
#
# 26.51% done, 90,609 trans-eQTLs
#
# 27.27% done, 93,440 trans-eQTLs
#
# 28.03% done, 485,501 cis-eQTLs, 95,523 trans-eQTLs
#
# 28.78% done, 97,581 trans-eQTLs
#
# 29.54% done, 99,996 trans-eQTLs
#
# 30.30% done, 102,322 trans-eQTLs
#
# 31.06% done, 499,360 cis-eQTLs, 105,811 trans-eQTLs
#
# 31.81% done, 556,506 cis-eQTLs, 109,094 trans-eQTLs
#
# 32.57% done, 113,298 trans-eQTLs
#
# 33.33% done, 116,775 trans-eQTLs
#
# 34.09% done, 118,983 trans-eQTLs
#
# 34.84% done, 619,114 cis-eQTLs, 121,134 trans-eQTLs
#
# 35.60% done, 123,139 trans-eQTLs
#
# 36.36% done, 124,996 trans-eQTLs
#
# 37.12% done, 126,514 trans-eQTLs
#
# 37.87% done, 689,764 cis-eQTLs, 128,169 trans-eQTLs
#
# 38.63% done, 129,560 trans-eQTLs
#
# 39.39% done, 130,810 trans-eQTLs
#
# 40.15% done, 132,802 trans-eQTLs
#
# 40.90% done, 762,948 cis-eQTLs, 134,440 trans-eQTLs
#
# 41.66% done, 136,568 trans-eQTLs
#
# 42.42% done, 138,578 trans-eQTLs
#
# 43.18% done, 140,712 trans-eQTLs
#
# 43.93% done, 858,661 cis-eQTLs, 142,701 trans-eQTLs
#
# 44.69% done, 144,760 trans-eQTLs
#
# 45.45% done, 146,697 trans-eQTLs
#
# 46.21% done, 148,627 trans-eQTLs
#
# 46.96% done, 922,392 cis-eQTLs, 150,830 trans-eQTLs
#
# 47.72% done, 153,313 trans-eQTLs
#
# 48.48% done, 155,125 trans-eQTLs
#
# 49.24% done, 157,288 trans-eQTLs
#
# 50.00% done, 936,901 cis-eQTLs, 159,747 trans-eQTLs
#
# 50.75% done, 972,659 cis-eQTLs, 162,196 trans-eQTLs
#
# 51.51% done, 164,401 trans-eQTLs
#
# 52.27% done, 166,445 trans-eQTLs
#
# 53.03% done, 168,852 trans-eQTLs
#
# 53.78% done, 1,005,032 cis-eQTLs, 170,832 trans-eQTLs
#
# 54.54% done, 172,837 trans-eQTLs
#
# 55.30% done, 174,334 trans-eQTLs
#
# 56.06% done, 175,684 trans-eQTLs
#
# 56.81% done, 1,065,256 cis-eQTLs, 177,220 trans-eQTLs
#
# 57.57% done, 179,073 trans-eQTLs
#
# 58.33% done, 181,438 trans-eQTLs
#
# 59.09% done, 183,656 trans-eQTLs
#
# 59.84% done, 1,130,596 cis-eQTLs, 185,685 trans-eQTLs
#
# 60.60% done, 187,722 trans-eQTLs
#
# 61.36% done, 189,535 trans-eQTLs
#
# 62.12% done, 191,465 trans-eQTLs
#
# 62.87% done, 1,196,430 cis-eQTLs, 193,317 trans-eQTLs
#
# 63.63% done, 195,055 trans-eQTLs
#
# 64.39% done, 197,080 trans-eQTLs
#
# 65.15% done, 199,220 trans-eQTLs
#
# 65.90% done, 1,238,366 cis-eQTLs, 201,240 trans-eQTLs
#
# 66.66% done, 203,048 trans-eQTLs
#
# 67.42% done, 205,364 trans-eQTLs
#
# 68.18% done, 207,878 trans-eQTLs
#
# 68.93% done, 1,273,401 cis-eQTLs, 210,381 trans-eQTLs
#
# 69.69% done, 212,923 trans-eQTLs
#
# 70.45% done, 214,716 trans-eQTLs
#
# 71.21% done, 216,729 trans-eQTLs
#
# 71.96% done, 1,316,479 cis-eQTLs, 218,400 trans-eQTLs
#
# 72.72% done, 219,983 trans-eQTLs
#
# 73.48% done, 222,147 trans-eQTLs
#
# 74.24% done, 225,026 trans-eQTLs
#
# 75.00% done, 1,380,196 cis-eQTLs, 227,237 trans-eQTLs
#
# 75.75% done, 229,435 trans-eQTLs
#
# 76.51% done, 232,519 trans-eQTLs
#
# 77.27% done, 235,504 trans-eQTLs
#
# 78.03% done, 1,415,337 cis-eQTLs, 237,649 trans-eQTLs
#
# 78.78% done, 240,230 trans-eQTLs
#
# 79.54% done, 242,535 trans-eQTLs
#
# 80.30% done, 244,597 trans-eQTLs
#
# 81.06% done, 1,434,637 cis-eQTLs, 246,795 trans-eQTLs
#
# 81.81% done, 1,439,740 cis-eQTLs, 248,618 trans-eQTLs
#
# 82.57% done, 250,526 trans-eQTLs
#
# 83.33% done, 252,497 trans-eQTLs
#
# 84.09% done, 254,581 trans-eQTLs
#
# 84.84% done, 1,475,930 cis-eQTLs, 256,849 trans-eQTLs
#
# 85.60% done, 258,918 trans-eQTLs
#
# 86.36% done, 260,931 trans-eQTLs
#
# 87.12% done, 263,134 trans-eQTLs
#
# 87.87% done, 1,614,958 cis-eQTLs, 264,995 trans-eQTLs
#
# 88.63% done, 266,947 trans-eQTLs
#
# 89.39% done, 268,898 trans-eQTLs
#
# 90.15% done, 270,955 trans-eQTLs
#
# 90.90% done, 1,710,418 cis-eQTLs, 272,513 trans-eQTLs
#
# 91.66% done, 274,420 trans-eQTLs
#
# 92.42% done, 276,107 trans-eQTLs
#
# 93.18% done, 277,950 trans-eQTLs
#
# 93.93% done, 1,760,597 cis-eQTLs, 279,694 trans-eQTLs
#
# 94.69% done, 282,119 trans-eQTLs
#
# 95.45% done, 284,334 trans-eQTLs
#
# 96.21% done, 286,682 trans-eQTLs
#
# 96.96% done, 1,824,111 cis-eQTLs, 288,812 trans-eQTLs
#
# 97.72% done, 290,537 trans-eQTLs
#
# 98.48% done, 291,766 trans-eQTLs
#
# 99.24% done, 293,505 trans-eQTLs
#
# 100.00% done, 1,915,313 cis-eQTLs, 295,272 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 8,000
#
# Rows read: 8735 done.
#
# 8735 of 8735 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.60% done, 50,091 cis-eQTLs, 2,605 trans-eQTLs
#
#  1.21% done, 4,292 trans-eQTLs
#
#  1.81% done, 6,574 trans-eQTLs
#
#  2.42% done, 8,631 trans-eQTLs
#
#  3.03% done, 9,260 trans-eQTLs
#
#  3.63% done, 119,903 cis-eQTLs, 11,245 trans-eQTLs
#
#  4.24% done, 13,863 trans-eQTLs
#
#  4.84% done, 15,977 trans-eQTLs
#
#  5.45% done, 18,704 trans-eQTLs
#
#  6.06% done, 19,414 trans-eQTLs
#
#  6.66% done, 191,493 cis-eQTLs, 21,358 trans-eQTLs
#
#  7.27% done, 23,606 trans-eQTLs
#
#  7.87% done, 25,538 trans-eQTLs
#
#  8.48% done, 27,095 trans-eQTLs
#
#  9.09% done, 27,914 trans-eQTLs
#
#  9.69% done, 245,051 cis-eQTLs, 30,373 trans-eQTLs
#
# 10.30% done, 32,570 trans-eQTLs
#
# 10.90% done, 34,839 trans-eQTLs
#
# 11.51% done, 37,307 trans-eQTLs
#
# 12.12% done, 38,567 trans-eQTLs
#
# 12.72% done, 327,818 cis-eQTLs, 40,476 trans-eQTLs
#
# 13.33% done, 42,041 trans-eQTLs
#
# 13.93% done, 43,902 trans-eQTLs
#
# 14.54% done, 45,750 trans-eQTLs
#
# 15.15% done, 46,652 trans-eQTLs
#
# 15.75% done, 379,984 cis-eQTLs, 48,767 trans-eQTLs
#
# 16.36% done, 50,561 trans-eQTLs
#
# 16.96% done, 52,323 trans-eQTLs
#
# 17.57% done, 54,111 trans-eQTLs
#
# 18.18% done, 54,802 trans-eQTLs
#
# 18.78% done, 407,756 cis-eQTLs, 56,704 trans-eQTLs
#
# 19.39% done, 58,681 trans-eQTLs
#
# 20.00% done, 60,393 trans-eQTLs
#
# 20.60% done, 62,835 trans-eQTLs
#
# 21.21% done, 63,719 trans-eQTLs
#
# 21.81% done, 443,796 cis-eQTLs, 65,801 trans-eQTLs
#
# 22.42% done, 67,936 trans-eQTLs
#
# 23.03% done, 70,093 trans-eQTLs
#
# 23.63% done, 72,353 trans-eQTLs
#
# 24.24% done, 73,094 trans-eQTLs
#
# 24.84% done, 492,666 cis-eQTLs, 75,028 trans-eQTLs
#
# 25.45% done, 76,774 trans-eQTLs
#
# 26.06% done, 78,744 trans-eQTLs
#
# 26.66% done, 80,336 trans-eQTLs
#
# 27.27% done, 80,978 trans-eQTLs
#
# 27.87% done, 502,782 cis-eQTLs, 82,375 trans-eQTLs
#
# 28.48% done, 533,753 cis-eQTLs, 84,815 trans-eQTLs
#
# 29.09% done, 86,783 trans-eQTLs
#
# 29.69% done, 88,692 trans-eQTLs
#
# 30.30% done, 89,212 trans-eQTLs
#
# 30.90% done, 91,219 trans-eQTLs
#
# 31.51% done, 610,003 cis-eQTLs, 93,783 trans-eQTLs
#
# 32.12% done, 95,926 trans-eQTLs
#
# 32.72% done, 98,371 trans-eQTLs
#
# 33.33% done, 99,136 trans-eQTLs
#
# 33.93% done, 101,474 trans-eQTLs
#
# 34.54% done, 677,325 cis-eQTLs, 103,554 trans-eQTLs
#
# 35.15% done, 105,526 trans-eQTLs
#
# 35.75% done, 107,348 trans-eQTLs
#
# 36.36% done, 108,051 trans-eQTLs
#
# 36.96% done, 110,032 trans-eQTLs
#
# 37.57% done, 753,120 cis-eQTLs, 111,961 trans-eQTLs
#
# 38.18% done, 113,850 trans-eQTLs
#
# 38.78% done, 115,671 trans-eQTLs
#
# 39.39% done, 116,316 trans-eQTLs
#
# 40.00% done, 119,167 trans-eQTLs
#
# 40.60% done, 832,362 cis-eQTLs, 121,084 trans-eQTLs
#
# 41.21% done, 123,481 trans-eQTLs
#
# 41.81% done, 125,643 trans-eQTLs
#
# 42.42% done, 126,799 trans-eQTLs
#
# 43.03% done, 128,573 trans-eQTLs
#
# 43.63% done, 931,726 cis-eQTLs, 130,269 trans-eQTLs
#
# 44.24% done, 941,614 cis-eQTLs, 132,720 trans-eQTLs
#
# 44.84% done, 134,652 trans-eQTLs
#
# 45.45% done, 135,414 trans-eQTLs
#
# 46.06% done, 137,570 trans-eQTLs
#
# 46.66% done, 139,349 trans-eQTLs
#
# 47.27% done, 1,013,027 cis-eQTLs, 141,184 trans-eQTLs
#
# 47.87% done, 143,099 trans-eQTLs
#
# 48.48% done, 143,760 trans-eQTLs
#
# 49.09% done, 145,757 trans-eQTLs
#
# 49.69% done, 147,789 trans-eQTLs
#
# 50.30% done, 1,072,014 cis-eQTLs, 150,261 trans-eQTLs
#
# 50.90% done, 152,005 trans-eQTLs
#
# 51.51% done, 152,794 trans-eQTLs
#
# 52.12% done, 155,162 trans-eQTLs
#
# 52.72% done, 157,375 trans-eQTLs
#
# 53.33% done, 1,108,295 cis-eQTLs, 159,264 trans-eQTLs
#
# 53.93% done, 161,349 trans-eQTLs
#
# 54.54% done, 161,999 trans-eQTLs
#
# 55.15% done, 164,163 trans-eQTLs
#
# 55.75% done, 166,412 trans-eQTLs
#
# 56.36% done, 1,178,607 cis-eQTLs, 169,222 trans-eQTLs
#
# 56.96% done, 171,718 trans-eQTLs
#
# 57.57% done, 172,656 trans-eQTLs
#
# 58.18% done, 174,913 trans-eQTLs
#
# 58.78% done, 177,034 trans-eQTLs
#
# 59.39% done, 1,248,583 cis-eQTLs, 178,705 trans-eQTLs
#
# 60.00% done, 180,487 trans-eQTLs
#
# 60.60% done, 181,071 trans-eQTLs
#
# 61.21% done, 183,130 trans-eQTLs
#
# 61.81% done, 185,462 trans-eQTLs
#
# 62.42% done, 1,319,835 cis-eQTLs, 187,459 trans-eQTLs
#
# 63.03% done, 189,173 trans-eQTLs
#
# 63.63% done, 189,990 trans-eQTLs
#
# 64.24% done, 192,137 trans-eQTLs
#
# 64.84% done, 194,099 trans-eQTLs
#
# 65.45% done, 1,367,881 cis-eQTLs, 195,771 trans-eQTLs
#
# 66.06% done, 197,484 trans-eQTLs
#
# 66.66% done, 198,102 trans-eQTLs
#
# 67.27% done, 200,265 trans-eQTLs
#
# 67.87% done, 202,329 trans-eQTLs
#
# 68.48% done, 1,405,239 cis-eQTLs, 204,347 trans-eQTLs
#
# 69.09% done, 205,970 trans-eQTLs
#
# 69.69% done, 206,591 trans-eQTLs
#
# 70.30% done, 208,264 trans-eQTLs
#
# 70.90% done, 210,013 trans-eQTLs
#
# 71.51% done, 1,432,052 cis-eQTLs, 211,343 trans-eQTLs
#
# 72.12% done, 1,446,880 cis-eQTLs, 213,326 trans-eQTLs
#
# 72.72% done, 214,148 trans-eQTLs
#
# 73.33% done, 216,270 trans-eQTLs
#
# 73.93% done, 218,230 trans-eQTLs
#
# 74.54% done, 220,735 trans-eQTLs
#
# 75.15% done, 1,513,555 cis-eQTLs, 222,537 trans-eQTLs
#
# 75.75% done, 223,218 trans-eQTLs
#
# 76.36% done, 225,502 trans-eQTLs
#
# 76.96% done, 227,762 trans-eQTLs
#
# 77.57% done, 229,951 trans-eQTLs
#
# 78.18% done, 1,550,051 cis-eQTLs, 232,335 trans-eQTLs
#
# 78.78% done, 233,299 trans-eQTLs
#
# 79.39% done, 235,089 trans-eQTLs
#
# 80.00% done, 237,394 trans-eQTLs
#
# 80.60% done, 239,268 trans-eQTLs
#
# 81.21% done, 1,574,097 cis-eQTLs, 240,979 trans-eQTLs
#
# 81.81% done, 241,620 trans-eQTLs
#
# 82.42% done, 243,561 trans-eQTLs
#
# 83.03% done, 245,647 trans-eQTLs
#
# 83.63% done, 247,437 trans-eQTLs
#
# 84.24% done, 1,614,624 cis-eQTLs, 249,293 trans-eQTLs
#
# 84.84% done, 249,968 trans-eQTLs
#
# 85.45% done, 251,973 trans-eQTLs
#
# 86.06% done, 254,043 trans-eQTLs
#
# 86.66% done, 255,858 trans-eQTLs
#
# 87.27% done, 1,772,263 cis-eQTLs, 257,717 trans-eQTLs
#
# 87.87% done, 258,582 trans-eQTLs
#
# 88.48% done, 260,469 trans-eQTLs
#
# 89.09% done, 262,455 trans-eQTLs
#
# 89.69% done, 264,136 trans-eQTLs
#
# 90.30% done, 1,879,995 cis-eQTLs, 265,989 trans-eQTLs
#
# 90.90% done, 266,771 trans-eQTLs
#
# 91.51% done, 268,569 trans-eQTLs
#
# 92.12% done, 270,670 trans-eQTLs
#
# 92.72% done, 272,615 trans-eQTLs
#
# 93.33% done, 1,927,385 cis-eQTLs, 274,415 trans-eQTLs
#
# 93.93% done, 1,936,334 cis-eQTLs, 275,275 trans-eQTLs
#
# 94.54% done, 277,089 trans-eQTLs
#
# 95.15% done, 278,481 trans-eQTLs
#
# 95.75% done, 280,292 trans-eQTLs
#
# 96.36% done, 282,189 trans-eQTLs
#
# 96.96% done, 2,011,280 cis-eQTLs, 282,850 trans-eQTLs
#
# 97.57% done, 284,337 trans-eQTLs
#
# 98.18% done, 286,289 trans-eQTLs
#
# 98.78% done, 287,986 trans-eQTLs
#
# 99.39% done, 289,391 trans-eQTLs
#
# 100.00% done, 2,110,706 cis-eQTLs, 290,160 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7933 done.
#
# 7933 of 7933 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 46,331 cis-eQTLs, 1,891 trans-eQTLs
#
#  1.51% done, 3,906 trans-eQTLs
#
#  2.27% done, 5,636 trans-eQTLs
#
#  3.03% done, 7,351 trans-eQTLs
#
#  3.78% done, 110,859 cis-eQTLs, 9,625 trans-eQTLs
#
#  4.54% done, 11,759 trans-eQTLs
#
#  5.30% done, 13,792 trans-eQTLs
#
#  6.06% done, 15,553 trans-eQTLs
#
#  6.81% done, 178,226 cis-eQTLs, 18,163 trans-eQTLs
#
#  7.57% done, 20,628 trans-eQTLs
#
#  8.33% done, 23,011 trans-eQTLs
#
#  9.09% done, 25,117 trans-eQTLs
#
#  9.84% done, 226,233 cis-eQTLs, 27,683 trans-eQTLs
#
# 10.60% done, 29,796 trans-eQTLs
#
# 11.36% done, 32,083 trans-eQTLs
#
# 12.12% done, 33,835 trans-eQTLs
#
# 12.87% done, 299,456 cis-eQTLs, 35,631 trans-eQTLs
#
# 13.63% done, 37,375 trans-eQTLs
#
# 14.39% done, 38,887 trans-eQTLs
#
# 15.15% done, 40,201 trans-eQTLs
#
# 15.90% done, 346,798 cis-eQTLs, 41,964 trans-eQTLs
#
# 16.66% done, 43,875 trans-eQTLs
#
# 17.42% done, 46,428 trans-eQTLs
#
# 18.18% done, 48,339 trans-eQTLs
#
# 18.93% done, 370,823 cis-eQTLs, 50,064 trans-eQTLs
#
# 19.69% done, 51,991 trans-eQTLs
#
# 20.45% done, 53,945 trans-eQTLs
#
# 21.21% done, 55,216 trans-eQTLs
#
# 21.96% done, 407,505 cis-eQTLs, 57,092 trans-eQTLs
#
# 22.72% done, 58,926 trans-eQTLs
#
# 23.48% done, 60,974 trans-eQTLs
#
# 24.24% done, 62,778 trans-eQTLs
#
# 25.00% done, 452,275 cis-eQTLs, 64,977 trans-eQTLs
#
# 25.75% done, 66,811 trans-eQTLs
#
# 26.51% done, 68,685 trans-eQTLs
#
# 27.27% done, 70,565 trans-eQTLs
#
# 28.03% done, 490,679 cis-eQTLs, 72,492 trans-eQTLs
#
# 28.78% done, 73,978 trans-eQTLs
#
# 29.54% done, 75,521 trans-eQTLs
#
# 30.30% done, 76,691 trans-eQTLs
#
# 31.06% done, 503,296 cis-eQTLs, 79,427 trans-eQTLs
#
# 31.81% done, 560,236 cis-eQTLs, 81,895 trans-eQTLs
#
# 32.57% done, 84,395 trans-eQTLs
#
# 33.33% done, 86,367 trans-eQTLs
#
# 34.09% done, 88,518 trans-eQTLs
#
# 34.84% done, 621,671 cis-eQTLs, 90,227 trans-eQTLs
#
# 35.60% done, 92,248 trans-eQTLs
#
# 36.36% done, 93,961 trans-eQTLs
#
# 37.12% done, 96,081 trans-eQTLs
#
# 37.87% done, 689,007 cis-eQTLs, 98,320 trans-eQTLs
#
# 38.63% done, 100,842 trans-eQTLs
#
# 39.39% done, 102,603 trans-eQTLs
#
# 40.15% done, 104,647 trans-eQTLs
#
# 40.90% done, 761,162 cis-eQTLs, 106,436 trans-eQTLs
#
# 41.66% done, 107,939 trans-eQTLs
#
# 42.42% done, 109,308 trans-eQTLs
#
# 43.18% done, 110,890 trans-eQTLs
#
# 43.93% done, 857,169 cis-eQTLs, 112,694 trans-eQTLs
#
# 44.69% done, 114,386 trans-eQTLs
#
# 45.45% done, 115,744 trans-eQTLs
#
# 46.21% done, 117,252 trans-eQTLs
#
# 46.96% done, 923,025 cis-eQTLs, 118,902 trans-eQTLs
#
# 47.72% done, 120,249 trans-eQTLs
#
# 48.48% done, 121,923 trans-eQTLs
#
# 49.24% done, 123,611 trans-eQTLs
#
# 50.00% done, 941,056 cis-eQTLs, 125,924 trans-eQTLs
#
# 50.75% done, 977,355 cis-eQTLs, 127,913 trans-eQTLs
#
# 51.51% done, 129,946 trans-eQTLs
#
# 52.27% done, 131,457 trans-eQTLs
#
# 53.03% done, 133,027 trans-eQTLs
#
# 53.78% done, 1,010,687 cis-eQTLs, 134,282 trans-eQTLs
#
# 54.54% done, 136,193 trans-eQTLs
#
# 55.30% done, 137,433 trans-eQTLs
#
# 56.06% done, 139,035 trans-eQTLs
#
# 56.81% done, 1,071,133 cis-eQTLs, 141,000 trans-eQTLs
#
# 57.57% done, 142,677 trans-eQTLs
#
# 58.33% done, 144,377 trans-eQTLs
#
# 59.09% done, 146,035 trans-eQTLs
#
# 59.84% done, 1,135,433 cis-eQTLs, 148,268 trans-eQTLs
#
# 60.60% done, 150,003 trans-eQTLs
#
# 61.36% done, 151,981 trans-eQTLs
#
# 62.12% done, 153,818 trans-eQTLs
#
# 62.87% done, 1,201,477 cis-eQTLs, 156,059 trans-eQTLs
#
# 63.63% done, 157,877 trans-eQTLs
#
# 64.39% done, 159,246 trans-eQTLs
#
# 65.15% done, 160,641 trans-eQTLs
#
# 65.90% done, 1,245,989 cis-eQTLs, 162,327 trans-eQTLs
#
# 66.66% done, 163,907 trans-eQTLs
#
# 67.42% done, 165,453 trans-eQTLs
#
# 68.18% done, 167,318 trans-eQTLs
#
# 68.93% done, 1,281,073 cis-eQTLs, 169,073 trans-eQTLs
#
# 69.69% done, 170,872 trans-eQTLs
#
# 70.45% done, 172,335 trans-eQTLs
#
# 71.21% done, 174,128 trans-eQTLs
#
# 71.96% done, 1,322,183 cis-eQTLs, 175,772 trans-eQTLs
#
# 72.72% done, 177,469 trans-eQTLs
#
# 73.48% done, 179,044 trans-eQTLs
#
# 74.24% done, 180,387 trans-eQTLs
#
# 75.00% done, 1,384,253 cis-eQTLs, 182,273 trans-eQTLs
#
# 75.75% done, 183,833 trans-eQTLs
#
# 76.51% done, 186,395 trans-eQTLs
#
# 77.27% done, 188,983 trans-eQTLs
#
# 78.03% done, 1,419,528 cis-eQTLs, 191,143 trans-eQTLs
#
# 78.78% done, 193,089 trans-eQTLs
#
# 79.54% done, 195,524 trans-eQTLs
#
# 80.30% done, 197,275 trans-eQTLs
#
# 81.06% done, 1,438,513 cis-eQTLs, 199,237 trans-eQTLs
#
# 81.81% done, 1,442,551 cis-eQTLs, 201,059 trans-eQTLs
#
# 82.57% done, 202,423 trans-eQTLs
#
# 83.33% done, 203,907 trans-eQTLs
#
# 84.09% done, 205,702 trans-eQTLs
#
# 84.84% done, 1,480,209 cis-eQTLs, 207,396 trans-eQTLs
#
# 85.60% done, 209,013 trans-eQTLs
#
# 86.36% done, 211,352 trans-eQTLs
#
# 87.12% done, 212,985 trans-eQTLs
#
# 87.87% done, 1,621,004 cis-eQTLs, 214,760 trans-eQTLs
#
# 88.63% done, 216,736 trans-eQTLs
#
# 89.39% done, 218,402 trans-eQTLs
#
# 90.15% done, 219,868 trans-eQTLs
#
# 90.90% done, 1,711,905 cis-eQTLs, 221,733 trans-eQTLs
#
# 91.66% done, 223,785 trans-eQTLs
#
# 92.42% done, 226,077 trans-eQTLs
#
# 93.18% done, 228,031 trans-eQTLs
#
# 93.93% done, 1,764,838 cis-eQTLs, 230,148 trans-eQTLs
#
# 94.69% done, 231,952 trans-eQTLs
#
# 95.45% done, 233,657 trans-eQTLs
#
# 96.21% done, 235,658 trans-eQTLs
#
# 96.96% done, 1,834,265 cis-eQTLs, 237,377 trans-eQTLs
#
# 97.72% done, 239,143 trans-eQTLs
#
# 98.48% done, 241,118 trans-eQTLs
#
# 99.24% done, 242,912 trans-eQTLs
#
# 100.00% done, 1,923,487 cis-eQTLs, 244,847 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7519 done.
#
# 7519 of 7519 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 43,533 cis-eQTLs, 3,998 trans-eQTLs
#
#  1.51% done, 7,262 trans-eQTLs
#
#  2.27% done, 11,091 trans-eQTLs
#
#  3.03% done, 13,264 trans-eQTLs
#
#  3.78% done, 107,415 cis-eQTLs, 15,822 trans-eQTLs
#
#  4.54% done, 17,792 trans-eQTLs
#
#  5.30% done, 19,654 trans-eQTLs
#
#  6.06% done, 21,553 trans-eQTLs
#
#  6.81% done, 169,856 cis-eQTLs, 24,041 trans-eQTLs
#
#  7.57% done, 26,453 trans-eQTLs
#
#  8.33% done, 28,891 trans-eQTLs
#
#  9.09% done, 30,412 trans-eQTLs
#
#  9.84% done, 214,357 cis-eQTLs, 32,463 trans-eQTLs
#
# 10.60% done, 34,576 trans-eQTLs
#
# 11.36% done, 37,111 trans-eQTLs
#
# 12.12% done, 38,531 trans-eQTLs
#
# 12.87% done, 290,524 cis-eQTLs, 41,169 trans-eQTLs
#
# 13.63% done, 42,547 trans-eQTLs
#
# 14.39% done, 44,400 trans-eQTLs
#
# 15.15% done, 45,603 trans-eQTLs
#
# 15.90% done, 339,155 cis-eQTLs, 47,619 trans-eQTLs
#
# 16.66% done, 50,060 trans-eQTLs
#
# 17.42% done, 51,878 trans-eQTLs
#
# 18.18% done, 53,726 trans-eQTLs
#
# 18.93% done, 361,507 cis-eQTLs, 55,801 trans-eQTLs
#
# 19.69% done, 57,632 trans-eQTLs
#
# 20.45% done, 59,872 trans-eQTLs
#
# 21.21% done, 61,172 trans-eQTLs
#
# 21.96% done, 393,651 cis-eQTLs, 63,785 trans-eQTLs
#
# 22.72% done, 66,071 trans-eQTLs
#
# 23.48% done, 68,088 trans-eQTLs
#
# 24.24% done, 69,725 trans-eQTLs
#
# 25.00% done, 434,915 cis-eQTLs, 71,859 trans-eQTLs
#
# 25.75% done, 74,098 trans-eQTLs
#
# 26.51% done, 76,993 trans-eQTLs
#
# 27.27% done, 78,719 trans-eQTLs
#
# 28.03% done, 472,022 cis-eQTLs, 80,684 trans-eQTLs
#
# 28.78% done, 83,039 trans-eQTLs
#
# 29.54% done, 85,859 trans-eQTLs
#
# 30.30% done, 87,764 trans-eQTLs
#
# 31.06% done, 505,575 cis-eQTLs, 90,331 trans-eQTLs
#
# 31.81% done, 536,912 cis-eQTLs, 93,529 trans-eQTLs
#
# 32.57% done, 96,269 trans-eQTLs
#
# 33.33% done, 98,083 trans-eQTLs
#
# 34.09% done, 99,809 trans-eQTLs
#
# 34.84% done, 596,095 cis-eQTLs, 101,324 trans-eQTLs
#
# 35.60% done, 102,959 trans-eQTLs
#
# 36.36% done, 104,136 trans-eQTLs
#
# 37.12% done, 105,831 trans-eQTLs
#
# 37.87% done, 658,930 cis-eQTLs, 107,337 trans-eQTLs
#
# 38.63% done, 108,891 trans-eQTLs
#
# 39.39% done, 110,163 trans-eQTLs
#
# 40.15% done, 112,190 trans-eQTLs
#
# 40.90% done, 728,778 cis-eQTLs, 114,043 trans-eQTLs
#
# 41.66% done, 116,268 trans-eQTLs
#
# 42.42% done, 117,596 trans-eQTLs
#
# 43.18% done, 119,728 trans-eQTLs
#
# 43.93% done, 821,227 cis-eQTLs, 121,849 trans-eQTLs
#
# 44.69% done, 123,757 trans-eQTLs
#
# 45.45% done, 125,062 trans-eQTLs
#
# 46.21% done, 126,465 trans-eQTLs
#
# 46.96% done, 873,522 cis-eQTLs, 128,613 trans-eQTLs
#
# 47.72% done, 130,465 trans-eQTLs
#
# 48.48% done, 131,748 trans-eQTLs
#
# 49.24% done, 133,884 trans-eQTLs
#
# 50.00% done, 921,086 cis-eQTLs, 135,506 trans-eQTLs
#
# 50.75% done, 137,069 trans-eQTLs
#
# 51.51% done, 138,993 trans-eQTLs
#
# 52.27% done, 140,932 trans-eQTLs
#
# 53.03% done, 945,770 cis-eQTLs, 142,994 trans-eQTLs
#
# 53.78% done, 954,728 cis-eQTLs, 144,879 trans-eQTLs
#
# 54.54% done, 146,116 trans-eQTLs
#
# 55.30% done, 147,839 trans-eQTLs
#
# 56.06% done, 149,404 trans-eQTLs
#
# 56.81% done, 1,014,203 cis-eQTLs, 151,391 trans-eQTLs
#
# 57.57% done, 152,459 trans-eQTLs
#
# 58.33% done, 155,199 trans-eQTLs
#
# 59.09% done, 157,880 trans-eQTLs
#
# 59.84% done, 1,071,797 cis-eQTLs, 160,253 trans-eQTLs
#
# 60.60% done, 161,995 trans-eQTLs
#
# 61.36% done, 164,153 trans-eQTLs
#
# 62.12% done, 166,354 trans-eQTLs
#
# 62.87% done, 1,135,762 cis-eQTLs, 168,319 trans-eQTLs
#
# 63.63% done, 169,899 trans-eQTLs
#
# 64.39% done, 171,884 trans-eQTLs
#
# 65.15% done, 173,868 trans-eQTLs
#
# 65.90% done, 1,177,032 cis-eQTLs, 175,821 trans-eQTLs
#
# 66.66% done, 177,181 trans-eQTLs
#
# 67.42% done, 180,501 trans-eQTLs
#
# 68.18% done, 184,384 trans-eQTLs
#
# 68.93% done, 1,209,487 cis-eQTLs, 188,330 trans-eQTLs
#
# 69.69% done, 191,411 trans-eQTLs
#
# 70.45% done, 193,510 trans-eQTLs
#
# 71.21% done, 195,269 trans-eQTLs
#
# 71.96% done, 1,246,444 cis-eQTLs, 197,566 trans-eQTLs
#
# 72.72% done, 198,986 trans-eQTLs
#
# 73.48% done, 200,880 trans-eQTLs
#
# 74.24% done, 202,333 trans-eQTLs
#
# 75.00% done, 1,305,101 cis-eQTLs, 204,084 trans-eQTLs
#
# 75.75% done, 205,263 trans-eQTLs
#
# 76.51% done, 208,253 trans-eQTLs
#
# 77.27% done, 211,683 trans-eQTLs
#
# 78.03% done, 1,338,891 cis-eQTLs, 215,587 trans-eQTLs
#
# 78.78% done, 217,927 trans-eQTLs
#
# 79.54% done, 219,812 trans-eQTLs
#
# 80.30% done, 222,485 trans-eQTLs
#
# 81.06% done, 1,361,690 cis-eQTLs, 224,483 trans-eQTLs
#
# 81.81% done, 226,570 trans-eQTLs
#
# 82.57% done, 228,473 trans-eQTLs
#
# 83.33% done, 230,602 trans-eQTLs
#
# 84.09% done, 1,393,585 cis-eQTLs, 232,384 trans-eQTLs
#
# 84.84% done, 233,939 trans-eQTLs
#
# 85.60% done, 236,500 trans-eQTLs
#
# 86.36% done, 238,903 trans-eQTLs
#
# 87.12% done, 1,439,509 cis-eQTLs, 241,749 trans-eQTLs
#
# 87.87% done, 1,525,703 cis-eQTLs, 243,784 trans-eQTLs
#
# 88.63% done, 245,346 trans-eQTLs
#
# 89.39% done, 247,465 trans-eQTLs
#
# 90.15% done, 248,936 trans-eQTLs
#
# 90.90% done, 1,618,473 cis-eQTLs, 250,252 trans-eQTLs
#
# 91.66% done, 252,111 trans-eQTLs
#
# 92.42% done, 254,156 trans-eQTLs
#
# 93.18% done, 256,467 trans-eQTLs
#
# 93.93% done, 1,667,286 cis-eQTLs, 258,181 trans-eQTLs
#
# 94.69% done, 259,712 trans-eQTLs
#
# 95.45% done, 261,285 trans-eQTLs
#
# 96.21% done, 263,054 trans-eQTLs
#
# 96.96% done, 1,732,359 cis-eQTLs, 264,352 trans-eQTLs
#
# 97.72% done, 267,296 trans-eQTLs
#
# 98.48% done, 270,139 trans-eQTLs
#
# 99.24% done, 272,781 trans-eQTLs
#
# 100.00% done, 1,813,907 cis-eQTLs, 275,200 trans-eQTLs
