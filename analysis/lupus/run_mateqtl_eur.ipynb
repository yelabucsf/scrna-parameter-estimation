# %% [markdown]
# # Matrix eQTL

# %%
library("MatrixEQTL");

# %%
base.dir = '/data_volume/memento/lupus/full_analysis/mateqtl/inputs/'

# %%
pop <- 'eur'

# %%
useModel = modelLINEAR; # modelANOVA, modelLINEAR, or modelLINEAR_CROSS
SNP_file_name = paste(base.dir, pop, '_genos.tsv', sep="");
snps_location_file_name = paste(base.dir, pop, "_snpspos.txt", sep="");
covariates_file_name = paste(base.dir,  pop, '_mateqtl_cov.txt', sep="");
pvOutputThreshold_cis = 1;
errorCovariance = numeric();
cisDist = 100000;

gene_location_file_name = paste(base.dir, "geneloc_tss_hg19.txt", sep="");


## Load genotype data

snps = SlicedData$new();
snps$fileDelimiter = "\t";      # the TAB character
snps$fileOmitCharacters = "NA"; # denote missing values;
snps$fileSkipRows = 1;          # one row of column labels
snps$fileSkipColumns = 1;       # one column of row labels
snps$fileSliceSize = 100000;      # read file in slices of 2,000 rows
snps$LoadFile(SNP_file_name);


## Load covariates

cvrt = SlicedData$new();
cvrt$fileDelimiter = "\t";      # the TAB character
cvrt$fileOmitCharacters = "NA"; # denote missing values;
cvrt$fileSkipRows = 1;          # one row of column labels
cvrt$fileSkipColumns = 1;       # one column of row labels
if(length(covariates_file_name)>0) {
cvrt$LoadFile(covariates_file_name);
}
# Out:
# Rows read: 100,000
#
# Rows read: 200,000
#
# Rows read: 300,000
#
# Rows read: 400,000
#
# Rows read: 500,000
#
# Rows read: 600,000
#
# Rows read: 700,000
#
# Rows read: 800,000
#
# Rows read: 900,000
#
# Rows read: 1,000,000
#
# Rows read: 1,100,000
#
# Rows read: 1,200,000
#
# Rows read: 1,300,000
#
# Rows read: 1,400,000
#
# Rows read: 1,500,000
#
# Rows read: 1,600,000
#
# Rows read: 1,700,000
#
# Rows read: 1,800,000
#
# Rows read: 1,900,000
#
# Rows read: 2,000,000
#
# Rows read: 2,100,000
#
# Rows read: 2,200,000
#
# Rows read: 2,300,000
#
# Rows read: 2,400,000
#
# Rows read: 2,500,000
#
# Rows read: 2,600,000
#
# Rows read: 2,700,000
#
# Rows read: 2,800,000
#
# Rows read: 2,900,000
#
# Rows read: 3,000,000
#
# Rows read: 3,100,000
#
# Rows read: 3,200,000
#
# Rows read: 3285470 done.
#
# Rows read: 35 done.

# %%
snpspos = read.table(snps_location_file_name, header = TRUE, stringsAsFactors = FALSE);
genepos = read.table(gene_location_file_name, header = TRUE, stringsAsFactors = FALSE, sep='\t');

for (ct in c('B','T8', 'T4', 'NK', 'ncM', 'cM')){


    expression_file_name = paste(base.dir, "../pseudobulk/", pop, '_', ct, '.csv',sep="");
    output_file_name = paste(base.dir, "../outputs/", pop, '_', ct, '_all_hg19.csv', sep="");
    ## Load gene expression data

    gene = SlicedData$new();
    gene$fileDelimiter = "\t";      # the TAB character
    gene$fileOmitCharacters = "NA"; # denote missing values;
    gene$fileSkipRows = 1;          # one row of column labels
    gene$fileSkipColumns = 1;       # one column of row labels
    gene$fileSliceSize = 2000;      # read file in slices of 2,000 rows
    gene$LoadFile(expression_file_name);


    me = Matrix_eQTL_main(
        snps = snps,
        gene = gene,
        cvrt = cvrt,
#         output_file_name     = output_file_name,
#         pvOutputThreshold     = pvOutputThreshold,
        useModel = useModel,
        errorCovariance = errorCovariance,
        verbose = FALSE,
        output_file_name.cis = output_file_name,
        pvOutputThreshold.cis = pvOutputThreshold_cis,
        snpspos = snpspos,
        genepos = genepos,
        cisDist = cisDist,
        pvalue.hist = "qqplot",
        min.pv.by.genesnp = FALSE,
        noFDRsaveMemory = FALSE);
    
    }
# Out:
# Rows read: 2,000
#
# Rows read: 3945 done.
#
# 3886 of 3945 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  1.51% done, 20,341 cis-eQTLs, 2,128 trans-eQTLs
#
#  3.03% done, 4,230 trans-eQTLs
#
#  4.54% done, 44,741 cis-eQTLs, 6,513 trans-eQTLs
#
#  6.06% done, 9,052 trans-eQTLs
#
#  7.57% done, 76,495 cis-eQTLs, 11,117 trans-eQTLs
#
#  9.09% done, 13,242 trans-eQTLs
#
# 10.60% done, 97,091 cis-eQTLs, 15,417 trans-eQTLs
#
# 12.12% done, 17,120 trans-eQTLs
#
# 13.63% done, 141,077 cis-eQTLs, 19,088 trans-eQTLs
#
# 15.15% done, 20,606 trans-eQTLs
#
# 16.66% done, 162,484 cis-eQTLs, 22,618 trans-eQTLs
#
# 18.18% done, 24,292 trans-eQTLs
#
# 19.69% done, 172,970 cis-eQTLs, 25,576 trans-eQTLs
#
# 21.21% done, 26,925 trans-eQTLs
#
# 22.72% done, 186,519 cis-eQTLs, 28,586 trans-eQTLs
#
# 24.24% done, 30,254 trans-eQTLs
#
# 25.75% done, 205,461 cis-eQTLs, 31,766 trans-eQTLs
#
# 27.27% done, 33,922 trans-eQTLs
#
# 28.78% done, 223,983 cis-eQTLs, 35,975 trans-eQTLs
#
# 30.30% done, 37,382 trans-eQTLs
#
# 31.81% done, 254,279 cis-eQTLs, 38,884 trans-eQTLs
#
# 33.33% done, 40,410 trans-eQTLs
#
# 34.84% done, 278,190 cis-eQTLs, 42,507 trans-eQTLs
#
# 36.36% done, 44,290 trans-eQTLs
#
# 37.87% done, 307,881 cis-eQTLs, 45,572 trans-eQTLs
#
# 39.39% done, 46,939 trans-eQTLs
#
# 40.90% done, 342,441 cis-eQTLs, 48,125 trans-eQTLs
#
# 42.42% done, 49,533 trans-eQTLs
#
# 43.93% done, 384,004 cis-eQTLs, 51,587 trans-eQTLs
#
# 45.45% done, 54,080 trans-eQTLs
#
# 46.96% done, 406,689 cis-eQTLs, 55,815 trans-eQTLs
#
# 48.48% done, 57,515 trans-eQTLs
#
# 50.00% done, 419,287 cis-eQTLs, 60,297 trans-eQTLs
#
# 51.51% done, 427,925 cis-eQTLs, 62,536 trans-eQTLs
#
# 53.03% done, 65,568 trans-eQTLs
#
# 54.54% done, 442,468 cis-eQTLs, 67,933 trans-eQTLs
#
# 56.06% done, 69,797 trans-eQTLs
#
# 57.57% done, 469,933 cis-eQTLs, 71,571 trans-eQTLs
#
# 59.09% done, 73,398 trans-eQTLs
#
# 60.60% done, 495,310 cis-eQTLs, 75,199 trans-eQTLs
#
# 62.12% done, 76,866 trans-eQTLs
#
# 63.63% done, 521,949 cis-eQTLs, 78,963 trans-eQTLs
#
# 65.15% done, 81,229 trans-eQTLs
#
# 66.66% done, 539,033 cis-eQTLs, 83,773 trans-eQTLs
#
# 68.18% done, 85,764 trans-eQTLs
#
# 69.69% done, 555,197 cis-eQTLs, 87,590 trans-eQTLs
#
# 71.21% done, 89,596 trans-eQTLs
#
# 72.72% done, 571,062 cis-eQTLs, 91,564 trans-eQTLs
#
# 74.24% done, 93,681 trans-eQTLs
#
# 75.75% done, 598,848 cis-eQTLs, 95,738 trans-eQTLs
#
# 77.27% done, 97,522 trans-eQTLs
#
# 78.78% done, 615,632 cis-eQTLs, 99,292 trans-eQTLs
#
# 80.30% done, 101,129 trans-eQTLs
#
# 81.81% done, 624,763 cis-eQTLs, 103,473 trans-eQTLs
#
# 83.33% done, 107,648 trans-eQTLs
#
# 84.84% done, 638,477 cis-eQTLs, 111,532 trans-eQTLs
#
# 86.36% done, 113,493 trans-eQTLs
#
# 87.87% done, 701,475 cis-eQTLs, 115,078 trans-eQTLs
#
# 89.39% done, 117,076 trans-eQTLs
#
# 90.90% done, 741,814 cis-eQTLs, 118,948 trans-eQTLs
#
# 92.42% done, 120,555 trans-eQTLs
#
# 93.93% done, 766,302 cis-eQTLs, 122,134 trans-eQTLs
#
# 95.45% done, 124,100 trans-eQTLs
#
# 96.96% done, 797,898 cis-eQTLs, 126,201 trans-eQTLs
#
# 98.48% done, 127,585 trans-eQTLs
#
# 100.00% done, 834,372 cis-eQTLs, 128,852 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 4650 done.
#
# 4586 of 4650 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  1.01% done, 20,310 cis-eQTLs, 1,417 trans-eQTLs
#
#  2.02% done, 2,987 trans-eQTLs
#
#  3.03% done, 3,473 trans-eQTLs
#
#  4.04% done, 53,709 cis-eQTLs, 5,319 trans-eQTLs
#
#  5.05% done, 7,813 trans-eQTLs
#
#  6.06% done, 8,360 trans-eQTLs
#
#  7.07% done, 88,615 cis-eQTLs, 10,433 trans-eQTLs
#
#  8.08% done, 12,280 trans-eQTLs
#
#  9.09% done, 12,916 trans-eQTLs
#
# 10.10% done, 112,299 cis-eQTLs, 16,222 trans-eQTLs
#
# 11.11% done, 19,119 trans-eQTLs
#
# 12.12% done, 20,055 trans-eQTLs
#
# 13.13% done, 160,193 cis-eQTLs, 21,654 trans-eQTLs
#
# 14.14% done, 23,709 trans-eQTLs
#
# 15.15% done, 23,991 trans-eQTLs
#
# 16.16% done, 185,260 cis-eQTLs, 26,194 trans-eQTLs
#
# 17.17% done, 28,364 trans-eQTLs
#
# 18.18% done, 29,079 trans-eQTLs
#
# 19.19% done, 197,357 cis-eQTLs, 30,790 trans-eQTLs
#
# 20.20% done, 32,612 trans-eQTLs
#
# 21.21% done, 33,708 trans-eQTLs
#
# 22.22% done, 214,358 cis-eQTLs, 35,336 trans-eQTLs
#
# 23.23% done, 37,148 trans-eQTLs
#
# 24.24% done, 37,620 trans-eQTLs
#
# 25.25% done, 237,905 cis-eQTLs, 40,232 trans-eQTLs
#
# 26.26% done, 42,554 trans-eQTLs
#
# 27.27% done, 43,543 trans-eQTLs
#
# 28.28% done, 258,960 cis-eQTLs, 46,177 trans-eQTLs
#
# 29.29% done, 48,529 trans-eQTLs
#
# 30.30% done, 49,172 trans-eQTLs
#
# 31.31% done, 296,088 cis-eQTLs, 51,420 trans-eQTLs
#
# 32.32% done, 53,913 trans-eQTLs
#
# 33.33% done, 54,699 trans-eQTLs
#
# 34.34% done, 326,529 cis-eQTLs, 56,827 trans-eQTLs
#
# 35.35% done, 58,783 trans-eQTLs
#
# 36.36% done, 59,277 trans-eQTLs
#
# 37.37% done, 364,273 cis-eQTLs, 61,290 trans-eQTLs
#
# 38.38% done, 63,522 trans-eQTLs
#
# 39.39% done, 64,052 trans-eQTLs
#
# 40.40% done, 405,001 cis-eQTLs, 66,654 trans-eQTLs
#
# 41.41% done, 68,646 trans-eQTLs
#
# 42.42% done, 69,597 trans-eQTLs
#
# 43.43% done, 422,585 cis-eQTLs, 71,670 trans-eQTLs
#
# 44.44% done, 455,097 cis-eQTLs, 73,452 trans-eQTLs
#
# 45.45% done, 74,020 trans-eQTLs
#
# 46.46% done, 75,603 trans-eQTLs
#
# 47.47% done, 483,310 cis-eQTLs, 77,042 trans-eQTLs
#
# 48.48% done, 77,824 trans-eQTLs
#
# 49.49% done, 79,938 trans-eQTLs
#
# 50.50% done, 506,974 cis-eQTLs, 82,043 trans-eQTLs
#
# 51.51% done, 82,886 trans-eQTLs
#
# 52.52% done, 85,355 trans-eQTLs
#
# 53.53% done, 522,507 cis-eQTLs, 87,290 trans-eQTLs
#
# 54.54% done, 87,897 trans-eQTLs
#
# 55.55% done, 89,897 trans-eQTLs
#
# 56.56% done, 554,233 cis-eQTLs, 91,669 trans-eQTLs
#
# 57.57% done, 92,170 trans-eQTLs
#
# 58.58% done, 93,964 trans-eQTLs
#
# 59.59% done, 586,690 cis-eQTLs, 95,936 trans-eQTLs
#
# 60.60% done, 96,490 trans-eQTLs
#
# 61.61% done, 98,120 trans-eQTLs
#
# 62.62% done, 617,197 cis-eQTLs, 99,704 trans-eQTLs
#
# 63.63% done, 100,194 trans-eQTLs
#
# 64.64% done, 102,064 trans-eQTLs
#
# 65.65% done, 636,405 cis-eQTLs, 103,935 trans-eQTLs
#
# 66.66% done, 104,565 trans-eQTLs
#
# 67.67% done, 106,312 trans-eQTLs
#
# 68.68% done, 655,855 cis-eQTLs, 107,958 trans-eQTLs
#
# 69.69% done, 108,619 trans-eQTLs
#
# 70.70% done, 110,576 trans-eQTLs
#
# 71.71% done, 675,363 cis-eQTLs, 112,879 trans-eQTLs
#
# 72.72% done, 114,005 trans-eQTLs
#
# 73.73% done, 115,926 trans-eQTLs
#
# 74.74% done, 710,719 cis-eQTLs, 117,542 trans-eQTLs
#
# 75.75% done, 118,157 trans-eQTLs
#
# 76.76% done, 120,202 trans-eQTLs
#
# 77.77% done, 728,314 cis-eQTLs, 121,722 trans-eQTLs
#
# 78.78% done, 122,488 trans-eQTLs
#
# 79.79% done, 124,771 trans-eQTLs
#
# 80.80% done, 740,140 cis-eQTLs, 126,721 trans-eQTLs
#
# 81.81% done, 127,281 trans-eQTLs
#
# 82.82% done, 129,363 trans-eQTLs
#
# 83.83% done, 756,825 cis-eQTLs, 131,172 trans-eQTLs
#
# 84.84% done, 131,911 trans-eQTLs
#
# 85.85% done, 134,147 trans-eQTLs
#
# 86.86% done, 830,707 cis-eQTLs, 135,848 trans-eQTLs
#
# 87.87% done, 136,501 trans-eQTLs
#
# 88.88% done, 138,429 trans-eQTLs
#
# 89.89% done, 851,735 cis-eQTLs, 140,728 trans-eQTLs
#
# 90.90% done, 873,778 cis-eQTLs, 141,276 trans-eQTLs
#
# 91.91% done, 143,569 trans-eQTLs
#
# 92.92% done, 145,336 trans-eQTLs
#
# 93.93% done, 900,451 cis-eQTLs, 146,015 trans-eQTLs
#
# 94.94% done, 148,191 trans-eQTLs
#
# 95.95% done, 150,036 trans-eQTLs
#
# 96.96% done, 938,125 cis-eQTLs, 150,713 trans-eQTLs
#
# 97.97% done, 151,916 trans-eQTLs
#
# 98.98% done, 153,355 trans-eQTLs
#
# 100.00% done, 981,975 cis-eQTLs, 154,118 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 4832 done.
#
# 4763 of 4832 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  1.01% done, 20,295 cis-eQTLs, 1,804 trans-eQTLs
#
#  2.02% done, 3,361 trans-eQTLs
#
#  3.03% done, 4,161 trans-eQTLs
#
#  4.04% done, 54,153 cis-eQTLs, 5,975 trans-eQTLs
#
#  5.05% done, 8,017 trans-eQTLs
#
#  6.06% done, 8,871 trans-eQTLs
#
#  7.07% done, 90,447 cis-eQTLs, 11,217 trans-eQTLs
#
#  8.08% done, 13,203 trans-eQTLs
#
#  9.09% done, 13,915 trans-eQTLs
#
# 10.10% done, 115,207 cis-eQTLs, 16,491 trans-eQTLs
#
# 11.11% done, 18,965 trans-eQTLs
#
# 12.12% done, 20,056 trans-eQTLs
#
# 13.13% done, 163,536 cis-eQTLs, 22,298 trans-eQTLs
#
# 14.14% done, 25,015 trans-eQTLs
#
# 15.15% done, 25,951 trans-eQTLs
#
# 16.16% done, 189,635 cis-eQTLs, 29,435 trans-eQTLs
#
# 17.17% done, 32,534 trans-eQTLs
#
# 18.18% done, 33,799 trans-eQTLs
#
# 19.19% done, 203,532 cis-eQTLs, 35,592 trans-eQTLs
#
# 20.20% done, 37,461 trans-eQTLs
#
# 21.21% done, 38,025 trans-eQTLs
#
# 22.22% done, 220,918 cis-eQTLs, 40,474 trans-eQTLs
#
# 23.23% done, 42,311 trans-eQTLs
#
# 24.24% done, 43,022 trans-eQTLs
#
# 25.25% done, 245,677 cis-eQTLs, 44,710 trans-eQTLs
#
# 26.26% done, 46,759 trans-eQTLs
#
# 27.27% done, 47,548 trans-eQTLs
#
# 28.28% done, 267,704 cis-eQTLs, 49,770 trans-eQTLs
#
# 29.29% done, 52,665 trans-eQTLs
#
# 30.30% done, 53,497 trans-eQTLs
#
# 31.31% done, 304,823 cis-eQTLs, 55,571 trans-eQTLs
#
# 32.32% done, 57,459 trans-eQTLs
#
# 33.33% done, 58,421 trans-eQTLs
#
# 34.34% done, 336,283 cis-eQTLs, 60,477 trans-eQTLs
#
# 35.35% done, 62,806 trans-eQTLs
#
# 36.36% done, 63,610 trans-eQTLs
#
# 37.37% done, 374,163 cis-eQTLs, 66,148 trans-eQTLs
#
# 38.38% done, 67,977 trans-eQTLs
#
# 39.39% done, 68,828 trans-eQTLs
#
# 40.40% done, 414,545 cis-eQTLs, 71,516 trans-eQTLs
#
# 41.41% done, 73,717 trans-eQTLs
#
# 42.42% done, 74,540 trans-eQTLs
#
# 43.43% done, 418,224 cis-eQTLs, 76,230 trans-eQTLs
#
# 44.44% done, 465,114 cis-eQTLs, 78,435 trans-eQTLs
#
# 45.45% done, 79,016 trans-eQTLs
#
# 46.46% done, 80,500 trans-eQTLs
#
# 47.47% done, 494,615 cis-eQTLs, 82,213 trans-eQTLs
#
# 48.48% done, 82,801 trans-eQTLs
#
# 49.49% done, 85,263 trans-eQTLs
#
# 50.50% done, 520,293 cis-eQTLs, 87,465 trans-eQTLs
#
# 51.51% done, 88,398 trans-eQTLs
#
# 52.52% done, 90,130 trans-eQTLs
#
# 53.53% done, 537,723 cis-eQTLs, 92,738 trans-eQTLs
#
# 54.54% done, 93,703 trans-eQTLs
#
# 55.55% done, 95,617 trans-eQTLs
#
# 56.56% done, 570,185 cis-eQTLs, 97,650 trans-eQTLs
#
# 57.57% done, 98,266 trans-eQTLs
#
# 58.58% done, 99,564 trans-eQTLs
#
# 59.59% done, 604,258 cis-eQTLs, 100,771 trans-eQTLs
#
# 60.60% done, 101,200 trans-eQTLs
#
# 61.61% done, 102,678 trans-eQTLs
#
# 62.62% done, 636,297 cis-eQTLs, 104,623 trans-eQTLs
#
# 63.63% done, 105,249 trans-eQTLs
#
# 64.64% done, 107,775 trans-eQTLs
#
# 65.65% done, 657,266 cis-eQTLs, 110,033 trans-eQTLs
#
# 66.66% done, 110,819 trans-eQTLs
#
# 67.67% done, 112,933 trans-eQTLs
#
# 68.68% done, 676,756 cis-eQTLs, 114,946 trans-eQTLs
#
# 69.69% done, 116,126 trans-eQTLs
#
# 70.70% done, 118,187 trans-eQTLs
#
# 71.71% done, 697,340 cis-eQTLs, 120,129 trans-eQTLs
#
# 72.72% done, 121,116 trans-eQTLs
#
# 73.73% done, 123,054 trans-eQTLs
#
# 74.74% done, 733,525 cis-eQTLs, 124,731 trans-eQTLs
#
# 75.75% done, 125,539 trans-eQTLs
#
# 76.76% done, 127,761 trans-eQTLs
#
# 77.77% done, 753,099 cis-eQTLs, 130,244 trans-eQTLs
#
# 78.78% done, 130,875 trans-eQTLs
#
# 79.79% done, 132,993 trans-eQTLs
#
# 80.80% done, 765,067 cis-eQTLs, 135,423 trans-eQTLs
#
# 81.81% done, 136,832 trans-eQTLs
#
# 82.82% done, 139,405 trans-eQTLs
#
# 83.83% done, 784,163 cis-eQTLs, 141,968 trans-eQTLs
#
# 84.84% done, 142,938 trans-eQTLs
#
# 85.85% done, 145,205 trans-eQTLs
#
# 86.86% done, 846,188 cis-eQTLs, 147,459 trans-eQTLs
#
# 87.87% done, 859,459 cis-eQTLs, 148,423 trans-eQTLs
#
# 88.88% done, 150,164 trans-eQTLs
#
# 89.89% done, 151,650 trans-eQTLs
#
# 90.90% done, 906,281 cis-eQTLs, 152,275 trans-eQTLs
#
# 91.91% done, 155,154 trans-eQTLs
#
# 92.92% done, 157,792 trans-eQTLs
#
# 93.93% done, 933,631 cis-eQTLs, 158,882 trans-eQTLs
#
# 94.94% done, 160,606 trans-eQTLs
#
# 95.95% done, 162,115 trans-eQTLs
#
# 96.96% done, 971,091 cis-eQTLs, 162,852 trans-eQTLs
#
# 97.97% done, 164,479 trans-eQTLs
#
# 98.98% done, 165,999 trans-eQTLs
#
# 100.00% done, 1,015,529 cis-eQTLs, 166,921 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 4147 done.
#
# 4088 of 4147 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  1.01% done, 19,500 cis-eQTLs, 2,173 trans-eQTLs
#
#  2.02% done, 4,320 trans-eQTLs
#
#  3.03% done, 4,483 trans-eQTLs
#
#  4.04% done, 50,085 cis-eQTLs, 6,199 trans-eQTLs
#
#  5.05% done, 8,069 trans-eQTLs
#
#  6.06% done, 8,150 trans-eQTLs
#
#  7.07% done, 81,783 cis-eQTLs, 9,569 trans-eQTLs
#
#  8.08% done, 11,324 trans-eQTLs
#
#  9.09% done, 11,412 trans-eQTLs
#
# 10.10% done, 103,053 cis-eQTLs, 13,592 trans-eQTLs
#
# 11.11% done, 16,033 trans-eQTLs
#
# 12.12% done, 16,271 trans-eQTLs
#
# 13.13% done, 145,064 cis-eQTLs, 18,678 trans-eQTLs
#
# 14.14% done, 21,026 trans-eQTLs
#
# 15.15% done, 21,148 trans-eQTLs
#
# 16.16% done, 167,281 cis-eQTLs, 23,342 trans-eQTLs
#
# 17.17% done, 25,024 trans-eQTLs
#
# 18.18% done, 25,286 trans-eQTLs
#
# 19.19% done, 176,166 cis-eQTLs, 27,525 trans-eQTLs
#
# 20.20% done, 29,877 trans-eQTLs
#
# 21.21% done, 30,082 trans-eQTLs
#
# 22.22% done, 191,147 cis-eQTLs, 32,591 trans-eQTLs
#
# 23.23% done, 34,786 trans-eQTLs
#
# 24.24% done, 34,884 trans-eQTLs
#
# 25.25% done, 210,712 cis-eQTLs, 36,320 trans-eQTLs
#
# 26.26% done, 37,995 trans-eQTLs
#
# 27.27% done, 38,160 trans-eQTLs
#
# 28.28% done, 230,226 cis-eQTLs, 39,646 trans-eQTLs
#
# 29.29% done, 40,811 trans-eQTLs
#
# 30.30% done, 40,886 trans-eQTLs
#
# 31.31% done, 262,020 cis-eQTLs, 42,363 trans-eQTLs
#
# 32.32% done, 43,936 trans-eQTLs
#
# 33.33% done, 44,015 trans-eQTLs
#
# 34.34% done, 289,085 cis-eQTLs, 46,201 trans-eQTLs
#
# 35.35% done, 48,365 trans-eQTLs
#
# 36.36% done, 48,612 trans-eQTLs
#
# 37.37% done, 322,798 cis-eQTLs, 50,167 trans-eQTLs
#
# 38.38% done, 52,352 trans-eQTLs
#
# 39.39% done, 52,551 trans-eQTLs
#
# 40.40% done, 361,142 cis-eQTLs, 54,307 trans-eQTLs
#
# 41.41% done, 56,153 trans-eQTLs
#
# 42.42% done, 56,339 trans-eQTLs
#
# 43.43% done, 405,345 cis-eQTLs, 58,715 trans-eQTLs
#
# 44.44% done, 61,476 trans-eQTLs
#
# 45.45% done, 61,590 trans-eQTLs
#
# 46.46% done, 417,010 cis-eQTLs, 63,357 trans-eQTLs
#
# 47.47% done, 432,067 cis-eQTLs, 65,633 trans-eQTLs
#
# 48.48% done, 65,784 trans-eQTLs
#
# 49.49% done, 68,404 trans-eQTLs
#
# 50.50% done, 454,156 cis-eQTLs, 71,164 trans-eQTLs
#
# 51.51% done, 71,295 trans-eQTLs
#
# 52.52% done, 73,538 trans-eQTLs
#
# 53.53% done, 465,995 cis-eQTLs, 76,005 trans-eQTLs
#
# 54.54% done, 76,118 trans-eQTLs
#
# 55.55% done, 78,667 trans-eQTLs
#
# 56.56% done, 493,900 cis-eQTLs, 80,872 trans-eQTLs
#
# 57.57% done, 81,130 trans-eQTLs
#
# 58.58% done, 83,576 trans-eQTLs
#
# 59.59% done, 523,286 cis-eQTLs, 85,303 trans-eQTLs
#
# 60.60% done, 85,431 trans-eQTLs
#
# 61.61% done, 87,004 trans-eQTLs
#
# 62.62% done, 551,006 cis-eQTLs, 88,750 trans-eQTLs
#
# 63.63% done, 88,905 trans-eQTLs
#
# 64.64% done, 90,746 trans-eQTLs
#
# 65.65% done, 567,420 cis-eQTLs, 92,530 trans-eQTLs
#
# 66.66% done, 92,581 trans-eQTLs
#
# 67.67% done, 95,035 trans-eQTLs
#
# 68.68% done, 584,366 cis-eQTLs, 97,317 trans-eQTLs
#
# 69.69% done, 97,416 trans-eQTLs
#
# 70.70% done, 99,142 trans-eQTLs
#
# 71.71% done, 600,968 cis-eQTLs, 100,796 trans-eQTLs
#
# 72.72% done, 100,906 trans-eQTLs
#
# 73.73% done, 102,689 trans-eQTLs
#
# 74.74% done, 633,550 cis-eQTLs, 104,565 trans-eQTLs
#
# 75.75% done, 104,754 trans-eQTLs
#
# 76.76% done, 106,552 trans-eQTLs
#
# 77.77% done, 648,262 cis-eQTLs, 108,204 trans-eQTLs
#
# 78.78% done, 108,281 trans-eQTLs
#
# 79.79% done, 110,270 trans-eQTLs
#
# 80.80% done, 657,295 cis-eQTLs, 112,477 trans-eQTLs
#
# 81.81% done, 112,664 trans-eQTLs
#
# 82.82% done, 114,876 trans-eQTLs
#
# 83.83% done, 671,465 cis-eQTLs, 116,753 trans-eQTLs
#
# 84.84% done, 116,922 trans-eQTLs
#
# 85.85% done, 118,773 trans-eQTLs
#
# 86.86% done, 740,216 cis-eQTLs, 120,378 trans-eQTLs
#
# 87.87% done, 120,517 trans-eQTLs
#
# 88.88% done, 123,277 trans-eQTLs
#
# 89.89% done, 780,804 cis-eQTLs, 125,818 trans-eQTLs
#
# 90.90% done, 126,097 trans-eQTLs
#
# 91.91% done, 127,807 trans-eQTLs
#
# 92.92% done, 804,162 cis-eQTLs, 129,790 trans-eQTLs
#
# 93.93% done, 130,001 trans-eQTLs
#
# 94.94% done, 132,454 trans-eQTLs
#
# 95.95% done, 837,714 cis-eQTLs, 134,800 trans-eQTLs
#
# 96.96% done, 135,012 trans-eQTLs
#
# 97.97% done, 136,358 trans-eQTLs
#
# 98.98% done, 857,778 cis-eQTLs, 137,749 trans-eQTLs
#
# 100.00% done, 878,466 cis-eQTLs, 137,840 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 5249 done.
#
# 5178 of 5249 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  1.01% done, 25,050 cis-eQTLs, 2,977 trans-eQTLs
#
#  2.02% done, 5,873 trans-eQTLs
#
#  3.03% done, 7,432 trans-eQTLs
#
#  4.04% done, 63,251 cis-eQTLs, 9,224 trans-eQTLs
#
#  5.05% done, 11,281 trans-eQTLs
#
#  6.06% done, 12,451 trans-eQTLs
#
#  7.07% done, 107,113 cis-eQTLs, 14,792 trans-eQTLs
#
#  8.08% done, 17,190 trans-eQTLs
#
#  9.09% done, 18,472 trans-eQTLs
#
# 10.10% done, 132,944 cis-eQTLs, 19,980 trans-eQTLs
#
# 11.11% done, 21,816 trans-eQTLs
#
# 12.12% done, 22,818 trans-eQTLs
#
# 13.13% done, 183,287 cis-eQTLs, 24,914 trans-eQTLs
#
# 14.14% done, 26,783 trans-eQTLs
#
# 15.15% done, 28,344 trans-eQTLs
#
# 16.16% done, 209,997 cis-eQTLs, 30,139 trans-eQTLs
#
# 17.17% done, 31,910 trans-eQTLs
#
# 18.18% done, 33,269 trans-eQTLs
#
# 19.19% done, 224,425 cis-eQTLs, 34,808 trans-eQTLs
#
# 20.20% done, 36,826 trans-eQTLs
#
# 21.21% done, 38,014 trans-eQTLs
#
# 22.22% done, 242,848 cis-eQTLs, 39,758 trans-eQTLs
#
# 23.23% done, 41,938 trans-eQTLs
#
# 24.24% done, 43,147 trans-eQTLs
#
# 25.25% done, 269,131 cis-eQTLs, 45,343 trans-eQTLs
#
# 26.26% done, 47,584 trans-eQTLs
#
# 27.27% done, 49,010 trans-eQTLs
#
# 28.28% done, 292,694 cis-eQTLs, 51,034 trans-eQTLs
#
# 29.29% done, 53,524 trans-eQTLs
#
# 30.30% done, 55,096 trans-eQTLs
#
# 31.31% done, 333,076 cis-eQTLs, 56,716 trans-eQTLs
#
# 32.32% done, 58,539 trans-eQTLs
#
# 33.33% done, 59,645 trans-eQTLs
#
# 34.34% done, 368,111 cis-eQTLs, 61,611 trans-eQTLs
#
# 35.35% done, 63,568 trans-eQTLs
#
# 36.36% done, 64,844 trans-eQTLs
#
# 37.37% done, 408,275 cis-eQTLs, 66,937 trans-eQTLs
#
# 38.38% done, 69,428 trans-eQTLs
#
# 39.39% done, 70,739 trans-eQTLs
#
# 40.40% done, 419,601 cis-eQTLs, 72,762 trans-eQTLs
#
# 41.41% done, 454,625 cis-eQTLs, 75,786 trans-eQTLs
#
# 42.42% done, 77,105 trans-eQTLs
#
# 43.43% done, 79,001 trans-eQTLs
#
# 44.44% done, 514,755 cis-eQTLs, 81,094 trans-eQTLs
#
# 45.45% done, 82,724 trans-eQTLs
#
# 46.46% done, 85,207 trans-eQTLs
#
# 47.47% done, 546,431 cis-eQTLs, 87,252 trans-eQTLs
#
# 48.48% done, 88,316 trans-eQTLs
#
# 49.49% done, 90,668 trans-eQTLs
#
# 50.50% done, 576,671 cis-eQTLs, 93,095 trans-eQTLs
#
# 51.51% done, 94,307 trans-eQTLs
#
# 52.52% done, 96,110 trans-eQTLs
#
# 53.53% done, 593,991 cis-eQTLs, 98,407 trans-eQTLs
#
# 54.54% done, 99,738 trans-eQTLs
#
# 55.55% done, 101,748 trans-eQTLs
#
# 56.56% done, 630,264 cis-eQTLs, 103,905 trans-eQTLs
#
# 57.57% done, 105,102 trans-eQTLs
#
# 58.58% done, 107,088 trans-eQTLs
#
# 59.59% done, 667,238 cis-eQTLs, 109,180 trans-eQTLs
#
# 60.60% done, 110,459 trans-eQTLs
#
# 61.61% done, 112,603 trans-eQTLs
#
# 62.62% done, 700,498 cis-eQTLs, 114,490 trans-eQTLs
#
# 63.63% done, 115,759 trans-eQTLs
#
# 64.64% done, 117,962 trans-eQTLs
#
# 65.65% done, 720,472 cis-eQTLs, 119,340 trans-eQTLs
#
# 66.66% done, 120,498 trans-eQTLs
#
# 67.67% done, 122,391 trans-eQTLs
#
# 68.68% done, 741,733 cis-eQTLs, 124,135 trans-eQTLs
#
# 69.69% done, 125,424 trans-eQTLs
#
# 70.70% done, 127,356 trans-eQTLs
#
# 71.71% done, 762,444 cis-eQTLs, 129,785 trans-eQTLs
#
# 72.72% done, 130,837 trans-eQTLs
#
# 73.73% done, 132,685 trans-eQTLs
#
# 74.74% done, 800,991 cis-eQTLs, 134,483 trans-eQTLs
#
# 75.75% done, 135,602 trans-eQTLs
#
# 76.76% done, 137,032 trans-eQTLs
#
# 77.77% done, 820,033 cis-eQTLs, 138,832 trans-eQTLs
#
# 78.78% done, 140,231 trans-eQTLs
#
# 79.79% done, 142,041 trans-eQTLs
#
# 80.80% done, 832,293 cis-eQTLs, 144,427 trans-eQTLs
#
# 81.81% done, 146,037 trans-eQTLs
#
# 82.82% done, 147,904 trans-eQTLs
#
# 83.83% done, 843,891 cis-eQTLs, 149,870 trans-eQTLs
#
# 84.84% done, 849,728 cis-eQTLs, 151,225 trans-eQTLs
#
# 85.85% done, 153,496 trans-eQTLs
#
# 86.86% done, 155,461 trans-eQTLs
#
# 87.87% done, 934,810 cis-eQTLs, 156,552 trans-eQTLs
#
# 88.88% done, 158,539 trans-eQTLs
#
# 89.89% done, 160,569 trans-eQTLs
#
# 90.90% done, 985,553 cis-eQTLs, 161,681 trans-eQTLs
#
# 91.91% done, 163,982 trans-eQTLs
#
# 92.92% done, 165,893 trans-eQTLs
#
# 93.93% done, 1,013,977 cis-eQTLs, 167,677 trans-eQTLs
#
# 94.94% done, 169,342 trans-eQTLs
#
# 95.95% done, 171,429 trans-eQTLs
#
# 96.96% done, 1,054,921 cis-eQTLs, 172,580 trans-eQTLs
#
# 97.97% done, 174,381 trans-eQTLs
#
# 98.98% done, 175,838 trans-eQTLs
#
# 100.00% done, 1,109,255 cis-eQTLs, 177,110 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 5838 done.
#
# 5760 of 5838 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  1.01% done, 29,629 cis-eQTLs, 1,812 trans-eQTLs
#
#  2.02% done, 3,868 trans-eQTLs
#
#  3.03% done, 6,299 trans-eQTLs
#
#  4.04% done, 71,741 cis-eQTLs, 8,278 trans-eQTLs
#
#  5.05% done, 10,185 trans-eQTLs
#
#  6.06% done, 12,030 trans-eQTLs
#
#  7.07% done, 117,741 cis-eQTLs, 14,060 trans-eQTLs
#
#  8.08% done, 15,897 trans-eQTLs
#
#  9.09% done, 17,346 trans-eQTLs
#
# 10.10% done, 148,301 cis-eQTLs, 18,890 trans-eQTLs
#
# 11.11% done, 20,913 trans-eQTLs
#
# 12.12% done, 22,230 trans-eQTLs
#
# 13.13% done, 203,003 cis-eQTLs, 24,101 trans-eQTLs
#
# 14.14% done, 25,734 trans-eQTLs
#
# 15.15% done, 27,242 trans-eQTLs
#
# 16.16% done, 233,318 cis-eQTLs, 29,708 trans-eQTLs
#
# 17.17% done, 32,129 trans-eQTLs
#
# 18.18% done, 34,493 trans-eQTLs
#
# 19.19% done, 249,098 cis-eQTLs, 36,508 trans-eQTLs
#
# 20.20% done, 38,550 trans-eQTLs
#
# 21.21% done, 40,164 trans-eQTLs
#
# 22.22% done, 271,973 cis-eQTLs, 42,620 trans-eQTLs
#
# 23.23% done, 44,925 trans-eQTLs
#
# 24.24% done, 46,818 trans-eQTLs
#
# 25.25% done, 300,483 cis-eQTLs, 48,748 trans-eQTLs
#
# 26.26% done, 50,633 trans-eQTLs
#
# 27.27% done, 52,166 trans-eQTLs
#
# 28.28% done, 324,075 cis-eQTLs, 54,123 trans-eQTLs
#
# 29.29% done, 55,860 trans-eQTLs
#
# 30.30% done, 57,475 trans-eQTLs
#
# 31.31% done, 368,703 cis-eQTLs, 59,678 trans-eQTLs
#
# 32.32% done, 61,932 trans-eQTLs
#
# 33.33% done, 63,775 trans-eQTLs
#
# 34.34% done, 408,774 cis-eQTLs, 66,111 trans-eQTLs
#
# 35.35% done, 68,281 trans-eQTLs
#
# 36.36% done, 70,832 trans-eQTLs
#
# 37.37% done, 429,676 cis-eQTLs, 72,456 trans-eQTLs
#
# 38.38% done, 453,094 cis-eQTLs, 74,118 trans-eQTLs
#
# 39.39% done, 75,630 trans-eQTLs
#
# 40.40% done, 77,618 trans-eQTLs
#
# 41.41% done, 504,639 cis-eQTLs, 79,692 trans-eQTLs
#
# 42.42% done, 81,613 trans-eQTLs
#
# 43.43% done, 83,294 trans-eQTLs
#
# 44.44% done, 567,411 cis-eQTLs, 85,017 trans-eQTLs
#
# 45.45% done, 86,400 trans-eQTLs
#
# 46.46% done, 88,129 trans-eQTLs
#
# 47.47% done, 604,092 cis-eQTLs, 89,886 trans-eQTLs
#
# 48.48% done, 91,881 trans-eQTLs
#
# 49.49% done, 94,146 trans-eQTLs
#
# 50.50% done, 637,654 cis-eQTLs, 96,537 trans-eQTLs
#
# 51.51% done, 98,702 trans-eQTLs
#
# 52.52% done, 100,826 trans-eQTLs
#
# 53.53% done, 656,920 cis-eQTLs, 103,079 trans-eQTLs
#
# 54.54% done, 105,077 trans-eQTLs
#
# 55.55% done, 106,881 trans-eQTLs
#
# 56.56% done, 695,078 cis-eQTLs, 109,456 trans-eQTLs
#
# 57.57% done, 111,597 trans-eQTLs
#
# 58.58% done, 113,101 trans-eQTLs
#
# 59.59% done, 737,234 cis-eQTLs, 114,750 trans-eQTLs
#
# 60.60% done, 116,720 trans-eQTLs
#
# 61.61% done, 118,420 trans-eQTLs
#
# 62.62% done, 774,626 cis-eQTLs, 120,241 trans-eQTLs
#
# 63.63% done, 121,760 trans-eQTLs
#
# 64.64% done, 123,346 trans-eQTLs
#
# 65.65% done, 797,917 cis-eQTLs, 125,130 trans-eQTLs
#
# 66.66% done, 126,730 trans-eQTLs
#
# 67.67% done, 129,615 trans-eQTLs
#
# 68.68% done, 821,015 cis-eQTLs, 132,342 trans-eQTLs
#
# 69.69% done, 134,849 trans-eQTLs
#
# 70.70% done, 136,735 trans-eQTLs
#
# 71.71% done, 839,128 cis-eQTLs, 138,750 trans-eQTLs
#
# 72.72% done, 844,386 cis-eQTLs, 140,157 trans-eQTLs
#
# 73.73% done, 142,497 trans-eQTLs
#
# 74.74% done, 144,773 trans-eQTLs
#
# 75.75% done, 886,426 cis-eQTLs, 146,826 trans-eQTLs
#
# 76.76% done, 148,541 trans-eQTLs
#
# 77.77% done, 150,310 trans-eQTLs
#
# 78.78% done, 908,820 cis-eQTLs, 152,060 trans-eQTLs
#
# 79.79% done, 153,878 trans-eQTLs
#
# 80.80% done, 155,671 trans-eQTLs
#
# 81.81% done, 924,307 cis-eQTLs, 157,733 trans-eQTLs
#
# 82.82% done, 159,920 trans-eQTLs
#
# 83.83% done, 161,797 trans-eQTLs
#
# 84.84% done, 944,159 cis-eQTLs, 163,669 trans-eQTLs
#
# 85.85% done, 165,658 trans-eQTLs
#
# 86.86% done, 168,101 trans-eQTLs
#
# 87.87% done, 1,038,837 cis-eQTLs, 169,825 trans-eQTLs
#
# 88.88% done, 171,602 trans-eQTLs
#
# 89.89% done, 173,137 trans-eQTLs
#
# 90.90% done, 1,095,276 cis-eQTLs, 174,770 trans-eQTLs
#
# 91.91% done, 176,146 trans-eQTLs
#
# 92.92% done, 177,747 trans-eQTLs
#
# 93.93% done, 1,130,121 cis-eQTLs, 179,110 trans-eQTLs
#
# 94.94% done, 181,209 trans-eQTLs
#
# 95.95% done, 183,312 trans-eQTLs
#
# 96.96% done, 1,175,070 cis-eQTLs, 185,422 trans-eQTLs
#
# 97.97% done, 186,710 trans-eQTLs
#
# 98.98% done, 188,120 trans-eQTLs
#
# 100.00% done, 1,232,835 cis-eQTLs, 189,753 trans-eQTLs
