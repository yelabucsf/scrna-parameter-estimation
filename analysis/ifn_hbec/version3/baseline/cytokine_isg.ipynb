# %% [markdown]
# # Cell type differences and effects of interferon stimulation on immune cells
#
# Demonstrating differential expression between cell types and the effect of interferon stimulation within a cell type (CD4 T cells).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scanpy as sc
import scipy as sp
import itertools
import numpy as np
import scipy.stats as stats
from scipy.integrate import dblquad
import seaborn as sns
from statsmodels.stats.multitest import fdrcorrection
import imp
pd.options.display.max_rows = 999
pd.set_option('display.max_colwidth', 100)
import pickle as pkl
import time
# Out:
# /tmp/ipykernel_3425515/3878399115.py:11: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
# %matplotlib inline

# %%
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'medium',
         'axes.titlesize':'medium',
         'figure.titlesize':'medium',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small'}
pylab.rcParams.update(params)

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import warnings
# warnings.filterwarnings('ignore')

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import StandardScaler

# %%
import sys
sys.path.append('/home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg')
import memento

# %%
fig_path = '/home/ssm-user/Github/scrna-parameter-estimation/figures/fig4/main/'
data_path = '/data_volume/memento/hbec/'

# %% [markdown]
# ### Perform some basic filtering

# %%
adata = sc.read(data_path + 'HBEC_type_I_filtered_counts_deep.h5ad')

# %% [markdown]
# ### Setup memento

# %%
def assign_q(batch):
    
    if batch == 0:
        return 0.387*0.25
    elif batch == 1:
        return 0.392*0.25
    elif batch == 2:
        return 0.436*0.25
    else:
        return 0.417*0.25

# %%
adata.obs['q'] = adata.obs['batch'].apply(assign_q)

# %%
memento.setup_memento(adata, q_column='q')

# %% [markdown]
# ### WT cytokine variability

# %%
adata.obs.cell_type.value_counts()
# Out:
# cell_type
# basal/club       29792
# basal            22844
# ciliated         15041
# goblet            1525
# ionocyte/tuft      546
# neuroendo          210
# Name: count, dtype: int64

# %%
converter = {'basal/club':'BC', 'basal':'B', 'ciliated':'C', 'goblet':'G', 'ionocyte/tuft':'IT', 'neuroendo':'N'}

# %%
adata.obs['ct'] = adata.obs['cell_type'].apply(lambda x: converter[x])

# %%
ctrl = adata[(adata.obs.stim=='control') & (adata.obs.ct.isin(['B', 'BC', 'C']))].copy().copy()
ctrl.obs['group'] = 1
memento.create_groups(ctrl, label_columns=['ct', 'donor'])
memento.compute_1d_moments(ctrl, min_perc_group=.3)

m_df, v_df = memento.get_1d_moments(ctrl, groupby='ct')

cytokines = pd.read_csv('cytokines.txt')['Gene name'].tolist()
m_df['cytokine'] = m_df['gene'].isin(cytokines)
v_df['cytokine'] = v_df['gene'].isin(cytokines)
cytokines = v_df.query('cytokine').gene.tolist()

# %%
v_df_melt = v_df.melt(['gene', 'cytokine'], m_df.columns[1:-1])
m_df_melt = m_df.melt(['gene', 'cytokine'], m_df.columns[1:-1])

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x='variable', y='value', hue='cytokine',data=v_df_melt, fliersize=0.1)
plt.legend(bbox_to_anchor=(1,0.5), title='cytokine'); 
plt.ylabel('Variability'); plt.xlabel(None)
plt.ylim(-3.5,4)
# Out:
# (-3.5, 4.0)

# %% [markdown]
# ### Identify IFNB ISGs

# %%
ct = adata[(adata.obs.ct=='C') & adata.obs.time.isin(['0', '6']) & adata.obs.stim.isin(['control', 'beta'])].copy().copy()
ct.obs['stim_indicator'] = (ct.obs['stim']=='beta').astype(int)
memento.create_groups(ct, label_columns=['stim_indicator', 'donor'])
memento.compute_1d_moments(ct, min_perc_group=.9)

meta_df = memento.get_groups(ct)
treatment = meta_df[['stim_indicator']]
covariate = pd.get_dummies(meta_df[['donor']], drop_first=True)

memento.ht_1d_moments(
        ct, 
        covariate=covariate,
        treatment=treatment,
        num_boot=10000, 
        verbose=1,
        num_cpus=14,
        resample_rep=False,
        approx=False)
# Out:
# [Parallel(n_jobs=14)]: Using backend LokyBackend with 14 concurrent workers.
# [Parallel(n_jobs=14)]: Done  22 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=14)]: Done 172 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=14)]: Done 422 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=14)]: Done 772 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=14)]: Done 1222 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=14)]: Done 1772 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=14)]: Done 2422 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=14)]: Done 3172 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=14)]: Done 4022 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=14)]: Done 4972 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=14)]: Done 6022 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=14)]: Done 7172 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=14)]: Done 8422 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=14)]: Done 9679 out of 9679 | elapsed:  4.2min finished

# %%
ct_df = memento.get_1d_ht_result(ct)
ct_df['de_fdr'] = memento.util._fdrcorrect(ct_df['de_pval'])
ifnb_isg = ct_df.query('de_coef > 1 & de_fdr < 0.1').gene.tolist()

# %% [markdown]
# ### Do the same thing for ISGs

# %%
def get_labeled_variability(adata, key):
    
    m_df, v_df = memento.get_1d_moments(adata, groupby=key)
    
    m_df['cytokine'] = m_df['gene'].isin(cytokines)
    v_df['cytokine'] = v_df['gene'].isin(cytokines)
    m_df['ifnb_isg'] = m_df['gene'].isin(ifnb_isg)
    v_df['ifnb_isg'] = v_df['gene'].isin(ifnb_isg)
    ifnb_isg_ctrl = m_df.query('ifnb_isg').gene.tolist()
    
    v_df_melt = v_df.melt(['gene', 'cytokine', 'ifnb_isg'], v_df.columns[1:-2])
    m_df_melt = m_df.melt(['gene', 'cytokine', 'ifnb_isg'], m_df.columns[1:-2])
    
    return m_df_melt, v_df_melt

# %%
hbec_m, hbec_v = get_labeled_variability(ctrl, 'ct')
# Out:
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x='variable', y='value', hue='ifnb_isg',data=hbec_v, fliersize=0.1)
plt.legend(bbox_to_anchor=(1,0.5), title='ifnb_isg'); 
plt.ylabel('Variability'); plt.xlabel(None)
plt.ylim(-3.5,4)
# Out:
# (-3.5, 4.0)

# %% [markdown]
# ### Do the same in PBMCs

# %%
pbmc = sc.datasets.pbmc3k_processed()
pbmc = sc.AnnData(X=pbmc.raw.X.expm1(), obs = pbmc.obs, var=pbmc.raw.var)

# %%
pbmc.obs['group'] = 1
pbmc.obs['q'] = 0.1
memento.setup_memento(pbmc, q_column='q')
memento.create_groups(pbmc, label_columns=['louvain'])
memento.compute_1d_moments(pbmc, min_perc_group=.3)

pbmc_m, pbmc_v = get_labeled_variability(pbmc, 'louvain')
# Out:
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:563: RuntimeWarning: divide by zero encountered in log
#   moment_mean_df[group] = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:590: RuntimeWarning: divide by zero encountered in log
#   m = np.log(val[0])
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.1.0-py3.10.egg/memento/main.py:602: RuntimeWarning: invalid value encountered in divide
#   groupby_var[key] /= groupby_var_count[key]

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x='variable', y='value', hue='ifnb_isg',data=pbmc_v, fliersize=0.1)
plt.legend(bbox_to_anchor=(1,0.5), title='ifnb_isg'); 
plt.ylabel('Variability'); plt.xlabel(None); plt.xticks(rotation=90);
# plt.ylim(-3.5,4)

# %% [markdown]
# ### All gene correlations

# %%
def get_ct_correlation(df, ct1, ct2, s=5, color='grey', alpha=1):
    
    df1 = df.query('variable == "{}"'.format(ct1))
    df2 = df.query('variable == "{}"'.format(ct2))
    joined = df1.merge(df2, on='gene')
    # print(joined)
    plt.scatter(x=joined.dropna()['value_x'], y=joined.dropna()['value_y'],s=s, color=color, alpha=alpha)
    # r,p = stats.pearsonr(joined.dropna()['value_x'], joined.dropna()['value_y'])
    # plt.title('R={:.2f}, p={:.2f}'.format(r,p))
    # plt.xlabel(ct1.split('_')[1]);plt.ylabel(ct2.split('_')[1])

# %%
all_v = pd.concat([pbmc_v, hbec_v])
isg_v = pd.concat([pbmc_v.query('ifnb_isg'), hbec_v.query('ifnb_isg')])
hbec_cts, pbmc_cts = hbec_v.variable.drop_duplicates().tolist(), pbmc_v.variable.drop_duplicates().tolist()

# %%
pbmc_cts
# Out:
# ['louvain_CD4 T cells',
#  'louvain_B cells',
#  'louvain_CD14+ Monocytes',
#  'louvain_NK cells',
#  'louvain_CD8 T cells',
#  'louvain_FCGR3A+ Monocytes',
#  'louvain_Dendritic cells',
#  'louvain_Megakaryocytes']

# %%
plt.figure(figsize=(3, 3));
plt.subplots_adjust(wspace=0.6, hspace=0.8)
# idx=1
for c1, c2 in itertools.product(['ct_C'], ['louvain_CD4 T cells']):
    

    get_ct_correlation(all_v, c1, c2, s=5, color='lightgrey', alpha=0.08)
    get_ct_correlation(isg_v, c1, c2, s=10, color='orange')
    plt.xlabel('Ciliated cells'); plt.ylabel(c2.split('_')[1])
    # plt.axhline(y=0, color='k',ls='--')
    # plt.axvline(x=0, color='k', ls='--')
    
    # if idx == 3:
    #     plt.title('Expression variablities across cell types')
    # idx +=1 

plt.savefig('c_cd4_variabilities.png', dpi=100, bbox_inches='tight')

# %%
plt.figure(figsize=(15, 2));
plt.subplots_adjust(wspace=0.6, hspace=0.8)
idx=1
for c1, c2 in itertools.product(['ct_C'], pbmc_cts[:5] + ['louvain_Dendritic cells']):
    
    print(c1, c2)
    plt.subplot(1, 7, idx)
    
    get_ct_correlation(all_v, c1, c2, s=1, color='lightgrey', alpha=0.2)
    get_ct_correlation(isg_v, c1, c2, s=5, color='orange')
    plt.xlabel('Ciliated cells'); plt.ylabel(c2.split('_')[1])
    # plt.axhline(y=0, color='k',ls='--')
    # plt.axvline(x=0, color='k', ls='--')
    
    if idx == 3:
        plt.title('Expression variablities across cell types')
    idx +=1 

# plt.savefig('hbec_pbmc_varibilities.png', dpi=100, bbox_inches='tight')
# Out:
# ct_C louvain_CD4 T cells
# ct_C louvain_B cells
# ct_C louvain_CD14+ Monocytes
# ct_C louvain_NK cells
# ct_C louvain_CD8 T cells
# ct_C louvain_Dendritic cells

# %% [markdown]
# ### ISG correlations

# %%
isg_v = pd.concat([pbmc_v.query('ifnb_isg'), hbec_v.query('ifnb_isg')])

# %%
plt.figure(figsize=(15, 5));
plt.subplots_adjust(wspace=1, hspace=0.8)
idx=1
for c1, c2 in itertools.product(hbec_cts, pbmc_cts):
    
    plt.subplot(3, 8, idx)
    
    get_ct_correlation(isg_v, c1, c2)
    idx +=1 
plt.savefig('hbec_pbmc_varibilities.png', dpi=100, bbox_inches='tight')

# %%
len(list())
# Out:
# 24

# %%
get_ct_correlation(isg_v, 'ct_B', 'louvain_CD4 T cells')

# %%
isg_v
# Out:
#              gene  cytokine  ifnb_isg                   variable     value
# 2           ISG15     False      True        louvain_CD4 T cells  1.988591
# 58           IFI6     False      True        louvain_CD4 T cells  1.860306
# 142        IFI44L     False      True        louvain_CD4 T cells  1.850379
# 143         IFI44     False      True        louvain_CD4 T cells -0.497812
# 152          GBP1     False      True        louvain_CD4 T cells  3.197121
# 335         CMPK2     False      True        louvain_CD4 T cells  0.638500
# 494         STAT1     False      True        louvain_CD4 T cells  0.082344
# 526         SP110     False      True        louvain_CD4 T cells  0.423761
# 644         PARP9     False      True        louvain_CD4 T cells -0.765446
# 645        PARP14     False      True        louvain_CD4 T cells  0.274536
# 680       TNFSF10      True      True        louvain_CD4 T cells  1.213114
# 754         PPM1K     False      True        louvain_CD4 T cells -0.542358
# 842       C5orf56     False      True        louvain_CD4 T cells  3.433691
# 941          GMPR     False      True        louvain_CD4 T cells  1.053543
# 954         HLA-F     False      True        louvain_CD4 T cells -1.675446
# 958         HLA-E     False      True        louvain_CD4 T cells  0.112380
# 991         PSMB9     False      True        louvain_CD4 T cells  0.999282
# 992          TAP1     False      True        louvain_CD4 T cells  0.307409
# 1128       NT5C3A     False      True        louvain_CD4 T cells  3.904471
# 1177       SAMD9L     False      True        louvain_CD4 T cells  1.038715
# 1415         LY6E     False      True        louvain_CD4 T cells  0.979928
# 1586        IFIT2     False      True        louvain_CD4 T cells  0.829294
# 1587        IFIT3     False      True        louvain_CD4 T cells  1.507357
# 1588        IFIT1     False      True        louvain_CD4 T cells  3.939892
# 1627       IFITM2     False      True        louvain_CD4 T cells  0.625415
# 1628       IFITM1     False      True        louvain_CD4 T cells -0.723788
# 1629       IFITM3     False      True        louvain_CD4 T cells  0.381256
# 1632         IRF7     False      True        louvain_CD4 T cells -0.227121
# 1649       TRIM22     False      True        louvain_CD4 T cells -1.769510
# 1688       UBE2L6     False      True        louvain_CD4 T cells -0.603598
# 1980         OAS1     False      True        louvain_CD4 T cells  3.514752
# 1981         OAS3     False      True        louvain_CD4 T cells  0.101027
# 1982         OAS2     False      True        louvain_CD4 T cells -0.477133
# 1996         OASL     False      True        louvain_CD4 T cells  2.819283
# 2033       EPSTI1     False      True        louvain_CD4 T cells  0.062712
# 2145        IFI27     False      True        louvain_CD4 T cells  1.884571
# 2154         WARS     False      True        louvain_CD4 T cells -0.122759
# 2183       TRIM69     False      True        louvain_CD4 T cells -1.438374
# 2241        ISG20     False      True        louvain_CD4 T cells  0.251451
# 2336         MT2A     False      True        louvain_CD4 T cells  0.981894
# 2409         XAF1     False      True        louvain_CD4 T cells  0.672611
# 2421         CD68     False      True        louvain_CD4 T cells  0.941355
# 2442       LGALS9     False      True        louvain_CD4 T cells -0.392956
# 2486        IFI35     False      True        louvain_CD4 T cells  2.510699
# 2554     LGALS3BP     False      True        louvain_CD4 T cells  1.288177
# 2777     C19orf38     False      True        louvain_CD4 T cells  0.667397
# 2810        HSH2D     False      True        louvain_CD4 T cells -0.463383
# 2819         BST2     False      True        louvain_CD4 T cells -0.766334
# 3064          MX2     False      True        louvain_CD4 T cells  1.449757
# 3065          MX1     False      True        louvain_CD4 T cells  0.816288
# 3093        ISG15     False      True            louvain_B cells  2.547982
# 3149         IFI6     False      True            louvain_B cells  1.651705
# 3233       IFI44L     False      True            louvain_B cells -0.095062
# 3234        IFI44     False      True            louvain_B cells  0.126482
# 3243         GBP1     False      True            louvain_B cells  0.497118
# 3426        CMPK2     False      True            louvain_B cells  0.837479
# 3585        STAT1     False      True            louvain_B cells -0.798267
# 3617        SP110     False      True            louvain_B cells -1.002651
# 3735        PARP9     False      True            louvain_B cells -0.450869
# 3736       PARP14     False      True            louvain_B cells -0.348757
# 3771      TNFSF10      True      True            louvain_B cells -0.529310
# 3845        PPM1K     False      True            louvain_B cells -0.459787
# 3933      C5orf56     False      True            louvain_B cells -0.834976
# 4032         GMPR     False      True            louvain_B cells -0.212471
# 4045        HLA-F     False      True            louvain_B cells -0.917517
# 4049        HLA-E     False      True            louvain_B cells  0.705611
# 4082        PSMB9     False      True            louvain_B cells -0.102556
# 4083         TAP1     False      True            louvain_B cells -0.805979
# 4219       NT5C3A     False      True            louvain_B cells -1.976116
# 4268       SAMD9L     False      True            louvain_B cells  3.548303
# 4506         LY6E     False      True            louvain_B cells  1.392343
# 4677        IFIT2     False      True            louvain_B cells  4.398087
# 4678        IFIT3     False      True            louvain_B cells  0.659952
# 4679        IFIT1     False      True            louvain_B cells  1.005325
# 4718       IFITM2     False      True            louvain_B cells -0.445459
# 4719       IFITM1     False      True            louvain_B cells  0.555225
# 4720       IFITM3     False      True            louvain_B cells  0.818783
# 4723         IRF7     False      True            louvain_B cells  0.060022
# 4740       TRIM22     False      True            louvain_B cells -0.996391
# 4779       UBE2L6     False      True            louvain_B cells  4.027221
# 5071         OAS1     False      True            louvain_B cells  0.246435
# 5072         OAS3     False      True            louvain_B cells  1.743311
# 5073         OAS2     False      True            louvain_B cells -0.924084
# 5087         OASL     False      True            louvain_B cells -0.302856
# 5124       EPSTI1     False      True            louvain_B cells  0.767845
# 5236        IFI27     False      True            louvain_B cells -0.258726
# 5245         WARS     False      True            louvain_B cells  1.740919
# 5274       TRIM69     False      True            louvain_B cells  3.593633
# 5332        ISG20     False      True            louvain_B cells  0.512727
# 5427         MT2A     False      True            louvain_B cells  2.586861
# 5500         XAF1     False      True            louvain_B cells -1.492823
# 5512         CD68     False      True            louvain_B cells  1.395433
# 5533       LGALS9     False      True            louvain_B cells  0.494707
# 5577        IFI35     False      True            louvain_B cells  2.325344
# 5645     LGALS3BP     False      True            louvain_B cells  4.223141
# 5868     C19orf38     False      True            louvain_B cells -0.083601
# 5901        HSH2D     False      True            louvain_B cells  0.353485
# 5910         BST2     False      True            louvain_B cells  0.228064
# 6155          MX2     False      True            louvain_B cells  0.066982
# 6156          MX1     False      True            louvain_B cells  2.105537
# 6184        ISG15     False      True    louvain_CD14+ Monocytes  0.728223
# 6240         IFI6     False      True    louvain_CD14+ Monocytes -0.173448
# 6324       IFI44L     False      True    louvain_CD14+ Monocytes -0.489080
# 6325        IFI44     False      True    louvain_CD14+ Monocytes -0.241350
# 6334         GBP1     False      True    louvain_CD14+ Monocytes -0.486540
# 6517        CMPK2     False      True    louvain_CD14+ Monocytes -0.197218
# 6676        STAT1     False      True    louvain_CD14+ Monocytes -0.028347
# 6708        SP110     False      True    louvain_CD14+ Monocytes -0.678066
# 6826        PARP9     False      True    louvain_CD14+ Monocytes -1.587744
# 6827       PARP14     False      True    louvain_CD14+ Monocytes -0.588230
# 6862      TNFSF10      True      True    louvain_CD14+ Monocytes  1.931420
# 6936        PPM1K     False      True    louvain_CD14+ Monocytes -0.436575
# 7024      C5orf56     False      True    louvain_CD14+ Monocytes -0.425119
# 7123         GMPR     False      True    louvain_CD14+ Monocytes  3.198198
# 7136        HLA-F     False      True    louvain_CD14+ Monocytes -0.721554
# 7140        HLA-E     False      True    louvain_CD14+ Monocytes  0.466201
# 7173        PSMB9     False      True    louvain_CD14+ Monocytes -0.660888
# 7174         TAP1     False      True    louvain_CD14+ Monocytes -0.409962
# 7310       NT5C3A     False      True    louvain_CD14+ Monocytes  4.157369
# 7359       SAMD9L     False      True    louvain_CD14+ Monocytes -1.241146
# 7597         LY6E     False      True    louvain_CD14+ Monocytes  0.238358
# 7768        IFIT2     False      True    louvain_CD14+ Monocytes  1.701807
# 7769        IFIT3     False      True    louvain_CD14+ Monocytes  1.291536
# 7770        IFIT1     False      True    louvain_CD14+ Monocytes  1.507671
# 7809       IFITM2     False      True    louvain_CD14+ Monocytes  0.922240
# 7810       IFITM1     False      True    louvain_CD14+ Monocytes  0.091675
# 7811       IFITM3     False      True    louvain_CD14+ Monocytes  0.652030
# 7814         IRF7     False      True    louvain_CD14+ Monocytes -0.444265
# 7831       TRIM22     False      True    louvain_CD14+ Monocytes -1.011496
# 7870       UBE2L6     False      True    louvain_CD14+ Monocytes  1.860855
# 8162         OAS1     False      True    louvain_CD14+ Monocytes -0.702055
# 8163         OAS3     False      True    louvain_CD14+ Monocytes  0.004809
# 8164         OAS2     False      True    louvain_CD14+ Monocytes -0.066088
# 8178         OASL     False      True    louvain_CD14+ Monocytes -0.280094
# 8215       EPSTI1     False      True    louvain_CD14+ Monocytes -0.377884
# 8327        IFI27     False      True    louvain_CD14+ Monocytes  3.323935
# 8336         WARS     False      True    louvain_CD14+ Monocytes  1.976590
# 8365       TRIM69     False      True    louvain_CD14+ Monocytes -0.151905
# 8423        ISG20     False      True    louvain_CD14+ Monocytes  0.517143
# 8518         MT2A     False      True    louvain_CD14+ Monocytes  0.533678
# 8591         XAF1     False      True    louvain_CD14+ Monocytes -0.601240
# 8603         CD68     False      True    louvain_CD14+ Monocytes -0.296114
# 8624       LGALS9     False      True    louvain_CD14+ Monocytes -1.246849
# 8668        IFI35     False      True    louvain_CD14+ Monocytes  2.206495
# 8736     LGALS3BP     False      True    louvain_CD14+ Monocytes  0.129171
# 8959     C19orf38     False      True    louvain_CD14+ Monocytes -1.184944
# 8992        HSH2D     False      True    louvain_CD14+ Monocytes  0.312355
# 9001         BST2     False      True    louvain_CD14+ Monocytes  0.821909
# 9246          MX2     False      True    louvain_CD14+ Monocytes -0.390408
# 9247          MX1     False      True    louvain_CD14+ Monocytes -0.333099
# 9275        ISG15     False      True           louvain_NK cells  0.318302
# 9331         IFI6     False      True           louvain_NK cells  0.042879
# 9415       IFI44L     False      True           louvain_NK cells  0.541504
# 9416        IFI44     False      True           louvain_NK cells  0.117701
# 9425         GBP1     False      True           louvain_NK cells  3.149833
# 9608        CMPK2     False      True           louvain_NK cells -0.099279
# 9767        STAT1     False      True           louvain_NK cells  1.281765
# 9799        SP110     False      True           louvain_NK cells -0.460421
# 9917        PARP9     False      True           louvain_NK cells -1.584043
# 9918       PARP14     False      True           louvain_NK cells -1.860321
# 9953      TNFSF10      True      True           louvain_NK cells  0.267466
# 10027       PPM1K     False      True           louvain_NK cells -0.970280
# 10115     C5orf56     False      True           louvain_NK cells -0.910452
# 10214        GMPR     False      True           louvain_NK cells       NaN
# 10227       HLA-F     False      True           louvain_NK cells  3.026010
# 10231       HLA-E     False      True           louvain_NK cells  1.425335
# 10264       PSMB9     False      True           louvain_NK cells -0.031850
# 10265        TAP1     False      True           louvain_NK cells       NaN
# 10401      NT5C3A     False      True           louvain_NK cells -2.184729
# 10450      SAMD9L     False      True           louvain_NK cells       NaN
# 10688        LY6E     False      True           louvain_NK cells  0.426706
# 10859       IFIT2     False      True           louvain_NK cells -1.016829
# 10860       IFIT3     False      True           louvain_NK cells -0.235666
# 10861       IFIT1     False      True           louvain_NK cells  1.302704
# 10900      IFITM2     False      True           louvain_NK cells -0.420396
# 10901      IFITM1     False      True           louvain_NK cells -0.042806
# 10902      IFITM3     False      True           louvain_NK cells  1.230972
# 10905        IRF7     False      True           louvain_NK cells  2.565246
# 10922      TRIM22     False      True           louvain_NK cells -2.480066
# 10961      UBE2L6     False      True           louvain_NK cells -0.722055
# 11253        OAS1     False      True           louvain_NK cells -0.006468
# 11254        OAS3     False      True           louvain_NK cells -1.223835
# 11255        OAS2     False      True           louvain_NK cells  0.622768
# 11269        OASL     False      True           louvain_NK cells  0.225918
# 11306      EPSTI1     False      True           louvain_NK cells -0.520468
# 11418       IFI27     False      True           louvain_NK cells -0.684073
# 11427        WARS     False      True           louvain_NK cells -1.350882
# 11456      TRIM69     False      True           louvain_NK cells  0.096846
# 11514       ISG20     False      True           louvain_NK cells -0.053053
# 11609        MT2A     False      True           louvain_NK cells  0.492062
# 11682        XAF1     False      True           louvain_NK cells -0.355249
# 11694        CD68     False      True           louvain_NK cells -0.772066
# 11715      LGALS9     False      True           louvain_NK cells  0.647881
# 11759       IFI35     False      True           louvain_NK cells  1.459501
# 11827    LGALS3BP     False      True           louvain_NK cells -0.476849
# 12050    C19orf38     False      True           louvain_NK cells       NaN
# 12083       HSH2D     False      True           louvain_NK cells  1.088320
# 12092        BST2     False      True           louvain_NK cells -3.104966
# 12337         MX2     False      True           louvain_NK cells -1.404217
# 12338         MX1     False      True           louvain_NK cells  0.475569
# 12366       ISG15     False      True        louvain_CD8 T cells  0.633013
# 12422        IFI6     False      True        louvain_CD8 T cells  0.629383
# 12506      IFI44L     False      True        louvain_CD8 T cells  0.672070
# 12507       IFI44     False      True        louvain_CD8 T cells  4.357801
# 12516        GBP1     False      True        louvain_CD8 T cells -0.956932
# 12699       CMPK2     False      True        louvain_CD8 T cells -0.426945
# 12858       STAT1     False      True        louvain_CD8 T cells  0.322624
# 12890       SP110     False      True        louvain_CD8 T cells -0.267296
# 13008       PARP9     False      True        louvain_CD8 T cells  0.651194
# 13009      PARP14     False      True        louvain_CD8 T cells  0.501135
# 13044     TNFSF10      True      True        louvain_CD8 T cells -0.339922
# 13118       PPM1K     False      True        louvain_CD8 T cells -0.400846
# 13206     C5orf56     False      True        louvain_CD8 T cells  0.309441
# 13305        GMPR     False      True        louvain_CD8 T cells       NaN
# 13318       HLA-F     False      True        louvain_CD8 T cells -0.279562
# 13322       HLA-E     False      True        louvain_CD8 T cells  0.469311
# 13355       PSMB9     False      True        louvain_CD8 T cells -1.398575
# 13356        TAP1     False      True        louvain_CD8 T cells -1.017708
# 13492      NT5C3A     False      True        louvain_CD8 T cells  1.983999
# 13541      SAMD9L     False      True        louvain_CD8 T cells -3.425058
# 13779        LY6E     False      True        louvain_CD8 T cells -0.798511
# 13950       IFIT2     False      True        louvain_CD8 T cells -0.236048
# 13951       IFIT3     False      True        louvain_CD8 T cells -1.027971
# 13952       IFIT1     False      True        louvain_CD8 T cells  1.024017
# 13991      IFITM2     False      True        louvain_CD8 T cells -1.082314
# 13992      IFITM1     False      True        louvain_CD8 T cells -0.525834
# 13993      IFITM3     False      True        louvain_CD8 T cells  2.695063
# 13996        IRF7     False      True        louvain_CD8 T cells  3.577739
# 14013      TRIM22     False      True        louvain_CD8 T cells -0.305306
# 14052      UBE2L6     False      True        louvain_CD8 T cells -1.129164
# 14344        OAS1     False      True        louvain_CD8 T cells  0.407820
# 14345        OAS3     False      True        louvain_CD8 T cells -0.703781
# 14346        OAS2     False      True        louvain_CD8 T cells  0.060297
# 14360        OASL     False      True        louvain_CD8 T cells -1.466869
# 14397      EPSTI1     False      True        louvain_CD8 T cells -0.985777
# 14509       IFI27     False      True        louvain_CD8 T cells  2.925167
# 14518        WARS     False      True        louvain_CD8 T cells -1.085825
# 14547      TRIM69     False      True        louvain_CD8 T cells -0.961741
# 14605       ISG20     False      True        louvain_CD8 T cells -0.571783
# 14700        MT2A     False      True        louvain_CD8 T cells  0.394623
# 14773        XAF1     False      True        louvain_CD8 T cells -0.048773
# 14785        CD68     False      True        louvain_CD8 T cells -0.624161
# 14806      LGALS9     False      True        louvain_CD8 T cells -0.450611
# 14850       IFI35     False      True        louvain_CD8 T cells -2.070322
# 14918    LGALS3BP     False      True        louvain_CD8 T cells  1.019495
# 15141    C19orf38     False      True        louvain_CD8 T cells  0.860407
# 15174       HSH2D     False      True        louvain_CD8 T cells -1.287382
# 15183        BST2     False      True        louvain_CD8 T cells -0.905092
# 15428         MX2     False      True        louvain_CD8 T cells  2.754892
# 15429         MX1     False      True        louvain_CD8 T cells  0.402563
# 15457       ISG15     False      True  louvain_FCGR3A+ Monocytes  0.554052
# 15513        IFI6     False      True  louvain_FCGR3A+ Monocytes  0.089649
# 15597      IFI44L     False      True  louvain_FCGR3A+ Monocytes  0.378466
# 15598       IFI44     False      True  louvain_FCGR3A+ Monocytes  0.632856
# 15607        GBP1     False      True  louvain_FCGR3A+ Monocytes  0.984882
# 15790       CMPK2     False      True  louvain_FCGR3A+ Monocytes  0.262342
# 15949       STAT1     False      True  louvain_FCGR3A+ Monocytes -2.235464
# 15981       SP110     False      True  louvain_FCGR3A+ Monocytes -0.345219
# 16099       PARP9     False      True  louvain_FCGR3A+ Monocytes -0.351751
# 16100      PARP14     False      True  louvain_FCGR3A+ Monocytes  0.661221
# 16135     TNFSF10      True      True  louvain_FCGR3A+ Monocytes  2.769552
# 16209       PPM1K     False      True  louvain_FCGR3A+ Monocytes -1.077522
# 16297     C5orf56     False      True  louvain_FCGR3A+ Monocytes  0.889669
# 16396        GMPR     False      True  louvain_FCGR3A+ Monocytes -1.131491
# 16409       HLA-F     False      True  louvain_FCGR3A+ Monocytes       NaN
# 16413       HLA-E     False      True  louvain_FCGR3A+ Monocytes -0.119062
# 16446       PSMB9     False      True  louvain_FCGR3A+ Monocytes  0.595234
# 16447        TAP1     False      True  louvain_FCGR3A+ Monocytes -0.124779
# 16583      NT5C3A     False      True  louvain_FCGR3A+ Monocytes       NaN
# 16632      SAMD9L     False      True  louvain_FCGR3A+ Monocytes -0.665695
# 16870        LY6E     False      True  louvain_FCGR3A+ Monocytes  0.055884
# 17041       IFIT2     False      True  louvain_FCGR3A+ Monocytes  0.537970
# 17042       IFIT3     False      True  louvain_FCGR3A+ Monocytes -0.017273
# 17043       IFIT1     False      True  louvain_FCGR3A+ Monocytes -0.309435
# 17082      IFITM2     False      True  louvain_FCGR3A+ Monocytes  0.063384
# 17083      IFITM1     False      True  louvain_FCGR3A+ Monocytes -0.579213
# 17084      IFITM3     False      True  louvain_FCGR3A+ Monocytes  0.823956
# 17087        IRF7     False      True  louvain_FCGR3A+ Monocytes -0.645247
# 17104      TRIM22     False      True  louvain_FCGR3A+ Monocytes -1.049618
# 17143      UBE2L6     False      True  louvain_FCGR3A+ Monocytes       NaN
# 17435        OAS1     False      True  louvain_FCGR3A+ Monocytes -0.249624
# 17436        OAS3     False      True  louvain_FCGR3A+ Monocytes -1.364885
# 17437        OAS2     False      True  louvain_FCGR3A+ Monocytes -0.248177
# 17451        OASL     False      True  louvain_FCGR3A+ Monocytes  0.549240
# 17488      EPSTI1     False      True  louvain_FCGR3A+ Monocytes  2.731542
# 17600       IFI27     False      True  louvain_FCGR3A+ Monocytes  3.813997
# 17609        WARS     False      True  louvain_FCGR3A+ Monocytes  1.473323
# 17638      TRIM69     False      True  louvain_FCGR3A+ Monocytes -0.127407
# 17696       ISG20     False      True  louvain_FCGR3A+ Monocytes -0.989353
# 17791        MT2A     False      True  louvain_FCGR3A+ Monocytes  1.055562
# 17864        XAF1     False      True  louvain_FCGR3A+ Monocytes -0.142342
# 17876        CD68     False      True  louvain_FCGR3A+ Monocytes -2.207580
# 17897      LGALS9     False      True  louvain_FCGR3A+ Monocytes  0.756045
# 17941       IFI35     False      True  louvain_FCGR3A+ Monocytes -0.255180
# 18009    LGALS3BP     False      True  louvain_FCGR3A+ Monocytes -0.859991
# 18232    C19orf38     False      True  louvain_FCGR3A+ Monocytes -1.627170
# 18265       HSH2D     False      True  louvain_FCGR3A+ Monocytes -0.560022
# 18274        BST2     False      True  louvain_FCGR3A+ Monocytes  0.848069
# 18519         MX2     False      True  louvain_FCGR3A+ Monocytes -0.192419
# 18520         MX1     False      True  louvain_FCGR3A+ Monocytes  3.217884
# 18548       ISG15     False      True    louvain_Dendritic cells  1.591809
# 18604        IFI6     False      True    louvain_Dendritic cells  2.639760
# 18688      IFI44L     False      True    louvain_Dendritic cells -2.103174
# 18689       IFI44     False      True    louvain_Dendritic cells       NaN
# 18698        GBP1     False      True    louvain_Dendritic cells       NaN
# 18881       CMPK2     False      True    louvain_Dendritic cells -1.245577
# 19040       STAT1     False      True    louvain_Dendritic cells -0.620609
# 19072       SP110     False      True    louvain_Dendritic cells       NaN
# 19190       PARP9     False      True    louvain_Dendritic cells       NaN
# 19191      PARP14     False      True    louvain_Dendritic cells       NaN
# 19226     TNFSF10      True      True    louvain_Dendritic cells  0.207359
# 19300       PPM1K     False      True    louvain_Dendritic cells  0.954426
# 19388     C5orf56     False      True    louvain_Dendritic cells  0.318005
# 19487        GMPR     False      True    louvain_Dendritic cells  0.889555
# 19500       HLA-F     False      True    louvain_Dendritic cells  0.480455
# 19504       HLA-E     False      True    louvain_Dendritic cells -0.072310
# 19537       PSMB9     False      True    louvain_Dendritic cells -1.251883
# 19538        TAP1     False      True    louvain_Dendritic cells  0.435947
# 19674      NT5C3A     False      True    louvain_Dendritic cells       NaN
# 19723      SAMD9L     False      True    louvain_Dendritic cells  0.413690
# 19961        LY6E     False      True    louvain_Dendritic cells  0.729479
# 20132       IFIT2     False      True    louvain_Dendritic cells  1.956209
# 20133       IFIT3     False      True    louvain_Dendritic cells       NaN
# 20134       IFIT1     False      True    louvain_Dendritic cells  1.657610
# 20173      IFITM2     False      True    louvain_Dendritic cells  0.018786
# 20174      IFITM1     False      True    louvain_Dendritic cells  0.014864
# 20175      IFITM3     False      True    louvain_Dendritic cells  2.794632
# 20178        IRF7     False      True    louvain_Dendritic cells  2.697209
# 20195      TRIM22     False      True    louvain_Dendritic cells -1.746025
# 20234      UBE2L6     False      True    louvain_Dendritic cells -0.931993
# 20526        OAS1     False      True    louvain_Dendritic cells  0.335749
# 20527        OAS3     False      True    louvain_Dendritic cells  1.467382
# 20528        OAS2     False      True    louvain_Dendritic cells  0.016789
# 20542        OASL     False      True    louvain_Dendritic cells       NaN
# 20579      EPSTI1     False      True    louvain_Dendritic cells  0.054525
# 20691       IFI27     False      True    louvain_Dendritic cells  2.271690
# 20700        WARS     False      True    louvain_Dendritic cells  0.595833
# 20729      TRIM69     False      True    louvain_Dendritic cells  0.007517
# 20787       ISG20     False      True    louvain_Dendritic cells  0.687372
# 20882        MT2A     False      True    louvain_Dendritic cells  1.106350
# 20955        XAF1     False      True    louvain_Dendritic cells  1.558464
# 20967        CD68     False      True    louvain_Dendritic cells  1.132185
# 20988      LGALS9     False      True    louvain_Dendritic cells -1.866917
# 21032       IFI35     False      True    louvain_Dendritic cells  1.872683
# 21100    LGALS3BP     False      True    louvain_Dendritic cells  0.950596
# 21323    C19orf38     False      True    louvain_Dendritic cells       NaN
# 21356       HSH2D     False      True    louvain_Dendritic cells       NaN
# 21365        BST2     False      True    louvain_Dendritic cells -1.585695
# 21610         MX2     False      True    louvain_Dendritic cells -1.157400
# 21611         MX1     False      True    louvain_Dendritic cells -0.078093
# 21639       ISG15     False      True     louvain_Megakaryocytes  1.458415
# 21695        IFI6     False      True     louvain_Megakaryocytes       NaN
# 21779      IFI44L     False      True     louvain_Megakaryocytes       NaN
# 21780       IFI44     False      True     louvain_Megakaryocytes       NaN
# 21789        GBP1     False      True     louvain_Megakaryocytes -3.413498
# 21972       CMPK2     False      True     louvain_Megakaryocytes -3.413498
# 22131       STAT1     False      True     louvain_Megakaryocytes       NaN
# 22163       SP110     False      True     louvain_Megakaryocytes -3.413498
# 22281       PARP9     False      True     louvain_Megakaryocytes       NaN
# 22282      PARP14     False      True     louvain_Megakaryocytes       NaN
# 22317     TNFSF10      True      True     louvain_Megakaryocytes  1.095264
# 22391       PPM1K     False      True     louvain_Megakaryocytes       NaN
# 22479     C5orf56     False      True     louvain_Megakaryocytes -2.337214
# 22578        GMPR     False      True     louvain_Megakaryocytes  1.727540
# 22591       HLA-F     False      True     louvain_Megakaryocytes -1.407692
# 22595       HLA-E     False      True     louvain_Megakaryocytes -1.031914
# 22628       PSMB9     False      True     louvain_Megakaryocytes  0.712157
# 22629        TAP1     False      True     louvain_Megakaryocytes       NaN
# 22765      NT5C3A     False      True     louvain_Megakaryocytes  0.540238
# 22814      SAMD9L     False      True     louvain_Megakaryocytes -3.413498
# 23052        LY6E     False      True     louvain_Megakaryocytes  1.375802
# 23223       IFIT2     False      True     louvain_Megakaryocytes       NaN
# 23224       IFIT3     False      True     louvain_Megakaryocytes -1.389893
# 23225       IFIT1     False      True     louvain_Megakaryocytes -2.288361
# 23264      IFITM2     False      True     louvain_Megakaryocytes  1.436903
# 23265      IFITM1     False      True     louvain_Megakaryocytes       NaN
# 23266      IFITM3     False      True     louvain_Megakaryocytes  0.606655
# 23269        IRF7     False      True     louvain_Megakaryocytes -3.413498
# 23286      TRIM22     False      True     louvain_Megakaryocytes -1.350880
# 23325      UBE2L6     False      True     louvain_Megakaryocytes  0.043596
# 23617        OAS1     False      True     louvain_Megakaryocytes       NaN
# 23618        OAS3     False      True     louvain_Megakaryocytes  0.043596
# 23619        OAS2     False      True     louvain_Megakaryocytes -3.413498
# 23633        OASL     False      True     louvain_Megakaryocytes       NaN
# 23670      EPSTI1     False      True     louvain_Megakaryocytes  0.043596
# 23782       IFI27     False      True     louvain_Megakaryocytes       NaN
# 23791        WARS     False      True     louvain_Megakaryocytes  0.719269
# 23820      TRIM69     False      True     louvain_Megakaryocytes       NaN
# 23878       ISG20     False      True     louvain_Megakaryocytes  1.530072
# 23973        MT2A     False      True     louvain_Megakaryocytes  0.556541
# 24046        XAF1     False      True     louvain_Megakaryocytes -0.353865
# 24058        CD68     False      True     louvain_Megakaryocytes -3.998253
# 24079      LGALS9     False      True     louvain_Megakaryocytes       NaN
# 24123       IFI35     False      True     louvain_Megakaryocytes       NaN
# 24191    LGALS3BP     False      True     louvain_Megakaryocytes -2.096716
# 24414    C19orf38     False      True     louvain_Megakaryocytes  0.043596
# 24447       HSH2D     False      True     louvain_Megakaryocytes -2.215160
# 24456        BST2     False      True     louvain_Megakaryocytes -0.469648
# 24701         MX2     False      True     louvain_Megakaryocytes       NaN
# 24702         MX1     False      True     louvain_Megakaryocytes  0.200867
# 5           ISG15     False      True                       ct_C  2.414528
# 230          IFI6     False      True                       ct_C  2.483643
# 518        IFI44L     False      True                       ct_C  2.335062
# 519         IFI44     False      True                       ct_C  0.259799
# 547          GBP1     False      True                       ct_C  1.178460
# 549          GBP4     False      True                       ct_C  0.676885
# 1190        CMPK2     False      True                       ct_C  1.289247
# 1191        RSAD2     False      True                       ct_C  1.638866
# 1670        IFIH1     False      True                       ct_C  0.784976
# 1719       CHROMR     False      True                       ct_C  0.295378
# 1749        STAT1     False      True                       ct_C  0.725456
# 1886        SP110     False      True                       ct_C  0.961521
# 2055       TRANK1     False      True                       ct_C -0.905126
# 2346        PARP9     False      True                       ct_C  0.531668
# 2348       PARP14     False      True                       ct_C  1.430029
# 2512      TNFSF10      True      True                       ct_C  1.299776
# 2537        LAMP3     False      True                       ct_C  0.032019
# 2687         CD38     False      True                       ct_C  1.249825
# 2807       CXCL10      True      True                       ct_C  0.789678
# 2808       CXCL11      True      True                       ct_C  0.647631
# 2857        PPM1K     False      True                       ct_C  1.082362
# 2858        HERC6     False      True                       ct_C  1.197515
# 2859        HERC5     False      True                       ct_C  1.457669
# 3010       DDX60L     False      True                       ct_C  1.560377
# 3127         LIFR      True      True                       ct_C  0.193310
# 3243   SCAMP1-AS1     False      True                       ct_C -0.850273
# 3370      C5orf56     False      True                       ct_C -0.225364
# 3646         GMPR     False      True                       ct_C  0.291986
# 3706        HLA-F     False      True                       ct_C  0.713682
# 3717        HLA-E     False      True                       ct_C  0.606306
# 3781         TAP2     False      True                       ct_C -0.695297
# 3784        PSMB9     False      True                       ct_C  0.776893
# 3785         TAP1     False      True                       ct_C  0.464015
# 3834         ETV7     False      True                       ct_C -0.429443
# 3975       TENT5A     False      True                       ct_C  1.427171
# 4340       NT5C3A     False      True                       ct_C  0.579236
# 4498        SAMD9     False      True                       ct_C  2.120327
# 4499       SAMD9L     False      True                       ct_C  1.114331
# 4694       PARP12     False      True                       ct_C  0.615664
# 4826       ADAM28     False      True                       ct_C  0.758608
# 5119         LY6E     False      True                       ct_C  0.702251
# 5138       PARP10     False      True                       ct_C  0.027970
# 5227        DDX58     False      True                       ct_C  0.810069
# 5887        IFIT2     False      True                       ct_C  2.431597
# 5888        IFIT3     False      True                       ct_C  1.841657
# 5889        IFIT1     False      True                       ct_C  1.937702
# 5938     SLC25A28     False      True                       ct_C -0.365991
# 6088       IFITM2     False      True                       ct_C  1.385259
# 6089       IFITM1     False      True                       ct_C  1.801698
# 6090       IFITM3     False      True                       ct_C  1.450659
# 6102         IRF7     False      True                       ct_C  0.381115
# 6154        TRIM5     False      True                       ct_C  0.087042
# 6155       TRIM22     False      True                       ct_C  0.540986
# 6256         LMO2     False      True                       ct_C  0.240285
# 6314       UBE2L6     False      True                       ct_C  0.412159
# 6315     SERPING1     False      True                       ct_C  0.796950
# 6352      SCGB1A1     False      True                       ct_C  3.772315
# 6378       PLAAT2     False      True                       ct_C  0.876695
# 6608       ENDOD1     False      True                       ct_C  0.237665
# 6829      BCL2L14     False      True                       ct_C  0.045978
# 6982         KRT4     False      True                       ct_C  2.315032
# 7035        STAT2     False      True                       ct_C  0.662659
# 7232         OAS1     False      True                       ct_C  1.599035
# 7233         OAS3     False      True                       ct_C  1.144404
# 7234         OAS2     False      True                       ct_C  0.701193
# 7278         OASL     False      True                       ct_C  2.026844
# 7430       EPSTI1     False      True                       ct_C  1.368834
# 7875        IFI27     False      True                       ct_C  2.301664
# 7899         WARS     False      True                       ct_C  1.131339
# 8046        PATL2     False      True                       ct_C -0.720059
# 8048       TRIM69     False      True                       ct_C -0.549053
# 8051       DUOXA2     False      True                       ct_C  3.353106
# 8187          PML     False      True                       ct_C  0.021969
# 8269        ISG20     False      True                       ct_C  1.765312
# 8462        SOCS1     False      True                       ct_C  1.309085
# 8640         MT2A     False      True                       ct_C  2.137659
# 8938         XAF1     False      True                       ct_C  1.419399
# 8963         CD68     False      True                       ct_C  0.143152
# 9057       LGALS9     False      True                       ct_C  0.166815
# 9218        IFI35     False      True                       ct_C  0.689226
# 9474     LGALS3BP     False      True                       ct_C  0.202779
# 9526       SECTM1      True      True                       ct_C  0.477823
# 9887         SHFL     False      True                       ct_C  0.126946
# 9911     C19orf38     False      True                       ct_C -0.348272
# 9997        HSH2D     False      True                       ct_C  0.165587
# 10020        BST2     False      True                       ct_C  1.861557
# 10021       BISPR     False      True                       ct_C  0.145534
# 10693       ZNFX1     False      True                       ct_C  0.595523
# 10761       HELZ2     False      True                       ct_C  0.501783
# 10851         MX2     False      True                       ct_C  1.740384
# 10852         MX1     False      True                       ct_C  1.978719
# 10861        TFF3     False      True                       ct_C  3.800218
# 10900       USP18     False      True                       ct_C  0.319726
# 11023       APOL1     False      True                       ct_C  1.189107
# 11061    APOBEC3A     False      True                       ct_C  2.931266
# 11157     KLHDC7B     False      True                       ct_C  0.885092
# 11527       ISG15     False      True                      ct_BC  2.254339
# 11752        IFI6     False      True                      ct_BC  3.060238
# 12040      IFI44L     False      True                      ct_BC  2.396891
# 12041       IFI44     False      True                      ct_BC  0.111484
# 12069        GBP1     False      True                      ct_BC  1.245171
# 12071        GBP4     False      True                      ct_BC  0.780404
# 12712       CMPK2     False      True                      ct_BC  1.314532
# 12713       RSAD2     False      True                      ct_BC  1.074540
# 13192       IFIH1     False      True                      ct_BC  0.870465
# 13241      CHROMR     False      True                      ct_BC  0.004959
# 13271       STAT1     False      True                      ct_BC  0.762963
# 13408       SP110     False      True                      ct_BC  0.963795
# 13577      TRANK1     False      True                      ct_BC -1.212824
# 13868       PARP9     False      True                      ct_BC  0.406340
# 13870      PARP14     False      True                      ct_BC  1.576125
# 14034     TNFSF10      True      True                      ct_BC  0.906841
# 14059       LAMP3     False      True                      ct_BC -0.469738
# 14209        CD38     False      True                      ct_BC  0.569267
# 14329      CXCL10      True      True                      ct_BC  0.805270
# 14330      CXCL11      True      True                      ct_BC  0.838378
# 14379       PPM1K     False      True                      ct_BC  1.211153
# 14380       HERC6     False      True                      ct_BC  1.297298
# 14381       HERC5     False      True                      ct_BC  1.031724
# 14532      DDX60L     False      True                      ct_BC  1.029384
# 14649        LIFR      True      True                      ct_BC -0.266206
# 14765  SCAMP1-AS1     False      True                      ct_BC -0.466743
# 14892     C5orf56     False      True                      ct_BC -0.033109
# 15168        GMPR     False      True                      ct_BC -0.265382
# 15228       HLA-F     False      True                      ct_BC  0.791658
# 15239       HLA-E     False      True                      ct_BC  0.628088
# 15303        TAP2     False      True                      ct_BC -0.736272
# 15306       PSMB9     False      True                      ct_BC  0.558141
# 15307        TAP1     False      True                      ct_BC  0.280933
# 15356        ETV7     False      True                      ct_BC -1.113803
# 15497      TENT5A     False      True                      ct_BC  2.040787
# 15862      NT5C3A     False      True                      ct_BC  0.436778
# 16020       SAMD9     False      True                      ct_BC  2.768118
# 16021      SAMD9L     False      True                      ct_BC  0.828040
# 16216      PARP12     False      True                      ct_BC  0.498282
# 16348      ADAM28     False      True                      ct_BC  0.577234
# 16641        LY6E     False      True                      ct_BC  0.475492
# 16660      PARP10     False      True                      ct_BC -0.047051
# 16749       DDX58     False      True                      ct_BC  0.389790
# 17409       IFIT2     False      True                      ct_BC  1.924522
# 17410       IFIT3     False      True                      ct_BC  1.317128
# 17411       IFIT1     False      True                      ct_BC  1.816493
# 17460    SLC25A28     False      True                      ct_BC -0.711896
# 17610      IFITM2     False      True                      ct_BC  0.982581
# 17611      IFITM1     False      True                      ct_BC  1.552947
# 17612      IFITM3     False      True                      ct_BC  1.502235
# 17624        IRF7     False      True                      ct_BC -0.092186
# 17676       TRIM5     False      True                      ct_BC  0.077007
# 17677      TRIM22     False      True                      ct_BC  0.719979
# 17778        LMO2     False      True                      ct_BC  0.209643
# 17836      UBE2L6     False      True                      ct_BC  0.350243
# 17837    SERPING1     False      True                      ct_BC  0.573284
# 17874     SCGB1A1     False      True                      ct_BC  3.156344
# 17900      PLAAT2     False      True                      ct_BC  0.880518
# 18130      ENDOD1     False      True                      ct_BC  0.521566
# 18351     BCL2L14     False      True                      ct_BC -0.257534
# 18504        KRT4     False      True                      ct_BC  3.015117
# 18557       STAT2     False      True                      ct_BC  0.535250
# 18754        OAS1     False      True                      ct_BC  1.889272
# 18755        OAS3     False      True                      ct_BC  0.926231
# 18756        OAS2     False      True                      ct_BC  0.266026
# 18800        OASL     False      True                      ct_BC  1.945187
# 18952      EPSTI1     False      True                      ct_BC  1.026302
# 19397       IFI27     False      True                      ct_BC  2.932644
# 19421        WARS     False      True                      ct_BC  1.438369
# 19568       PATL2     False      True                      ct_BC -1.315988
# 19570      TRIM69     False      True                      ct_BC -0.987236
# 19573      DUOXA2     False      True                      ct_BC  3.616940
# 19709         PML     False      True                      ct_BC  0.120112
# 19791       ISG20     False      True                      ct_BC  1.318383
# 19984       SOCS1     False      True                      ct_BC  1.773476
# 20162        MT2A     False      True                      ct_BC  2.234467
# 20460        XAF1     False      True                      ct_BC  1.323689
# 20485        CD68     False      True                      ct_BC  0.102711
# 20579      LGALS9     False      True                      ct_BC  0.112515
# 20740       IFI35     False      True                      ct_BC  0.393160
# 20996    LGALS3BP     False      True                      ct_BC  0.399623
# 21048      SECTM1      True      True                      ct_BC  0.137694
# 21409        SHFL     False      True                      ct_BC -0.500974
# 21433    C19orf38     False      True                      ct_BC -0.755335
# 21519       HSH2D     False      True                      ct_BC -0.017762
# 21542        BST2     False      True                      ct_BC  1.916006
# 21543       BISPR     False      True                      ct_BC  0.118594
# 22215       ZNFX1     False      True                      ct_BC  0.767914
# 22283       HELZ2     False      True                      ct_BC -0.142172
# 22373         MX2     False      True                      ct_BC  1.490427
# 22374         MX1     False      True                      ct_BC  2.047318
# 22383        TFF3     False      True                      ct_BC  3.182595
# 22422       USP18     False      True                      ct_BC -0.059736
# 22545       APOL1     False      True                      ct_BC  1.758639
# 22583    APOBEC3A     False      True                      ct_BC  3.817912
# 22679     KLHDC7B     False      True                      ct_BC  0.486208
# 23049       ISG15     False      True                       ct_B  2.031740
# 23274        IFI6     False      True                       ct_B  2.960112
# 23562      IFI44L     False      True                       ct_B  2.401715
# 23563       IFI44     False      True                       ct_B  0.245450
# 23591        GBP1     False      True                       ct_B  1.008946
# 23593        GBP4     False      True                       ct_B  0.371646
# 24234       CMPK2     False      True                       ct_B  0.624925
# 24235       RSAD2     False      True                       ct_B  0.430800
# 24714       IFIH1     False      True                       ct_B  0.854755
# 24763      CHROMR     False      True                       ct_B -0.198126
# 24793       STAT1     False      True                       ct_B  0.464482
# 24930       SP110     False      True                       ct_B  0.633001
# 25099      TRANK1     False      True                       ct_B -0.797938
# 25390       PARP9     False      True                       ct_B  0.172112
# 25392      PARP14     False      True                       ct_B  1.493731
# 25556     TNFSF10      True      True                       ct_B  1.037224
# 25581       LAMP3     False      True                       ct_B -0.065974
# 25731        CD38     False      True                       ct_B  0.366918
# 25851      CXCL10      True      True                       ct_B  0.916451
# 25852      CXCL11      True      True                       ct_B  0.605822
# 25901       PPM1K     False      True                       ct_B  0.841228
# 25902       HERC6     False      True                       ct_B  0.849417
# 25903       HERC5     False      True                       ct_B  0.414320
# 26054      DDX60L     False      True                       ct_B  1.034417
# 26171        LIFR      True      True                       ct_B -0.548460
# 26287  SCAMP1-AS1     False      True                       ct_B -0.346054
# 26414     C5orf56     False      True                       ct_B  0.093625
# 26690        GMPR     False      True                       ct_B  0.185722
# 26750       HLA-F     False      True                       ct_B  0.630136
# 26761       HLA-E     False      True                       ct_B  0.246041
# 26825        TAP2     False      True                       ct_B -0.401017
# 26828       PSMB9     False      True                       ct_B  0.327690
# 26829        TAP1     False      True                       ct_B  0.192846
# 26878        ETV7     False      True                       ct_B -1.005463
# 27019      TENT5A     False      True                       ct_B  1.889696
# 27384      NT5C3A     False      True                       ct_B  0.262798
# 27542       SAMD9     False      True                       ct_B  2.175871
# 27543      SAMD9L     False      True                       ct_B  0.758840
# 27738      PARP12     False      True                       ct_B  0.329442
# 27870      ADAM28     False      True                       ct_B  0.831069
# 28163        LY6E     False      True                       ct_B  0.371331
# 28182      PARP10     False      True                       ct_B -0.467351
# 28271       DDX58     False      True                       ct_B  0.290257
# 28931       IFIT2     False      True                       ct_B  0.720833
# 28932       IFIT3     False      True                       ct_B  0.854013
# 28933       IFIT1     False      True                       ct_B  1.245638
# 28982    SLC25A28     False      True                       ct_B -0.750764
# 29132      IFITM2     False      True                       ct_B  0.881376
# 29133      IFITM1     False      True                       ct_B  1.624921
# 29134      IFITM3     False      True                       ct_B  1.465951
# 29146        IRF7     False      True                       ct_B -0.495482
# 29198       TRIM5     False      True                       ct_B  0.053984
# 29199      TRIM22     False      True                       ct_B  0.746332
# 29300        LMO2     False      True                       ct_B  0.323522
# 29358      UBE2L6     False      True                       ct_B  0.006338
# 29359    SERPING1     False      True                       ct_B  0.805680
# 29396     SCGB1A1     False      True                       ct_B  3.916884
# 29422      PLAAT2     False      True                       ct_B  0.654982
# 29652      ENDOD1     False      True                       ct_B  0.207207
# 29873     BCL2L14     False      True                       ct_B -0.362547
# 30026        KRT4     False      True                       ct_B  3.007033
# 30079       STAT2     False      True                       ct_B  0.454777
# 30276        OAS1     False      True                       ct_B  1.531283
# 30277        OAS3     False      True                       ct_B  0.623620
# 30278        OAS2     False      True                       ct_B -0.043291
# 30322        OASL     False      True                       ct_B  1.217535
# 30474      EPSTI1     False      True                       ct_B  0.928364
# 30919       IFI27     False      True                       ct_B  2.558464
# 30943        WARS     False      True                       ct_B  0.805099
# 31090       PATL2     False      True                       ct_B -1.542934
# 31092      TRIM69     False      True                       ct_B -0.296243
# 31095      DUOXA2     False      True                       ct_B  3.465282
# 31231         PML     False      True                       ct_B -0.028473
# 31313       ISG20     False      True                       ct_B  1.126445
# 31506       SOCS1     False      True                       ct_B  1.211827
# 31684        MT2A     False      True                       ct_B  2.387559
# 31982        XAF1     False      True                       ct_B  1.154448
# 32007        CD68     False      True                       ct_B  0.134052
# 32101      LGALS9     False      True                       ct_B  0.309349
# 32262       IFI35     False      True                       ct_B  0.402973
# 32518    LGALS3BP     False      True                       ct_B -0.010477
# 32570      SECTM1      True      True                       ct_B -0.002290
# 32931        SHFL     False      True                       ct_B -0.080925
# 32955    C19orf38     False      True                       ct_B -1.043899
# 33041       HSH2D     False      True                       ct_B  0.112418
# 33064        BST2     False      True                       ct_B  1.877679
# 33065       BISPR     False      True                       ct_B -0.031631
# 33737       ZNFX1     False      True                       ct_B  0.377260
# 33805       HELZ2     False      True                       ct_B  0.072777
# 33895         MX2     False      True                       ct_B  1.289174
# 33896         MX1     False      True                       ct_B  1.653711
# 33905        TFF3     False      True                       ct_B  2.154971
# 33944       USP18     False      True                       ct_B -0.097874
# 34067       APOL1     False      True                       ct_B  1.513184
# 34105    APOBEC3A     False      True                       ct_B  3.339390
# 34201     KLHDC7B     False      True                       ct_B  0.403714
