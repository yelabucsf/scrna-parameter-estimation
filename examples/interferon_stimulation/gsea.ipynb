# %% [markdown]
# # GSEA Analysis

# %%
library('clusterProfiler')
library('org.Hs.eg.db')

# %%
df = read.csv('upreg_genes.csv', sep=',')
converter = bitr(upreg_df$gene, fromType='SYMBOL', toType='ENTREZID', OrgDb="org.Hs.eg.db", drop=FALSE)
df = merge(df, converter, by.x='gene', by.y='SYMBOL', all.x=TRUE)
upreg_df = df[df$de_diff > 0 & df$de_fdr < 0.05,]
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(upreg_df$gene, fromType = "SYMBOL", toType = "ENTREZID", :
# “3.59% of input gene IDs are fail to map...”

# %% [markdown]
# ### All CT Over Representation Analysis - ALL GENES

# %%
dec_var_all_ct <- enrichKEGG(
    gene=unique(df[!is.na(upreg_df$ENTREZID) & (df$dv_fdr < 0.1) & (df$dv_diff < 0),]$ENTREZID), 
    qvalueCutoff=0.1, 
    pvalueCutoff=1,
    use_internal_data=FALSE)
inc_var_all_ct <- enrichKEGG(
    gene=unique(df[!is.na(upreg_df$ENTREZID) & (df$dv_fdr < 0.1) & (df$dv_diff > 0),]$ENTREZID),
    qvalueCutoff=0.1, 
    pvalueCutoff=1,
    use_internal_data=FALSE)
# Out:
# Warning message in !is.na(upreg_df$ENTREZID) & (df$dv_fdr < 0.1):
# “longer object length is not a multiple of shorter object length”
# Warning message in !is.na(upreg_df$ENTREZID) & (df$dv_fdr < 0.1):
# “longer object length is not a multiple of shorter object length”

# %%
length(unique(df[!is.na(df$ENTREZID) & (df$dv_fdr < 0.1) & (df$dv_diff < 0),]$ENTREZID))
# Out:
# [1] 633

# %%
length(unique(df[!is.na(df$ENTREZID) & (df$dv_fdr < 0.1) & (df$dv_diff > 0),]$ENTREZID))
# Out:
# [1] 667

# %%
head(dec_var_all_ct, 100)
# Out:
#          ID       Description                                     GeneRatio
# hsa05164 hsa05164 Influenza A                                     25/326
# hsa05169 hsa05169 Epstein-Barr virus infection                    27/326
# hsa04621 hsa04621 NOD-like receptor signaling pathway             23/326
# hsa05160 hsa05160 Hepatitis C                                     21/326
# hsa03050 hsa03050 Proteasome                                      11/326
# hsa05162 hsa05162 Measles                                         19/326
# hsa05170 hsa05170 Human immunodeficiency virus 1 infection        20/326
# hsa04622 hsa04622 RIG-I-like receptor signaling pathway           10/326
# hsa05167 hsa05167 Kaposi sarcoma-associated herpesvirus infection 18/326
# hsa04623 hsa04623 Cytosolic DNA-sensing pathway                   9/326
# hsa04141 hsa04141 Protein processing in endoplasmic reticulum     16/326
# hsa05165 hsa05165 Human papillomavirus infection                  25/326
# hsa05203 hsa05203 Viral carcinogenesis                            17/326
# hsa04210 hsa04210 Apoptosis                                       13/326
# hsa01210 hsa01210 2-Oxocarboxylic acid metabolism                 4/326
#          BgRatio  pvalue       p.adjust     qvalue
# hsa05164 170/8026 1.815262e-08 4.635355e-06 4.223889e-06
# hsa05169 201/8026 3.459220e-08 4.635355e-06 4.223889e-06
# hsa05133 801/836/929/2353/2771/51135/3659/4615/5970
# hsa05321 3113/3115/3119/3123/3566/5970/6774/6778
# hsa05320 356/3002/3113/3115/3119/3123/5551
# hsa05170 8905/200315/572/637/801/811/836/841/7852/356/2353/2771/51135/4615/5970/7132/7133
# hsa04650 637/836/356/2207/2214/3002/3454/3455/27040/5551/8743/7305
# hsa05310 2207/3113/3115/3119/3123
# hsa04061 6347/6351/6355/1236/3627/2833/7852/7132/7133/8743
# hsa05014 572/637/836/2876/7132/7133/10452
# hsa05142 811/841/6347/356/2353/2771/51135/4615/5970/7132
# hsa04620 841/6351/929/3627/2353/3454/3455/51135/4615/5970
# hsa05162 572/637/836/841/356/2353/3454/3455/51135/4615/5970/6774
#          Count
# hsa03010 50
# hsa05164 24
# hsa04210 19
# hsa05152 20
# hsa05140 12
# hsa05132 22
# hsa05130 21
# hsa05416 10
# hsa05145 14
# hsa05131 22
# hsa04145 16
# hsa05169 19
# hsa05330  7
# hsa04216  7
# hsa05332  7
# hsa04940  7
# hsa04142 13
# hsa04380 13
# hsa04640 11
# hsa05100  9
# hsa05133  9
# hsa05321  8
# hsa05320  7
# hsa05170 17
# hsa04650 12
# hsa05310  5
# hsa04061 10
# hsa05014  7
# hsa05142 10
# hsa04620 10
# hsa05162 12

# %% [markdown]
# ### All CT Over Representation Analysis

# %%
dec_var_all_ct <- enrichKEGG(
    gene=unique(upreg_df[!is.na(upreg_df$ENTREZID) & (upreg_df$dv_fdr < 0.1) & (upreg_df$dv_diff < 0),]$ENTREZID), 
    qvalueCutoff=0.1, 
    pvalueCutoff=1,
    use_internal_data=FALSE)
inc_var_all_ct <- enrichKEGG(
    gene=unique(upreg_df[!is.na(upreg_df$ENTREZID) & (upreg_df$dv_fdr < 0.1) & (upreg_df$dv_diff > 0),]$ENTREZID),
    qvalueCutoff=0.1, 
    pvalueCutoff=1,
    use_internal_data=FALSE)

# %%
length(unique(upreg_df[!is.na(upreg_df$ENTREZID) & (upreg_df$dv_fdr < 0.1) & (upreg_df$dv_diff < 0),]$ENTREZID))
# Out:
# [1] 178

# %%
length(unique(upreg_df[!is.na(upreg_df$ENTREZID) & (upreg_df$dv_fdr < 0.1) & (upreg_df$dv_diff > 0),]$ENTREZID))
# Out:
# [1] 120

# %%
head(dec_var_all_ct, 100)
write.csv(dec_var_all_ct, 'dec_var_all_ct_pathway.csv')
# Out:
#          ID       Description                                     GeneRatio
# hsa05164 hsa05164 Influenza A                                     16/106
# hsa04621 hsa04621 NOD-like receptor signaling pathway             14/106
# hsa05160 hsa05160 Hepatitis C                                     12/106
# hsa05169 hsa05169 Epstein-Barr virus infection                    12/106
# hsa05162 hsa05162 Measles                                         10/106
# hsa04623 hsa04623 Cytosolic DNA-sensing pathway                   5/106
# hsa05170 hsa05170 Human immunodeficiency virus 1 infection        9/106
# hsa04210 hsa04210 Apoptosis                                       7/106
# hsa03050 hsa03050 Proteasome                                      4/106
# hsa05167 hsa05167 Kaposi sarcoma-associated herpesvirus infection 8/106
# hsa05210 hsa05210 Colorectal cancer                               5/106
#          BgRatio  pvalue       p.adjust     qvalue
# hsa05164 170/8026 5.711667e-10 9.367134e-08 8.417194e-08
# hsa04621 181/8026 9.201502e-08 7.545231e-06 6.780054e-06
# hsa05160 155/8026 8.094641e-07 4.425070e-05 3.976315e-05
ique(upreg_df[!is.na(upreg_df$ENTREZID) & (upreg_df$dv_fdr < 0.1) & (upreg_df$dv_diff > 0) & (upreg_df$ct == ct),]$ENTREZID),
    qvalueCutoff=0.1, 
    pvalueCutoff=0.05,
    use_internal_data=FALSE)

# %%
tail(gene_list)
# Out:
#     81847     84196      8562     65109      7295     64231
# -3.311425 -3.327958 -3.388133 -3.668224 -3.900273 -3.955485

# %%
head(dec_var_all_ct, 20)
# Out:
#          ID       Description                         GeneRatio BgRatio
# hsa05160 hsa05160 Hepatitis C                         3/11      155/8026
# hsa04621 hsa04621 NOD-like receptor signaling pathway 3/11      181/8026
# hsa04623 hsa04623 Cytosolic DNA-sensing pathway       2/11      63/8026
# hsa05212 hsa05212 Pancreatic cancer                   2/11      76/8026
# hsa05210 hsa05210 Colorectal cancer                   2/11      86/8026
#          pvalue      p.adjust   qvalue     geneID         Count
# hsa05160 0.001040215 0.03339043 0.02486065 578/3434/91543 3
# hsa04621 0.001628801 0.03339043 0.02486065 9447/837/10616 3
# hsa04623 0.003186649 0.04355087 0.03242555 9447/11277     2
# hsa05212 0.004605258 0.04720390 0.03514539 578/5899       2
# hsa05210 0.005862033 0.04806867 0.03578925 578/5899       2

# %%
head(inc_var_all_ct, 100)
write.csv(inc_var_all_ct, 'inc_var_cd8_pathway.csv')
# Out:
#          ID       Description                      GeneRatio BgRatio
# hsa04931 hsa04931 Insulin resistance               3/12      108/8026
# hsa05330 hsa05330 Allograft rejection              2/12      38/8026
# hsa04216 hsa04216 Ferroptosis                      2/12      40/8026
# hsa05332 hsa05332 Graft-versus-host disease        2/12      41/8026
# hsa05164 hsa05164 Influenza A                      3/12      170/8026
# hsa04940 hsa04940 Type I diabetes mellitus         2/12      43/8026
# hsa05320 hsa05320 Autoimmune thyroid disease       2/12      53/8026
# hsa05416 hsa05416 Viral myocarditis                2/12      60/8026
# hsa05321 hsa05321 Inflammatory bowel disease (IBD) 2/12      65/8026
# hsa04920 hsa04920 Adipocytokine signaling pathway  2/12      69/8026
# hsa04917 hsa04917 Prolactin signaling pathway      2/12      70/8026
#          pvalue       p.adjust   qvalue     geneID          Count
# hsa04931 0.0004772365 0.01967493 0.01412077 5770/9021/6774  3
# hsa05330 0.0013982741 0.01967493 0.01412077 3113/5551       2
# hsa04216 0.0015488520 0.01967493 0.01412077 5621/6303       2
# hsa05332 0.0016269280 0.01967493 0.01412077 3113/5551       2
# hsa05164 0.0017843159 0.01967493 0.01412077 10241/3113/9021 3
# hsa04940 0.0017886304 0.01967493 0.01412077 3113/5551       2
# hsa05320 0.0027069122 0.02552232 0.01831745 3113/5551       2
# hsa05416 0.0034567897 0.02806474 0.02014216 3113/5551       2
# hsa05321 0.0040453809 0.02806474 0.02014216 3113/6774       2
# hsa04920 0.0045475898 0.02806474 0.02014216 9021/6774       2
# hsa04917 0.0046774561 0.02806474 0.02014216 9021/6774       2

# %% [markdown]
# ### CT specific ORA NK cells

# %%
ct = 'NK cells'

dec_var_all_ct <- enrichKEGG(
    gene=unique(upreg_df[!is.na(upreg_df$ENTREZID) & (upreg_df$dv_fdr < 0.1) & (upreg_df$dv_diff < 0) & (upreg_df$ct == ct),]$ENTREZID), 
    qvalueCutoff=0.1, 
    pvalueCutoff=0.05,
    use_internal_data=FALSE)
inc_var_all_ct <- enrichKEGG(
    gene=unique(upreg_df[!is.na(upreg_df$ENTREZID) & (upreg_df$dv_fdr < 0.1) & (upreg_df$dv_diff > 0) & (upreg_df$ct == ct),]$ENTREZID),
    qvalueCutoff=0.1, 
    pvalueCutoff=0.05,
    use_internal_data=FALSE)

# %%
tail(gene_list)
# Out:
#     81847     84196      8562     65109      7295     64231
# -3.311425 -3.327958 -3.388133 -3.668224 -3.900273 -3.955485

# %%
head(dec_var_all_ct, 20)
# Out:
#          ID       Description                                     GeneRatio
# hsa05162 hsa05162 Measles                                         3/12
# hsa05160 hsa05160 Hepatitis C                                     3/12
# hsa05164 hsa05164 Influenza A                                     3/12
# hsa05167 hsa05167 Kaposi sarcoma-associated herpesvirus infection 3/12
# hsa05170 hsa05170 Human immunodeficiency virus 1 infection        3/12
#          BgRatio  pvalue       p.adjust   qvalue     geneID           Count
# hsa05162 138/8026 0.0009766454 0.02713162 0.01276067 3665/4599/4940   3
# hsa05160 155/8026 0.0013673840 0.02713162 0.01276067 3665/4599/4940   3
# hsa05164 170/8026 0.0017843159 0.02713162 0.01276067 3665/4599/4940   3
# hsa05167 186/8026 0.0023090743 0.02713162 0.01276067 59345/2787/3665  3
# hsa05170 212/8026 0.0033511313 0.03150063 0.01481553 59345/2787/85363 3

# %%
head(inc_var_all_ct, 100)
write.csv(inc_var_all_ct, 'inc_var_nk_pathway.csv')
# Out:
#          ID       Description
# hsa05164 hsa05164 Influenza A
# hsa05330 hsa05330 Allograft rejection
# hsa05332 hsa05332 Graft-versus-host disease
# hsa04940 hsa04940 Type I diabetes mellitus
# hsa04650 hsa04650 Natural killer cell mediated cytotoxicity
# hsa04210 hsa04210 Apoptosis
# hsa05168 hsa05168 Herpes simplex virus 1 infection
# hsa05320 hsa05320 Autoimmune thyroid disease
# hsa05130 hsa05130 Pathogenic Escherichia coli infection
# hsa05170 hsa05170 Human immunodeficiency virus 1 infection
# hsa04061 hsa04061 Viral protein interaction with cytokine and cytokine receptor
# hsa05142 hsa05142 Chagas disease (American trypanosomiasis)
# hsa04668 hsa04668 TNF signaling pathway
# hsa05145 hsa05145 Toxoplasmosis
# hsa04060 hsa04060 Cytokine-cytokine receptor interaction
# hsa05162 hsa05162 Measles
# hsa05143 hsa05143 African trypanosomiasis
# hsa04932 hsa04932 Non-alcoholic fatty liver disease (NAFLD)
# hsa05160 hsa05160 Hepatitis C
# hsa05161 hsa05161 Hepatitis B
# hsa05152 hsa05152 Tuberculosis
# hsa04621 hsa04621 NOD-like receptor signaling pathway
# hsa05144 hsa05144 Malaria
# hsa05134 hsa05134 Legionellosis
# hsa05169 hsa05169 Epstein-Barr virus infection
# hsa05416 hsa05416 Viral myocarditis
# hsa05132 hsa05132 Salmonella infection
# hsa05163 hsa05163 Human cytomegalovirus infection
# hsa01524 hsa01524 Platinum drug resistance
# hsa05133 hsa05133 Pertussis
# hsa05323 2/13      93/8026  9.535034e-03 2.595582e-02 1.459239e-02
# hsa04657 2/13      94/8026  9.733433e-03 2.595582e-02 1.459239e-02
# hsa04010 3/13      294/8026 1.058847e-02 2.740546e-02 1.540738e-02
# hsa04933 2/13      100/8026 1.096259e-02 2.756308e-02 1.549599e-02
# hsa05135 2/13      120/8026 1.552689e-02 3.795463e-02 2.133813e-02
# hsa04068 2/13      131/8026 1.833226e-02 4.360105e-02 2.451255e-02
#          geneID                           Count
# hsa05164 836/6347/356/3123/4615/9021/8743 7
# hsa05330 356/3002/3123                    3
# hsa05332 356/3002/3123                    3
# hsa04940 356/3002/3123                    3
# hsa04650 836/356/3002/8743                4
# hsa04210 836/356/3002/8743                4
# hsa05168 836/6347/356/3123/4615/9021      6
# hsa05320 356/3002/3123                    3
# hsa05130 836/356/4615/8743                4
# hsa05170 200315/836/356/4615              4
# hsa04061 6347/6355/8743                   3
# hsa05142 6347/356/4615                    3
# hsa04668 836/6347/9021                    3
# hsa05145 836/3123/4615                    3
# hsa04060 6347/6355/356/8743               4
# hsa05162 836/356/4615                     3
# hsa05143 356/4615                         2
# hsa04932 836/356/9021                     3
# hsa05160 836/356/9021                     3
# hsa05161 836/356/4615                     3
# hsa05152 836/3123/4615                    3
# hsa04621 6347/2633/4615                   3
# hsa05144 6347/4615                        2
# hsa05134 836/4615                         2
# hsa05169 836/3123/4615                    3
# hsa05416 836/3123                         2
# hsa05132 836/4615/8743                    3
# hsa05163 836/6347/356                     3
# hsa01524 836/356                          2
# hsa05133 836/4615                         2
# hsa05140 3123/4615                        2
# hsa05323 6347/3123                        2
# hsa04657 836/6347                         2
# hsa04010 836/356/4615                     3
# hsa04933 836/6347                         2
# hsa05135 6347/4615                        2
# hsa04068 356/8743                         2

# %% [markdown]
# ### GSEA

# %%
ct = 'CD8 T cells'

# %%
gene_list = df[!is.na(df$ENTREZID) & (df$ct == ct),]$dv_diff
names(gene_list) = df[!is.na(df$ENTREZID) & (df$ct == ct),]$ENTREZID
gene_list = sort(gene_list, decreasing=TRUE)

# %%
length(gene_list)
# Out:
# [1] 3424

# %%
gsea <- gseKEGG(
    gene_list,
    organism = "hsa",
    keyType = "kegg",
    exponent = 1,
    nPerm = 1000,
    minGSSize = 10,
    maxGSSize = 500,
    pvalueCutoff = 0.1,
    pAdjustMethod = "BH",
    verbose = TRUE,
    use_internal_data = FALSE,
    seed = FALSE,
    by = "fgsea"
    )
# Out:
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...

# %%
barplot(gene_list)
# Out:
# plot without title

# %%
head(gsea, 30)
# Out:
#      ID Description setSize enrichmentScore NES pvalue p.adjust qvalues

# %%
head(df)$gene
# Out:
# [1] HES4     ISG15    NADK     RER1     TNFRSF14 ENO1
# 1347 Levels: AAED1 ABHD12 ABHD3 ABI1 ABLIM1 ABRACL ACAA1 ACAT1 ACOT9 ... ZRSR2
