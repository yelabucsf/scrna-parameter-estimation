# %% [markdown]
# # Analyzing the effect of Interferon Beta stimulation on PBMCs
#
# Dataset is from demuxlet: https://www.ncbi.nlm.nih.gov/pubmed/29227470.
#
# This notebook is meant to serve as a tutorial for using scMeMo, initially designed for members of the Ye Lab. This tutorial walks you through a very small analysis of the interferon dataset, limited to a few thousand genes and 2 cell types.

# %% [markdown]
# ### Import some helpful packages

# %%
import scanpy as sc
import numpy as np
import pandas as pd
import imp
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### Import scMeMo
#
# Eventually, we will have scMeMo available through pip and conda. Until then, please use the github version.

# %%
import sys
sys.path.append('/home/ssm-user/Github/scrna-parameter-estimation/scmemo')
import mme, utils, sparse_array, scmemo

# %% [markdown]
# ### Load the data
#
# In general, I suggest to use the full dataset (the one with 30k genes). Of course, many of these genes will be all zeros, etc. scMeMo is designed to take in sparse matrices, since almost all the operations are performed directly on the count data.
#
# This dataset has 29065 cells and 35635 genes.

# %%
data_path = '/data/mincheol/parameter_estimation/interferon_data/20200412/'
adata = sc.read(data_path + 'interferon.h5ad')
adata.obs['cell_type'] = (adata.obs['cell'].astype(str) + ' - ' + adata.obs['stim'].astype(str)).astype('category')
adata = adata[(adata.obs.multiplets == 'singlet') & (adata.obs.cell != 'nan'), :].copy()

# %%
adata_highcount = sc.read(data_path + 'interferon_highcount.raw.h5ad')
adata_highcount.obs['cell_type'] = (adata_highcount.obs['cell'].astype(str) + ' - ' + adata_highcount.obs['stim'].astype(str)).astype('category')

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 24673 × 35635
#     obs: 'tsne1', 'tsne2', 'ind', 'stim', 'cluster', 'cell', 'multiplets', 'cell_type'
#     var: 'gene_ids'
#     obsm: 'X_tsne'

# %%
# %matplotlib inline

# %%
sc.pl.tsne(adata, color='cell')
# Out:
# ... storing 'ind' as categorical
# ... storing 'stim' as categorical
# ... storing 'cluster' as categorical
# ... storing 'cell' as categorical
# ... storing 'multiplets' as categorical

# %% [markdown]
# ### Prepare the AnnData object for scMeMo
#
# scMeMo takes in an anndata object with up to three different features of each cell, which are columns in the `adata.obs` DataFrame. To explain the vocabulary further:
# - `covariate`: this is the variable that the hypothesis test is performed under. In this case, this column can be either `ctrl` or `stim`. The column name here is `stim`
# -`replicate`: In the Ye Lab, this is most likely going to be individuals. These are ways to naturally group the cells to be considered separately, and different from batches. The column name here is `ind`
# -`batch`: we all know what batches are. There are no batches in this dataset.
# -`subsection`: this is the labels that will divide up the hypothesis test. In this case, cell types will comprise the different `subsections` to study the effect of IFN-B. Here the column name is `cell`
#
# scMeMo also expects the `anndata` object to be composed of a sparse matrix of an integer type.

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.obs.sample(5)
# Out:
#                       tsne1      tsne2   ind  stim cluster         cell  \
# index
# CGTCCATGGGTAAA-1  41.527146  -0.126415  1039  stim       7     NK cells
# CCCTTACTACACGT-1 -22.751158  -1.293608  1488  stim       4      B cells
# ATATACGACTGTTT-1  20.928101 -31.134170   101  ctrl       7     NK cells
# GTCTAGGATGCTAG-1 -17.649422 -18.931473  1244  ctrl       5  CD4 T cells
# GTAGTGACCTCGCT-1  25.619372 -27.144429  1256  ctrl       7     NK cells
#
#                  multiplets           cell_type
# index
# CGTCCATGGGTAAA-1    singlet     NK cells - stim
# CCCTTACTACACGT-1    singlet      B cells - stim
# ATATACGACTGTTT-1    singlet     NK cells - ctrl
# GTCTAGGATGCTAG-1    singlet  CD4 T cells - ctrl
# GTAGTGACCTCGCT-1    singlet     NK cells - ctrl

# %% [markdown]
# ### Provide an estimate for $\mathbb{E}[q]$
#
# The value you should provide is the product of the capture efficiency (generally known for each technology) and the sequencing capture rate. The latter number is generally estimated from the alignment tool such as cell ranger. In this example, we used a 10X v1 kit (capture rate of around 0.08) and sequenced until about 90% of the transcripts are recovered. For this tutorial, we will use $\mathbb{E}[q] = 0.7$
#
# For 10X: https://kb.10xgenomics.com/hc/en-us/articles/360001539051-What-fraction-of-mRNA-transcripts-are-captured-per-cell-

# %%
q = 0.07

# %% [markdown]
# ### Instantiate the estimator
#
# To be clear:
# - `adata` is the `anndata` object
# - `covariate_label` is the column name specifying the `covariate` in the `adata.obs` DataFrame.
# - `replicate_label` is the column name specifying the `replicate` in the `adata.obs` DataFrame.
# - `batch_label` is the column name specifying the `batch` in the `adata.obs` DataFrame.
# - `subsection_label` is the column name specifying the `subsection` in the `adata.obs` DataFrame.
# - `num_permute` is the number of bootstrap iterations.
# - `covariate_converter` codes the string representation of the covariates into numerical levels. If the variable is ordinal (such as genetics), we could code for example `{'AA':0, 'Aa':1, 'aa':2}`
# - `use_hat_matrix` refers to precomputing the hat matrix for getting the estimated/bootstrapped effect sizes. If `# of replicates` x `# number of batches` x `# of levels in the covariate` is less than ~50 or so, this could provide a significant speed up. However, if there are many individuals, it would take a large amount of memory.
#
# Initialization could take up to half a minute to instantiate empty sparse matrices to hold information later on.

# %%
# %%time
imp.reload(utils)
imp.reload(sparse_array)
imp.reload(mme)

estimator = mme.SingleCellEstimator(
    adata=adata,
    covariate_label='stim',
    replicate_label='ind',
    batch_label=None,
    subsection_label='cell',
    num_permute=10000,
    covariate_converter={'ctrl':0, 'stim':1},
    q=q,
    smooth=10,
    use_hat_matrix=True)
# Out:
# CPU times: user 14.3 s, sys: 1.68 s, total: 16 s
# Wall time: 16 s

# %% [markdown]
# ### Estimate $\mathbb{E}[q^2]$ from the data
#
# We can qualitatively assess the quality of the estimate visually by plotting the log mean versus the log CV (coefficient of variation) using all cells. When `plot_cv_mean_curve` is called, you should see the red line hugging the convex portion of the scatterplot. For highly expressed genes (on the left end of the plot), the effect of the variance of $q$ becomes more prominent.
#
# If this curve looks weird for some reason, or does not hug the bottom of the scatter plot, try adjusting the `k` parameter to include/exclude more genes.

# %%
estimator.estimate_q_sq(k=5)
estimator.plot_cv_mean_curve()
# Out:
# E[q^2] falls in [0.00490, 0.00656014], with the current estimate of 0.00583650. Estimated with 5939 genes that have max expr > 5.

# %% [markdown]
# ### Define some genes to look at for one dimensional analysis
#
# Here, we will simply take the 2000 genes that are expressed in the largest number of cells. In general, particularly for the variability/correlation analysis, genes that are very lowly expressed (>90% of cells have 0's) will not yield accurate estimates.

# %%
adata.var['n_cells'] = (adata.X > 0).sum(axis=0).A1
adata.var.sample(3)
# Out:
#                       gene_ids  n_cells
# index
# CABP1          ENSG00000157782        2
# CTD-2227E11.1  ENSG00000270933        0
# AC021224.1     ENSG00000262477        0

# %%
gene_list = adata_highcount.var.index.tolist()

# %% [markdown]
# ### Get point estimates for the moments for each group.
#
# scMeMo defines groups of cells by covariate/replicate/batch/subsection (much like how we make pseudobulks in a more conventional analysis. For each of these groups, we get a point estimate of mean and variability.

# %%
estimator.compute_observed_moments(gene_list)
estimator.estimate_1d_parameters(gene_list)

# %% [markdown]
# ### Set up the hypothesis testing
#
# We will focus on the CD14+ Monocytes and CD4 T cells. This step defines the subsections that you would like to perform hypothesis testing of the covariate for, and the list can include as many subsections as you want.

# %%
estimator.setup_hypothesis_testing(subsections=['CD14+ Monocytes'])

# %% [markdown]
# ### Perform hypothesis testing for mean and variability
#
# First we compute the effect sizes using the given dataset. Then, we compute the significance levels via the bootstrap.

# %%
# %%time
estimator.compute_effect_sizes_1d(gene_list)
estimator.compute_confidence_intervals_1d(gene_list, verbose=False)

# %% [markdown]
# ### Get the hypothesis test results
#
# All of the results for hypothesis testing are stored in the `estimator.hypothesis_test_result` dictionary. This is an example of how one would extract the result for the 1D test.
#
# Eventually I plan to provide wrapper functions for these to increase convenience.

# %%
# Grab the idxs to retrieve from the sparse data structures
gene_idxs = estimator._get_gene_idxs(gene_list)

# %%
test_1d_result = pd.DataFrame()
test_1d_result['gene'] = adata.var.iloc[gene_idxs, :].index.tolist()
for col in ['de_effect_size', 'de_pval', 'de_fdr', 'dv_effect_size', 'dv_pval', 'dv_fdr']:
    test_1d_result[col] = estimator.hypothesis_test_result['CD14+ Monocytes'][col][gene_idxs]

# %% [markdown]
# ### Explore the 1D result a bit
#
# Use standard operations to explore the data, such as looking at upregulated genes that were either increased or decreased in variability.
#
# Here, we use FDR < 0.1 for DV and FDR < 0.05 for DE.
#
# Many of the genes that are "canonically" associated with Type I interferon are upregulated with decreased variability, indicating that this process is highly uniform across different cells.

# %%
# Upregulated genes that decreased in variability
test_1d_result.query('dv_fdr < 0.1 & de_fdr < 0.05 & de_effect_size > 0 & dv_effect_size < 0').sort_values('dv_effect_size').head(8)
# Out:
#          gene  de_effect_size       de_pval        de_fdr  dv_effect_size  \
# 119     ISG15        4.893924  6.168105e-07  2.267686e-06       -6.722795
# 458    CXCL10        6.167340  1.140854e-07  8.749120e-07       -4.661539
# 647  APOBEC3A        3.901172  2.862087e-08  4.240129e-07       -3.400285
# 890      IDO1        4.095276  2.147068e-07  1.262981e-06       -3.160524
# 146      IFI6        3.099739  4.657890e-10  7.165984e-08       -2.965109
# 612  TNFSF13B        3.578907  3.526636e-05  5.642617e-05       -2.861993
# 221    IFITM2        2.973849  8.614105e-07  2.769809e-06       -2.494188
# 565      CCL2        1.635130  4.715570e-07  1.916898e-06       -2.489128
#
#           dv_pval    dv_fdr
# 119  5.177356e-06  0.000279
# 458  2.999700e-03  0.031679
# 647  3.286121e-06  0.000273
# 890  1.757178e-04  0.002875
# 146  5.608876e-05  0.001116
# 612  5.791183e-04  0.008316
# 221  2.994171e-05  0.000687
# 565  4.288281e-07  0.000078

# %%
# Upregulated genes that increased in variability
test_1d_result.query('dv_fdr < 0.1 & de_fdr < 0.05 & de_effect_size > 0 & dv_effect_size > 0').sort_values('dv_effect_size', ascending=False).head(8)
# Out:
#           gene  de_effect_size       de_pval        de_fdr  dv_effect_size  \
# 1982      NEXN        6.403522  1.994220e-07  1.200552e-06        4.905220
# 1893     HSH2D        4.826347  8.819748e-09  2.989745e-07        3.001474
# 1871  LGALS3BP        3.608416  2.130042e-08  3.670655e-07        2.877453
# 1359      CD38        6.213120  2.385801e-09  1.445940e-07        2.555112
# 1535      HES4        5.668182  8.853774e-08  7.665606e-07        2.260857
# 1798     HERC6        4.120646  1.002546e-07  8.184050e-07        2.012484
# 1440      PRF1        1.964011  2.767501e-07  1.461480e-06        1.797528
# 501   FAM177A1        0.769603  5.719506e-08  6.020532e-07        1.414278
#
#            dv_pval    dv_fdr
# 1982  5.310503e-06  0.000279
# 1893  4.537960e-05  0.000953
# 1871  5.212048e-06  0.000279
# 1359  1.433642e-07  0.000048
# 1535  3.239795e-07  0.000072
# 1798  2.354397e-04  0.003615
# 1440  9.599040e-03  0.082585
# 501   1.512934e-04  0.002517

# %%
# Downregulated genes that increased in variability
test_1d_result.query('dv_fdr < 0.1 & de_fdr < 0.05 & de_effect_size < 0 & dv_effect_size > 0').sort_values('dv_effect_size', ascending=False).head(8)
# Out:
#           gene  de_effect_size       de_pval        de_fdr  dv_effect_size  \
# 1438      LSM2       -0.346625  1.999800e-03  2.654015e-03        1.967604
# 786        IL8       -1.908357  2.933576e-05  4.743049e-05        1.875686
# 147      RPL23       -1.096293  5.296212e-06  1.011693e-05        1.697884
# 218      TIMP1       -0.535756  4.416870e-08  5.372411e-07        1.643236
# 37       RPL26       -0.500796  7.917481e-07  2.642821e-06        1.547466
# 28        RPL7       -0.902851  8.547373e-08  7.497696e-07        1.471561
# 433   MARCKSL1       -1.249626  1.233062e-08  3.074634e-07        1.426609
# 61        RPL6       -1.181856  2.656688e-07  1.435079e-06        1.415941
#
#            dv_pval    dv_fdr
# 1438  1.078855e-04  0.001841
# 786   4.632939e-09  0.000005
# 147   1.205038e-05  0.000399
# 218   4.621271e-06  0.000279
# 37    1.036916e-05  0.000376
# 28    2.987534e-07  0.000072
# 433   1.358337e-05  0.000424
# 61    1.929226e-04  0.003081

# %% [markdown]
# ### Get gene lists 2D hypothesis testing
#
# As a small example, we will look at the effect of interferon on the correlation between known TFs and other genes. Particularly, we will look at STAT1 and STAT2 as the major mediators of the IFNB->JAK/STAT pathway.
#
# We will take the previously analyzed 2k genes as potentially being implicated in the same regulatory circuit as the STATs.
#
# Testing for correlation scales roughly similar to the 1D analysis, except that it scales with the number of **pairs** of genes. So in this case, we are testing 4000 "cases," since we are looking at 2 TFs.

# %%
gene_list_1 = ['STAT1', 'STAT2']
gene_list_2 = gene_list#[-200:]
# gene_list_2 = ['IFIT1']

# %%
# Grab the idxs to retrieve from the sparse data structures
gene_idxs_1 = estimator._get_gene_idxs(gene_list_1)
gene_idxs_2 = estimator._get_gene_idxs(gene_list_2)

# %% [markdown]
# ### Estimate the 2D parameters for the given genes

# %%
estimator.estimate_2d_parameters(gene_list_1, gene_list_2)

# %% [markdown]
# ### Perform hypothesis testing for changes in correlation

# %%
estimator.compute_effect_sizes_2d(gene_list_1, gene_list_2)

# %%
# %%time
estimator.compute_confidence_intervals_2d(gene_list_1, gene_list_2, verbose=True)
# Out:
# Computing the 0st/th gene pair of 7190. 5.66442 seconds have passed.
# /home/ssm-user/Github/scrna-parameter-estimation/scmemo/mme.py:872: RuntimeWarning: invalid value encountered in sqrt
#   estimated_corrs[group] = cov / np.sqrt(estimated_vars_1[group]*estimated_vars_2[group])
# Computing the 100st/th gene pair of 7190. 36.82526 seconds have passed.
# Computing the 200st/th gene pair of 7190. 65.76943 seconds have passed.
# Computing the 300st/th gene pair of 7190. 99.55992 seconds have passed.
# Computing the 400st/th gene pair of 7190. 125.85513 seconds have passed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/Github/scrna-parameter-estimation/scmemo/mme.py in compute_confidence_intervals_2d(self, gene_list_1, gene_list_2, hypothesis_test, gene_tracker_count, verbose)
#     821                                         expr_values, counts = np.unique(cantor_code, return_counts=True)
#     822                                         cantor_codes[group] = expr_values
# --> 823                                         gene_mult_rvs[group] = stats.multinomial.rvs(n=data.shape[0], p=counts/data.shape[0], size=self.num_permute)
#     824
#     825                                 # Construct the repeated values matrix
#
# ~/anaconda3/envs/single_cell/lib/python3.7/site-packages/scipy/stats/_multivariate.py in rvs(self, n, p, size, random_state)
#    3218         n, p, npcond = self._process_parameters(n, p)
#    3219         random_state = self._get_random_state(random_state)
# -> 3220         return random_state.multinomial(n, p, size)
#    3221
#    3222
#
# KeyboardInterrupt:

# %%
dfs = []
for idx, tf in enumerate(['STAT1', 'STAT2']):
    test_2d_result = pd.DataFrame()
    test_2d_result['gene'] = gene_list_2
    test_2d_result['tf'] = tf

    for col in ['dc_effect_size', 'dc_pval', 'dc_fdr', 'dc_es_ci']:
        test_2d_result[col] = estimator.hypothesis_test_result['CD14+ Monocytes'][col][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()[idx, :]
    dfs.append(test_2d_result)
test_2d_result = pd.concat(dfs)

# %%
test_2d_result['dc_pval'].hist(bins=30)

# %%
test_2d_result_norep = pd.read_csv('temp.csv')

# %%
plt.scatter(
    test_2d_result_norep['dc_effect_size'],
    test_2d_result['dc_effect_size'], s=1
)
plt.plot([-1, 1], [0, 0])
plt.plot([0, 0], [-1, 1])
plt.plot([-1, 1], [-1, 1])

# %%
((test_2d_result_norep['dc_effect_size']*test_2d_result['dc_effect_size'])<0).mean()
# Out:
# 0.23833333333333334

# %%
def robust_hist(x):
    
    sns.distplot(x[np.isfinite(x)])

# %%
test_2d_result.query('tf == "STAT1"')['dc_effect_size'].mean()
# Out:
# 0.040744726

# %%
robust_hist(test_2d_result_norep.query('tf == "STAT1"')['dc_effect_size'])
robust_hist(test_2d_result_norep.query('tf == "STAT2"')['dc_effect_size'])

# %%
robust_hist(test_2d_result.query('tf == "STAT1"')['dc_effect_size'])
robust_hist(test_2d_result.query('tf == "STAT2"')['dc_effect_size'])

# %%
sns.distplot(test_2d_result_norep['dc_es_ci'])
sns.distplot(test_2d_result['dc_es_ci'])
plt.xlim(0, 0.5)
# Out:
# (0, 0.5)

# %%
test_2d_result['dc_pval'].hist(bins=20)

# %%
test_2d_result.shape
# Out:
# (400, 6)

# %%
test_2d_result.query('gene == "MX1"')
# Out:
#     gene     tf  dc_effect_size   dc_pval    dc_fdr  dc_es_ci
# 189  MX1  STAT1       -0.164896  0.081392  0.719928  0.110134
# 189  MX1  STAT2       -0.777273  0.000010  0.003521  0.134840

# %%
test_2d_result.query('dc_fdr < 0.1')
# Out:
#          gene     tf  dc_effect_size   dc_pval    dc_fdr  dc_es_ci
# 118    LGALS1  STAT1        0.405874  0.001000  0.066660  0.113111
# 126  APOBEC3A  STAT1       -0.385499  0.000018  0.003521  0.096223
# 126  APOBEC3A  STAT2       -0.829219  0.000244  0.032563  0.127697
# 157      TYMP  STAT2       -0.729983  0.001000  0.066660  0.201740
# 188       MX2  STAT2       -0.839651  0.000563  0.056314  0.192476
# 189       MX1  STAT2       -0.777273  0.000010  0.003521  0.134840

# %%
variabilities = []
for group in estimator.hypothesis_test_result['CD14+ Monocytes']['groups']:
    
    if 'ctrl' in group:
        continue
    variabilities.append(estimator.parameters[group]['log_residual_var'][gene_idxs])

# %%
import itertools

# %%
import scipy.stats as stats

# %%
def _robust_corr(a,b):
    
    condition = np.isfinite(a) & np.isfinite(b)
    
    return stats.pearsonr(a[condition], b[condition])

# %%
for a, b in itertools.combinations(variabilities, 2):
    plt.figure(figsize=(1,1))
    plt.scatter(a,b, s=1, alpha=0.1)
    plt.title(_robust_corr(a,b))

# %%
expression_values = []
ci = []
gene_idx = adata.var.index.tolist().index('PRMT2')
for group in estimator.hypothesis_test_result['CD14+ Monocytes']['groups']:
    expression_values.append([estimator.parameters[group]['corr'][gene_idxs_1[0], gene_idx]][0])
    ci.append([estimator.parameters_confidence_intervals[group]['corr'][gene_idxs_1[0], gene_idx]][0])
df = estimator.hypothesis_test_result['CD14+ Monocytes']['design_df']
df['expr'] = expression_values
df['ci'] = ci

# %%
df.dropna()['ci'][df['covariate'] == 0].sum()/(df['covariate'] == 0).sum()**2
# Out:
# 0.14922202774323523

# %%
df.dropna()['ci'][df['covariate'] == 1].sum()/(df['covariate'] == 1).sum()**2
# Out:
# 0.12169766868464649

# %%
df.groupby('covariate')['expr'].mean()
# Out:
# covariate
# 0   -0.286381
# 1    0.111159
# Name: expr, dtype: float64

# %%
gene_list_2[:5]
# Out:
# ['TTC39C', 'RNF125', 'RNF138', 'ZNF24', 'INO80C']

# %%
test_2d_result.shape
# Out:
# (500, 6)

# %%
test_2d_result.head(5)
# Out:
#      gene     tf  dc_effect_size   dc_pval    dc_fdr  dc_es_ci
# 0  TTC39C  STAT1         0.00000  0.033597  0.942874  0.322208
# 1  RNF125  STAT1         0.00000  0.031397  0.942874  0.216992
# 2  RNF138  STAT1         0.00000  0.861114  0.981534  0.360847
# 3   ZNF24  STAT1         0.00453  0.507949  0.948090  0.550816
# 4  INO80C  STAT1         0.00000  0.297370  0.948090  0.651587

# %%
test_2d_result_norep = pd.read_csv('temp.csv')

# %%
sns.distplot(test_2d_result['dc_es_ci'])
sns.distplot(test_2d_result_norep['dc_es_ci'])

# %%
test_2d_result.query('dc_effect_size == 0')['dc_pval'].hist()

# %%
plt.scatter(
    test_2d_result['dc_effect_size'],
    test_2d_result_norep.query('tf == "STAT1"')['dc_effect_size']
)

# %%
test_2d_result_norep.head(5)
# Out:
#      gene     tf  dc_effect_size   dc_pval    dc_fdr
# 0  TTC39C  STAT1        0.363061  0.046395  0.414244
# 1  RNF125  STAT1        0.224592  0.084792  0.488476
# 2  RNF138  STAT1        0.132553  0.468353  0.843880
# 3   ZNF24  STAT1        0.020568  0.886511  0.972689
# 4  INO80C  STAT1        0.266307  0.161984  0.605106

# %%
test_2d_result['dc_pval'].hist(bins=30)

# %%
import pickle as pkl

# %%
corrs = []
counts = []
names = []

for group in estimator.hypothesis_test_result['CD14+ Monocytes']['groups']:
    if 'stim' in group:
        continue
    corrs.append(estimator.parameters[group]['corr']\
    [gene_idxs_1[0], gene_idxs_2].toarray().reshape(-1))
    counts.append(estimator.group_cells[group].shape[0])
    names.append(group)
    
corrs = np.vstack(corrs)

# %%
pd.DataFrame(corrs[:, :10], index=names)
# Out:
#                                                    0         1         2  \
# sg^ctrl^1016^default_batch^CD14+ Monocytes -0.412083 -0.093880  0.516264
# sg^ctrl^1256^default_batch^CD14+ Monocytes -0.031379 -0.074278 -0.181619
# sg^ctrl^1015^default_batch^CD14+ Monocytes -0.029155  0.427232 -0.347447
# sg^ctrl^101^default_batch^CD14+ Monocytes  -0.730728 -0.235231  1.000000
# sg^ctrl^1244^default_batch^CD14+ Monocytes -0.545205 -0.316520  0.334931
# sg^ctrl^1488^default_batch^CD14+ Monocytes  0.005150 -0.130700  0.053653
# sg^ctrl^1039^default_batch^CD14+ Monocytes       NaN       NaN       NaN
# sg^ctrl^107^default_batch^CD14+ Monocytes  -0.261265 -0.177887 -0.472631
#
#                                                    3         4         5  \
# sg^ctrl^1016^default_batch^CD14+ Monocytes  0.098678  0.523412 -0.344939
# sg^ctrl^1256^default_batch^CD14+ Monocytes -0.389573  0.250059 -0.243415
# sg^ctrl^1015^default_batch^CD14+ Monocytes -0.099494 -0.286396  0.101118
# sg^ctrl^101^default_batch^CD14+ Monocytes   0.207762  0.369570  0.503433
# sg^ctrl^1244^default_batch^CD14+ Monocytes -0.371089  0.055136  0.255347
# sg^ctrl^1488^default_batch^CD14+ Monocytes -0.149578 -0.647089 -0.264519
# sg^ctrl^1039^default_batch^CD14+ Monocytes       NaN       NaN       NaN
# sg^ctrl^107^default_batch^CD14+ Monocytes        NaN  0.257062  0.588908
#
#                                                    6         7         8  \
# sg^ctrl^1016^default_batch^CD14+ Monocytes  0.279332  0.300139  0.706018
# sg^ctrl^1256^default_batch^CD14+ Monocytes -0.128263 -0.143078 -0.549467
# sg^ctrl^1015^default_batch^CD14+ Monocytes -0.011741  0.266565  0.058515
# sg^ctrl^101^default_batch^CD14+ Monocytes  -0.410555  0.038492  0.704040
# sg^ctrl^1244^default_batch^CD14+ Monocytes  0.081513 -0.033245 -0.251826
# sg^ctrl^1488^default_batch^CD14+ Monocytes -0.078385 -0.023019  0.140970
# sg^ctrl^1039^default_batch^CD14+ Monocytes       NaN       NaN       NaN
# sg^ctrl^107^default_batch^CD14+ Monocytes   0.063147 -0.005803 -0.472631
#
#                                                    9
# sg^ctrl^1016^default_batch^CD14+ Monocytes  0.456365
# sg^ctrl^1256^default_batch^CD14+ Monocytes -0.137085
# sg^ctrl^1015^default_batch^CD14+ Monocytes  0.216458
# sg^ctrl^101^default_batch^CD14+ Monocytes  -0.459444
# sg^ctrl^1244^default_batch^CD14+ Monocytes -0.181788
# sg^ctrl^1488^default_batch^CD14+ Monocytes  0.836497
# sg^ctrl^1039^default_batch^CD14+ Monocytes       NaN
# sg^ctrl^107^default_batch^CD14+ Monocytes   0.201776

# %%
with open('temp.pkl', 'rb') as f:
    no_rep_corrs = pkl.load(f)

# %%
avg_corrs = np.nanmean(corrs, axis=0)#np.average(corrs, weights=counts, axis=0)
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.

# %%
# corrs[corrs == 1] = np.nan
# corrs[corrs == -1] = np.nan

# %%
x = np.log(estimator.observed_central_moments['sg^ctrl^1016^default_batch^CD14+ Monocytes']['first'][gene_idxs])
y = np.log(estimator.observed_central_moments['sg^ctrl^1016^default_batch^CD14+ Monocytes']['second'][gene_idxs])
plt.scatter(x, y/2-x, s=5)

# x = np.log(estimator.observed_central_moments['sg^stim^1016^default_batch^CD14+ Monocytes']['first'][gene_idxs])
# y = np.log(estimator.observed_central_moments['sg^stim^1016^default_batch^CD14+ Monocytes']['second'][gene_idxs])
# plt.scatter(x, y/2-x, s=5)

# x = np.log(estimator.observed_central_moments['sg^ctrl^107^default_batch^CD14+ Monocytes']['first'][gene_idxs])
# y = np.log(estimator.observed_central_moments['sg^ctrl^107^default_batch^CD14+ Monocytes']['second'][gene_idxs])
# plt.scatter(x, y/2-x, s=5)

# x = np.log(estimator.observed_central_moments['sg^stim^107^default_batch^CD14+ Monocytes']['first'][gene_idxs])
# y = np.log(estimator.observed_central_moments['sg^stim^107^default_batch^CD14+ Monocytes']['second'][gene_idxs])
# plt.scatter(x, y/2-x, s=5)

# x = np.log(estimator.observed_central_moments['sg^ctrl^107^default_batch^CD4 T cells']['first'][gene_idxs])
# y = np.log(estimator.observed_central_moments['sg^ctrl^107^default_batch^CD4 T cells']['second'][gene_idxs])
# plt.scatter(x, y/2-x, s=5)

x = np.log(estimator.observed_central_moments['sg^stim^107^default_batch^CD4 T cells']['first'][gene_idxs])
y = np.log(estimator.observed_central_moments['sg^stim^107^default_batch^CD4 T cells']['second'][gene_idxs])
plt.scatter(x, y/2-x, s=5)

x = np.log(estimator.observed_central_moments['sg^stim^107^default_batch^NK cells']['first'][gene_idxs])
y = np.log(estimator.observed_central_moments['sg^stim^107^default_batch^NK cells']['second'][gene_idxs])
plt.scatter(x, y/2-x, s=5)

x = np.log(estimator.observed_central_moments['sg^stim^107^default_batch^NK cells']['first'][gene_idxs])
y = np.log(estimator.observed_central_moments['sg^stim^107^default_batch^NK cells']['second'][gene_idxs])
plt.scatter(x, y/2-x, s=5)


# x = np.log(estimator.observed_central_moments['all']['first'][gene_idxs])
# y = np.log(estimator.observed_central_moments['all']['second'][gene_idxs])
# plt.scatter(x, y/2-x, s=5)

plt.xlim(-6, 4)
plt.ylim(-1, 4)
# Out:
# (-1, 4)

# %%
plt.scatter(avg_corrs, no_rep_corrs)
plt.plot([-0.5, 0.5], [-0.5, 0.5])

# %%
def robust_hist(x):
    
    sns.distplot(x[np.isfinite(x)])

# %%
robust_hist(avg_corrs)
robust_hist(no_rep_corrs)

# %%
estimator.group_cells['sg^ctrl^1039^default_batch^CD14+ Monocytes'][:, 4857].data.shape
# Out:
# (19,)

# %%
19/1000
# Out:
# 0.019

# %%
utils._estimate_variance(
        0.1484309938464877, 
        0.17,
        1e-4,
        estimator.q,
        estimator.q_sq)
# Out:
# 1.3259534772263306

# %%
estimator.observed_central_moments['sg^ctrl^1039^default_batch^CD14+ Monocytes']['second'][4857]
# Out:
# 0.1484309938464877

# %%
estimator.observed_central_moments['sg^ctrl^1039^default_batch^CD14+ Monocytes']['first'][4857]
# Out:
# 0.15748425196850394

# %%
avg_corrs.shape
# Out:
# (500,)

# %%
import pickle as pkl

# %%
with open('temp.pkl', 'rb') as f:
    no_rep_corrs = pkl.load(f)

# %%
robust_hist(avg_corrs)
robust_hist(no_rep_corrs)

# %%
for c in corrs:
    robust_hist(c)
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.7/site-packages/seaborn/distributions.py:198: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.7/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
dfs = []
for idx, tf in enumerate(['STAT1']):
    test_2d_result = pd.DataFrame()
    test_2d_result['gene'] = adata.var.iloc[gene_idxs_2, :].index.tolist()
    test_2d_result['tf'] = tf

    for col in ['dc_effect_size', 'dc_pval', 'dc_fdr']:
        test_2d_result[col] = estimator.hypothesis_test_result['CD14+ Monocytes'][col][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()[idx, :]
    dfs.append(test_2d_result)
test_2d_result = pd.concat(dfs)

# %%
plt.hist(ind_test_2d_result['dc_pval'], bins=30)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-74-42a830ed6a66> in <module>
# ----> 1 plt.hist(ind_test_2d_result['dc_pval'], bins=30)
#
# NameError: name 'ind_test_2d_result' is not defined

# %%
plt.hist(test_2d_result['dc_pval'], bins=20)
# Out:
# (array([114.,  46.,  30.,  27.,  28.,  29.,  14.,  23.,  17.,  17.,  17.,
#          18.,  12.,  19.,  18.,  16.,  10.,  19.,  17.,   9.]),
#  array([0.        , 0.04955504, 0.09911009, 0.14866513, 0.19822018,
#         0.24777523, 0.29733026, 0.34688532, 0.39644036, 0.44599542,
#         0.49555045, 0.5451055 , 0.5946605 , 0.6442156 , 0.69377065,
#         0.7433257 , 0.7928807 , 0.8424358 , 0.89199084, 0.94154584,
#         0.9911009 ], dtype=float32),
#  <a list of 20 Patch objects>)

# %%
es_ind = estimator.compute_confidence_intervals_2d(gene_list_1, gene_list_2)
# Out:
# /Users/mincheolkim/Github/scrna-parameter-estimation/scmemo/mme.py:806: RuntimeWarning: invalid value encountered in sqrt
#
# /Users/mincheolkim/Github/scrna-parameter-estimation/scmemo/utils.py:134: RuntimeWarning: invalid value encountered in greater
#   extreme_count = (perm_diff > 0).sum()
# //anaconda3/envs/single_cell/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1667: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %%
sns.distplot(es_ind)
sns.distplot(es)

plt.xlim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
dfs = []
for idx, tf in enumerate(['STAT1', 'STAT2']):
    test_2d_result = pd.DataFrame()
    test_2d_result['gene'] = adata.var.iloc[gene_idxs_2, :].index.tolist()
    test_2d_result['tf'] = tf

    for col in ['dc_effect_size', 'dc_pval', 'dc_fdr']:
        test_2d_result[col] = estimator.hypothesis_test_result['CD14+ Monocytes'][col][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()[idx, :]
    dfs.append(test_2d_result)
test_2d_result = pd.concat(dfs)

# %%
test_2d_result_ind.query('dc_fdr < 0.1 & tf == "STAT1"').shape
# Out:
# (8, 5)

# %%
test_2d_result.query('dc_fdr < 0.1 & tf == "STAT1"').shape
# Out:
# (61, 5)

# %%
(test_2d_result['dc_effect_size'].abs() - test_2d_result_ind['dc_effect_size'].abs()).mean()
# Out:
# -0.0074170423

# %%
plt.scatter(test_2d_result['dc_effect_size'].abs(), test_2d_result_ind['dc_effect_size'].abs())
plt.plot([-0.5, 0.5], [-0.5, 0.5])

# %%
plt.scatter(-np.log(test_2d_result['dc_pval']), -np.log(test_2d_result_ind['dc_pval']))

# %%
dfs_ind = []
for idx, tf in enumerate(['STAT1', 'STAT2']):
    test_2d_result_ind = pd.DataFrame()
    test_2d_result_ind['gene'] = adata.var.iloc[gene_idxs_2, :].index.tolist()
    test_2d_result_ind['tf'] = tf

    for col in ['dc_effect_size', 'dc_pval', 'dc_fdr']:
        test_2d_result_ind[col] = estimator.hypothesis_test_result['CD14+ Monocytes'][col][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()[idx, :]
    dfs_ind.append(test_2d_result_ind)
test_2d_result_ind = pd.concat(dfs_ind)

# %%
test_2d_result_ind.head(5)
# Out:
#       gene     tf  dc_effect_size   dc_pval    dc_fdr
# 0    NCOR1  STAT1        0.238636  0.493951  0.618688
# 1  PSMA2-1  STAT1        0.051664  0.995100  0.995100
# 2    MITD1  STAT1        0.061154  0.735926  0.822264
# 3    PDCD4  STAT1        0.239563  0.139786  0.241355
# 4    ZNFX1  STAT1        0.137907  0.459754  0.591323

# %%
group = 'sg^ctrl^1488^default_batch^CD14+ Monocytes'

# %%
np.isfinite(a['sg^ctrl^1488^default_batch^CD14+ Monocytes']).sum()
# Out:
# 9912

# %%
np.nanmean(a[group])
# Out:
# -0.08439668752733395

# %%
estimator.parameters[group]['corr'][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()
# Out:
# array([[-0.05553349],
#        [        nan]], dtype=float32)

# %%
sns.distplot(a['sg^ctrl^1016^default_batch^CD14+ Monocytes'])

# %%
estimator.hypothesis_test_result['CD14+ Monocytes']['dc_effect_size'][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()
# Out:
# array([[0.05452165],
#        [       nan]], dtype=float32)

# %%
import seaborn as sns

# %%
plt.hist()

# %%
np.nanmean(estimator.hypothesis_test_result['CD14+ Monocytes']['dc_effect_size'][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()[0, :])
# Out:
# 0.092377305

# %%
plt.hist(estimator.hypothesis_test_result['CD14+ Monocytes']['dc_effect_size'][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()[0, :])
# Out:
# //anaconda3/envs/single_cell/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# //anaconda3/envs/single_cell/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([  4.,   7.,  16.,  95., 194., 272., 255., 119.,  28.,   8.]),
#  array([-0.5886951 , -0.467702  , -0.34670892, -0.22571582, -0.10472272,
#          0.01627037,  0.13726346,  0.25825655,  0.37924966,  0.50024277,
#          0.62123585], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
dfs = []
for idx, tf in enumerate(['STAT1', 'STAT2']):
    test_2d_result = pd.DataFrame()
    test_2d_result['gene'] = adata.var.iloc[gene_idxs_2, :].index.tolist()
    test_2d_result['tf'] = tf

    for col in ['dc_effect_size', 'dc_pval', 'dc_fdr']:
        test_2d_result[col] = estimator.hypothesis_test_result['CD14+ Monocytes'][col][gene_idxs_1[:, np.newaxis], gene_idxs_2].toarray()[idx, :]
    dfs.append(test_2d_result)
test_2d_result = pd.concat(dfs)

# %%
plt.hist(test_2d_result['dc_effect_size'], bins=30)
# Out:
# //anaconda3/envs/single_cell/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# //anaconda3/envs/single_cell/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([ 1.,  0.,  0.,  1.,  1.,  2.,  2.,  1.,  3.,  7., 12., 14.,  8.,
#         15., 11., 17., 17., 19., 12., 19., 10.,  9.,  8.,  3.,  4.,  2.,
#          0.,  1.,  0.,  1.]),
#  array([-0.33754793, -0.3091513 , -0.28075466, -0.25235802, -0.2239614 ,
#         -0.19556476, -0.16716813, -0.13877149, -0.11037486, -0.08197823,
#         -0.0535816 , -0.02518496,  0.00321167,  0.03160831,  0.06000494,
#          0.08840157,  0.11679821,  0.14519484,  0.17359146,  0.2019881 ,
#          0.23038474,  0.25878137,  0.287178  ,  0.31557465,  0.34397128,
#          0.37236792,  0.40076452,  0.42916116,  0.4575578 ,  0.48595443,
#          0.51435107], dtype=float32),
#  <a list of 30 Patch objects>)

# %%
plt.hist(test_2d_result['dc_pval'], bins=30)
# Out:
# (array([235.,  16.,  13.,  19.,   6.,   6.,   5.,   8.,   5.,   7.,   4.,
#           5.,   2.,   5.,   5.,   2.,   4.,   5.,   4.,   7.,   1.,   5.,
#           6.,   1.,   2.,   4.,   4.,   4.,   4.,   6.]),
#  array([0.        , 0.03327001, 0.06654001, 0.09981002, 0.13308002,
#         0.16635002, 0.19962004, 0.23289004, 0.26616004, 0.29943004,
#         0.33270004, 0.36597005, 0.39924008, 0.43251008, 0.46578008,
#         0.49905008, 0.5323201 , 0.5655901 , 0.5988601 , 0.6321301 ,
#         0.6654001 , 0.6986701 , 0.7319401 , 0.76521015, 0.79848015,
#         0.83175015, 0.86502016, 0.89829016, 0.93156016, 0.96483016,
#         0.99810016], dtype=float32),
#  <a list of 30 Patch objects>)

# %%
test_2d_result.query('tf == "STAT1" & dc_fdr < 0.1')
# Out:
#          gene     tf  dc_effect_size   dc_pval    dc_fdr
# 0        OSTC  STAT1        0.249027  0.005000  0.009389
# 9       BIRC3  STAT1        0.194520  0.014999  0.026783
# 15   C11orf58  STAT1        0.297341  0.012599  0.022803
# 18      ANXA2  STAT1        0.338699  0.000006  0.000011
# 21     NDUFS8  STAT1        0.345122  0.009399  0.017325
# 23       RIT1  STAT1        0.218273  0.057594  0.092894
# 25     OCIAD2  STAT1        0.268811  0.003200  0.006124
# 34     DNASE2  STAT1       -0.193883  0.059594  0.095733
# 39     OSBPL8  STAT1        0.225560  0.049995  0.082296
# 40     TMEM66  STAT1        0.248237  0.001600  0.003091
# 43      RAP1B  STAT1        0.337250  0.036396  0.060914
# 45        HBB  STAT1       -0.074923  0.006999  0.013083
# 47       EIF6  STAT1        0.308019  0.011399  0.020725
# 48     NDUFC2  STAT1        0.273458  0.034597  0.058391
# 57       CNBP  STAT1        0.278757  0.009799  0.017980
# 59      RRP7A  STAT1        0.302256  0.016598  0.029508
# 61      RPL29  STAT1        0.288320  0.003800  0.007203
# 63     SCAMP2  STAT1        0.274202  0.026197  0.044974
# 73       RPN1  STAT1        0.395112  0.010999  0.020089
# 77      PA2G4  STAT1        0.202309  0.061194  0.097520
# 78        TKT  STAT1        0.299380  0.022398  0.039123
# 81     TALDO1  STAT1        0.277198  0.000002  0.000004
# 84   HSP90AA1  STAT1        0.211055  0.008999  0.016665
# 88       DBNL  STAT1        0.218920  0.060194  0.096310
# 89      SMDT1  STAT1        0.298445  0.020598  0.036137
# 96      CNPY2  STAT1        0.272970  0.026997  0.046149
# 97     UBE2L6  STAT1       -0.232284  0.054395  0.088446
# 98       CTSL  STAT1        0.146873  0.023998  0.041554
# 104   HSP90B1  STAT1        0.183475  0.014599  0.026304
# 118    COMMD8  STAT1        0.255798  0.033397  0.056605
# 120      XRN2  STAT1        0.236518  0.055594  0.090031
# 123     PRDX4  STAT1        0.220242  0.037996  0.063327
# 131   HNRNPA1  STAT1        0.340640  0.000800  0.001561
# 134    UBE2V2  STAT1        0.370824  0.005000  0.009389
# 139      ARF1  STAT1        0.217198  0.053995  0.088154
# 145     GTF3A  STAT1        0.193082  0.024198  0.041720
# 147   ARHGDIB  STAT1        0.292767  0.000017  0.000033
# 152      CCT2  STAT1        0.261034  0.042796  0.071030
# 158    SEC61B  STAT1        0.377949  0.001600  0.003091
# 160      LGMN  STAT1        0.297272  0.000005  0.000010
# 163     TCEB1  STAT1       -0.337548  0.018198  0.032067
# 164     RPS19  STAT1        0.233396  0.003200  0.006124
# 168     TM2D2  STAT1        0.345026  0.003800  0.007203
# 171    MRPS16  STAT1        0.261436  0.050995  0.083598
# 172     EIF3J  STAT1        0.282653  0.018198  0.032067
# 173     EIF3F  STAT1        0.200898  0.034997  0.058818
# 175    NDUFB4  STAT1        0.357692  0.007399  0.013766
# 190       UBC  STAT1        0.217077  0.029397  0.050038
# 192    BCLAF1  STAT1        0.229439  0.023998  0.041554
# 194   TMEM123  STAT1        0.225322  0.049395  0.081645
# 197      GNL3  STAT1        0.247654  0.014799  0.026544

# %%
test_2d_result.query('tf == "STAT2" & dc_fdr < 0.1')
# Out:
# Empty DataFrame
# Columns: [gene, tf, dc_effect_size, dc_pval, dc_fdr]
# Index: []

# %%
estimator.hypothesis_test_result['CD14+ Monocytes']['design_df']
# Out:
#     covariate replicate          batch  constant  cell_count
# 0           0      1016  default_batch         1         461
# 1           0      1256  default_batch         1         469
# 2           0      1015  default_batch         1         908
# 3           0       107  default_batch         1         255
# 4           0      1244  default_batch         1         500
# 5           0       101  default_batch         1         247
# 6           0      1488  default_batch         1         365
# 7           0      1039  default_batch         1         160
# 8           1       101  default_batch         1         302
# 9           1      1016  default_batch         1         401
# 10          1      1256  default_batch         1         420
# 11          1      1244  default_batch         1         358
# 12          1      1488  default_batch         1         396
# 13          1      1015  default_batch         1         786
# 14          1      1039  default_batch         1         206
# 15          1       107  default_batch         1         213

# %%
plt.hist(test_2d_result['dc_pval'])
# Out:
# (array([299., 339., 367., 377., 436., 422., 414., 461., 432., 453.]),
#  array([0.     , 0.09997, 0.19994, 0.29991, 0.39988, 0.49985, 0.59982,
#         0.69979, 0.79976, 0.89973, 0.9997 ], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
test_2d_result.head(100)
# Out:
#         gene     tf  dc_effect_size   dc_pval    dc_fdr
# 0        B2M  STAT1        0.102194  0.940906  0.997311
# 1     MALAT1  STAT1        0.257830  0.064194  0.997311
# 2     TMSB4X  STAT1        0.238927  0.012399  0.982358
# 3       FTH1  STAT1        0.022244  0.929507  0.997311
# 4      HLA-B  STAT1       -0.083608  0.640336  0.997311
# 5      RPLP1  STAT1        0.144014  0.558344  0.997311
# 6       RPS2  STAT1        0.216442  0.031797  0.997311
# 7      RPL10  STAT1        0.272418  0.010199  0.982358
# 8      RPL13  STAT1        0.172212  0.082392  0.997311
# 9      RPL21  STAT1        0.156887  0.115188  0.997311
# 10     RPS19  STAT1        0.264694  0.005799  0.982358
# 11    RPL13A  STAT1        0.213442  0.021398  0.997311
# 12     RPS18  STAT1        0.171247  0.085991  0.997311
# 13     RPS14  STAT1        0.135462  0.230977  0.997311
# 14     RPL32  STAT1        0.276014  0.007799  0.982358
# 15      RPS6  STAT1        0.219020  0.017798  0.997311
# 16     RPL11  STAT1        0.274889  0.017598  0.997311
# 17     RPS4X  STAT1        0.274151  0.003400  0.982358
# 18      RPS3  STAT1        0.232683  0.013799  0.982358
# 19     RPL15  STAT1        0.322810  0.006199  0.982358
# 20     HLA-A  STAT1        0.128213  0.544746  0.997311
# 21    RPS27A  STAT1        0.192454  0.064994  0.997311
# 22     H3F3B  STAT1             NaN  0.105189  0.997311
# 23    RPL18A  STAT1        0.198023  0.078792  0.997311
# 24     RPL19  STAT1        0.272990  0.021198  0.997311
# 25     HLA-C  STAT1       -0.174250  0.547145  0.997311
# 26     RPL34  STAT1        0.100950  0.334167  0.997311
# 27     RPS3A  STAT1        0.198038  0.044796  0.997311
# 28      RPL7  STAT1        0.189326  0.062194  0.997311
# 29      RPL3  STAT1        0.210985  0.024198  0.997311
# 30      RPL8  STAT1        0.133127  0.241776  0.997311
# 31     RPS13  STAT1        0.238763  0.094591  0.997311
# 32     RPLP2  STAT1        0.191950  0.141386  0.997311
# 33      RPS9  STAT1        0.235217  0.218378  0.997311
# 34     RPS15  STAT1        0.227803  0.045195  0.997311
# 35     RPS12  STAT1        0.092099  0.407559  0.997311
# 36      EIF1  STAT1       -0.114249  0.899710  0.997311
# 37     RPL26  STAT1        0.349742  0.042996  0.997311
# 38      TPT1  STAT1       -0.276868  0.268173  0.997311
# 39     RPS27  STAT1        0.180872  0.063594  0.997311
# 40    RPL23A  STAT1        0.128775  0.235376  0.997311
# 41     RPL12  STAT1        0.314640  0.010399  0.982358
# 42      PTMA  STAT1        0.191334  0.054595  0.997311
# 43    RPL27A  STAT1        0.159358  0.154185  0.997311
# 44    RPS15A  STAT1        0.219586  0.040996  0.997311
# 45    RPL35A  STAT1        0.236466  0.059394  0.997311
# 46     RPL30  STAT1        0.250660  0.045995  0.997311
# 47      RPL9  STAT1        0.222529  0.062994  0.997311
# 48     RPL31  STAT1        0.170943  0.103590  0.997311
# 49       FAU  STAT1        0.299471  0.327967  0.997311
# 50     RPL28  STAT1        0.089798  0.574143  0.997311
# 51     RPS23  STAT1        0.174329  0.202180  0.997311
# 52       FTL  STAT1       -0.046467  0.586941  0.997311
# 53     RPL18  STAT1        0.173240  0.104790  0.997311
# 54     RPS16  STAT1        0.022046  0.952505  0.997311
# 55     RPL14  STAT1        0.228650  0.041596  0.997311
# 56      RPS7  STAT1        0.210215  0.047795  0.997311
# 57      RPS8  STAT1        0.123310  0.299770  0.997311
# 58     RPL29  STAT1        0.356961  0.006799  0.982358
# 59    TMSB10  STAT1        0.155123  0.779322  0.997311
# 60      OAZ1  STAT1             NaN  0.089591  0.997311
# 61      RPL6  STAT1        0.135862  0.211979  0.997311
# 62      RPS5  STAT1        0.217095  0.035196  0.997311
# 63      MYL6  STAT1        0.546959  0.185981  0.997311
# 64      ACTB  STAT1        0.365362  0.002800  0.982358
# 65     RPS20  STAT1        0.056404  0.705329  0.997311
# 66    GNB2L1  STAT1        0.175711  0.226377  0.997311
# 67    PABPC1  STAT1        0.230349  0.016998  0.997311
# 68     EEF1D  STAT1        0.181973  0.249575  0.997311
# 69     PFDN5  STAT1        0.139425  0.585741  0.997311
# 70     HLA-E  STAT1       -0.401615  0.148185  0.997311
# 71     UBA52  STAT1        0.338491  0.212379  0.997311
# 72     RPS25  STAT1        0.180081  0.148385  0.997311
# 73      NACA  STAT1        0.222863  0.077592  0.997311
# 74     RPL24  STAT1        0.098090  0.518748  0.997311
# 75      PFN1  STAT1        0.487719  0.004200  0.982358
# 76     RPL35  STAT1        0.232954  0.065193  0.997311
# 77     RPS24  STAT1        0.005908  0.794521  0.997311
# 78      BTG1  STAT1        0.094681  0.263174  0.997311
# 79     SERF2  STAT1             NaN  0.214579  0.997311
# 80    RPL10A  STAT1        0.100556  0.268173  0.997311
# 81    COX4I1  STAT1        0.342321  0.103790  0.997311
# 82      SRGN  STAT1        0.108929  0.721928  0.997311
# 83       UBC  STAT1        0.206439  0.270173  0.997311
# 84     RPL27  STAT1       -0.055574  0.562344  0.997311
# 85  SH3BGRL3  STAT1        0.168172  0.367363  0.997311
# 86       UBB  STAT1       -0.116790  0.335166  0.997311
# 87    EEF1A1  STAT1        0.236548  0.075592  0.997311
# 88   RPL36AL  STAT1        0.259223  0.248975  0.997311
# 89     RPLP0  STAT1        0.275550  0.009199  0.982358
# 90    TMEM66  STAT1        0.217302  0.076592  0.997311
# 91     RPS28  STAT1        0.000062  0.973303  0.997393
# 92      BTF3  STAT1        0.214586  0.151585  0.997311
# 93     RPL7A  STAT1        0.115812  0.258774  0.997311
# 94     RPL36  STAT1        0.148269  0.251575  0.997311
# 95     ARPC2  STAT1        0.424986  0.181382  0.997311
# 96    MYL12B  STAT1       -0.218651  0.328367  0.997311
# 97    TMBIM6  STAT1        0.133373  0.745725  0.997311
# 98    MYL12A  STAT1        0.022869  0.718528  0.997311
# 99     ANXA1  STAT1        0.143600  0.047395  0.997311
