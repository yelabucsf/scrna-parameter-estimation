# %% [markdown]
# ### Run GLM for power analysis

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import scanpy as sc
import seaborn as sns
import pandas as pd
import numpy as np
import itertools
import logging
import statsmodels.api as sm

import pymare as meta

# %%
import sys
sys.path.append('/home/ssm-user/Github/memento')

# %%
data_path = '/data_volume/memento/'

# %%
logging.basicConfig(
    format="%(asctime)s %(process)-7s %(levelname)-8s %(message)s",
    level=logging.INFO, 
    datefmt="%Y-%m-%d %H:%M:%S",
)
logging.captureWarnings(True)

# %%
import memento.model.rna as rna

# %%
pop = 'asian'
inds = 50
rep=0
ct = 'cM'

# %%
data_path  = '/data_volume/memento/lupus/'

pos = pd.read_csv(data_path + 'mateqtl_input/sampled_pos/{}_{}_{}.tsv'.format(pop, inds ,rep), sep='\t', index_col=0)
cov = pd.read_csv(data_path + 'mateqtl_input/sampled_cov/{}_{}_{}.tsv'.format(pop, inds, rep), sep='\t', index_col=0).T

# Randomly generate genotypes
shuffled_pos = pos.copy()
shuffled_pos[shuffled_pos.columns] = np.random.choice([0, 1, 2], size=pos.shape)
onek_replication = pd.read_csv(data_path + 'filtered_onek_eqtls.csv')

adata = sc.read(data_path + 'single_cell/{}_{}.h5ad'.format(pop, ct))
adata = adata[adata.obs.ind_cov.isin(pos.columns)].copy()

# %%
adata.obs['q'] = 0.1
rna.MementoRNA.setup_anndata(
    adata=adata,
    q_column='q',
    label_columns=['ind_cov'])
# Out:
# 2023-07-14 11:10:28 2423080 INFO     setup_anndata: creating groups
# 2023-07-14 11:10:28 2423080 INFO     setup_anndata: computing cell sizes

# %%
cov_df = cov.loc[[x.split('^')[1] for x in adata.uns['memento']['groups']]]
donor_df = pos[[x.split('^')[1] for x in adata.uns['memento']['groups']]].T
shuffled_donor_df =  shuffled_pos[[x.split('^')[1] for x in adata.uns['memento']['groups']]].T

cov_df.index = 'memento_group^'+cov_df.index
cov_df = sm.add_constant(cov_df)
donor_df.index = 'memento_group^'+donor_df.index
shuffled_donor_df.index = 'memento_group^'+shuffled_donor_df.index

# %%
gene_snp_pairs = onek_replication.query('cg_cov == "{}"'.format(ct))
gene_to_snp = dict(gene_snp_pairs[gene_snp_pairs.gene.isin(adata.var.index)].groupby('gene').rsid.apply(list))

# %%
# Define expressed genes
adata.var['expr_genes'] = (adata.X.mean(axis=0).A1 > 0.01)
adata = adata[:, adata.var['expr_genes']]

# %%
model = rna.MementoRNA(adata=adata)
model.compute_estimate(
estimand='mean',
get_se=True,
n_jobs=30,
)
# Out:
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: running estimators for ['sum', 'mean', 'log_mean', 'log1p_mean', 'se_sum', 'se_mean', 'se_log_mean', 'se_log1p_mean', 'total_umi', 'cell_count']
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: gene_list is None, using all genes in AnnData object
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-519 using 30 parallel jobs
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: getting estimates for memento_group^1791_1791 using 30 parallel jobs
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: getting estimates for memento_group^1240_1240 using 30 parallel jobs
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-022 using 30 parallel jobs
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: getting estimates for memento_group^1771_1771 using 30 parallel jobs
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: getting estimates for memento_group^1472_1472 using 30 parallel jobs
# 2023-07-14 11:10:46 2423080 INFO     compute_estimate: getting estimates for memento_group^1754_1754 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1193_1193 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1886_1886 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1022_1022 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-558 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1197_1197 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1329_1329 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1417_1417 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-500 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1680_1680 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1031_1031 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1320_1320 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1054_1054 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1881_1881 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1119_1119 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-532 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1418_1418 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-538 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1222_1222 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1660_1660 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1682_1682 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1419_1419 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1584_1584 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1366_1366 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1404_1404 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-545 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1772_1772 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1445_1445 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-563 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1767_1767 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1279_1279 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1195_1195 using 30 parallel jobs
# 2023-07-14 11:10:47 2423080 INFO     compute_estimate: getting estimates for memento_group^1479_1479 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^1056_1056 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^1333_1333 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^1888_1888 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^1535_1535 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^1741_1741 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^1582_1582 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-556 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^1452_1452 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-551 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-574 using 30 parallel jobs
# 2023-07-14 11:10:48 2423080 INFO     compute_estimate: getting estimates for memento_group^HC-566 using 30 parallel jobs

# %%
result = model.differential_mean(covariates=covariate, treatments=treatment, family='quasiGLM', n_jobs=30, verbose=2)

# %%
sm.families.links.log()

# %%
result
# Out:
#                 treatment      coef        se      pval
# gene
# RP11-108M9.4   1:16796721 -0.024074  0.394824  0.951380
# PADI2          1:17414305  0.267382  0.492513  0.587203
# CDA            1:20935986  0.242343  0.459535  0.597940
# CDC42          1:22414785  0.044723  0.412463  0.913655
# PNRC2          1:24375663 -0.389440  0.409567  0.341676
# ...                   ...       ...       ...       ...
# AP001055.6    21:45636583 -0.113024  0.303645  0.709726
# ITGB2         21:46328099 -0.493111  0.532804  0.354705
# ITGB2-AS1     21:46349496  0.082331  0.391374  0.833383
# YBEY          21:47714607 -0.525984  0.322604  0.103010
# PRMT2         21:48040562  0.099826  0.516657  0.846791
#
# [329 rows x 4 columns]

# %%
def quasi_nb_var(mean, scale, dispersion):
    
    return scale*(mean + dispersion*mean**2)


def quasi_nb_objective(scale, dispersion, mean, variance):
    
    valid = (mean > 0) & (variance > 0)
    pred_y = np.log(quasi_nb_var(mean[valid], scale, dispersion))
    y = np.log(variance[valid])
    
    return ((pred_y-y)**2).mean()

    
    

def fit_quasi_nb(mean, variance):

    dispersion0 = 1
    scale0 = np.median((mean[variance > 0]/variance[variance > 0]))
        
    optim_obj = lambda params: quasi_nb_objective(params[0], params[1], mean, variance)

    res =  minimize(
        optim_obj, 
        [scale0, dispersion0],
        bounds=[(1e-5,None), (1e-10, 10)],
        method='Nelder-Mead'
    )
    return res.x

# %%
n_groups = model.estimates['mean'].shape[0]

# %%
group_idx = 0

# %%
mean = expr.iloc[group_idx].values
variance = sampling_variance.iloc[group_idx].values

# %%
optim_obj = lambda params: quasi_nb_objective(params[0], params[1], mean, variance)

# %%
optim_obj([1.6, 0.1])
# Out:
# 5.525925

# %%
minimize(
        optim_obj, 
        [1.6, 1],
        bounds=[(1e-5,None), (1e-10, 10)],
        method='Nelder-Mead',
    )
# Out:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 0.025494040921330452
#              x: [ 6.138e-01  1.000e-10]
#            nit: 74
#           nfev: 138
#  final_simplex: (array([[ 6.138e-01,  1.000e-10],
#                        [ 6.137e-01,  1.000e-10],
#                        [ 6.137e-01,  1.000e-10]]), array([ 2.549e-02,  2.549e-02,  2.549e-02]))

# %%
fit_quasi_nb(    
        mean = mean,
        variance = variance)
# Out:
# array([0.47579199, 0.        ])

# %%
quasi_nb_objective(1.6, 0.1, mean, variance)
# Out:
# 5.525925

# %%
expr = (
    model.estimates['mean']/
    model.adata.uns['memento']['umi_depth']*
    model.estimates['total_umi'].values)
count_multiplier = model.estimates['total_umi'].values/model.adata.uns['memento']['umi_depth']
sampling_variance =  (model.estimates['se_mean']**2)*count_multiplier**2

# Fit within-sample variance function parameters
intra_var_scale = np.zeros(n_groups)
intra_var_dispersion = np.zeros(n_groups)
for group_idx in range(n_groups):
    intra_var_scale[group_idx], intra_var_dispersion[group_idx] = fit_quasi_nb(    
        mean = expr.iloc[group_idx].values,
        variance = sampling_variance.iloc[group_idx].values)

# %%
result = model.differential_mean(
    covariates=cov_df, 
    treatments=donor_df,
    treatment_for_gene=gene_to_snp,
    family='quasiGLM',
    verbose=2,
    n_jobs=1)

shuffled_result = model.differential_mean(
    covariates=cov_df, 
    treatments=shuffled_donor_df,
    treatment_for_gene=gene_to_snp,
    family='quasiGLM',
    verbose=2,
    n_jobs=5)

rr = result.query('pval<0.05').shape[0]/result.shape[0]
fpr =shuffled_result.query('pval<0.05').shape[0]/shuffled_result.shape[0]
print(f'replication rate: {rr}')
print(f'FPR rate: {fpr}')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# 2023-07-14 11:43:25 2423080 WARNING  /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
#
# 2023-07-14 11:43:25 2423080 WARNING  /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
#
# 2023-07-14 11:43:25 2423080 WARNING  /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
#
# 2023-07-14 11:43:25 2423080 WARNING  fit_loglinear: HLA-DRB5, 6:32599999 fitted with OLS
# 2023-07-14 11:43:25 2423080 WARNING  /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:426: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
#
# 2023-07-14 11:43:25 2423080 WARNING  /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: divide by zero encountered in divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
#
# 2023-07-14 11:43:25 2423080 WARNING  fit_loglinear: CES1, 16:55864560 fitted with OLS
# [Parallel(n_jobs=1)]: Done 329 out of 329 | elapsed:    1.6s finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  37 tasks      | elapsed:    0.4s
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:426: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: divide by zero encountered in divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# WARNING:root:fit_loglinear: HLA-DRB5, 6:32599999 fitted with OLS
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:426: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: divide by zero encountered in divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# WARNING:root:fit_loglinear: TMEM176B, 7:150477909 fitted with OLS
# WARNING:root:fit_loglinear: TMEM176A, 7:150477909 fitted with OLS
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:426: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: divide by zero encountered in divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# WARNING:root:fit_loglinear: CES1, 16:55864560 fitted with OLS
# [Parallel(n_jobs=5)]: Done 329 out of 329 | elapsed:    1.0s finished
# replication rate: 0.3768996960486322
# FPR rate: 0.0182370820668693

# %%
gene ='PADI2'
t = '1:17414305'
design_matrix = pd.concat([cov_df, donor_df[[t]]], axis=1)

# %%
groups_in_test = cov_df.index.tolist()
test_estimates = {est:res.loc[groups_in_test] for est,res in model.estimates.items()}

test_estimates['log1p_mean'] = np.log(test_estimates['mean']+1)
l = np.log((test_estimates['mean']+1) - test_estimates['sem'])
u = np.log((test_estimates['mean']+1) + test_estimates['sem'])
test_estimates['log1p_sem'] = (u-l)/2

expr = test_estimates['log1p_mean']
expr_sem = test_estimates['log1p_sem']
min_sem = expr_sem[expr_sem > 0].min(axis=0)
for col in expr_sem.columns:
    expr_sem[col] = expr_sem[col].replace(0.0, min_sem[col])

# %%
y=expr.loc[:,[gene]]
X=design_matrix.values
v=expr_sem.loc[:,[gene]]**2

# %%
# MetaRegression
data = meta.core.Dataset(
    y=y,
    X=X,
    v=v,
    X_names=design_matrix.columns)

dsl = meta.estimators.WeightedLeastSquares()
dsl.fit_dataset(data)
result = dsl.summary()
coef = float(result.get_fe_stats()['est'][-1])
p = float(result.get_fe_stats()['p'][-1])

print(result.to_df().iloc[-1, :])
print(result.get_heterogeneity_stats())
print(result.get_re_stats())
# Out:
# name        (1:17414305,)
# estimate         0.007764
# se               0.001547
# z-score          5.017171
# p-value          0.000001
# ci_0.025         0.004731
# ci_0.975         0.010797
# Name: 35, dtype: object
# {'Q': array([48.41112721]), 'p(Q)': array([1.12369722e-05]), 'I^2': array([71.08102867]), 'H': array([1.85955308])}
# {'tau^2': 0.0, 'ci_l': array([1.05065384e-05]), 'ci_u': array([0.00010914])}

# %%
ols_model= sm.OLS(y, design_matrix).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PADI2   R-squared:                       0.873
# Model:                            OLS   Adj. R-squared:                  0.587
# Method:                 Least Squares   F-statistic:                     3.046
# Date:                Fri, 30 Jun 2023   Prob (F-statistic):             0.0123
# Time:                        19:35:07   Log-Likelihood:                 208.26
# No. Observations:                  50   AIC:                            -346.5
# Df Residuals:                      15   BIC:                            -279.6
# Df Model:                          34
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0149      0.016      0.937      0.363      -0.019       0.049
# age                0.0002      0.000      1.437      0.171   -8.93e-05       0.000
# Female            -0.0123      0.005     -2.277      0.038      -0.024      -0.001
# status            -0.0026      0.006     -0.437      0.669      -0.015       0.010
# PC1_e              0.0014      0.002      0.909      0.378      -0.002       0.005
# PC2_e              0.0012      0.002      0.548      0.591      -0.004       0.006
# PC3_e             -0.0003      0.000     -0.750      0.465      -0.001       0.001
# PC4_e             -0.0004      0.000     -0.955      0.355      -0.001       0.001
# PC5_e              0.0006      0.001      1.059      0.306      -0.001       0.002
# PC6_e              0.0003      0.000      1.754      0.100   -6.94e-05       0.001
# PC7_e             -0.0002      0.000     -0.854      0.407      -0.001       0.000
# PC8_e             -0.0001      0.000     -0.494      0.629      -0.001       0.000
# PC9_e              0.0005      0.000      1.769      0.097      -0.000       0.001
# PC10_e            -0.0001      0.000     -0.357      0.726      -0.001       0.001
# PC1_g           -2.72e-05      0.013     -0.002      0.998      -0.029       0.029
# PC2_g             -0.0214      0.019     -1.144      0.271      -0.061       0.018
# PC3_g             -0.0298      0.015     -2.024      0.061      -0.061       0.002
# PC4_g              0.0077      0.018      0.427      0.676      -0.031       0.046
# PC5_g             -0.0112      0.018     -0.606      0.554      -0.051       0.028
# PC6_g             -0.0049      0.019     -0.256      0.802      -0.046       0.036
# PC7_g              0.0189      0.013      1.464      0.164      -0.009       0.046
# batch_cov_b_1     -0.0169      0.030     -0.566      0.580      -0.081       0.047
# batch_cov_b_10    -0.0066      0.018     -0.362      0.722      -0.046       0.032
# batch_cov_b_11    -0.0043      0.029     -0.146      0.886      -0.066       0.058
# batch_cov_b_12     0.0149      0.069      0.215      0.833      -0.133       0.163
# batch_cov_b_13     0.0128      0.063      0.202      0.843      -0.122       0.148
# batch_cov_b_14     0.0041      0.036      0.113      0.912      -0.073       0.081
# batch_cov_b_15     0.0097      0.036      0.270      0.791      -0.067       0.086
# batch_cov_b_2     -0.0054      0.019     -0.279      0.784      -0.047       0.036
# batch_cov_b_4     -0.0337      0.025     -1.373      0.190      -0.086       0.019
# batch_cov_b_6     -0.0103      0.010     -1.084      0.295      -0.031       0.010
# batch_cov_b_7     -0.0274      0.015     -1.851      0.084      -0.059       0.004
# batch_cov_b_8     -0.0103      0.011     -0.908      0.378      -0.034       0.014
# batch_cov_b_9     -0.0088      0.011     -0.828      0.421      -0.032       0.014
# 1:17414305         0.0073      0.003      2.653      0.018       0.001       0.013
# ==============================================================================
# Omnibus:                        3.679   Durbin-Watson:                   2.401
# Prob(Omnibus):                  0.159   Jarque-Bera (JB):                2.857
# Skew:                           0.575   Prob(JB):                        0.240
# Kurtosis:                       3.222   Cond. No.                     5.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
np.linalg.matrix_rank(design_matrix)
# Out:
# 36

# %%
design_matrix
# Out:
#                           age  Female  status       PC1_e      PC2_e
# memento_group^1791_1791  66.0     0.0     0.0   -7.161831  10.069257  \
# memento_group^1240_1240  23.0     0.0     0.0   -8.648941  13.411016
# memento_group^HC-022     74.0     0.0     1.0    2.728118 -13.795299
# memento_group^1771_1771  49.0     0.0     0.0   -7.359370  10.981154
# memento_group^1334_1334  52.0     0.0     0.0    5.260662 -28.224529
# memento_group^HC-573     31.0     0.0     1.0    8.553464 -22.598488
# memento_group^1754_1754  45.0     0.0     0.0   -8.188705  12.238516
# memento_group^HC-571     52.0     0.0     1.0   13.338191 -28.923302
# memento_group^1886_1886  23.0     0.0     0.0   -0.590112  -8.827822
# memento_group^1022_1022  56.0     0.0     0.0   -3.538297  11.315355
# memento_group^1197_1197  42.0     0.0     0.0   -6.845650  24.362411
# memento_group^1522_1522  56.0     1.0     0.0  -10.479478  10.580180
# memento_group^1417_1417  45.0     0.0     0.0   -9.214747  16.006852
# memento_group^HC-500     48.0     0.0     1.0    6.928247 -32.189163
# memento_group^1121_1121  28.0     0.0     0.0  -14.004374  26.198086
# memento_group^1680_1680  46.0     0.0     0.0   -6.440348  -4.136405
# memento_group^1320_1320  29.0     0.0     0.0   -6.009938  -4.725941
# memento_group^1672_1672  47.0     0.0     0.0   -7.398451  10.634159
# memento_group^1721_1721  40.0     0.0     0.0   -7.426765  -5.507994
# memento_group^HC-546     28.0     0.0     1.0   -2.438605  -9.058376
# memento_group^1743_1743  48.0     0.0     0.0   11.127703 -32.302163
# memento_group^1051_1051  45.0     1.0     0.0   -3.618569  10.441025
# memento_group^HC-532     51.0     0.0     1.0   27.203738 -34.456320
# memento_group^1763_1763  34.0     0.0     0.0   -8.948985  11.237377
# memento_group^1418_1418  39.0     0.0     0.0   -7.761962  14.009203
# memento_group^1582_1582  26.911601  -0.477758  19.368407  -2.481525
# memento_group^HC-556     12.084320  17.923862  11.252334  -2.868265
# memento_group^1452_1452  -4.006588   5.301584   5.041411  -3.276195
# memento_group^1046_1046  17.123775   7.290970  -6.777024  -1.911976
# memento_group^HC-551     -0.187612   9.188371  12.150184  -3.418964
# memento_group^HC-574      6.024208   2.846335   2.008142   1.497958
# memento_group^1248_1248   3.951833   1.355017  -6.489395   1.109050
# memento_group^HC-566    -11.490071  -3.561998  -1.568238  -1.670776
#
#                              PC7_e  ...  batch_cov_b_15  batch_cov_b_2
# memento_group^1791_1791   3.677423  ...             0.0            0.0  \
# memento_group^1240_1240  -1.124865  ...             0.0            0.0
# memento_group^HC-022     -5.948432  ...             0.0            0.0
# memento_group^1771_1771   2.659662  ...             0.0            0.0
# memento_group^1334_1334  -3.568229  ...             0.0            0.0
# memento_group^HC-573    -10.778825  ...             0.0            0.0
# memento_group^1754_1754   3.796883  ...             0.0            0.0
# memento_group^HC-571     -5.951474  ...             0.0            0.0
# memento_group^1886_1886  -7.803633  ...             0.0            0.0
# memento_group^1022_1022  -3.783664  ...             0.0            0.0
# memento_group^1197_1197   5.726665  ...             0.0            1.0
# memento_group^1522_1522   1.478537  ...             0.0            0.0
# memento_group^1417_1417   3.205060  ...             0.0            0.0
# memento_group^HC-500     -2.195963  ...             0.0            0.0
# memento_group^1121_1121   2.159018  ...             0.0            0.0
# memento_group^1680_1680   2.682475  ...             1.0            0.0
# memento_group^1320_1320  -0.541675  ...             1.0            0.0
# memento_group^1672_1672   0.969312  ...             0.0            0.0
# memento_group^1721_1721   2.178699  ...             1.0            0.0
# memento_group^HC-546     -4.364669  ...             1.0            0.0
# memento_group^1743_1743   2.105001  ...             0.0            0.0
# memento_group^1051_1051  -3.404612  ...             0.0            0.0
# memento_group^HC-532     27.268345  ...             0.0            0.0
# memento_group^1763_1763   4.234846  ...             0.0            0.0
# memento_group^1418_1418   4.581250  ...             0.0            0.0
# memento_group^1641_1641   5.021218  ...             0.0            0.0
# memento_group^1660_1660  -6.402683  ...             0.0            0.0
# memento_group^1325_1325  -8.803791  ...             0.0            0.0
# memento_group^1682_1682  -2.186856  ...             0.0            0.0
# memento_group^1324_1324   0.562016  ...             0.0            0.0
# memento_group^1737_1737  -2.880144  ...             0.0            0.0
# memento_group^1122_1122  -1.419811  ...             0.0            0.0
# memento_group^1419_1419  -1.434419  ...             1.0            0.0
# memento_group^1768_1768   2.665288  ...             0.0            0.0
# memento_group^1420_1420  -6.720400  ...             0.0            0.0
# memento_group^1584_1584   1.635319  ...             0.0            0.0
# memento_group^1366_1366   6.299006  ...             0.0            0.0
# memento_group^1404_1404   2.647329  ...             0.0            0.0
# memento_group^1567_1567  -0.745425  ...             0.0            0.0
# memento_group^1772_1772  -4.615961  ...             0.0            0.0
# memento_group^1767_1767   3.982162  ...             0.0            0.0
# memento_group^1279_1279   3.795706  ...             0.0            0.0
# memento_group^1165_1165  -0.643690  ...             0.0            1.0
# memento_group^1479_1479  -1.411669  ...             0.0            0.0
# memento_group^1597_1597  -3.320854  ...             0.0            0.0
# memento_group^1226_1226   4.128810  ...             0.0            1.0
# memento_group^1341_1341  -1.966987  ...             0.0            0.0
# memento_group^2061_2061  -1.257215  ...             0.0            0.0
# memento_group^1888_1888  -3.962727  ...             0.0            0.0
# memento_group^1667_1667  -0.774206  ...             0.0            0.0
# memento_group^1535_1535   6.123103  ...             0.0            0.0
# memento_group^1741_1741   3.732910  ...             0.0            0.0
# memento_group^1582_1582  -1.203065  ...             0.0            0.0
# memento_group^HC-556    -13.000092  ...             1.0            0.0
# memento_group^1452_1452  -1.762716  ...             0.0            0.0
# memento_group^1046_1046  -3.898217  ...             0.0            0.0
# memento_group^HC-551     -6.047395  ...             1.0            0.0
# memento_group^HC-574     -8.840718  ...             0.0            0.0
# memento_group^1248_1248   0.468000  ...             0.0            0.0
# memento_group^HC-566     -5.861222  ...             0.0            0.0
#
#                          batch_cov_b_3  batch_cov_b_4  batch_cov_b_5
# memento_group^1791_1791            0.0            0.0            0.0  \
# memento_group^1240_1240            1.0            0.0            0.0
# memento_group^HC-022               0.0            0.0            0.0
# memento_group^1771_1771            0.0            0.0            0.0
# memento_group^1334_1334            0.0            0.0            0.0
# memento_group^HC-573               0.0            0.0            0.0
# memento_group^1754_1754            0.0            0.0            0.0
# memento_group^HC-571               0.0            0.0            0.0
# memento_group^1886_1886            0.0            0.0            0.0
# memento_group^1022_1022            0.0            0.0            0.0
# memento_group^1197_1197            0.0            0.0            0.0
# memento_group^1522_1522            0.0            0.0            0.0
# memento_group^1417_1417            0.0            0.0            0.0
# memento_group^HC-500               0.0            0.0            0.0
# memento_group^1121_1121            0.0            0.0            0.0
# memento_group^1680_1680            0.0            0.0            0.0
# memento_group^1320_1320            0.0            0.0            0.0
# memento_group^1672_1672            0.0            0.0            1.0
# memento_group^1721_1721            0.0            0.0            0.0
# memento_group^HC-546               0.0            0.0            0.0
# memento_group^1743_1743            0.0            0.0            0.0
# memento_group^1051_1051            0.0            0.0            0.0
# memento_group^HC-532               0.0            0.0            0.0
# memento_group^1763_1763            0.0            0.0            0.0
# memento_group^1418_1418            0.0            0.0            0.0
# memento_group^1641_1641            0.0            0.0            1.0
# memento_group^1660_1660            0.0            0.0            0.0
# memento_group^1325_1325            0.0            0.0            0.0
# memento_group^1682_1682            0.0            0.0            0.0
# memento_group^1324_1324            0.0            0.0            0.0
# memento_group^1737_1737            0.0            0.0            0.0
# memento_group^1122_1122            0.0            0.0            0.0
# memento_group^1419_1419            0.0            0.0            0.0
# memento_group^1768_1768            0.0            0.0            0.0
# memento_group^1420_1420            0.0            0.0            0.0
# memento_group^1584_1584            0.0            1.0            0.0
# memento_group^1366_1366            0.0            0.0            0.0
# memento_group^1404_1404            0.0            0.0            0.0
# memento_group^1567_1567            0.0            1.0            0.0
# memento_group^1772_1772            0.0            0.0            0.0
# memento_group^1767_1767            0.0            0.0            0.0
# memento_group^1279_1279            0.0            0.0            0.0
# memento_group^1165_1165            0.0            0.0            0.0
# memento_group^1479_1479            0.0            0.0            0.0
# memento_group^1597_1597            0.0            1.0            0.0
# memento_group^1226_1226            0.0            0.0            0.0
# memento_group^1341_1341            0.0            0.0            0.0
# memento_group^2061_2061            0.0            0.0            0.0
# memento_group^1888_1888            0.0            0.0            0.0
# memento_group^1667_1667            0.0            0.0            0.0
# memento_group^1535_1535            0.0            0.0            0.0
# memento_group^1741_1741            0.0            0.0            0.0
# memento_group^1582_1582            0.0            1.0            0.0
# memento_group^HC-556               0.0            0.0            0.0
# memento_group^1452_1452            0.0            0.0            0.0
# memento_group^1046_1046            0.0            0.0            0.0
# memento_group^HC-551               0.0            0.0            0.0
# memento_group^HC-574               0.0            0.0            0.0
# memento_group^1248_1248            1.0            0.0            0.0
# memento_group^HC-566               0.0            0.0            0.0
#
#                          batch_cov_b_6  batch_cov_b_7  batch_cov_b_8
# memento_group^1791_1791            0.0            1.0            0.0  \
# memento_group^1240_1240            0.0            0.0            0.0
# memento_group^HC-022               0.0            0.0            0.0
# memento_group^1771_1771            0.0            1.0            0.0
# memento_group^1334_1334            0.0            0.0            0.0
# memento_group^HC-573               0.0            0.0            0.0
# memento_group^1754_1754            0.0            1.0            0.0
# memento_group^HC-571               0.0            0.0            0.0
# memento_group^1886_1886            0.0            0.0            0.0
# memento_group^1022_1022            0.0            0.0            0.0
# memento_group^1197_1197            0.0            0.0            0.0
# memento_group^1522_1522            0.0            0.0            0.0
# memento_group^1417_1417            0.0            0.0            1.0
# memento_group^HC-500               0.0            0.0            0.0
# memento_group^1121_1121            0.0            0.0            0.0
# memento_group^1680_1680            0.0            0.0            0.0
# memento_group^1320_1320            0.0            0.0            0.0
# memento_group^1672_1672            0.0            0.0            0.0
# memento_group^1721_1721            0.0            0.0            0.0
# memento_group^HC-546               0.0            0.0            0.0
# memento_group^1743_1743            0.0            0.0            0.0
# memento_group^1051_1051            0.0            0.0            0.0
# memento_group^HC-532               0.0            0.0            0.0
# memento_group^1763_1763            0.0            1.0            0.0
# memento_group^1418_1418            0.0            0.0            1.0
# memento_group^1641_1641            0.0            0.0            0.0
# memento_group^1660_1660            0.0            0.0            0.0
# memento_group^1325_1325            0.0            0.0            0.0
# memento_group^1682_1682            0.0            0.0            0.0
# memento_group^1324_1324            1.0            0.0            0.0
# memento_group^1737_1737            0.0            0.0            0.0
# memento_group^1122_1122            0.0            0.0            0.0
# memento_group^1419_1419            0.0            0.0            0.0
# memento_group^1768_1768            0.0            0.0            0.0
# memento_group^1420_1420            0.0            0.0            0.0
# memento_group^1584_1584            0.0            0.0            0.0
# memento_group^1366_1366            0.0            0.0            1.0
# memento_group^1404_1404            0.0            0.0            1.0
# memento_group^1567_1567            0.0            0.0            0.0
# memento_group^1772_1772            0.0            0.0            0.0
# memento_group^1767_1767            0.0            1.0            0.0
# memento_group^1279_1279            0.0            0.0            0.0
# memento_group^1165_1165            0.0            0.0            0.0
# memento_group^1479_1479            0.0            0.0            0.0
# PADI2         1:17414305   0.0   1.0
# PNRC2         1:24375663   0.0   1.0
# FHL3          1:38465315   0.0   1.0
# ITGB3BP       1:63893394   0.0   1.0
# GSTM4        1:110172362   0.0   1.0
# ...                  ...   ...   ...
# UPK3A        22:45673477   0.0   1.0
# OLIG1        21:34432792   0.0   1.0
# AP001053.11  21:45649640   0.0   1.0
# AP001055.6   21:45636583   0.0   1.0
# ITGB2-AS1    21:46349496   0.0   1.0
#
# [157 rows x 3 columns]

# %%
result.query('pval <0.05')
# Out:
#             treatment      coef          pval
# gene
# CDA        1:20935986  0.105587  2.442491e-14
# CD52       1:26645806  0.290659  2.026619e-06
# C1orf122   1:38235343 -0.011924  4.227407e-03
# NDUFS5     1:39465139 -0.077633  3.822534e-03
# PPT1       1:40559207  0.102415  2.993161e-12
# ...               ...       ...           ...
# MAP3K7CL  21:30533397  0.040103  6.061818e-14
# IFNGR2    21:34776300  0.035621  2.710907e-04
# HMGN1     21:40731931  0.033734  1.507120e-02
# ITGB2     21:46328099 -0.207140  6.461541e-03
# YBEY      21:47714607 -0.021395  6.887046e-06
#
# [85 rows x 3 columns]

# %%
model.estimates['log1p_mean'] = np.log(model.estimates['mean']+1)
l = np.log((model.estimates['mean']+1) - model.estimates['sem'])
u = np.log((model.estimates['mean']+1) + model.estimates['sem'])
model.estimates['log1p_sem'] = (u-l)/2

# %%
dd

# %%
result = model.differential_mean(
    covariates=cov_df, 
    treatments=donor_df,
    treatment_for_gene=gene_to_snp,
    family='NB',
    verbose=2,
    n_jobs=5)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  74 tasks      | elapsed:    1.0s
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1342: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1346: RuntimeWarning: divide by zero encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/varfuncs.py:265: RuntimeWarning: overflow encountered in square
#   return p + self.alpha*p**2
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/varfuncs.py:265: RuntimeWarning: overflow encountered in square
#   return p + self.alpha*p**2
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1342: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1346: RuntimeWarning: divide by zero encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/varfuncs.py:265: RuntimeWarning: overflow encountered in square
#   return p + self.alpha*p**2
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1342: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1346: RuntimeWarning: divide by zero encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/varfuncs.py:265: RuntimeWarning: overflow encountered in square
#   return p + self.alpha*p**2
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1342: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1342: RuntimeWarning: overflow encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1346: RuntimeWarning: divide by zero encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/varfuncs.py:265: RuntimeWarning: overflow encountered in square
#   return p + self.alpha*p**2
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1342: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1346: RuntimeWarning: divide by zero encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.10/site-packages/statsmodels/genmod/generalized_linear_model.py:1211: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# [Parallel(n_jobs=5)]: Done 320 out of 329 | elapsed:    3.7s remaining:    0.1s
# [Parallel(n_jobs=5)]: Done 329 out of 329 | elapsed:    3.7s finished

# %%
result.query('pval < 0.05')
# Out:
#                  treatment      coef           pval
# gene
# CHST13         3:126268953  0.691833   6.108333e-04
# RP11-539L10.3    4:6675421 -0.665931   1.192296e-08
# SHROOM1        5:132613418  0.344046   2.402571e-06
# HLA-DQA1        6:32606756 -1.525906   4.212932e-02
# CCZ1B            7:6855646 -1.682542   3.673926e-03
# TMEM176A       7:150477909 -2.123900   4.185953e-02
# HP             16:72118324 -1.849975   7.743754e-04
# GSTT1          22:24334948 -2.280182  2.985696e-120
