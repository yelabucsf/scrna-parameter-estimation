# %% [markdown]
# # Matrix eQTL

# %%
library("MatrixEQTL");

# %%
base.dir = '/data_volume/memento/lupus/full_analysis/mateqtl/inputs/'

# %%
pop <- 'eur'

# %%
useModel = modelLINEAR; # modelANOVA, modelLINEAR, or modelLINEAR_CROSS
SNP_file_name = paste(base.dir, pop, '_genos.tsv', sep="");
snps_location_file_name = paste(base.dir, pop, "_snpspos.txt", sep="");
covariates_file_name = paste(base.dir,  pop, '_mateqtl_cov.txt', sep="");
pvOutputThreshold_cis = 1;
errorCovariance = numeric();
cisDist = 100000;

gene_location_file_name = paste(base.dir, "geneloc_tss_hg19.txt", sep="");


## Load genotype data

snps = SlicedData$new();
snps$fileDelimiter = "\t";      # the TAB character
snps$fileOmitCharacters = "NA"; # denote missing values;
snps$fileSkipRows = 1;          # one row of column labels
snps$fileSkipColumns = 1;       # one column of row labels
snps$fileSliceSize = 100000;      # read file in slices of 2,000 rows
snps$LoadFile(SNP_file_name);


## Load covariates

cvrt = SlicedData$new();
cvrt$fileDelimiter = "\t";      # the TAB character
cvrt$fileOmitCharacters = "NA"; # denote missing values;
cvrt$fileSkipRows = 1;          # one row of column labels
cvrt$fileSkipColumns = 1;       # one column of row labels
if(length(covariates_file_name)>0) {
cvrt$LoadFile(covariates_file_name);
}
# Out:
# Rows read: 100,000
#
# Rows read: 200,000
#
# Rows read: 300,000
#
# Rows read: 400,000
#
# Rows read: 500,000
#
# Rows read: 600,000
#
# Rows read: 700,000
#
# Rows read: 800,000
#
# Rows read: 900,000
#
# Rows read: 1,000,000
#
# Rows read: 1,100,000
#
# Rows read: 1,200,000
#
# Rows read: 1,300,000
#
# Rows read: 1,400,000
#
# Rows read: 1,500,000
#
# Rows read: 1,600,000
#
# Rows read: 1,700,000
#
# Rows read: 1,800,000
#
# Rows read: 1,900,000
#
# Rows read: 2,000,000
#
# Rows read: 2,100,000
#
# Rows read: 2,200,000
#
# Rows read: 2,300,000
#
# Rows read: 2,400,000
#
# Rows read: 2,500,000
#
# Rows read: 2,600,000
#
# Rows read: 2,700,000
#
# Rows read: 2,800,000
#
# Rows read: 2,900,000
#
# Rows read: 3,000,000
#
# Rows read: 3,100,000
#
# Rows read: 3,200,000
#
# Rows read: 3285470 done.
#
# Rows read: 35 done.

# %%
snpspos = read.table(snps_location_file_name, header = TRUE, stringsAsFactors = FALSE);
genepos = read.table(gene_location_file_name, header = TRUE, stringsAsFactors = FALSE, sep='\t');

for (ct in c('B','T8', 'T4', 'NK', 'ncM', 'cM')){


    expression_file_name = paste(base.dir, "../pseudobulk/", pop, '_', ct, '.csv',sep="");
    output_file_name = paste(base.dir, "../outputs/", pop, '_', ct, '_all_hg19.csv', sep="");
    ## Load gene expression data

    gene = SlicedData$new();
    gene$fileDelimiter = "\t";      # the TAB character
    gene$fileOmitCharacters = "NA"; # denote missing values;
    gene$fileSkipRows = 1;          # one row of column labels
    gene$fileSkipColumns = 1;       # one column of row labels
    gene$fileSliceSize = 2000;      # read file in slices of 2,000 rows
    gene$LoadFile(expression_file_name);


    me = Matrix_eQTL_main(
        snps = snps,
        gene = gene,
        cvrt = cvrt,
#         output_file_name     = output_file_name,
#         pvOutputThreshold     = pvOutputThreshold,
        useModel = useModel,
        errorCovariance = errorCovariance,
        verbose = FALSE,
        output_file_name.cis = output_file_name,
        pvOutputThreshold.cis = pvOutputThreshold_cis,
        snpspos = snpspos,
        genepos = genepos,
        cisDist = cisDist,
        pvalue.hist = "qqplot",
        min.pv.by.genesnp = FALSE,
        noFDRsaveMemory = FALSE);
    
    }
# Out:
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7681 done.
#
# 7681 of 7681 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 44,834 cis-eQTLs, 2,338 trans-eQTLs
#
#  1.51% done, 4,685 trans-eQTLs
#
#  2.27% done, 6,692 trans-eQTLs
#
#  3.03% done, 8,790 trans-eQTLs
#
#  3.78% done, 109,452 cis-eQTLs, 10,730 trans-eQTLs
#
#  4.54% done, 12,928 trans-eQTLs
#
#  5.30% done, 15,141 trans-eQTLs
#
#  6.06% done, 17,236 trans-eQTLs
#
#  6.81% done, 172,533 cis-eQTLs, 19,388 trans-eQTLs
#
#  7.57% done, 21,493 trans-eQTLs
#
#  8.33% done, 23,669 trans-eQTLs
#
#  9.09% done, 25,721 trans-eQTLs
#
#  9.84% done, 218,145 cis-eQTLs, 28,287 trans-eQTLs
#
# 10.60% done, 30,120 trans-eQTLs
#
# 11.36% done, 32,109 trans-eQTLs
#
# 12.12% done, 33,963 trans-eQTLs
#
# 12.87% done, 294,641 cis-eQTLs, 36,516 trans-eQTLs
#
# 13.63% done, 38,131 trans-eQTLs
#
# 14.39% done, 39,999 trans-eQTLs
#
# 15.15% done, 41,537 trans-eQTLs
#
# 15.90% done, 343,971 cis-eQTLs, 43,705 trans-eQTLs
#
# 16.66% done, 45,786 trans-eQTLs
#
# 17.42% done, 47,603 trans-eQTLs
#
# 18.18% done, 49,259 trans-eQTLs
#
# 18.93% done, 367,118 cis-eQTLs, 50,658 trans-eQTLs
#
# 19.69% done, 52,167 trans-eQTLs
#
# 20.45% done, 53,729 trans-eQTLs
#
# 21.21% done, 55,150 trans-eQTLs
#
# 21.96% done, 401,050 cis-eQTLs, 57,275 trans-eQTLs
#
# 22.72% done, 59,179 trans-eQTLs
#
# 23.48% done, 60,982 trans-eQTLs
#
# 24.24% done, 62,372 trans-eQTLs
#
# 25.00% done, 443,641 cis-eQTLs, 64,152 trans-eQTLs
#
# 25.75% done, 66,118 trans-eQTLs
#
# 26.51% done, 68,429 trans-eQTLs
#
# 27.27% done, 69,882 trans-eQTLs
#
# 28.03% done, 480,312 cis-eQTLs, 71,710 trans-eQTLs
#
# 28.78% done, 73,548 trans-eQTLs
#
# 29.54% done, 75,001 trans-eQTLs
#
# 30.30% done, 76,776 trans-eQTLs
#
# 31.06% done, 506,346 cis-eQTLs, 78,649 trans-eQTLs
#
# 31.81% done, 546,949 cis-eQTLs, 80,203 trans-eQTLs
#
# 32.57% done, 81,758 trans-eQTLs
#
# 33.33% done, 83,309 trans-eQTLs
#
# 34.09% done, 85,566 trans-eQTLs
#
# 34.84% done, 606,989 cis-eQTLs, 88,041 trans-eQTLs
#
# 35.60% done, 89,819 trans-eQTLs
#
# 36.36% done, 91,403 trans-eQTLs
#
# 37.12% done, 92,671 trans-eQTLs
#
# 37.87% done, 671,289 cis-eQTLs, 94,634 trans-eQTLs
#
# 38.63% done, 96,835 trans-eQTLs
#
# 39.39% done, 98,301 trans-eQTLs
#
# 40.15% done, 100,177 trans-eQTLs
#
# 40.90% done, 741,249 cis-eQTLs, 101,936 trans-eQTLs
#
# 41.66% done, 103,419 trans-eQTLs
#
# 42.42% done, 105,084 trans-eQTLs
#
# 43.18% done, 107,298 trans-eQTLs
#
# 43.93% done, 833,588 cis-eQTLs, 109,958 trans-eQTLs
#
# 44.69% done, 112,677 trans-eQTLs
#
# 45.45% done, 114,688 trans-eQTLs
#
# 46.21% done, 116,421 trans-eQTLs
#
# 46.96% done, 887,421 cis-eQTLs, 118,136 trans-eQTLs
#
# 47.72% done, 120,113 trans-eQTLs
#
# 48.48% done, 121,884 trans-eQTLs
#
# 49.24% done, 124,523 trans-eQTLs
#
# 50.00% done, 935,617 cis-eQTLs, 127,030 trans-eQTLs
#
# 50.75% done, 129,357 trans-eQTLs
#
# 51.51% done, 131,183 trans-eQTLs
#
# 52.27% done, 134,293 trans-eQTLs
#
# 53.03% done, 941,945 cis-eQTLs, 137,073 trans-eQTLs
#
# 53.78% done, 970,437 cis-eQTLs, 139,625 trans-eQTLs
#
# 54.54% done, 141,579 trans-eQTLs
#
# 55.30% done, 143,672 trans-eQTLs
#
# 56.06% done, 145,792 trans-eQTLs
#
# 56.81% done, 1,030,456 cis-eQTLs, 147,748 trans-eQTLs
#
# 57.57% done, 149,577 trans-eQTLs
#
# 58.33% done, 151,906 trans-eQTLs
#
# 59.09% done, 153,740 trans-eQTLs
#
# 59.84% done, 1,089,025 cis-eQTLs, 155,634 trans-eQTLs
#
# 60.60% done, 157,244 trans-eQTLs
#
# 61.36% done, 159,476 trans-eQTLs
#
# 62.12% done, 161,375 trans-eQTLs
#
# 62.87% done, 1,154,107 cis-eQTLs, 163,613 trans-eQTLs
#
# 63.63% done, 165,652 trans-eQTLs
#
# 64.39% done, 167,539 trans-eQTLs
#
# 65.15% done, 169,749 trans-eQTLs
#
# 65.90% done, 1,196,327 cis-eQTLs, 172,236 trans-eQTLs
#
# 66.66% done, 174,827 trans-eQTLs
#
# 67.42% done, 176,828 trans-eQTLs
#
# 68.18% done, 178,868 trans-eQTLs
#
# 68.93% done, 1,229,917 cis-eQTLs, 180,608 trans-eQTLs
#
# 69.69% done, 182,216 trans-eQTLs
#
# 70.45% done, 184,384 trans-eQTLs
#
# 71.21% done, 186,721 trans-eQTLs
#
# 71.96% done, 1,269,167 cis-eQTLs, 188,876 trans-eQTLs
#
# 72.72% done, 190,503 trans-eQTLs
#
# 73.48% done, 192,424 trans-eQTLs
#
# 74.24% done, 194,714 trans-eQTLs
#
# 75.00% done, 1,329,098 cis-eQTLs, 197,113 trans-eQTLs
#
# 75.75% done, 198,699 trans-eQTLs
#
# 76.51% done, 200,524 trans-eQTLs
#
# 77.27% done, 202,440 trans-eQTLs
#
# 78.03% done, 1,364,374 cis-eQTLs, 204,489 trans-eQTLs
#
# 78.78% done, 206,059 trans-eQTLs
#
# 79.54% done, 208,079 trans-eQTLs
#
# 80.30% done, 210,094 trans-eQTLs
#
# 81.06% done, 1,387,844 cis-eQTLs, 212,225 trans-eQTLs
#
# 81.81% done, 213,995 trans-eQTLs
#
# 82.57% done, 217,074 trans-eQTLs
#
# 83.33% done, 220,190 trans-eQTLs
#
# 84.09% done, 1,420,309 cis-eQTLs, 222,943 trans-eQTLs
#
# 84.84% done, 225,856 trans-eQTLs
#
# 85.60% done, 227,861 trans-eQTLs
#
# 86.36% done, 229,765 trans-eQTLs
#
# 87.12% done, 1,434,329 cis-eQTLs, 231,425 trans-eQTLs
#
# 87.87% done, 1,556,667 cis-eQTLs, 233,235 trans-eQTLs
#
# 88.63% done, 235,731 trans-eQTLs
#
# 89.39% done, 237,811 trans-eQTLs
#
# 90.15% done, 239,704 trans-eQTLs
#
# 90.90% done, 1,652,195 cis-eQTLs, 241,786 trans-eQTLs
#
# 91.66% done, 243,902 trans-eQTLs
#
# 92.42% done, 245,879 trans-eQTLs
#
# 93.18% done, 247,888 trans-eQTLs
#
# 93.93% done, 1,700,662 cis-eQTLs, 249,484 trans-eQTLs
#
# 94.69% done, 251,775 trans-eQTLs
#
# 95.45% done, 254,234 trans-eQTLs
#
# 96.21% done, 256,320 trans-eQTLs
#
# 96.96% done, 1,766,508 cis-eQTLs, 258,323 trans-eQTLs
#
# 97.72% done, 259,659 trans-eQTLs
#
# 98.48% done, 260,988 trans-eQTLs
#
# 99.24% done, 262,453 trans-eQTLs
#
# 100.00% done, 1,852,781 cis-eQTLs, 263,612 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7576 done.
#
# 7576 of 7576 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 41,262 cis-eQTLs, 1,748 trans-eQTLs
#
#  1.51% done, 3,261 trans-eQTLs
#
#  2.27% done, 4,858 trans-eQTLs
#
#  3.03% done, 6,236 trans-eQTLs
#
#  3.78% done, 103,414 cis-eQTLs, 7,994 trans-eQTLs
#
#  4.54% done, 10,000 trans-eQTLs
#
#  5.30% done, 12,526 trans-eQTLs
#
#  6.06% done, 13,796 trans-eQTLs
#
#  6.81% done, 166,760 cis-eQTLs, 15,929 trans-eQTLs
#
#  7.57% done, 17,840 trans-eQTLs
#
#  8.33% done, 19,517 trans-eQTLs
#
#  9.09% done, 20,972 trans-eQTLs
#
#  9.84% done, 211,397 cis-eQTLs, 23,539 trans-eQTLs
#
# 10.60% done, 26,537 trans-eQTLs
#
# 11.36% done, 29,132 trans-eQTLs
#
# 12.12% done, 31,070 trans-eQTLs
#
# 12.87% done, 284,878 cis-eQTLs, 33,224 trans-eQTLs
#
# 13.63% done, 34,873 trans-eQTLs
#
# 14.39% done, 37,101 trans-eQTLs
#
# 15.15% done, 38,058 trans-eQTLs
#
# 15.90% done, 330,188 cis-eQTLs, 40,121 trans-eQTLs
#
# 16.66% done, 42,204 trans-eQTLs
#
# 17.42% done, 44,167 trans-eQTLs
#
# 18.18% done, 45,941 trans-eQTLs
#
# 18.93% done, 353,722 cis-eQTLs, 47,606 trans-eQTLs
#
# 19.69% done, 49,687 trans-eQTLs
#
# 20.45% done, 51,616 trans-eQTLs
#
# 21.21% done, 53,970 trans-eQTLs
#
# 21.96% done, 385,672 cis-eQTLs, 55,780 trans-eQTLs
#
# 22.72% done, 57,775 trans-eQTLs
#
# 23.48% done, 59,716 trans-eQTLs
#
# 24.24% done, 61,054 trans-eQTLs
#
# 25.00% done, 428,435 cis-eQTLs, 63,590 trans-eQTLs
#
# 25.75% done, 66,064 trans-eQTLs
#
# 26.51% done, 68,472 trans-eQTLs
#
# 27.27% done, 70,354 trans-eQTLs
#
# 28.03% done, 464,732 cis-eQTLs, 73,342 trans-eQTLs
#
# 28.78% done, 75,142 trans-eQTLs
#
# 29.54% done, 77,305 trans-eQTLs
#
# 30.30% done, 79,349 trans-eQTLs
#
# 31.06% done, 499,706 cis-eQTLs, 81,648 trans-eQTLs
#
# 31.81% done, 531,665 cis-eQTLs, 83,715 trans-eQTLs
#
# 32.57% done, 86,267 trans-eQTLs
#
# 33.33% done, 87,839 trans-eQTLs
#
# 34.09% done, 89,807 trans-eQTLs
#
# 34.84% done, 591,774 cis-eQTLs, 92,184 trans-eQTLs
#
# 35.60% done, 94,194 trans-eQTLs
#
# 36.36% done, 95,536 trans-eQTLs
#
# 37.12% done, 97,380 trans-eQTLs
#
# 37.87% done, 657,380 cis-eQTLs, 99,814 trans-eQTLs
#
# 38.63% done, 102,200 trans-eQTLs
#
# 39.39% done, 103,712 trans-eQTLs
#
# 40.15% done, 106,079 trans-eQTLs
#
# 40.90% done, 727,182 cis-eQTLs, 108,383 trans-eQTLs
#
# 41.66% done, 110,376 trans-eQTLs
#
# 42.42% done, 112,049 trans-eQTLs
#
# 43.18% done, 113,858 trans-eQTLs
#
# 43.93% done, 818,527 cis-eQTLs, 116,059 trans-eQTLs
#
# 44.69% done, 118,453 trans-eQTLs
#
# 45.45% done, 119,908 trans-eQTLs
#
# 46.21% done, 121,486 trans-eQTLs
#
# 46.96% done, 876,404 cis-eQTLs, 123,222 trans-eQTLs
#
# 47.72% done, 124,859 trans-eQTLs
#
# 48.48% done, 126,373 trans-eQTLs
#
# 49.24% done, 128,302 trans-eQTLs
#
# 50.00% done, 924,974 cis-eQTLs, 130,279 trans-eQTLs
#
# 50.75% done, 132,320 trans-eQTLs
#
# 51.51% done, 134,188 trans-eQTLs
#
# 52.27% done, 136,326 trans-eQTLs
#
# 53.03% done, 937,158 cis-eQTLs, 138,309 trans-eQTLs
#
# 53.78% done, 957,644 cis-eQTLs, 140,595 trans-eQTLs
#
# 54.54% done, 141,898 trans-eQTLs
#
# 55.30% done, 143,472 trans-eQTLs
#
# 56.06% done, 145,969 trans-eQTLs
#
# 56.81% done, 1,016,780 cis-eQTLs, 147,775 trans-eQTLs
#
# 57.57% done, 149,113 trans-eQTLs
#
# 58.33% done, 151,049 trans-eQTLs
#
# 59.09% done, 152,924 trans-eQTLs
#
# 59.84% done, 1,077,309 cis-eQTLs, 154,858 trans-eQTLs
#
# 60.60% done, 156,307 trans-eQTLs
#
# 61.36% done, 157,875 trans-eQTLs
#
# 62.12% done, 159,278 trans-eQTLs
#
# 62.87% done, 1,140,702 cis-eQTLs, 161,005 trans-eQTLs
#
# 63.63% done, 162,325 trans-eQTLs
#
# 64.39% done, 164,210 trans-eQTLs
#
# 65.15% done, 165,944 trans-eQTLs
#
# 65.90% done, 1,182,469 cis-eQTLs, 167,759 trans-eQTLs
#
# 66.66% done, 169,502 trans-eQTLs
#
# 67.42% done, 171,291 trans-eQTLs
#
# 68.18% done, 172,901 trans-eQTLs
#
# 68.93% done, 1,214,123 cis-eQTLs, 174,874 trans-eQTLs
#
# 69.69% done, 176,518 trans-eQTLs
#
# 70.45% done, 178,207 trans-eQTLs
#
# 71.21% done, 180,478 trans-eQTLs
#
# 71.96% done, 1,253,612 cis-eQTLs, 182,700 trans-eQTLs
#
# 72.72% done, 184,795 trans-eQTLs
#
# 73.48% done, 186,753 trans-eQTLs
#
# 74.24% done, 188,370 trans-eQTLs
#
# 75.00% done, 1,314,283 cis-eQTLs, 190,842 trans-eQTLs
#
# 75.75% done, 192,201 trans-eQTLs
#
# 76.51% done, 194,191 trans-eQTLs
#
# 77.27% done, 196,335 trans-eQTLs
#
# 78.03% done, 1,345,288 cis-eQTLs, 197,807 trans-eQTLs
#
# 78.78% done, 199,244 trans-eQTLs
#
# 79.54% done, 201,394 trans-eQTLs
#
# 80.30% done, 203,397 trans-eQTLs
#
# 81.06% done, 1,368,038 cis-eQTLs, 205,599 trans-eQTLs
#
# 81.81% done, 207,101 trans-eQTLs
#
# 82.57% done, 209,330 trans-eQTLs
#
# 83.33% done, 211,262 trans-eQTLs
#
# 84.09% done, 1,401,730 cis-eQTLs, 213,078 trans-eQTLs
#
# 84.84% done, 214,669 trans-eQTLs
#
# 85.60% done, 216,763 trans-eQTLs
#
# 86.36% done, 218,968 trans-eQTLs
#
# 87.12% done, 1,424,241 cis-eQTLs, 220,887 trans-eQTLs
#
# 87.87% done, 1,534,317 cis-eQTLs, 222,425 trans-eQTLs
#
# 88.63% done, 224,181 trans-eQTLs
#
# 89.39% done, 226,129 trans-eQTLs
#
# 90.15% done, 228,603 trans-eQTLs
#
# 90.90% done, 1,622,846 cis-eQTLs, 229,953 trans-eQTLs
#
# 91.66% done, 232,080 trans-eQTLs
#
# 92.42% done, 234,084 trans-eQTLs
#
# 93.18% done, 236,077 trans-eQTLs
#
# 93.93% done, 1,672,155 cis-eQTLs, 237,624 trans-eQTLs
#
# 94.69% done, 239,723 trans-eQTLs
#
# 95.45% done, 241,602 trans-eQTLs
#
# 96.21% done, 243,541 trans-eQTLs
#
# 96.96% done, 1,731,690 cis-eQTLs, 245,145 trans-eQTLs
#
# 97.72% done, 246,505 trans-eQTLs
#
# 98.48% done, 247,975 trans-eQTLs
#
# 99.24% done, 249,475 trans-eQTLs
#
# 100.00% done, 1,816,932 cis-eQTLs, 250,869 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7398 done.
#
# 7398 of 7398 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 38,354 cis-eQTLs, 1,918 trans-eQTLs
#
#  1.51% done, 3,339 trans-eQTLs
#
#  2.27% done, 5,002 trans-eQTLs
#
#  3.03% done, 6,394 trans-eQTLs
#
#  3.78% done, 98,414 cis-eQTLs, 8,191 trans-eQTLs
#
#  4.54% done, 10,370 trans-eQTLs
#
#  5.30% done, 12,356 trans-eQTLs
#
#  6.06% done, 13,753 trans-eQTLs
#
#  6.81% done, 158,401 cis-eQTLs, 16,256 trans-eQTLs
#
#  7.57% done, 17,834 trans-eQTLs
#
#  8.33% done, 19,850 trans-eQTLs
#
#  9.09% done, 21,078 trans-eQTLs
#
#  9.84% done, 201,675 cis-eQTLs, 23,642 trans-eQTLs
#
# 10.60% done, 25,777 trans-eQTLs
#
# 11.36% done, 28,330 trans-eQTLs
#
# 12.12% done, 29,917 trans-eQTLs
#
# 12.87% done, 271,531 cis-eQTLs, 31,774 trans-eQTLs
#
# 13.63% done, 34,588 trans-eQTLs
#
# 14.39% done, 37,197 trans-eQTLs
#
# 15.15% done, 38,947 trans-eQTLs
#
# 15.90% done, 317,981 cis-eQTLs, 41,759 trans-eQTLs
#
# 16.66% done, 44,720 trans-eQTLs
#
# 17.42% done, 47,467 trans-eQTLs
#
# 18.18% done, 49,315 trans-eQTLs
#
# 18.93% done, 341,112 cis-eQTLs, 51,294 trans-eQTLs
#
# 19.69% done, 53,364 trans-eQTLs
#
# 20.45% done, 54,892 trans-eQTLs
#
# 21.21% done, 56,024 trans-eQTLs
#
# 21.96% done, 372,967 cis-eQTLs, 58,354 trans-eQTLs
#
# 22.72% done, 60,305 trans-eQTLs
#
# 23.48% done, 62,253 trans-eQTLs
#
# 24.24% done, 63,559 trans-eQTLs
#
# 25.00% done, 414,786 cis-eQTLs, 65,348 trans-eQTLs
#
# 25.75% done, 67,563 trans-eQTLs
#
# 26.51% done, 69,728 trans-eQTLs
#
# 27.27% done, 71,008 trans-eQTLs
#
# 28.03% done, 450,964 cis-eQTLs, 73,392 trans-eQTLs
#
# 28.78% done, 75,796 trans-eQTLs
#
# 29.54% done, 78,788 trans-eQTLs
#
# 30.30% done, 80,264 trans-eQTLs
#
# 31.06% done, 498,078 cis-eQTLs, 82,276 trans-eQTLs
#
# 31.81% done, 515,351 cis-eQTLs, 84,144 trans-eQTLs
#
# 32.57% done, 86,200 trans-eQTLs
#
# 33.33% done, 87,886 trans-eQTLs
#
# 34.09% done, 89,718 trans-eQTLs
#
# 34.84% done, 572,136 cis-eQTLs, 91,821 trans-eQTLs
#
# 35.60% done, 93,774 trans-eQTLs
#
# 36.36% done, 95,315 trans-eQTLs
#
# 37.12% done, 97,619 trans-eQTLs
#
# 37.87% done, 635,081 cis-eQTLs, 99,615 trans-eQTLs
#
# 38.63% done, 101,463 trans-eQTLs
#
# 39.39% done, 103,085 trans-eQTLs
#
# 40.15% done, 105,356 trans-eQTLs
#
# 40.90% done, 702,087 cis-eQTLs, 107,958 trans-eQTLs
#
# 41.66% done, 109,779 trans-eQTLs
#
# 42.42% done, 111,209 trans-eQTLs
#
# 43.18% done, 112,801 trans-eQTLs
#
# 43.93% done, 790,178 cis-eQTLs, 115,146 trans-eQTLs
#
# 44.69% done, 116,970 trans-eQTLs
#
# 45.45% done, 118,370 trans-eQTLs
#
# 46.21% done, 120,126 trans-eQTLs
#
# 46.96% done, 847,243 cis-eQTLs, 121,746 trans-eQTLs
#
# 47.72% done, 123,694 trans-eQTLs
#
# 48.48% done, 124,824 trans-eQTLs
#
# 49.24% done, 126,892 trans-eQTLs
#
# 50.00% done, 893,996 cis-eQTLs, 129,238 trans-eQTLs
#
# 50.75% done, 131,683 trans-eQTLs
#
# 51.51% done, 133,415 trans-eQTLs
#
# 52.27% done, 135,191 trans-eQTLs
#
# 53.03% done, 926,148 cis-eQTLs, 137,132 trans-eQTLs
#
# 53.78% done, 139,756 trans-eQTLs
#
# 54.54% done, 141,224 trans-eQTLs
#
# 55.30% done, 142,746 trans-eQTLs
#
# 56.06% done, 927,659 cis-eQTLs, 145,003 trans-eQTLs
#
# 56.81% done, 983,482 cis-eQTLs, 146,879 trans-eQTLs
#
# 57.57% done, 147,950 trans-eQTLs
#
# 58.33% done, 149,533 trans-eQTLs
#
# 59.09% done, 150,901 trans-eQTLs
#
# 59.84% done, 1,042,284 cis-eQTLs, 152,353 trans-eQTLs
#
# 60.60% done, 153,132 trans-eQTLs
#
# 61.36% done, 155,332 trans-eQTLs
#
# 62.12% done, 157,301 trans-eQTLs
#
# 62.87% done, 1,104,281 cis-eQTLs, 159,234 trans-eQTLs
#
# 63.63% done, 160,193 trans-eQTLs
#
# 64.39% done, 162,425 trans-eQTLs
#
# 65.15% done, 164,267 trans-eQTLs
#
# 65.90% done, 1,146,672 cis-eQTLs, 166,680 trans-eQTLs
#
# 66.66% done, 168,042 trans-eQTLs
#
# 67.42% done, 170,115 trans-eQTLs
#
# 68.18% done, 172,405 trans-eQTLs
#
# 68.93% done, 1,178,032 cis-eQTLs, 174,287 trans-eQTLs
#
# 69.69% done, 176,262 trans-eQTLs
#
# 70.45% done, 178,241 trans-eQTLs
#
# 71.21% done, 180,201 trans-eQTLs
#
# 71.96% done, 1,215,709 cis-eQTLs, 182,206 trans-eQTLs
#
# 72.72% done, 183,821 trans-eQTLs
#
# 73.48% done, 185,583 trans-eQTLs
#
# 74.24% done, 187,640 trans-eQTLs
#
# 75.00% done, 1,274,185 cis-eQTLs, 189,496 trans-eQTLs
#
# 75.75% done, 190,885 trans-eQTLs
#
# 76.51% done, 192,974 trans-eQTLs
#
# 77.27% done, 195,832 trans-eQTLs
#
# 78.03% done, 1,306,511 cis-eQTLs, 197,720 trans-eQTLs
#
# 78.78% done, 198,792 trans-eQTLs
#
# 79.54% done, 201,041 trans-eQTLs
#
# 80.30% done, 202,891 trans-eQTLs
#
# 81.06% done, 1,329,147 cis-eQTLs, 205,094 trans-eQTLs
#
# 81.81% done, 207,303 trans-eQTLs
#
# 82.57% done, 209,950 trans-eQTLs
#
# 83.33% done, 212,097 trans-eQTLs
#
# 84.09% done, 1,361,319 cis-eQTLs, 214,434 trans-eQTLs
#
# 84.84% done, 215,838 trans-eQTLs
#
# 85.60% done, 218,293 trans-eQTLs
#
# 86.36% done, 220,240 trans-eQTLs
#
# 87.12% done, 1,426,574 cis-eQTLs, 222,660 trans-eQTLs
#
# 87.87% done, 1,492,191 cis-eQTLs, 224,285 trans-eQTLs
#
# 88.63% done, 226,011 trans-eQTLs
#
# 89.39% done, 227,710 trans-eQTLs
#
# 90.15% done, 229,407 trans-eQTLs
#
# 90.90% done, 1,577,790 cis-eQTLs, 230,673 trans-eQTLs
#
# 91.66% done, 233,318 trans-eQTLs
#
# 92.42% done, 235,946 trans-eQTLs
#
# 93.18% done, 238,209 trans-eQTLs
#
# 93.93% done, 1,626,904 cis-eQTLs, 239,916 trans-eQTLs
#
# 94.69% done, 241,781 trans-eQTLs
#
# 95.45% done, 243,471 trans-eQTLs
#
# 96.21% done, 245,362 trans-eQTLs
#
# 96.96% done, 1,686,554 cis-eQTLs, 246,521 trans-eQTLs
#
# 97.72% done, 248,071 trans-eQTLs
#
# 98.48% done, 249,486 trans-eQTLs
#
# 99.24% done, 250,955 trans-eQTLs
#
# 100.00% done, 1,769,494 cis-eQTLs, 252,572 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7796 done.
#
# 7796 of 7796 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 43,106 cis-eQTLs, 2,158 trans-eQTLs
#
#  1.51% done, 4,436 trans-eQTLs
#
#  2.27% done, 6,578 trans-eQTLs
#
#  3.03% done, 8,499 trans-eQTLs
#
#  3.78% done, 105,155 cis-eQTLs, 10,331 trans-eQTLs
#
#  4.54% done, 12,065 trans-eQTLs
#
#  5.30% done, 14,038 trans-eQTLs
#
#  6.06% done, 15,616 trans-eQTLs
#
#  6.81% done, 168,850 cis-eQTLs, 16,990 trans-eQTLs
#
#  7.57% done, 18,944 trans-eQTLs
#
#  8.33% done, 20,806 trans-eQTLs
#
#  9.09% done, 22,192 trans-eQTLs
#
#  9.84% done, 215,210 cis-eQTLs, 24,439 trans-eQTLs
#
# 10.60% done, 26,583 trans-eQTLs
#
# 11.36% done, 28,772 trans-eQTLs
#
# 12.12% done, 31,258 trans-eQTLs
#
# 12.87% done, 287,518 cis-eQTLs, 33,502 trans-eQTLs
#
# 13.63% done, 35,771 trans-eQTLs
#
# 14.39% done, 38,297 trans-eQTLs
#
# 15.15% done, 40,343 trans-eQTLs
#
# 15.90% done, 333,381 cis-eQTLs, 42,555 trans-eQTLs
#
# 16.66% done, 44,444 trans-eQTLs
#
# 17.42% done, 46,275 trans-eQTLs
#
# 18.18% done, 48,185 trans-eQTLs
#
# 18.93% done, 355,938 cis-eQTLs, 50,338 trans-eQTLs
#
# 19.69% done, 52,831 trans-eQTLs
#
# 20.45% done, 55,000 trans-eQTLs
#
# 21.21% done, 57,039 trans-eQTLs
#
# 21.96% done, 392,092 cis-eQTLs, 59,151 trans-eQTLs
#
# 22.72% done, 61,509 trans-eQTLs
#
# 23.48% done, 63,782 trans-eQTLs
#
# 24.24% done, 65,900 trans-eQTLs
#
# 25.00% done, 434,597 cis-eQTLs, 67,890 trans-eQTLs
#
# 25.75% done, 69,493 trans-eQTLs
#
# 26.51% done, 71,388 trans-eQTLs
#
# 27.27% done, 72,835 trans-eQTLs
#
# 28.03% done, 472,710 cis-eQTLs, 74,933 trans-eQTLs
#
# 28.78% done, 76,306 trans-eQTLs
#
# 29.54% done, 77,428 trans-eQTLs
#
# 30.30% done, 78,424 trans-eQTLs
#
# 31.06% done, 499,630 cis-eQTLs, 80,071 trans-eQTLs
#
# 31.81% done, 540,559 cis-eQTLs, 81,549 trans-eQTLs
#
# 32.57% done, 83,039 trans-eQTLs
#
# 33.33% done, 85,036 trans-eQTLs
#
# 34.09% done, 87,535 trans-eQTLs
#
# 34.84% done, 602,476 cis-eQTLs, 89,531 trans-eQTLs
#
# 35.60% done, 91,737 trans-eQTLs
#
# 36.36% done, 93,462 trans-eQTLs
#
# 37.12% done, 95,275 trans-eQTLs
#
# 37.87% done, 668,808 cis-eQTLs, 97,191 trans-eQTLs
#
# 38.63% done, 99,404 trans-eQTLs
#
# 39.39% done, 101,356 trans-eQTLs
#
# 40.15% done, 103,160 trans-eQTLs
#
# 40.90% done, 741,281 cis-eQTLs, 104,889 trans-eQTLs
#
# 41.66% done, 106,729 trans-eQTLs
#
# 42.42% done, 108,311 trans-eQTLs
#
# 43.18% done, 110,752 trans-eQTLs
#
# 43.93% done, 835,271 cis-eQTLs, 113,392 trans-eQTLs
#
# 44.69% done, 115,755 trans-eQTLs
#
# 45.45% done, 117,880 trans-eQTLs
#
# 46.21% done, 119,551 trans-eQTLs
#
# 46.96% done, 895,568 cis-eQTLs, 122,051 trans-eQTLs
#
# 47.72% done, 124,517 trans-eQTLs
#
# 48.48% done, 126,462 trans-eQTLs
#
# 49.24% done, 128,831 trans-eQTLs
#
# 50.00% done, 928,208 cis-eQTLs, 132,014 trans-eQTLs
#
# 50.75% done, 944,909 cis-eQTLs, 134,516 trans-eQTLs
#
# 51.51% done, 136,687 trans-eQTLs
#
# 52.27% done, 138,594 trans-eQTLs
#
# 53.03% done, 141,336 trans-eQTLs
#
# 53.78% done, 976,950 cis-eQTLs, 143,968 trans-eQTLs
#
# 54.54% done, 145,963 trans-eQTLs
#
# 55.30% done, 148,329 trans-eQTLs
#
# 56.06% done, 150,376 trans-eQTLs
#
# 56.81% done, 1,037,093 cis-eQTLs, 152,338 trans-eQTLs
#
# 57.57% done, 154,749 trans-eQTLs
#
# 58.33% done, 157,356 trans-eQTLs
#
# 59.09% done, 159,344 trans-eQTLs
#
# 59.84% done, 1,099,689 cis-eQTLs, 161,538 trans-eQTLs
#
# 60.60% done, 163,142 trans-eQTLs
#
# 61.36% done, 164,825 trans-eQTLs
#
# 62.12% done, 166,699 trans-eQTLs
#
# 62.87% done, 1,165,000 cis-eQTLs, 168,835 trans-eQTLs
#
# 63.63% done, 170,572 trans-eQTLs
#
# 64.39% done, 172,408 trans-eQTLs
#
# 65.15% done, 174,333 trans-eQTLs
#
# 65.90% done, 1,207,310 cis-eQTLs, 176,691 trans-eQTLs
#
# 66.66% done, 178,462 trans-eQTLs
#
# 67.42% done, 180,791 trans-eQTLs
#
# 68.18% done, 183,311 trans-eQTLs
#
# 68.93% done, 1,242,095 cis-eQTLs, 185,417 trans-eQTLs
#
# 69.69% done, 187,639 trans-eQTLs
#
# 70.45% done, 189,337 trans-eQTLs
#
# 71.21% done, 191,195 trans-eQTLs
#
# 71.96% done, 1,282,369 cis-eQTLs, 193,082 trans-eQTLs
#
# 72.72% done, 195,071 trans-eQTLs
#
# 73.48% done, 196,955 trans-eQTLs
#
# 74.24% done, 198,843 trans-eQTLs
#
# 75.00% done, 1,344,533 cis-eQTLs, 200,994 trans-eQTLs
#
# 75.75% done, 202,816 trans-eQTLs
#
# 76.51% done, 204,419 trans-eQTLs
#
# 77.27% done, 206,197 trans-eQTLs
#
# 78.03% done, 1,378,254 cis-eQTLs, 207,912 trans-eQTLs
#
# 78.78% done, 209,385 trans-eQTLs
#
# 79.54% done, 211,657 trans-eQTLs
#
# 80.30% done, 213,968 trans-eQTLs
#
# 81.06% done, 1,402,006 cis-eQTLs, 216,539 trans-eQTLs
#
# 81.81% done, 218,415 trans-eQTLs
#
# 82.57% done, 220,337 trans-eQTLs
#
# 83.33% done, 222,565 trans-eQTLs
#
# 84.09% done, 1,428,651 cis-eQTLs, 224,805 trans-eQTLs
#
# 84.84% done, 1,437,203 cis-eQTLs, 226,506 trans-eQTLs
#
# 85.60% done, 228,532 trans-eQTLs
#
# 86.36% done, 230,417 trans-eQTLs
#
# 87.12% done, 232,128 trans-eQTLs
#
# 87.87% done, 1,574,523 cis-eQTLs, 233,799 trans-eQTLs
#
# 88.63% done, 236,709 trans-eQTLs
#
# 89.39% done, 239,772 trans-eQTLs
#
# 90.15% done, 242,569 trans-eQTLs
#
# 90.90% done, 1,668,758 cis-eQTLs, 245,018 trans-eQTLs
#
# 91.66% done, 247,200 trans-eQTLs
#
# 92.42% done, 249,171 trans-eQTLs
#
# 93.18% done, 251,025 trans-eQTLs
#
# 93.93% done, 1,718,326 cis-eQTLs, 252,923 trans-eQTLs
#
# 94.69% done, 255,383 trans-eQTLs
#
# 95.45% done, 257,405 trans-eQTLs
#
# 96.21% done, 259,833 trans-eQTLs
#
# 96.96% done, 1,779,804 cis-eQTLs, 262,037 trans-eQTLs
#
# 97.72% done, 263,693 trans-eQTLs
#
# 98.48% done, 264,940 trans-eQTLs
#
# 99.24% done, 266,292 trans-eQTLs
#
# 100.00% done, 1,869,521 cis-eQTLs, 267,918 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 8,000
#
# Rows read: 8673 done.
#
# 8673 of 8673 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.60% done, 50,094 cis-eQTLs, 2,687 trans-eQTLs
#
#  1.21% done, 5,257 trans-eQTLs
#
#  1.81% done, 7,674 trans-eQTLs
#
#  2.42% done, 10,610 trans-eQTLs
#
#  3.03% done, 11,077 trans-eQTLs
#
#  3.63% done, 119,775 cis-eQTLs, 13,056 trans-eQTLs
#
#  4.24% done, 15,020 trans-eQTLs
#
#  4.84% done, 17,012 trans-eQTLs
#
#  5.45% done, 18,871 trans-eQTLs
#
#  6.06% done, 19,459 trans-eQTLs
#
#  6.66% done, 190,245 cis-eQTLs, 21,850 trans-eQTLs
#
#  7.27% done, 24,153 trans-eQTLs
#
#  7.87% done, 26,314 trans-eQTLs
#
#  8.48% done, 29,117 trans-eQTLs
#
#  9.09% done, 30,011 trans-eQTLs
#
#  9.69% done, 242,856 cis-eQTLs, 31,639 trans-eQTLs
#
# 10.30% done, 33,557 trans-eQTLs
#
# 10.90% done, 35,584 trans-eQTLs
#
# 11.51% done, 37,310 trans-eQTLs
#
# 12.12% done, 37,963 trans-eQTLs
#
# 12.72% done, 324,369 cis-eQTLs, 40,393 trans-eQTLs
#
# 13.33% done, 42,949 trans-eQTLs
#
# 13.93% done, 44,915 trans-eQTLs
#
# 14.54% done, 47,098 trans-eQTLs
#
# 15.15% done, 47,845 trans-eQTLs
#
# 15.75% done, 376,938 cis-eQTLs, 49,816 trans-eQTLs
#
# 16.36% done, 52,004 trans-eQTLs
#
# 16.96% done, 53,819 trans-eQTLs
#
# 17.57% done, 55,529 trans-eQTLs
#
# 18.18% done, 56,201 trans-eQTLs
#
# 18.78% done, 405,018 cis-eQTLs, 57,821 trans-eQTLs
#
# 19.39% done, 59,928 trans-eQTLs
#
# 20.00% done, 62,210 trans-eQTLs
#
# 20.60% done, 63,904 trans-eQTLs
#
# 21.21% done, 64,612 trans-eQTLs
#
# 21.81% done, 440,900 cis-eQTLs, 66,303 trans-eQTLs
#
# 22.42% done, 68,143 trans-eQTLs
#
# 23.03% done, 70,134 trans-eQTLs
#
# 23.63% done, 72,223 trans-eQTLs
#
# 24.24% done, 72,898 trans-eQTLs
#
# 24.84% done, 488,825 cis-eQTLs, 75,163 trans-eQTLs
#
# 25.45% done, 77,370 trans-eQTLs
#
# 26.06% done, 79,566 trans-eQTLs
#
# 26.66% done, 82,009 trans-eQTLs
#
# 27.27% done, 82,591 trans-eQTLs
#
# 27.87% done, 503,506 cis-eQTLs, 85,145 trans-eQTLs
#
# 28.48% done, 529,999 cis-eQTLs, 86,873 trans-eQTLs
#
# 29.09% done, 88,845 trans-eQTLs
#
# 29.69% done, 91,572 trans-eQTLs
#
# 30.30% done, 92,478 trans-eQTLs
#
# 30.90% done, 94,215 trans-eQTLs
#
# 31.51% done, 605,802 cis-eQTLs, 95,772 trans-eQTLs
#
# 32.12% done, 97,741 trans-eQTLs
#
# 32.72% done, 99,493 trans-eQTLs
#
# 33.33% done, 100,155 trans-eQTLs
#
# 33.93% done, 102,092 trans-eQTLs
#
# 34.54% done, 673,057 cis-eQTLs, 104,066 trans-eQTLs
#
# 35.15% done, 106,253 trans-eQTLs
#
# 35.75% done, 108,026 trans-eQTLs
#
# 36.36% done, 108,869 trans-eQTLs
#
# 36.96% done, 111,070 trans-eQTLs
#
# 37.57% done, 747,486 cis-eQTLs, 112,867 trans-eQTLs
#
# 38.18% done, 115,270 trans-eQTLs
#
# 38.78% done, 117,797 trans-eQTLs
#
# 39.39% done, 118,393 trans-eQTLs
#
# 40.00% done, 120,230 trans-eQTLs
#
# 40.60% done, 825,628 cis-eQTLs, 122,576 trans-eQTLs
#
# 41.21% done, 125,149 trans-eQTLs
#
# 41.81% done, 127,401 trans-eQTLs
#
# 42.42% done, 127,985 trans-eQTLs
#
# 43.03% done, 129,975 trans-eQTLs
#
# 43.63% done, 930,304 cis-eQTLs, 132,104 trans-eQTLs
#
# 44.24% done, 933,606 cis-eQTLs, 133,988 trans-eQTLs
#
# 44.84% done, 136,488 trans-eQTLs
#
# 45.45% done, 137,302 trans-eQTLs
#
# 46.06% done, 139,382 trans-eQTLs
#
# 46.66% done, 141,884 trans-eQTLs
#
# 47.27% done, 1,005,142 cis-eQTLs, 144,098 trans-eQTLs
#
# 47.87% done, 146,219 trans-eQTLs
#
# 48.48% done, 146,714 trans-eQTLs
#
# 49.09% done, 149,095 trans-eQTLs
#
# 49.69% done, 151,250 trans-eQTLs
#
# 50.30% done, 1,063,333 cis-eQTLs, 153,748 trans-eQTLs
#
# 50.90% done, 155,965 trans-eQTLs
#
# 51.51% done, 156,722 trans-eQTLs
#
# 52.12% done, 158,617 trans-eQTLs
#
# 52.72% done, 160,815 trans-eQTLs
#
# 53.33% done, 1,098,451 cis-eQTLs, 162,960 trans-eQTLs
#
# 53.93% done, 165,258 trans-eQTLs
#
# 54.54% done, 166,046 trans-eQTLs
#
# 55.15% done, 168,008 trans-eQTLs
#
# 55.75% done, 170,221 trans-eQTLs
#
# 56.36% done, 1,168,423 cis-eQTLs, 172,076 trans-eQTLs
#
# 56.96% done, 174,299 trans-eQTLs
#
# 57.57% done, 174,970 trans-eQTLs
#
# 58.18% done, 177,121 trans-eQTLs
#
# 58.78% done, 179,188 trans-eQTLs
#
# 59.39% done, 1,238,212 cis-eQTLs, 181,373 trans-eQTLs
#
# 60.00% done, 183,513 trans-eQTLs
#
# 60.60% done, 184,249 trans-eQTLs
#
# 61.21% done, 186,346 trans-eQTLs
#
# 61.81% done, 188,170 trans-eQTLs
#
# 62.42% done, 1,308,955 cis-eQTLs, 190,009 trans-eQTLs
#
# 63.03% done, 191,975 trans-eQTLs
#
# 63.63% done, 192,499 trans-eQTLs
#
# 64.24% done, 194,466 trans-eQTLs
#
# 64.84% done, 196,198 trans-eQTLs
#
# 65.45% done, 1,356,657 cis-eQTLs, 197,954 trans-eQTLs
#
# 66.06% done, 199,819 trans-eQTLs
#
# 66.66% done, 200,290 trans-eQTLs
#
# 67.27% done, 202,514 trans-eQTLs
#
# 67.87% done, 204,561 trans-eQTLs
#
# 68.48% done, 1,393,362 cis-eQTLs, 206,529 trans-eQTLs
#
# 69.09% done, 208,514 trans-eQTLs
#
# 69.69% done, 209,223 trans-eQTLs
#
# 70.30% done, 210,895 trans-eQTLs
#
# 70.90% done, 213,178 trans-eQTLs
#
# 71.51% done, 1,431,469 cis-eQTLs, 215,927 trans-eQTLs
#
# 72.12% done, 1,435,156 cis-eQTLs, 217,629 trans-eQTLs
#
# 72.72% done, 218,548 trans-eQTLs
#
# 73.33% done, 220,277 trans-eQTLs
#
# 73.93% done, 222,242 trans-eQTLs
#
# 74.54% done, 224,191 trans-eQTLs
#
# 75.15% done, 1,502,256 cis-eQTLs, 226,492 trans-eQTLs
#
# 75.75% done, 227,074 trans-eQTLs
#
# 76.36% done, 228,981 trans-eQTLs
#
# 76.96% done, 230,746 trans-eQTLs
#
# 77.57% done, 232,829 trans-eQTLs
#
# 78.18% done, 1,538,957 cis-eQTLs, 234,890 trans-eQTLs
#
# 78.78% done, 235,858 trans-eQTLs
#
# 79.39% done, 237,829 trans-eQTLs
#
# 80.00% done, 240,110 trans-eQTLs
#
# 80.60% done, 242,308 trans-eQTLs
#
# 81.21% done, 1,563,048 cis-eQTLs, 245,136 trans-eQTLs
#
# 81.81% done, 245,915 trans-eQTLs
#
# 82.42% done, 247,692 trans-eQTLs
#
# 83.03% done, 250,330 trans-eQTLs
#
# 83.63% done, 252,324 trans-eQTLs
#
# 84.24% done, 1,603,062 cis-eQTLs, 254,327 trans-eQTLs
#
# 84.84% done, 254,989 trans-eQTLs
#
# 85.45% done, 257,245 trans-eQTLs
#
# 86.06% done, 259,371 trans-eQTLs
#
# 86.66% done, 261,638 trans-eQTLs
#
# 87.27% done, 1,760,110 cis-eQTLs, 263,560 trans-eQTLs
#
# 87.87% done, 264,297 trans-eQTLs
#
# 88.48% done, 266,281 trans-eQTLs
#
# 89.09% done, 268,280 trans-eQTLs
#
# 89.69% done, 270,480 trans-eQTLs
#
# 90.30% done, 1,866,247 cis-eQTLs, 273,075 trans-eQTLs
#
# 90.90% done, 273,488 trans-eQTLs
#
# 91.51% done, 275,748 trans-eQTLs
#
# 92.12% done, 277,829 trans-eQTLs
#
# 92.72% done, 279,834 trans-eQTLs
#
# 93.33% done, 1,921,551 cis-eQTLs, 282,584 trans-eQTLs
#
# 93.93% done, 283,341 trans-eQTLs
#
# 94.54% done, 285,333 trans-eQTLs
#
# 95.15% done, 287,579 trans-eQTLs
#
# 95.75% done, 289,848 trans-eQTLs
#
# 96.36% done, 1,923,976 cis-eQTLs, 291,640 trans-eQTLs
#
# 96.96% done, 1,995,863 cis-eQTLs, 292,385 trans-eQTLs
#
# 97.57% done, 294,112 trans-eQTLs
#
# 98.18% done, 295,825 trans-eQTLs
#
# 98.78% done, 297,300 trans-eQTLs
#
# 99.39% done, 299,139 trans-eQTLs
#
# 100.00% done, 2,094,035 cis-eQTLs, 300,153 trans-eQTLs
#
# Rows read: 2,000
#
# Rows read: 4,000
#
# Rows read: 6,000
#
# Rows read: 7942 done.
#
# 7942 of 7942 genes matched
#
# 3285470 of 3285470 SNPs matched
#
#
#  0.75% done, 45,760 cis-eQTLs, 1,751 trans-eQTLs
#
#  1.51% done, 3,678 trans-eQTLs
#
#  2.27% done, 5,850 trans-eQTLs
#
#  3.03% done, 8,297 trans-eQTLs
#
#  3.78% done, 111,463 cis-eQTLs, 10,590 trans-eQTLs
#
#  4.54% done, 12,914 trans-eQTLs
#
#  5.30% done, 14,396 trans-eQTLs
#
#  6.06% done, 16,476 trans-eQTLs
#
#  6.81% done, 179,144 cis-eQTLs, 18,647 trans-eQTLs
#
#  7.57% done, 20,879 trans-eQTLs
#
#  8.33% done, 22,729 trans-eQTLs
#
#  9.09% done, 24,461 trans-eQTLs
#
#  9.84% done, 227,164 cis-eQTLs, 25,955 trans-eQTLs
#
# 10.60% done, 27,966 trans-eQTLs
#
# 11.36% done, 29,832 trans-eQTLs
#
# 12.12% done, 31,321 trans-eQTLs
#
# 12.87% done, 300,575 cis-eQTLs, 33,581 trans-eQTLs
#
# 13.63% done, 35,151 trans-eQTLs
#
# 14.39% done, 37,130 trans-eQTLs
#
# 15.15% done, 38,769 trans-eQTLs
#
# 15.90% done, 347,710 cis-eQTLs, 40,976 trans-eQTLs
#
# 16.66% done, 43,691 trans-eQTLs
#
# 17.42% done, 45,960 trans-eQTLs
#
# 18.18% done, 48,405 trans-eQTLs
#
# 18.93% done, 371,669 cis-eQTLs, 50,313 trans-eQTLs
#
# 19.69% done, 52,611 trans-eQTLs
#
# 20.45% done, 54,707 trans-eQTLs
#
# 21.21% done, 56,501 trans-eQTLs
#
# 21.96% done, 408,276 cis-eQTLs, 58,748 trans-eQTLs
#
# 22.72% done, 61,136 trans-eQTLs
#
# 23.48% done, 63,312 trans-eQTLs
#
# 24.24% done, 65,323 trans-eQTLs
#
# 25.00% done, 453,419 cis-eQTLs, 67,420 trans-eQTLs
#
# 25.75% done, 69,021 trans-eQTLs
#
# 26.51% done, 70,933 trans-eQTLs
#
# 27.27% done, 72,813 trans-eQTLs
#
# 28.03% done, 490,985 cis-eQTLs, 74,980 trans-eQTLs
#
# 28.78% done, 76,571 trans-eQTLs
#
# 29.54% done, 78,628 trans-eQTLs
#
# 30.30% done, 80,178 trans-eQTLs
#
# 31.06% done, 502,569 cis-eQTLs, 82,441 trans-eQTLs
#
# 31.81% done, 561,368 cis-eQTLs, 84,604 trans-eQTLs
#
# 32.57% done, 86,720 trans-eQTLs
#
# 33.33% done, 88,496 trans-eQTLs
#
# 34.09% done, 90,826 trans-eQTLs
#
# 34.84% done, 622,772 cis-eQTLs, 92,975 trans-eQTLs
#
# 35.60% done, 95,268 trans-eQTLs
#
# 36.36% done, 97,888 trans-eQTLs
#
# 37.12% done, 99,427 trans-eQTLs
#
# 37.87% done, 690,708 cis-eQTLs, 101,182 trans-eQTLs
#
# 38.63% done, 102,767 trans-eQTLs
#
# 39.39% done, 104,255 trans-eQTLs
#
# 40.15% done, 106,117 trans-eQTLs
#
# 40.90% done, 763,311 cis-eQTLs, 108,204 trans-eQTLs
#
# 41.66% done, 110,238 trans-eQTLs
#
# 42.42% done, 112,385 trans-eQTLs
#
# 43.18% done, 114,292 trans-eQTLs
#
# 43.93% done, 860,274 cis-eQTLs, 116,058 trans-eQTLs
#
# 44.69% done, 117,777 trans-eQTLs
#
# 45.45% done, 119,434 trans-eQTLs
#
# 46.21% done, 121,235 trans-eQTLs
#
# 46.96% done, 925,263 cis-eQTLs, 123,053 trans-eQTLs
#
# 47.72% done, 125,125 trans-eQTLs
#
# 48.48% done, 127,131 trans-eQTLs
#
# 49.24% done, 129,369 trans-eQTLs
#
# 50.00% done, 938,884 cis-eQTLs, 132,032 trans-eQTLs
#
# 50.75% done, 978,904 cis-eQTLs, 134,264 trans-eQTLs
#
# 51.51% done, 136,538 trans-eQTLs
#
# 52.27% done, 138,668 trans-eQTLs
#
# 53.03% done, 140,844 trans-eQTLs
#
# 53.78% done, 1,012,579 cis-eQTLs, 142,966 trans-eQTLs
#
# 54.54% done, 145,179 trans-eQTLs
#
# 55.30% done, 146,882 trans-eQTLs
#
# 56.06% done, 149,259 trans-eQTLs
#
# 56.81% done, 1,071,366 cis-eQTLs, 151,546 trans-eQTLs
#
# 57.57% done, 153,665 trans-eQTLs
#
# 58.33% done, 155,214 trans-eQTLs
#
# 59.09% done, 156,834 trans-eQTLs
#
# 59.84% done, 1,135,508 cis-eQTLs, 158,677 trans-eQTLs
#
# 60.60% done, 160,421 trans-eQTLs
#
# 61.36% done, 162,094 trans-eQTLs
#
# 62.12% done, 163,843 trans-eQTLs
#
# 62.87% done, 1,200,678 cis-eQTLs, 165,661 trans-eQTLs
#
# 63.63% done, 167,235 trans-eQTLs
#
# 64.39% done, 168,952 trans-eQTLs
#
# 65.15% done, 170,646 trans-eQTLs
#
# 65.90% done, 1,244,623 cis-eQTLs, 172,606 trans-eQTLs
#
# 66.66% done, 174,266 trans-eQTLs
#
# 67.42% done, 177,034 trans-eQTLs
#
# 68.18% done, 179,611 trans-eQTLs
#
# 68.93% done, 1,279,165 cis-eQTLs, 182,184 trans-eQTLs
#
# 69.69% done, 184,705 trans-eQTLs
#
# 70.45% done, 186,495 trans-eQTLs
#
# 71.21% done, 188,316 trans-eQTLs
#
# 71.96% done, 1,319,061 cis-eQTLs, 190,668 trans-eQTLs
#
# 72.72% done, 192,719 trans-eQTLs
#
# 73.48% done, 194,970 trans-eQTLs
#
# 74.24% done, 197,402 trans-eQTLs
#
# 75.00% done, 1,381,369 cis-eQTLs, 199,777 trans-eQTLs
#
# 75.75% done, 201,983 trans-eQTLs
#
# 76.51% done, 203,579 trans-eQTLs
#
# 77.27% done, 205,804 trans-eQTLs
#
# 78.03% done, 1,416,606 cis-eQTLs, 207,430 trans-eQTLs
#
# 78.78% done, 209,409 trans-eQTLs
#
# 79.54% done, 211,121 trans-eQTLs
#
# 80.30% done, 213,019 trans-eQTLs
#
# 81.06% done, 1,435,269 cis-eQTLs, 215,083 trans-eQTLs
#
# 81.81% done, 1,439,471 cis-eQTLs, 217,288 trans-eQTLs
#
# 82.57% done, 219,277 trans-eQTLs
#
# 83.33% done, 221,247 trans-eQTLs
#
# 84.09% done, 223,343 trans-eQTLs
#
# 84.84% done, 1,477,129 cis-eQTLs, 225,160 trans-eQTLs
#
# 85.60% done, 226,956 trans-eQTLs
#
# 86.36% done, 229,139 trans-eQTLs
#
# 87.12% done, 231,327 trans-eQTLs
#
# 87.87% done, 1,619,201 cis-eQTLs, 232,965 trans-eQTLs
#
# 88.63% done, 234,671 trans-eQTLs
#
# 89.39% done, 236,636 trans-eQTLs
#
# 90.15% done, 237,929 trans-eQTLs
#
# 90.90% done, 1,710,919 cis-eQTLs, 240,138 trans-eQTLs
#
# 91.66% done, 241,536 trans-eQTLs
#
# 92.42% done, 243,336 trans-eQTLs
#
# 93.18% done, 244,991 trans-eQTLs
#
# 93.93% done, 1,764,192 cis-eQTLs, 246,609 trans-eQTLs
#
# 94.69% done, 248,913 trans-eQTLs
#
# 95.45% done, 251,190 trans-eQTLs
#
# 96.21% done, 253,057 trans-eQTLs
#
# 96.96% done, 1,833,236 cis-eQTLs, 255,418 trans-eQTLs
#
# 97.72% done, 256,738 trans-eQTLs
#
# 98.48% done, 258,278 trans-eQTLs
#
# 99.24% done, 259,887 trans-eQTLs
#
# 100.00% done, 1,920,790 cis-eQTLs, 261,544 trans-eQTLs
