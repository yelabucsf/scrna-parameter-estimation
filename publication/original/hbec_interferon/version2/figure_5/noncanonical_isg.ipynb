# %% [markdown]
# # Canonical vs non-canonical ISGs

# %%
import scanpy as sc
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
from pybedtools import BedTool
import pickle as pkl
import itertools
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import sys
sys.path.append('/home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.0.5-py3.8.egg')
sys.path.append('/home/ssm-user/Github/misc-seq/miscseq/')
import encode
import memento

# %%
data_path = '/data_volume/ifn_hbec/'
fig_path = '/home/ssm-user/Github/scrna-parameter-estimation/figures/fig5/main/'

# %%
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'medium',
         'axes.titlesize':'medium',
         'figure.titlesize':'medium',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)

# %% [markdown]
# ### Get the TFs

# %%
tf_df = pd.read_csv('../DatabaseExtract_v_1.01.csv', index_col=0)
tf_df = tf_df[tf_df['TF assessment'] == 'Known motif']
tf_df = tf_df[tf_df['Is a GO TF?'] == 'Yes']

tfs = tf_df['HGNC symbol'].tolist()

# %%
filtered_tfs = """MAFG
SPI1
ZNF655
MAX
ATF4
ATF3
IRF2
IRF1
ARID5A
BACH1
YY1
HMGA1
IRF7
STAT1
NR1H2
XBP1
ETV6
MSC
ATF5
MAFB
FOS
CEBPB
BBX
STAT3
REL
JUN
CEBPD
DDIT3
NR3C1
TGIF1
ZNF267
NFE2L2
HIF1A
AHR
GTF2B
CREM
HBP1
RELB
TFEC
YBX1
ELF1
JUNB
NFKB1
IRF9
RBPJ
KLF6""".split()

# %% [markdown]
# ### Read the processed RNA data
#
# Focus on the club and bc/club cells and type I interferons for now.
#
# Encode the timestamps to integers.

# %% [raw]
# adata_processed = sc.read(data_path + 'HBEC_type_I_processed.h5ad')

# %%
adata = sc.read(data_path + 'HBEC_type_I_filtered_counts_deep.h5ad')

# %%
adata = adata[:, ~adata.var.index.str.startswith('MT-')].copy()
adata.obs['cell_type'] = adata.obs['cell_type'].apply(lambda x: x if x != 'basal/club' else 'bc')
adata.obs['cell_type'] = adata.obs['cell_type'].apply(lambda x: x if x != 'ionocyte/tuft' else 'ion-tuft')
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %% [raw]
# sc.pl.umap(adata_processed, color=['cell_type', 'time', 'stim'])

# %%
adata.shape
# Out:
# (69958, 36588)

# %% [markdown]
# ### Setup memento

# %%
def assign_q(batch):
    
    if batch == 0:
        return 0.387*0.25
    elif batch == 1:
        return 0.392*0.25
    elif batch == 2:
        return 0.436*0.25
    else:
        return 0.417*0.25

# %%
adata.obs['q'] = adata.obs['batch'].apply(assign_q)

# %%
memento.setup_memento(adata, q_column='q', trim_percent=0.05)

# %% [markdown]
# ### Grab DE genes

# %%
cts = [['ciliated']]
tps = ['3', '6', '9', '24', '48']
stims = ['alpha', 'beta', 'gamma', 'lambda']

# %%
def read_result(ct):
    
    ht_dict = {}
    moments_dict = {}
    
    for stim in stims:
        ht_dict[stim] = {}
        moments_dict[stim] = {}
        for tp in tps: 
            adata_subset = sc.read('/data_volume/ifn_hbec/binary_test_deep/{}_{}_{}_20200320.h5ad'.format('-'.join(ct), stim, tp))
            ht_dict[stim][tp] = memento.get_1d_ht_result(adata_subset)
            ht_dict[stim][tp]['de_fdr'] = memento.util._fdrcorrect(ht_dict[stim][tp]['de_pval'])
            ht_dict[stim][tp]['dv_fdr'] = memento.util._fdrcorrect(ht_dict[stim][tp]['dv_pval'])
            moments_dict[stim][tp] = memento.get_1d_moments(adata_subset, groupby='time_step')
    return ht_dict,moments_dict

# %%
all_result = {}
for ct in cts:
    
    key = '-'.join(ct)
    all_result[key] = {}
    
    all_result[key]['ht'], all_result[key]['moments'] = read_result(ct)

# %%
ciliated_beta = all_result['ciliated']['ht']['beta']['6']
ciliated_gamma = all_result['ciliated']['ht']['gamma']['6']
ciliated_lambda = all_result['ciliated']['ht']['lambda']['6']

# %%
print('Number of DE genes', ciliated_beta.query('de_fdr < 0.01').shape[0])
print('Number of DV genes', ciliated_beta.query('dv_fdr < 0.1').shape[0])
# Out:
# Number of DE genes 3776
# Number of DV genes 761

# %%
de_genes = ciliated_beta.query('de_fdr < 0.01 & de_coef > 0').gene.tolist()

# %% [markdown]
# ### Get STAT1 correlations

# %%
adata_stim = adata.copy()[
    adata.obs.cell_type.isin(['ciliated']) & \
    adata.obs.stim.isin(['control', 'beta']), :].copy()
adata_stim.obs['group'] = 'A'
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
memento.create_groups(adata_stim, label_columns=['donor', 'time'])

# %%
memento.compute_1d_moments(adata_stim, min_perc_group=.9)
# Out:
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.0.5-py3.8.egg/memento/estimator.py:105: RuntimeWarning: invalid value encountered in log

# %%
de_genes = list(set(de_genes) & set(adata_stim.var.index))
memento.compute_2d_moments(adata_stim, list(itertools.product(['STAT1'], de_genes)))

# %%
moment_df = memento.get_2d_moments(adata_stim, groupby='time')[['gene_1', 'gene_2']+['time_'+str(i) for i in [0, 3, 6, 9, 24, 48]]].query('gene_1 != gene_2')
# Out:
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.0.5-py3.8.egg/memento/main.py:594: RuntimeWarning: invalid value encountered in true_divide

# %%
# sns.regplot(moment_df['time_0'], moment_df['time_6'], scatter_kws={'s':5})

plt.scatter(moment_df['time_0'], moment_df['time_6'], s=1)
plt.plot([-0.2, 0.8], [-0.2, 0.8], '--',color='k')
plt.xlabel('baseline correlation'); plt.ylabel('IFN-B correlation')
# Out:
# Text(0, 0.5, 'IFN-B correlation')

# %% [markdown]
# ### Get DC genes

# %%
beta_dc_result = pd.read_csv(data_path + 'STAT1_beta_dc_result_202010504.csv')

# %%
subset_list = []
for tf in tfs:
    
    subset = beta_dc_result.query('gene_1 == "{}"'.format(tf)).copy()
    if subset.shape[0] == 0:
        continue
    subset['corr_fdr'] = memento.util._fdrcorrect(subset['corr_pval'])
    subset_list.append(subset)

# %%
beta_dc_result_corrected = pd.concat(subset_list).query('gene_1 == "STAT1"')

# %%
dc_pairs = beta_dc_result_corrected.query('corr_fdr < 0.05').copy()[['gene_1', 'gene_2']].copy()
dc_pairs['nc'] = True

# %% [markdown]
# ### Merge datasets

# %%
moment_df_labeled = moment_df.merge(dc_pairs, on=['gene_1', 'gene_2'], how='left').fillna(False)
moment_df_labeled['c'] = moment_df_labeled.apply(lambda x: (x['time_0'] > 0.35) and (x['time_6'] > 0.35), axis=1)
moment_df_labeled['c'] = moment_df_labeled['c'].astype(bool)

# %%
plt.figure(figsize=(2.5, 2))
plt.scatter(moment_df_labeled['time_0'], moment_df_labeled['time_6'], s=1)
plt.scatter(moment_df_labeled.query('nc')['time_0'], moment_df_labeled.query('nc')['time_6'], s=3, label='non-canonical')
plt.scatter(moment_df_labeled.query('c')['time_0'], moment_df_labeled.query('c')['time_6'], s=3, label='canonical')
plt.legend(frameon=False, loc='upper center', ncol=2, bbox_to_anchor=(0.4,1.25),prop={'size': 13}, markerscale=3, handletextpad=0.01)

plt.plot([-0.2, 0.8], [-0.2, 0.8], '--',color='gray')
plt.plot([0.35, 0.35], [0.35, 0.8], '--',color='k')
plt.plot([0.35, 0.8], [0.35, 0.35], '--',color='k')

plt.xlabel('baseline STAT1 corr'); plt.ylabel('IFN-B STAT1 corr')
plt.savefig(fig_path + 'nc_vs_c_isg.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(2.5, 2))
plt.scatter(moment_df_labeled['time_0'], moment_df_labeled['time_6'], s=1)
plt.scatter(moment_df_labeled.query('nc')['time_0'], moment_df_labeled.query('nc')['time_6'], s=3, label='non-canonical')
plt.scatter(moment_df_labeled.query('c')['time_0'], moment_df_labeled.query('c')['time_6'], s=3, label='canonical')
plt.legend(frameon=False, loc='upper center', ncol=2, bbox_to_anchor=(0.4,1.25),prop={'size': 13}, markerscale=3, handletextpad=0.01)

plt.plot([-0.2, 0.8], [-0.2, 0.8], '--',color='gray')
plt.plot([0.35, 0.35], [0.35, 0.8], '--',color='k')
plt.plot([0.35, 0.8], [0.35, 0.35], '--',color='k')

gene = 'PSMF1'
plt.scatter(moment_df_labeled.query('gene_2 == "{}"'.format(gene))['time_0'], moment_df_labeled.query('gene_2 == "{}"'.format(gene))['time_6'], s=10, label='kek')


plt.xlabel('baseline STAT1 corr'); plt.ylabel('IFN-B STAT1 corr')
# plt.savefig(fig_path + 'nc_vs_c_isg.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'IFN-B STAT1 corr')

# %%
moment_df_labeled.query('nc').query('time_0 < 0.2').sort_values('time_6', ascending=False).query('gene_2.str.contains("PSM")', engine='python')
# Out:
#   gene_1 gene_2    time_0    time_3    time_6    time_9   time_24  time_48  \
# 0  STAT1  PSMF1 -0.159518  0.418939  0.539422  0.530408  0.726924  0.09205
#
#      nc      c
# 0  True  False

# %%
moment_df_labeled.query('gene_2 == "SRSF2"')
# Out:
#     gene_1 gene_2    time_0    time_3    time_6    time_9   time_24   time_48  \
# 436  STAT1  SRSF2  0.166384  0.421232  0.483469  0.475475  0.473107  0.608723
#
#        nc      c
# 436  True  False

# %%
moment_df_labeled.to_csv(data_path + 'noncanon_isg.csv', index=False)

# %%
moment_df_labeled.query('c').query('gene_2.str.contains("ISG") | gene_2.str.contains("IFIT") | gene_2.str.contains("MX") | gene_2.str.contains("OAS")', engine='python')
# Out:
#      gene_1  gene_2    time_0    time_3    time_6    time_9   time_24  \
# 43    STAT1   ISG20  0.612375  0.724147  0.644617  0.677305  0.751709
# 45    STAT1  IFITM2  0.430490  0.629136  0.562300  0.671375  0.609498
# 71    STAT1   ISG15  0.713398  0.753295  0.701947  0.756738  0.837461
# 176   STAT1   IFIT1  0.750174  0.776661  0.720937  0.778321  0.763726
# 304   STAT1  IFITM1  0.724981  0.701349  0.690540  0.695924  0.782964
# 570   STAT1    OAS2  0.899163  0.888795  0.831004  0.885696  0.846332
# 668   STAT1   IFIT2  0.400801  0.668263  0.647294  0.710090  0.763905
# 720   STAT1    OAS3  0.732475  0.797893  0.750959  0.811218  0.875592
# 798   STAT1    OASL  0.549513  0.602896  0.487745  0.610861  0.615558
# 845   STAT1     MX2  0.791370  0.755402  0.713779  0.751844  0.813904
# 850   STAT1   IFIT3  0.585969  0.720122  0.714494  0.743099  0.808302
# 980   STAT1    OAS1  0.646565  0.735620  0.694697  0.779622  0.818271
# 1254  STAT1  IFITM3  0.738673  0.724430  0.696807  0.744268  0.755558
# 1272  STAT1     MX1  0.823748  0.842608  0.825402  0.827184  0.849929
#
#        time_48     nc     c
# 43    0.777426  False  True
# 45    0.606780  False  True
# 71    0.769478  False  True
# 176   0.744627  False  True
# 304   0.717555  False  True
# 570   0.783497  False  True
# 668   0.703784   True  True
# 720   0.761659  False  True
# 798   0.717686  False  True
# 845   0.738706  False  True
# 850   0.697125  False  True
# 980   0.798242  False  True
# 1254  0.704314  False  True
# 1272  0.854277  False  True

# %%
for g in moment_df_labeled.query('c').gene_2.tolist():
    print(g)
# Out:
# IFI44
# IFI27
# PSMB9
# ISG20
# IFITM2
# CHMP5
# TRIM5
# IFI35
# SPATS2L
# KIF19
# ISG15
# C4orf33
# PSME2
# DHX58
# EXT1
# IFIT1
# BST2
# KCTD1
# IFI16
# APOL6
# APOBEC3G
# PANK2
# CCDC125
# TAP2
# PI4K2B
# PLAAT2
# PDE4D
# HSH2D
# MT2A
# IFITM1
# TRIM69
# RNF149
# DDX60
# ETV7
# FNDC3A
# DTX3L
# JADE2
# CD68
# LIMA1
# OPTN
# CD38
# ST5
# DDX3X
# TAP1
# FYTTD1
# IFI44L
# TLK2
# CCDC71L
# SAMD9
# BTC
# EIF2AK2
# UBE2D3
# IFIH1
# MYD88
# TCHP
# GRINA
# UBA7
# PSMA2
# OAS2
# SMCHD1
# C6orf62
# PCGF5
# NDUFA9
# U62317.4
# DDX58
# IFIT2
# NMI
# NUB1
# GLIPR2
# HLA-E
# LGALS3BP
# OAS3
# NT5C3A
# HELZ2
# SAMD9L
# AC073111.4
# GBP4
# SCARB2
# UBE2L6
# OASL
# HERC5
# IFI6
# CASP7
# ADAR
# GBP1
# MX2
# IFIT3
# PLSCR1
# JAK2
# BCL2L14
# CHROMR
# CMPK2
# IRF7
# RBCK1
# PSMB8
# PHF11
# HERC6
# OAS1
# APOL1
# USP18
# SP1
# SP100
# XRN1
# PARP12
# TRIM22
# TRIM34
# SERPING1
# BISPR
# XPNPEP1
# SP110
# PARP9
# WARS
# BMPR2
# SLC6A6
# PML
# TMEM62
# GSTO1
# NAMPT
# RIPK1
# RTP4
# CASP1
# EPSTI1
# TNFSF10
# CAND1
# IRF9
# IFITM3
# LAP3
# MX1
# SHISA5
# GSDMB
# RSAD2
# TNFSF13
# USP42
# GMPR
# WAC
# PNPT1
# ENDOD1
# PHACTR4

# %%
moment_df_labeled.query('gene_2.str.contains("HLA")', engine='python')
# Out:
#      gene_1    gene_2    time_0    time_3    time_6    time_9   time_24  \
# 40    STAT1     HLA-C  0.314121  0.541517  0.507735  0.532945  0.486173
# 179   STAT1  HLA-DRB1  0.111448  0.183183  0.135612  0.038277 -0.036674
# 263   STAT1  HLA-DQB1  0.061594  0.211300  0.237486  0.178941  0.360997
# 719   STAT1     HLA-E  0.416372  0.669303  0.632798  0.696580  0.734171
# 838   STAT1   HLA-DRA  0.102645  0.273425  0.251628  0.196346  0.157331
# 902   STAT1  HLA-DPA1  0.095922  0.178432  0.127153  0.037315 -0.050100
# 922   STAT1     HLA-B  0.196586  0.411582  0.400734  0.303317  0.208922
# 923   STAT1     HLA-A  0.172667  0.320142  0.390467  0.154589  0.096643
# 951   STAT1   HLA-DMA  0.182618  0.318014  0.260492  0.213925  0.211778
# 1316  STAT1     HLA-F  0.302112  0.525647  0.556464  0.560498  0.570216
# 1368  STAT1   HLA-DMB  0.292570  0.299052  0.306199  0.150316  0.225713
#
#        time_48     nc      c
# 40    0.322831   True  False
# 179  -0.089203  False  False
# 263   0.078359  False  False
# 719   0.666062   True   True
# 838   0.100464   True  False
# 902   0.028120  False  False
# 922   0.109860   True  False
# 923   0.023651   True  False
# 951   0.214576   True  False
# 1316  0.428869   True  False
# 1368  0.014138  False  False

# %% [markdown]
# ### Compute correlations

# %%
adata_stim = adata.copy()[
    adata.obs.cell_type.isin(['ciliated']) & \
    adata.obs.stim.isin(['control', 'beta']), :].copy()
adata_stim.obs['group'] = 'A'
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
memento.create_groups(adata_stim, label_columns=['donor', 'time'])

# %%
memento.compute_1d_moments(adata_stim, min_perc_group=.9)
# Out:
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.0.5-py3.8.egg/memento/estimator.py:105: RuntimeWarning: invalid value encountered in log

# %%
tfs = list(set(filtered_tfs) & set(adata_stim.var.index))

# %%
de_genes = list(set(de_genes) & set(adata_stim.var.index))
memento.compute_2d_moments(adata_stim, list(itertools.product(tfs, adata_stim.var.index.tolist())))

# %% [markdown]
# ### Construct network

# %%
moment_df = memento.get_2d_moments(adata_stim, groupby='time')[['gene_1', 'gene_2']+['time_'+str(i) for i in [0, 3, 6, 9, 24, 48]]].query('gene_1 != gene_2')

# %%
moment_df['max_corr'] = moment_df[['time_'+str(i) for i in [0, 6]]].max(axis=1)
moment_df['min_corr'] = moment_df[['time_'+str(i) for i in [0, 6]]].min(axis=1)

moment_df['mean_corr'] = moment_df[['time_'+str(i) for i in [0, 3, 6, 9, 24,48]]].mean(axis=1)
moment_df['var_corr'] = moment_df[['time_'+str(i) for i in [0, 3, 6, 9, 24, 48]]].std(axis=1)
moment_df['diff'] = moment_df['time_6'] - moment_df['time_0']

# %%
num_pairs_all = moment_df.shape[0]

top_edge_sets = {}

for time in [0, 3]:
    
    top_edge_sets[time] = moment_df.query('gene_1 != gene_2').sort_values('time_' + str(time), ascending=False).head(int(0.007*num_pairs_all))[['gene_1', 'gene_2']]

# %%
dc_pairs['dc'] = True

# %%
moment_df = moment_df.merge(dc_pairs[['gene_1', 'gene_2', 'dc']], on=['gene_1', 'gene_2'], how='left').fillna(False)

# %%
moment_df['high_min_corr'] = moment_df['min_corr'] > 0.5

# %%
moment_df['dc_de'] = moment_df['dc'] & moment_df['gene_2'].isin(de_genes)
moment_df['de'] = moment_df['gene_2'].isin(de_genes)

# %%
moment_df.query('high_min_corr').shape
# Out:
# (1711, 17)

# %%
moment_df.query('high_min_corr | (dc & (gene_2 in @de_genes))').shape
# Out:
# (2947, 17)

# %%
filtered_moment_df = moment_df.query('high_min_corr | (dc & (gene_2 in @de_genes))').copy()

# %%
def classify_row(row):
    
    if row['dc_de']:
        return 'dc_de'
    elif row['de']:
        return 'de'
    else:
        return 'rest'

# %%
filtered_moment_df['class'] = filtered_moment_df.apply(classify_row, axis=1)

# %%
ifn_tfs = ["IRF1", "IRF7", "IRF9", "STAT1"]

# %%
filtered_moment_df['TF'] = 1

# %%
print(filtered_moment_df.shape)
# Out:
# (2947, 19)

# %%
filtered_moment_df.time_3
# Out:
# 2         0.397195
# 3         0.775124
# 194       0.503221
# 240       0.332982
# 252       0.298843
#             ...
# 404529    0.470934
# 404999    0.322797
# 405035    0.300207
# 405055    0.411217
# 405056    0.412940
# Name: time_3, Length: 2947, dtype: float64

# %%
filtered_moment_df.to_csv('filtered_edges.csv', index=False)

# %% [markdown]
# ### Create igraph

# %%
import igraph
from igraph import plot

# %%
df = moment_df[['gene_1', 'gene_2', 'time_3']]

# %%
tuples = [tuple(x) for x in df.values]

# %%
g = igraph.Graph.TupleList(tuples, directed = False, edge_attrs = ['weight'])

# %%
# layout = g.layout('drl')
layout2 = g.layout('large')

# %%
import matplotlib.cm as cm
from matplotlib.colors import TwoSlopeNorm

cmap = cm.viridis
norm = Normalize(vmin=0, vmax=1)
print(cmap(norm(-0)))
# Out:
# (0.267004, 0.004874, 0.329415, 1.0)

# %%
plot(
    g, 
    layout=layout2,
    vertex_size=0,
    edge_color=[cmap(norm(x)) for x in g.es['weight']])

# %% [markdown]
# ### Clustering?

# %%
heatmap_dfs = {}
for time in ['0', '3', '6', '9', '24', '48']:
    heatmap_dfs[time] = pd.DataFrame(np.zeros((len(tfs), len(de_genes))), index=tfs, columns=de_genes).T

# %%
for idx, row in moment_df.iterrows():
    for time in ['0', '3', '6', '9', '24', '48']:
        heatmap_dfs[time].loc[row['gene_2'], row['gene_1']] = row['time_{}'.format(time)]

# %%
cg = sns.clustermap(heatmap_dfs['3']);
# plt.close()

# %%
tf_order = heatmap_df.columns[cg.dendrogram_col.reordered_ind].tolist()
gene_order = heatmap_df.index[cg.dendrogram_row.reordered_ind].tolist()

# %%
a = heatmap_df.loc[gene_order, :]

# %%
for time in ['0', '3', '6', '9', '24', '48']:
    plt.figure()
    sns.heatmap(heatmap_dfs[time].loc[gene_order, :].loc[:, tf_order], vmin=-0.5, vmax=0.7)
    plt.axis('off')

# %%
moment_df.shape
# Out:
# (18850, 10)

# %%
# !pip install py2cytoscape
# Out:
# Collecting py2cytoscape
#   Downloading py2cytoscape-0.7.1.tar.gz (57 kB)
#      |████████████████████████████████| 57 kB 1.8 MB/s eta 0:00:011
# Requirement already satisfied: pandas in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from py2cytoscape) (1.2.3)
# Requirement already satisfied: networkx in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from py2cytoscape) (2.5)
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      |████████████████████████████████| 278 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: requests in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from py2cytoscape) (2.25.1)
# Requirement already satisfied: pyparsing in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from py2cytoscape) (2.4.7)
# Requirement already satisfied: python-igraph in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from py2cytoscape) (0.8.3)
# Requirement already satisfied: decorator>=4.3.0 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from networkx->py2cytoscape) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from pandas->py2cytoscape) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from pandas->py2cytoscape) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from pandas->py2cytoscape) (1.19.2)
# Requirement already satisfied: six>=1.5 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->py2cytoscape) (1.15.0)
# Requirement already satisfied: texttable>=1.6.2 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from python-igraph->py2cytoscape) (1.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from requests->py2cytoscape) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from requests->py2cytoscape) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from requests->py2cytoscape) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages (from requests->py2cytoscape) (2.10)
# Building wheels for collected packages: py2cytoscape, pydotplus
#   Building wheel for py2cytoscape (setup.py) ... done
#   Created wheel for py2cytoscape: filename=py2cytoscape-0.7.1-py3-none-any.whl size=78811 sha256=be423ddcc76b6408e779a39df50437ab4251b08acedd4b059b413f710cd844a4
#   Stored in directory: /home/ssm-user/.cache/pip/wheels/5c/c3/5b/76436ed5d5c54edcb37239175c9e978c7994ffc9f9b5f8472a
#   Building wheel for pydotplus (setup.py) ... done
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24566 sha256=73ebd5dc27eec78fb93142a4e0386e9b80ddc0d5dd38316da8318e3643058e7e
#   Stored in directory: /home/ssm-user/.cache/pip/wheels/fe/cd/78/a7e873cc049759194f8271f780640cf96b35e5a48bef0e2f36
# Successfully built py2cytoscape pydotplus
# Installing collected packages: pydotplus, pydot, py2cytoscape
# Successfully installed py2cytoscape-0.7.1 pydot-1.4.2 pydotplus-2.0.2

# %% [markdown]
# ### Draw network

# %%
moment_df
# Out:
#      gene_1    gene_2    time_0    time_3    time_6    time_9   time_24  \
# 2210   IRF7    ZNF117  0.509409  0.059942 -0.125539 -0.228515  0.394727
# 2350   IRF7    ZNF274  0.701238  0.225473  0.079529 -0.019809 -0.050401
# 1260  STAT1  UHRF1BP1  0.802499  0.340098  0.192829  0.409275  0.250397
# 10    STAT1     SBNO2  0.711389  0.390954  0.126273  0.182214  0.215674
# 4025   IRF9    BTN2A1  0.586752  0.105627  0.020490  0.139511 -0.155333
# ...     ...       ...       ...       ...       ...       ...       ...
# 2358   IRF7      AFF1 -0.279018  0.264135  0.385862  0.378699  0.716724
# 1404  STAT1   SLC44A1 -0.058193  0.413500  0.626843  0.761874  0.610771
# 1568   IRF7    DAB2IP -0.312938  0.310283  0.373963  0.358779  0.586677
# 2780   IRF7      AZI2 -0.275647  0.347439  0.423486  0.584554  0.537752
# 4167   IRF9   TMEM187 -0.372106  0.313650  0.428325 -0.012377  0.613849
#
#        time_48  max_corr      diff
# 2210 -0.132296  0.509409 -0.634949
# 2350  0.057734  0.701238 -0.621709
# 1260  0.252184  0.802499 -0.609670
# 10    0.208296  0.711389 -0.585116
# 4025 -0.021664  0.586752 -0.566262
# ...        ...       ...       ...
# 2358  0.486672  0.716724  0.664880
# 1404  0.405393  0.761874  0.685036
# 1568  0.376880  0.586677  0.686901
# 2780  0.335689  0.584554  0.699133
# 4167  0.261524  0.613849  0.800431
#
# [2515 rows x 10 columns]

# %% [markdown]
# ### Compute baseline correlations

# %%
adata_ctrl = adata.copy()[
    adata.obs.cell_type.isin(['ciliated']) & \
    adata.obs.stim.isin(['control']), :].copy()
adata_ctrl.obs['group'] = 'A'
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
'IRF7' in adata_ctrl.var.index
# Out:
# True

# %%
'IRF7' in expr_tfs
# Out:
# True

# %%
expr_tfs = list(set(tfs) & set(adata_ctrl.var.index))
de_genes = list(set(de_genes) & set(adata_ctrl.var.index))

# %%
ctrl_corrs = memento.get_2d_moments(adata_ctrl, groupby='ALL')
# Out:
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.0.5-py3.8.egg/memento/main.py:594: RuntimeWarning: invalid value encountered in true_divide
#   groupby_corr[key] /= groupby_corr_count[key]

# %%
mean_ctrl_corrs = ctrl_corrs.dropna().groupby('gene_1')['ALL_sg'].mean()#.reset_index().sort_values('ALL_sg', ascending=False).head(30)

# %% [markdown]
# ### Compute TF mean corrs

# %%
def get_2d_moments(tf, adata_stim):
    
    if tf not in adata_stim.var.index.tolist():
        return None

    memento.compute_2d_moments(adata_stim, list(itertools.product([tf], adata_stim.var.index)))

    moment_df = memento.get_2d_moments(adata_stim, groupby='time')
    
    return moment_df

def get_corr_diffs(stim):
    
    adata_stim = adata.copy()[
    adata.obs.cell_type.isin(['ciliated']) & \
    adata.obs.stim.isin(['control', stim]) & \
    adata.obs.time.isin(['3','0'])].copy()

    memento.create_groups(adata_stim, label_columns=['time', 'donor'])
    memento.compute_1d_moments(adata_stim, min_perc_group=.9)
    moment_1d_df = memento.get_1d_moments(adata_stim, groupby='time')
    
    tf_df_list = []
    for idx, tf in enumerate(filtered_tfs):

        df = get_2d_moments(tf, adata_stim)
        if df is None:
            continue
        diff = (df['time_3'] - df['time_0']).mean()
        tf_df_list.append((tf, diff))
        del df

    tf_df = pd.DataFrame(tf_df_list, columns=['tf', 'diff']).sort_values('diff', ascending=False)
    tf_df['tf'] = tf_df['tf'].astype('category')
    tf_order = tf_df.sort_values('diff', ascending=False).tf.tolist()
    tf_df['tf'].cat.set_categories(tf_order, inplace=True)
    print('finished', stim)
    return tf_df

# %%
tf_df_alpha = get_corr_diffs('alpha')
tf_df_beta = get_corr_diffs('beta')
tf_df_gamma = get_corr_diffs('gamma')
tf_df_lambda = get_corr_diffs('lambda')
# Out:
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.0.5-py3.8.egg/memento/main.py:594: RuntimeWarning: invalid value encountered in true_divide
# finished alpha
# finished beta
# finished gamma
# finished lambda

# %%
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'medium',
         'axes.titlesize':'medium',
         'figure.titlesize':'medium',
         'xtick.labelsize':'5.5',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)


plt.figure(figsize=(8, 2))
plt.subplot(1, 2, 1);
sns.barplot(x='tf', y='diff', data=tf_df_beta, errwidth=2)
plt.xticks(rotation=90);
plt.ylabel('Mean shift in corr')
plt.xlabel(None)
plt.title('IFN-B')

plt.subplot(1, 2, 2);
plt.title('IFN-G')

sns.barplot(x='tf', y='diff', data=tf_df_gamma, errwidth=2)
plt.xticks(rotation=90);
plt.ylabel(None)
plt.xlabel(None)
plt.savefig(fig_path + 'tf_effect_sizes.pdf', bbox_inches='tight')

# %% [markdown]
# ### Individual examples
#
# IRF7, STAT1, IRF9

# %%
# Do beta stim first
adata_stim = adata.copy()[
    adata.obs.cell_type.isin(['ciliated']) & \
    adata.obs.stim.isin(['control', 'beta']) & \
    adata.obs.time.isin(['3','0'])].copy()

memento.create_groups(adata_stim, label_columns=['time', 'donor'])
memento.compute_1d_moments(adata_stim, min_perc_group=.9)
moment_1d_df = memento.get_1d_moments(adata_stim, groupby='time')

# STAT1 
memento.compute_2d_moments(adata_stim, list(itertools.product(['STAT1'], adata_stim.var.index)))
moment_df = memento.get_2d_moments(adata_stim, groupby='time')
stat1_ctrl = moment_df['time_0'].values
stat1_beta = moment_df['time_3'].values

# IRF7
memento.compute_2d_moments(adata_stim, list(itertools.product(['IRF7'], adata_stim.var.index)))
moment_df = memento.get_2d_moments(adata_stim, groupby='time')
irf7_ctrl = moment_df['time_0'].values
irf7_beta = moment_df['time_3'].values

# IRF9
memento.compute_2d_moments(adata_stim, list(itertools.product(['IRF9'], adata_stim.var.index)))
moment_df = memento.get_2d_moments(adata_stim, groupby='time')
irf9_ctrl = moment_df['time_0'].values
irf9_beta = moment_df['time_3'].values
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
# gamma stim
adata_stim = adata.copy()[
    adata.obs.cell_type.isin(['ciliated']) & \
    adata.obs.stim.isin(['control', 'gamma']) & \
    adata.obs.time.isin(['3','0'])].copy()

memento.create_groups(adata_stim, label_columns=['time', 'donor'])
memento.compute_1d_moments(adata_stim, min_perc_group=.9)
moment_1d_df = memento.get_1d_moments(adata_stim, groupby='time')

# STAT1 
memento.compute_2d_moments(adata_stim, list(itertools.product(['STAT1'], adata_stim.var.index)))
moment_df = memento.get_2d_moments(adata_stim, groupby='time')
stat1_ctrl = moment_df['time_0'].values
stat1_gamma = moment_df['time_3'].values

# IRF7
memento.compute_2d_moments(adata_stim, list(itertools.product(['IRF7'], adata_stim.var.index)))
moment_df = memento.get_2d_moments(adata_stim, groupby='time')
irf7_ctrl = moment_df['time_0'].values
irf7_gamma = moment_df['time_3'].values

# IRF9
memento.compute_2d_moments(adata_stim, list(itertools.product(['IRF9'], adata_stim.var.index)))
moment_df = memento.get_2d_moments(adata_stim, groupby='time')
irf9_ctrl = moment_df['time_0'].values
irf9_gamma = moment_df['time_3'].values
# Out:
# /home/ssm-user/anaconda3/envs/single_cell/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# /home/ssm-user/Github/scrna-parameter-estimation/dist/memento-0.0.5-py3.8.egg/memento/main.py:594: RuntimeWarning: invalid value encountered in true_divide

# %%
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'medium',
         'axes.titlesize':'medium',
         'figure.titlesize':'medium',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)

plt.figure(figsize=(5, 2));
plt.subplot(1, 2, 1);
sns.kdeplot(stat1_ctrl, label='control');
sns.kdeplot(stat1_beta, label='IFN-B');
sns.kdeplot(stat1_gamma, label='IFN-G');
plt.legend(loc='upper right', frameon=False, ncol=3, bbox_to_anchor=(2,1.2))
plt.xlim(-0.5, 0.6)
plt.xlabel('Correlation')
plt.ylabel(None)

plt.subplot(1, 2, 2);
sns.kdeplot(irf7_ctrl, label='control');
sns.kdeplot(irf7_beta, label='IFN-B');
sns.kdeplot(irf7_gamma, label='IFN-G');
plt.ylabel(None)
plt.xlabel('Correlation')

plt.xlim(-0.5, 0.6)
plt.savefig(fig_path + 'tf_corr_hist.pdf', bbox_inches='tight')

# %% [markdown]
# ### Heatmap attempt

# %%
tf_df_alpha.head(5)
# Out:
#        tf      diff
# 11  STAT1  0.192241
# 10   IRF7  0.161251
# 38   IRF9  0.151323
# 35   ELF1  0.143302
# 25  TGIF1  0.129898

# %%
joined = tf_df_beta \
    .merge(tf_df_gamma, on='tf', suffixes=('_beta', '_gamma'))\
    .merge(tf_df_alpha.rename(columns={'diff':'diff_alpha'}), on='tf')\
    .merge(tf_df_lambda.rename(columns={'diff':'diff_lambda'}), on='tf')
joined = joined.set_index('tf')#.clip(upper=0.07, lower=-0.07)

# %%
sns.clustermap(joined, z_score=1)

# %%
joined.head(5)
# Out:
#        diff_beta  diff_gamma  diff_alpha  diff_lambda
# tf
# HBP1    0.188903    0.146866    0.189643     0.144297
# HIF1A   0.179300    0.171330    0.186732     0.177091
# BACH1   0.177841    0.161292    0.185713     0.152557
# NFKB1   0.177778    0.168085    0.155215     0.164063
# MAX     0.175971    0.165930    0.182030     0.179327

# %%
plt.scatter(joined['diff_beta'], joined['diff_lambda'])

# %%
plt.scatter(joined['diff_beta'], joined['diff_gamma'])

# %%
plt.scatter(joined['diff_beta'], joined['diff_alpha'])

# %%
clustered = joined.iloc[cg.dendrogram_row.reordered_ind, :].reset_index()

# %%
# clustered = clustered.merge(tf_df_alpha.rename(columns={'diff':'diff_alpha'}), on='tf')

# %%
plt.figure(figsize=(8, 3))
sns.heatmap(clustered[['diff_alpha', 'diff_beta','diff_gamma']].values.T, cmap='coolwarm', center=0, vmax=0.1, vmin=-0.07)
x=426
# plt.plot([x, x], [-1, 10], color='k', lw=3)

# %%
# ATF5, STAT1, STAT3, JUN
# clustered.iloc[115:200].tf.tolist()
